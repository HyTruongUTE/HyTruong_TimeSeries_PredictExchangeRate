# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler #chuẩn hóa dữ liệu
from keras.callbacks import ModelCheckpoint #lưu lại huấn luyện tốt nhất
from tensorflow.keras.models import load_model #tải mô hình
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import ModelCheckpoint

import random
import tensorflow as tf

#các lớp để xây dựng mô hình
from keras.models import Sequential #đầu vào
from keras.layers import LSTM #học phụ thuộc
from keras.layers import Dropout, BatchNormalization #tránh học tủ
from keras.layers import Dense #đầu ra

#kiểm tra độ chính xác của mô hình
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
random.seed(42)
np.random.seed(42)
tf.random.set_seed(42)

# %%
df_usd = pd.read_parquet("./minio/usd/part-00000-18b834c3-cd6d-42ae-82c3-638999ff6d84-c000.snappy.parquet", engine="pyarrow")
df_usd.head()
# Out:
#         ngay ma_ngoai_te ten_ngoai_te  mua_chuyen_khoan      ban
# 0 2020-02-01         USD    US DOLLAR           23165.0  23305.0
# 1 2020-02-02         USD    US DOLLAR           23165.0  23305.0
# 2 2020-02-03         USD    US DOLLAR           23200.0  23340.0
# 3 2020-02-04         USD    US DOLLAR           23170.0  23310.0
# 4 2020-02-05         USD    US DOLLAR           23160.0  23300.0

# %%
df_usd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1911 entries, 0 to 1910
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ngay              1911 non-null   datetime64[ns]
#  1   ma_ngoai_te       1911 non-null   object
#  2   ten_ngoai_te      1911 non-null   object
#  3   mua_chuyen_khoan  1911 non-null   float64
#  4   ban               1911 non-null   float64
# dtypes: datetime64[ns](1), float64(2), object(2)
# memory usage: 74.8+ KB

# %%
df_usd.describe()
# Out:
#                       ngay  mua_chuyen_khoan           ban
# count                 1911       1911.000000   1911.000000
# mean   2022-09-13 00:00:00      23666.414443  23934.197279
# min    2020-02-01 00:00:00      22480.000000  22745.000000
# 25%    2021-05-23 12:00:00      22985.000000  23170.000000
# 50%    2022-09-13 00:00:00      23300.000000  23620.000000
# 75%    2024-01-03 12:00:00      24390.000000  24730.000000
# max    2025-04-25 00:00:00      25835.000000  26195.000000
# std                    NaN        885.147984    926.810272

# %%
print(df_usd.dtypes)
# Out:
# ngay                datetime64[ns]
# ma_ngoai_te                 object
# ten_ngoai_te                object
# mua_chuyen_khoan           float64
# ban                        float64
# dtype: object

# %%
import matplotlib.pyplot as plt
from matplotlib.dates import YearLocator, DateFormatter, MonthLocator

# Vẽ biểu đồ
plt.figure(figsize=(10, 5))
plt.plot(df_usd['ngay'].values, df_usd['mua_chuyen_khoan'].values, label='Giá mua chuyển khoản', color='red')

plt.xlabel('Năm')
plt.ylabel('Giá mua chuyển khoản')
plt.title('Biểu đồ tỷ giá VND_USD mua chuyển khoảng qua các năm')
plt.legend(loc='best')

# Định dạng trục x
plt.gca().xaxis.set_major_locator(YearLocator())
plt.gca().xaxis.set_major_formatter(DateFormatter('%Y'))
plt.gca().xaxis.set_minor_locator(MonthLocator())

plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
df_usd_ML = pd.DataFrame(df_usd, columns=['ngay','mua_chuyen_khoan'])
df_usd_ML.index = df_usd_ML.ngay
df_usd_ML.drop('ngay', axis = 1, inplace=True)
df_usd_ML.head()
# Out:
#             mua_chuyen_khoan
# ngay
# 2020-02-01           23165.0
# 2020-02-02           23165.0
# 2020-02-03           23200.0
# 2020-02-04           23170.0
# 2020-02-05           23160.0

# %%
print(df_usd_ML.columns)
# Out:
# Index(['mua_chuyen_khoan'], dtype='object')

# %%
data = df_usd_ML.values

# %%
data
# Out:
# array([[23165.],
#        [23165.],
#        [23200.],
#        ...,
#        [25781.],
#        [25814.],
#        [25835.]])

# %%
#hàm hóa dữ liệu
sc = MinMaxScaler(feature_range=(0,1))

#chuẩn hóa dữ train
scale_data = sc.fit_transform(data)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))

plt.plot(scale_data, label="Dữ liệu sau chuẩn hóa", color="red")

plt.xlabel("Thời gian (Index)")
plt.ylabel("Giá trị sau chuẩn hóa")
plt.title("Biểu đồ dữ liệu sau khi chuẩn hóa bằng MinMaxScaler")
plt.legend()
plt.show()

# %%
window_size = 14
X_train, Y_train = [], []

for i in range(len(scale_data) - window_size - 1):  # trừ 1 vì lấy 2 output
    X_train.append(scale_data[i:i + window_size])  # 14 giá trị làm input
    Y_train.append(scale_data[i + window_size : i + window_size + 2])  # 2 giá trị output kế tiếp

X_train = np.array(X_train)
Y_train = np.array(Y_train)

# Kiểm tra shape dữ liệu
print('X_train shape:', X_train.shape)  # (số mẫu, 14)
print('Y_train shape:', Y_train.shape)  # (số mẫu, 2)

# Phân chia tập train-test
split_index = int(0.8 * len(X_train))
X_train, X_test = X_train[:split_index], X_train[split_index:]
Y_train, Y_test = Y_train[:split_index], Y_train[split_index:]

#Reshape cho model LSTM
X_train = X_train.reshape((X_train.shape[0], window_size, 1))
X_test = X_test.reshape((X_test.shape[0], window_size, 1))
# Out:
# X_train shape: (1896, 14, 1)
# Y_train shape: (1896, 2, 1)

# %%
print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
print("y_train shape:", Y_train.shape)
print("y_test shape:", Y_test.shape)
# Out:
# X_train shape: (1516, 14, 1)
# X_test shape: (380, 14, 1)
# y_train shape: (1516, 2, 1)
# y_test shape: (380, 2, 1)

# %% [markdown]
# # MODEL

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Bidirectional, BatchNormalization

# Xây dựng mô hình BiLSTM
model = Sequential()

# Lớp BiLSTM đầu tiên (return_sequences=True để kết nối lớp tiếp theo)
model.add(Bidirectional(LSTM(units=64, return_sequences=True, input_shape=(14, 1))))
model.add(BatchNormalization())  # Ổn định dữ liệu đầu ra

# Lớp BiLSTM thứ hai
model.add(Bidirectional(LSTM(units=64)))
model.add(BatchNormalization())

# Dropout để giảm overfitting
model.add(Dropout(0.5))

# Lớp Dense đầu ra với 2 neuron (dự báo 2 giá trị)
model.add(Dense(2))

# Compile mô hình
model.compile(loss='mean_absolute_error', optimizer='adam')

# %% [markdown]
# # huấn luyện mô hình

# %%
save_model = "./Model/case_3/BiLSTM/model_14in2out/save_model.hdf5"
best_model = ModelCheckpoint(save_model,monitor='loss',verbose=2,save_best_only=True,mode='auto')

import time
start_model = time.time()  # Bắt đầu đo thời gian
model.fit(X_train,Y_train,epochs=100,batch_size=50,validation_split=0.4,verbose=2,callbacks=[best_model])
end_model = time.time()  # Kết thúc đo thời gian
print(f"Thời gian thực thi mô hình: {end_model - start_model:.2f} giây")
# Out:
# Epoch 1/100
#
# Epoch 1: loss improved from inf to 0.89483, saving model to ./Model/case_3/BiLSTM/model_14in2out\save_model.hdf5
# 19/19 - 6s - loss: 0.8948 - val_loss: 0.3357 - 6s/epoch - 313ms/step
# Epoch 2/100
#
# Epoch 2: loss improved from 0.89483 to 0.81936, saving model to ./Model/case_3/BiLSTM/model_14in2out\save_model.hdf5
# 19/19 - 0s - loss: 0.8194 - val_loss: 0.2828 - 431ms/epoch - 23ms/step
# Epoch 3/100
#
# Epoch 3: loss improved from 0.81936 to 0.72550, saving model to ./Model/case_3/BiLSTM/model_14in2out\save_model.hdf5
# 19/19 - 0s - loss: 0.7255 - val_loss: 0.2225 - 440ms/epoch - 23ms/step
# Epoch 4/100
#
# Epoch 4: loss improved from 0.72550 to 0.60345, saving model to ./Model/case_3/BiLSTM/model_14in2out\save_model.hdf5
# 19/19 - 0s - loss: 0.6034 - val_loss: 0.2234 - 437ms/epoch - 23ms/step
# Epoch 5/100
#
# Epoch 5: loss improved from 0.60345 to 0.37051, saving model to ./Model/case_3/BiLSTM/model_14in2out\save_model.hdf5
# 19/19 - 0s - loss: 0.3705 - val_loss: 0.2058 - 452ms/epoch - 24ms/step
# Epoch 6/100
#
# Epoch 6: loss improved from 0.37051 to 0.10277, saving model to ./Model/case_3/BiLSTM/model_14in2out\save_model.hdf5
# 19/19 - 0s - loss: 0.1028 - val_loss: 0.2118 - 480ms/epoch - 25ms/step
# Epoch 7/100
#
# Epoch 7: loss improved from 0.10277 to 0.03256, saving model to ./Model/case_3/BiLSTM/model_14in2out\save_model.hdf5
# 19/19 - 0s - loss: 0.0326 - val_loss: 0.2278 - 481ms/epoch - 25ms/step
# Epoch 8/100
#
# Epoch 8: loss improved from 0.03256 to 0.02404, saving model to ./Model/case_3/BiLSTM/model_14in2out\save_model.hdf5
# 19/19 - 0s - loss: 0.0240 - val_loss: 0.2496 - 456ms/epoch - 24ms/step
# Epoch 9/100
#
# Epoch 9: loss improved from 0.02404 to 0.02039, saving model to ./Model/case_3/BiLSTM/model_14in2out\save_model.hdf5
# 19/19 - 0s - loss: 0.0204 - val_loss: 0.2628 - 462ms/epoch - 24ms/step
# Epoch 10/100
#
# Epoch 10: loss improved from 0.02039 to 0.01875, saving model to ./Model/case_3/BiLSTM/model_14in2out\save_model.hdf5
# 19/19 - 0s - loss: 0.0188 - val_loss: 0.2920 - 460ms/epoch - 24ms/step
# Epoch 11/100
#
# Epoch 11: loss improved from 0.01875 to 0.01748, saving model to ./Model/case_3/BiLSTM/model_14in2out\save_model.hdf5
# 19/19 - 0s - loss: 0.0175 - val_loss: 0.3323 - 458ms/epoch - 24ms/step
# Epoch 12/100
#
# Epoch 12: loss did not improve from 0.01748
# 19/19 - 0s - loss: 0.0190 - val_loss: 0.3329 - 428ms/epoch - 23ms/step
# Epoch 13/100
#
# Epoch 13: loss did not improve from 0.01748
# 19/19 - 0s - loss: 0.0183 - val_loss: 0.3670 - 434ms/epoch - 23ms/step
# Epoch 14/100
#
# Epoch 14: loss improved from 0.01748 to 0.01612, saving model to ./Model/case_3/BiLSTM/model_14in2out\save_model.hdf5
# 19/19 - 0s - loss: 0.0161 - val_loss: 0.3930 - 456ms/epoch - 24ms/step
# Epoch 15/100
#
# Epoch 15: loss improved from 0.01612 to 0.01548, saving model to ./Model/case_3/BiLSTM/model_14in2out\save_model.hdf5
# 19/19 - 0s - loss: 0.0155 - val_loss: 0.3899 - 444ms/epoch - 23ms/step
# Epoch 16/100
#
# Epoch 16: loss did not improve from 0.01548
# 19/19 - 0s - loss: 0.0185 - val_loss: 0.3830 - 425ms/epoch - 22ms/step
# Epoch 17/100
#
# Epoch 17: loss did not improve from 0.01548
# 19/19 - 0s - loss: 0.0178 - val_loss: 0.4027 - 452ms/epoch - 24ms/step
# Epoch 18/100
#
# Epoch 18: loss improved from 0.01548 to 0.01524, saving model to ./Model/case_3/BiLSTM/model_14in2out\save_model.hdf5
# 19/19 - 0s - loss: 0.0152 - val_loss: 0.4200 - 444ms/epoch - 23ms/step
# Epoch 19/100
#
# Epoch 19: loss improved from 0.01524 to 0.01457, saving model to ./Model/case_3/BiLSTM/model_14in2out\save_model.hdf5
# 19/19 - 0s - loss: 0.0146 - val_loss: 0.4102 - 465ms/epoch - 24ms/step
# Epoch 20/100
#
# Epoch 20: loss did not improve from 0.01457
# 19/19 - 0s - loss: 0.0157 - val_loss: 0.3988 - 409ms/epoch - 22ms/step
# Epoch 21/100
#
# Epoch 21: loss did not improve from 0.01457
# 19/19 - 0s - loss: 0.0157 - val_loss: 0.4031 - 424ms/epoch - 22ms/step
# Epoch 22/100
#
# Epoch 22: loss did not improve from 0.01457
# 19/19 - 0s - loss: 0.0153 - val_loss: 0.4022 - 459ms/epoch - 24ms/step
# Epoch 23/100
#
# Epoch 23: loss did not improve from 0.01457
# 19/19 - 1s - loss: 0.0152 - val_loss: 0.3687 - 502ms/epoch - 26ms/step
# Epoch 24/100
#
# Epoch 24: loss improved from 0.01457 to 0.01278, saving model to ./Model/case_3/BiLSTM/model_14in2out\save_model.hdf5
# 19/19 - 1s - loss: 0.0128 - val_loss: 0.3678 - 503ms/epoch - 26ms/step
# Epoch 25/100
#
# Epoch 25: loss did not improve from 0.01278
# 19/19 - 0s - loss: 0.0132 - val_loss: 0.3404 - 470ms/epoch - 25ms/step
# Epoch 26/100
#
# Epoch 26: loss did not improve from 0.01278
# 19/19 - 0s - loss: 0.0155 - val_loss: 0.3197 - 470ms/epoch - 25ms/step
# Epoch 27/100
#
# Epoch 27: loss did not improve from 0.01278
# 19/19 - 0s - loss: 0.0166 - val_loss: 0.2922 - 457ms/epoch - 24ms/step
# Epoch 28/100
#
# Epoch 28: loss did not improve from 0.01278
# 19/19 - 0s - loss: 0.0129 - val_loss: 0.2652 - 470ms/epoch - 25ms/step
# Epoch 29/100
#
# Epoch 29: loss did not improve from 0.01278
# 19/19 - 0s - loss: 0.0137 - val_loss: 0.2921 - 430ms/epoch - 23ms/step
# Epoch 30/100
#
# Epoch 30: loss did not improve from 0.01278
# 19/19 - 0s - loss: 0.0136 - val_loss: 0.2708 - 435ms/epoch - 23ms/step
# Epoch 31/100
#
# Epoch 31: loss did not improve from 0.01278
# 19/19 - 0s - loss: 0.0135 - val_loss: 0.2730 - 431ms/epoch - 23ms/step
# Epoch 32/100
#
# Epoch 32: loss did not improve from 0.01278
# 19/19 - 0s - loss: 0.0147 - val_loss: 0.2228 - 434ms/epoch - 23ms/step
# Epoch 33/100
#
# Epoch 33: loss did not improve from 0.01278
# 19/19 - 0s - loss: 0.0146 - val_loss: 0.1836 - 439ms/epoch - 23ms/step
# Epoch 34/100
#
# Epoch 34: loss did not improve from 0.01278
# 19/19 - 0s - loss: 0.0133 - val_loss: 0.1888 - 429ms/epoch - 23ms/step
# Epoch 35/100
#
# Epoch 35: loss did not improve from 0.01278
# 19/19 - 0s - loss: 0.0140 - val_loss: 0.1655 - 429ms/epoch - 23ms/step
# Epoch 36/100
#
# Epoch 36: loss did not improve from 0.01278
# 19/19 - 0s - loss: 0.0141 - val_loss: 0.0855 - 414ms/epoch - 22ms/step
# Epoch 37/100
#
# Epoch 37: loss did not improve from 0.01278
# 19/19 - 0s - loss: 0.0149 - val_loss: 0.0806 - 417ms/epoch - 22ms/step
# Epoch 38/100
#
# Epoch 38: loss did not improve from 0.01278
# 19/19 - 0s - loss: 0.0150 - val_loss: 0.0359 - 421ms/epoch - 22ms/step
# Epoch 39/100
#
# Epoch 39: loss did not improve from 0.01278
# 19/19 - 0s - loss: 0.0142 - val_loss: 0.0391 - 424ms/epoch - 22ms/step
# Epoch 40/100
#
# Epoch 40: loss did not improve from 0.01278
# 19/19 - 0s - loss: 0.0147 - val_loss: 0.0307 - 443ms/epoch - 23ms/step
# Epoch 41/100
#
# Epoch 41: loss did not improve from 0.01278
# 19/19 - 0s - loss: 0.0140 - val_loss: 0.0473 - 410ms/epoch - 22ms/step
# Epoch 42/100
#
# Epoch 42: loss did not improve from 0.01278
# 19/19 - 0s - loss: 0.0163 - val_loss: 0.0391 - 414ms/epoch - 22ms/step
# Epoch 43/100
#
# Epoch 43: loss did not improve from 0.01278
# 19/19 - 0s - loss: 0.0136 - val_loss: 0.0414 - 414ms/epoch - 22ms/step
# Epoch 44/100
#
# Epoch 44: loss improved from 0.01278 to 0.01227, saving model to ./Model/case_3/BiLSTM/model_14in2out\save_model.hdf5
# 19/19 - 0s - loss: 0.0123 - val_loss: 0.0516 - 462ms/epoch - 24ms/step
# Epoch 45/100
#
# Epoch 45: loss did not improve from 0.01227
# 19/19 - 0s - loss: 0.0127 - val_loss: 0.0383 - 428ms/epoch - 23ms/step
# Epoch 46/100
#
# Epoch 46: loss did not improve from 0.01227
# 19/19 - 0s - loss: 0.0167 - val_loss: 0.0278 - 438ms/epoch - 23ms/step
# Epoch 47/100
#
# Epoch 47: loss did not improve from 0.01227
# 19/19 - 0s - loss: 0.0150 - val_loss: 0.0410 - 445ms/epoch - 23ms/step
# Epoch 48/100
#
# Epoch 48: loss did not improve from 0.01227
# 19/19 - 0s - loss: 0.0138 - val_loss: 0.0576 - 412ms/epoch - 22ms/step
# Epoch 49/100
#
# Epoch 49: loss did not improve from 0.01227
# 19/19 - 0s - loss: 0.0127 - val_loss: 0.0325 - 430ms/epoch - 23ms/step
# Epoch 50/100
#
# Epoch 50: loss improved from 0.01227 to 0.01211, saving model to ./Model/case_3/BiLSTM/model_14in2out\save_model.hdf5
# 19/19 - 0s - loss: 0.0121 - val_loss: 0.0330 - 478ms/epoch - 25ms/step
# Epoch 51/100
#
# Epoch 51: loss did not improve from 0.01211
# 19/19 - 0s - loss: 0.0150 - val_loss: 0.0654 - 435ms/epoch - 23ms/step
# Epoch 52/100
#
# Epoch 52: loss did not improve from 0.01211
# 19/19 - 0s - loss: 0.0132 - val_loss: 0.0503 - 436ms/epoch - 23ms/step
# Epoch 53/100
#
# Epoch 53: loss did not improve from 0.01211
# 19/19 - 0s - loss: 0.0136 - val_loss: 0.0212 - 422ms/epoch - 22ms/step
# Epoch 54/100
#
# Epoch 54: loss did not improve from 0.01211
# 19/19 - 0s - loss: 0.0132 - val_loss: 0.0149 - 414ms/epoch - 22ms/step
# Epoch 55/100
#
# Epoch 55: loss did not improve from 0.01211
# 19/19 - 0s - loss: 0.0126 - val_loss: 0.1227 - 425ms/epoch - 22ms/step
# Epoch 56/100
#
# Epoch 56: loss did not improve from 0.01211
# 19/19 - 0s - loss: 0.0160 - val_loss: 0.1186 - 445ms/epoch - 23ms/step
# Epoch 57/100
#
# Epoch 57: loss did not improve from 0.01211
# 19/19 - 0s - loss: 0.0121 - val_loss: 0.0468 - 440ms/epoch - 23ms/step
# Epoch 58/100
#
# Epoch 58: loss did not improve from 0.01211
# 19/19 - 0s - loss: 0.0139 - val_loss: 0.0292 - 428ms/epoch - 23ms/step
# Epoch 59/100
#
# Epoch 59: loss did not improve from 0.01211
# 19/19 - 0s - loss: 0.0134 - val_loss: 0.0340 - 445ms/epoch - 23ms/step
# Epoch 60/100
#
# Epoch 60: loss improved from 0.01211 to 0.01184, saving model to ./Model/case_3/BiLSTM/model_14in2out\save_model.hdf5
# 19/19 - 0s - loss: 0.0118 - val_loss: 0.0565 - 493ms/epoch - 26ms/step
# Epoch 61/100
#
# Epoch 61: loss did not improve from 0.01184
# 19/19 - 0s - loss: 0.0142 - val_loss: 0.0303 - 432ms/epoch - 23ms/step
# Epoch 62/100
#
# Epoch 62: loss did not improve from 0.01184
# 19/19 - 0s - loss: 0.0124 - val_loss: 0.0288 - 450ms/epoch - 24ms/step
# Epoch 63/100
#
# Epoch 63: loss did not improve from 0.01184
# 19/19 - 0s - loss: 0.0126 - val_loss: 0.0423 - 438ms/epoch - 23ms/step
# Epoch 64/100
#
# Epoch 64: loss did not improve from 0.01184
# 19/19 - 0s - loss: 0.0125 - val_loss: 0.0234 - 440ms/epoch - 23ms/step
# Epoch 65/100
#
# Epoch 65: loss did not improve from 0.01184
# 19/19 - 0s - loss: 0.0136 - val_loss: 0.0218 - 416ms/epoch - 22ms/step
# Epoch 66/100
#
# Epoch 66: loss did not improve from 0.01184
# 19/19 - 0s - loss: 0.0144 - val_loss: 0.0210 - 440ms/epoch - 23ms/step
# Epoch 67/100
#
# Epoch 67: loss improved from 0.01184 to 0.01178, saving model to ./Model/case_3/BiLSTM/model_14in2out\save_model.hdf5
# 19/19 - 0s - loss: 0.0118 - val_loss: 0.0467 - 474ms/epoch - 25ms/step
# Epoch 68/100
#
# Epoch 68: loss did not improve from 0.01178
# 19/19 - 0s - loss: 0.0140 - val_loss: 0.0350 - 460ms/epoch - 24ms/step
# Epoch 69/100
#
# Epoch 69: loss did not improve from 0.01178
# 19/19 - 0s - loss: 0.0132 - val_loss: 0.0187 - 450ms/epoch - 24ms/step
# Epoch 70/100
#
# Epoch 70: loss did not improve from 0.01178
# 19/19 - 0s - loss: 0.0129 - val_loss: 0.0214 - 480ms/epoch - 25ms/step
# Epoch 71/100
#
# Epoch 71: loss did not improve from 0.01178
# 19/19 - 0s - loss: 0.0128 - val_loss: 0.0410 - 459ms/epoch - 24ms/step
# Epoch 72/100
#
# Epoch 72: loss did not improve from 0.01178
# 19/19 - 0s - loss: 0.0119 - val_loss: 0.0196 - 408ms/epoch - 21ms/step
# Epoch 73/100
#
# Epoch 73: loss did not improve from 0.01178
# 19/19 - 0s - loss: 0.0132 - val_loss: 0.0623 - 447ms/epoch - 24ms/step
# Epoch 74/100
#
# Epoch 74: loss did not improve from 0.01178
# 19/19 - 0s - loss: 0.0121 - val_loss: 0.0452 - 457ms/epoch - 24ms/step
# Epoch 75/100
#
# Epoch 75: loss did not improve from 0.01178
# 19/19 - 0s - loss: 0.0137 - val_loss: 0.0391 - 460ms/epoch - 24ms/step
# Epoch 76/100
#
# Epoch 76: loss did not improve from 0.01178
# 19/19 - 1s - loss: 0.0143 - val_loss: 0.0470 - 524ms/epoch - 28ms/step
# Epoch 77/100
#
# Epoch 77: loss did not improve from 0.01178
# 19/19 - 0s - loss: 0.0151 - val_loss: 0.0451 - 494ms/epoch - 26ms/step
# Epoch 78/100
#
# Epoch 78: loss did not improve from 0.01178
# 19/19 - 0s - loss: 0.0142 - val_loss: 0.0388 - 466ms/epoch - 25ms/step
# Epoch 79/100
#
# Epoch 79: loss did not improve from 0.01178
# 19/19 - 0s - loss: 0.0131 - val_loss: 0.0125 - 457ms/epoch - 24ms/step
# Epoch 80/100
#
# Epoch 80: loss did not improve from 0.01178
# 19/19 - 0s - loss: 0.0131 - val_loss: 0.0295 - 429ms/epoch - 23ms/step
# Epoch 81/100
#
# Epoch 81: loss did not improve from 0.01178
# 19/19 - 0s - loss: 0.0134 - val_loss: 0.0327 - 435ms/epoch - 23ms/step
# Epoch 82/100
#
# Epoch 82: loss did not improve from 0.01178
# 19/19 - 0s - loss: 0.0152 - val_loss: 0.0407 - 420ms/epoch - 22ms/step
# Epoch 83/100
#
# Epoch 83: loss did not improve from 0.01178
# 19/19 - 0s - loss: 0.0140 - val_loss: 0.0490 - 438ms/epoch - 23ms/step
# Epoch 84/100
#
# Epoch 84: loss did not improve from 0.01178
# 19/19 - 0s - loss: 0.0136 - val_loss: 0.0419 - 435ms/epoch - 23ms/step
# Epoch 85/100
#
# Epoch 85: loss did not improve from 0.01178
# 19/19 - 0s - loss: 0.0136 - val_loss: 0.0416 - 440ms/epoch - 23ms/step
# Epoch 86/100
#
# Epoch 86: loss did not improve from 0.01178
# 19/19 - 0s - loss: 0.0153 - val_loss: 0.0197 - 445ms/epoch - 23ms/step
# Epoch 87/100
#
# Epoch 87: loss did not improve from 0.01178
# 19/19 - 0s - loss: 0.0128 - val_loss: 0.0514 - 449ms/epoch - 24ms/step
# Epoch 88/100
#
# Epoch 88: loss improved from 0.01178 to 0.01140, saving model to ./Model/case_3/BiLSTM/model_14in2out\save_model.hdf5
# 19/19 - 0s - loss: 0.0114 - val_loss: 0.0160 - 477ms/epoch - 25ms/step
# Epoch 89/100
#
# Epoch 89: loss did not improve from 0.01140
# 19/19 - 0s - loss: 0.0115 - val_loss: 0.0421 - 430ms/epoch - 23ms/step
# Epoch 90/100
#
# Epoch 90: loss did not improve from 0.01140
# 19/19 - 0s - loss: 0.0137 - val_loss: 0.0398 - 459ms/epoch - 24ms/step
# Epoch 91/100
#
# Epoch 91: loss did not improve from 0.01140
# 19/19 - 0s - loss: 0.0137 - val_loss: 0.0380 - 450ms/epoch - 24ms/step
# Epoch 92/100
#
# Epoch 92: loss improved from 0.01140 to 0.01115, saving model to ./Model/case_3/BiLSTM/model_14in2out\save_model.hdf5
# 19/19 - 0s - loss: 0.0112 - val_loss: 0.0285 - 472ms/epoch - 25ms/step
# Epoch 93/100
#
# Epoch 93: loss did not improve from 0.01115
# 19/19 - 0s - loss: 0.0126 - val_loss: 0.0274 - 426ms/epoch - 22ms/step
# Epoch 94/100
#
# Epoch 94: loss did not improve from 0.01115
# 19/19 - 0s - loss: 0.0129 - val_loss: 0.0105 - 428ms/epoch - 23ms/step
# Epoch 95/100
#
# Epoch 95: loss did not improve from 0.01115
# 19/19 - 0s - loss: 0.0121 - val_loss: 0.0643 - 429ms/epoch - 23ms/step
# Epoch 96/100
#
# Epoch 96: loss did not improve from 0.01115
# 19/19 - 0s - loss: 0.0129 - val_loss: 0.0545 - 415ms/epoch - 22ms/step
# Epoch 97/100
#
# Epoch 97: loss did not improve from 0.01115
# 19/19 - 0s - loss: 0.0134 - val_loss: 0.0314 - 417ms/epoch - 22ms/step
# Epoch 98/100
#
# Epoch 98: loss did not improve from 0.01115
# 19/19 - 0s - loss: 0.0145 - val_loss: 0.0357 - 424ms/epoch - 22ms/step
# Epoch 99/100
#
# Epoch 99: loss did not improve from 0.01115
# 19/19 - 0s - loss: 0.0121 - val_loss: 0.0559 - 410ms/epoch - 22ms/step
# Epoch 100/100
#
# Epoch 100: loss did not improve from 0.01115
# 19/19 - 0s - loss: 0.0114 - val_loss: 0.0432 - 451ms/epoch - 24ms/step
# Thời gian thực thi mô hình: 50.16 giây

# %%
#Model
final_model = load_model("./Model/case_3/BiLSTM/model_14in2out/save_model.hdf5")

# %%
#dữ liệu train
Y_train_predict = final_model.predict(X_train) 
# Nếu Y_train_predict là 3 chiều (samples, 2, 1) -> chuyển thành 2 chiều (samples, 2)
Y_train_predict = Y_train_predict.reshape(Y_train_predict.shape[0], Y_train_predict.shape[1])
Y_train_predict = sc.inverse_transform(Y_train_predict) #giá thực dự đoán

# Nếu Y_train là 3 chiều (samples, 2, 1) -> chuyển thành 2 chiều (samples, 2)
Y_train = Y_train.reshape(Y_train.shape[0], Y_train.shape[1])
Y_train = sc.inverse_transform(Y_train) #giá thực train
# Out:
# 48/48 [==============================] - 1s 3ms/step

# %%
print('Y_train_predict shape:', Y_train_predict.shape)
print('Y_train shape:', Y_train.shape)
# Out:
# Y_train_predict shape: (1516, 2)
# Y_train shape: (1516, 2)

# %% [markdown]
# # DỰ ĐOÁN TRÊN TẬP TEST

# %%
#dữ liệu test
import time
start_model = time.time()  # Bắt đầu đo thời gian
Y_test_predict = final_model.predict(X_test)
end_model = time.time()  # Kết thúc đo thời gian
print(f"Thời gian thực thi mô hình: {end_model - start_model:.2f} giây")
# Nếu Y_test_predict là 3 chiều (samples, 2, 1) -> chuyển thành 2 chiều (samples, 2)
Y_test_predict = Y_test_predict.reshape(Y_test_predict.shape[0], Y_test_predict.shape[1])
Y_test_predict = sc.inverse_transform(Y_test_predict) #giá thực dự đoán

# Nếu Y_test là 3 chiều (samples, 2, 1) -> chuyển thành 2 chiều (samples, 2)
Y_test = Y_test.reshape(Y_test.shape[0], Y_test.shape[1])
Y_test = sc.inverse_transform(Y_test) #giá thực train
# Out:
# 12/12 [==============================] - 0s 3ms/step
# Thời gian thực thi mô hình: 0.09 giây

# %%
print('Y_test_predict shape:', Y_test_predict.shape)
print('Y_test shape:', Y_test.shape)
# Out:
# Y_test_predict shape: (380, 2)
# Y_test shape: (380, 2)

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import mean_absolute_error, mean_squared_error

# Tính toán các giá trị cho tập Train
mae_train = round(mean_absolute_error(Y_train, Y_train_predict), 3)
mse_train = round(mean_squared_error(Y_train, Y_train_predict), 3)
rmse_train = round(np.sqrt(mse_train), 3)

# Tính toán các giá trị cho tập Test
mae_test = round(mean_absolute_error(Y_test, Y_test_predict), 3)
mse_test = round(mean_squared_error(Y_test, Y_test_predict), 3)
rmse_test = round(np.sqrt(mse_test), 3)

# Tạo DataFrame để hiển thị kết quả
metrics = pd.DataFrame({
    "Tập dữ liệu": ["Train", "Test"],
    "MAE": [mae_train, mae_test],
    "MSE": [mse_train, mse_test],
    "RMSE": [rmse_train, rmse_test]
})

# In kết quả
print(metrics)
print(f"Thời gian thực thi mô hình: {end_model - start_model:.2f} giây")
# Out:
#   Tập dữ liệu      MAE        MSE     RMSE
# 0       Train   57.212   6404.362   80.027
# 1        Test  161.842  37250.304  193.003
# Thời gian thực thi mô hình: 0.09 giây

# %%
from tensorflow.keras.models import load_model

# Gọi lại mô hình đã lưu
loaded_model = load_model("./Model/case_3/BiLSTM/model_14in2out/save_model.hdf5")
# Dự đoán lại trên tập test
Y_test_predict = loaded_model.predict(X_test)
# Đảo chuẩn hóa (inverse transform)
Y_test_predict = sc.inverse_transform(Y_test_predict)

# Tạo bảng so sánh
compare_df = pd.DataFrame({
    "Giá thực tế": Y_test.flatten(),
    "Giá dự đoán": Y_test_predict.flatten()
})

# Làm tròn về số nguyên
compare_df = compare_df.astype(int)
pd.set_option('display.max_rows', None)
# Hiển thị toàn bộ bảng
display(compare_df)
compare_df.to_csv("./Model/case_3/BiLSTM/model_14in2out/predict.csv", index=False)
# Out:
# 12/12 [==============================] - 1s 3ms/step
#      Giá thực tế  Giá dự đoán
# 0          24790        24693
# 1          24830        24570
# 2          24830        24691
# 3          24840        24568
# 4          24840        24721
# 5          24840        24595
# 6          24840        24735
# 7          24840        24607
# 8          24840        24740
# 9          24960        24611
# 10         24960        24742
# 11         25008        24613
# 12         25008        24840
# 13         25130        24700
# 14         25130        24904
# 15         25130        24757
# 16         25130        25017
# 17         25163        24857
# 18         25163        25048
# 19         25163        24883
# 20         25163        25085
# 21         25163        24914
# 22         25163        25092
# 23         25175        24917
# 24         25175        25091
# 25         25178        24914
# 26         25178        25095
# 27         25177        24917
# 28         25177        25095
# 29         25167        24915
# 30         25167        25092
# 31         25118        24912
# 32         25118        25082
# 33         25118        24901
# 34         25118        25039
# 35         25118        24863
# 36         25118        25028
# 37         25118        24853
# 38         25118        25031
# 39         25118        24856
# 40         25118        25033
# 41         25118        24859
# 42         25118        25041
# 43         25144        24867
# 44         25144        25043
# 45         25143        24868
# 46         25143        25066
# 47         25147        24890
# 48         25147        25072
# 49         25147        24895
# 50         25147        25079
# 51         25157        24900
# 52         25157        25081
# 53         25155        24902
# 54         25155        25090
# 55         25161        24910
# 56         25161        25089
# 57         25178        24909
# 58         25178        25093
# 59         25184        24912
# 60         25184        25104
# 61         25184        24922
# 62         25184        25112
# 63         25184        24928
# 64         25184        25115
# 65         25179        24930
# 66         25179        25116
# 67         25182        24930
# 68         25182        25112
# 69         25182        24927
# 70         25182        25113
# 71         25152        24927
# 72         25152        25114
# 73         25250        24928
# 74         25250        25089
# 75         25250        24907
# 76         25250        25162
# 77         25250        24970
# 78         25250        25179
# 79         25259        24985
# 80         25259        25188
# 81         25263        24992
# 82         25263        25198
# 83         25266        25000
# 84         25266        25205
# 85         25250        25004
# 86         25250        25209
# 87         25277        25007
# 88         25277        25196
# 89         25277        24996
# 90         25277        25213
# 91         25277        25011
# 92         25277        25216
# 93         25281        25013
# 94         25281        25217
# 95         25268        25013
# 96         25268        25221
# 97         25265        25016
# 98         25265        25211
# 99         25250        25007
# 100        25250        25205
# 101        25254        25001
# 102        25254        25197
# 103        25254        24995
# 104        25254        25196
# 105        25254        24995
# 106        25254        25196
# 107        25234        24994
# 108        25234        25196
# 109        25218        24995
# 110        25218        25180
# 111        25213        24982
# 112        25213        25164
# 113        25213        24968
# 114        25213        25155
# 115        25213        24960
# 116        25213        25153
# 117        25213        24960
# 118        25213        25153
# 119        25213        24960
# 120        25213        25153
# 121        25214        24960
# 122        25214        25154
# 123        25222        24961
# 124        25222        25154
# 125        25226        24962
# 126        25226        25161
# 127        25217        24968
# 128        25217        25166
# 129        25221        24972
# 130        25221        25161
# 131        25221        24967
# 132        25221        25163
# 133        25221        24969
# 134        25221        25163
# 135        25231        24969
# 136        25231        25161
# 137        25251        24967
# 138        25251        25168
# 139        25249        24973
# 140        25249        25186
# 141        25247        24988
# 142        25247        25189
# 143        25248        24991
# 144        25248        25189
# 145        25248        24991
# 146        25248        25190
# 147        25248        24991
# 148        25248        25190
# 149        25255        24991
# 150        25255        25189
# 151        25245        24990
# 152        25245        25195
# 153        25250        24995
# 154        25250        25188
# 155        25257        24989
# 156        25257        25190
# 157        25253        24990
# 158        25253        25196
# 159        25253        24996
# 160        25253        25194
# 161        25253        24994
# 162        25253        25194
# 163        25244        24994
# 164        25244        25195
# 165        25245        24995
# 166        25245        25189
# 167        25250        24990
# 168        25250        25188
# 169        25243        24988
# 170        25243        25191
# 171        25238        24991
# 172        25238        25186
# 173        25238        24987
# 174        25238        25181
# 175        25238        24983
# 176        25238        25180
# 177        25235        24982
# 178        25235        25180
# 179        25234        24982
# 180        25234        25177
# 181        25239        24979
# 182        25239        25176
# 183        25245        24979
# 184        25245        25180
# 185        25240        24983
# 186        25240        25185
# 187        25240        24987
# 188        25240        25183
# 189        25240        24985
# 190        25240        25183
# 191        25237        24985
# 192        25237        25182
# 193        25237        24984
# 194        25237        25180
# 195        25168        24982
# 196        25168        25179
# 197        25150        24982
# 198        25150        25123
# 199        25158        24933
# 200        25158        25094
# 201        25158        24908
# 202        25158        25090
# 203        25158        24906
# 204        25158        25088
# 205        25154        24905
# 206        25154        25088
# 207        25157        24906
# 208        25157        25087
# 209        25177        24905
# 210        25177        25090
# 211        25120        24909
# 212        25120        25109
# 213        25121        24925
# 214        25121        25068
# 215        25121        24890
# 216        25121        25060
# 217        25121        24883
# 218        25121        25056
# 219        25115        24880
# 220        25115        25054
# 221        25120        24878
# 222        25120        25048
# 223        25080        24873
# 224        25080        25047
# 225        25060        24872
# 226        25060        25015
# 227        25040        24845
# 228        25040        24993
# 229        25040        24826
# 230        25040        24971
# 231        25040        24806
# 232        25040        24964
# 233        24930        24801
# 234        24930        24962
# 235        24980        24800
# 236        24980        24877
# 237        24995        24725
# 238        24995        24896
# 239        24980        24742
# 240        24980        24906
# 241        24930        24752
# 242        24930        24901
# 243        24930        24748
# 244        24930        24863
# 245        24930        24715
# 246        24930        24855
# 247        24940        24708
# 248        24940        24851
# 249        24950        24705
# 250        24950        24858
# 251        24850        24712
# 252        24850        24866
# 253        24870        24719
# 254        24870        24792
# 255        24890        24653
# 256        24890        24789
# 257        24890        24650
# 258        24890        24800
# 259        24890        24661
# 260        24890        24803
# 261        24820        24664
# 262        24820        24800
# 263        24740        24661
# 264        24740        24752
# 265        24760        24618
# 266        24760        24679
# 267        24780        24553
# 268        24780        24672
# 269        24810        24547
# 270        24810        24681
# 271        24810        24555
# 272        24810        24708
# 273        24810        24580
# 274        24810        24718
# 275        24710        24590
# 276        24710        24724
# 277        24660        24595
# 278        24660        24652
# 279        24680        24530
# 280        24680        24591
# 281        24690        24475
# 282        24690        24590
# 283        24690        24474
# 284        24690        24596
# 285        24690        24480
# 286        24690        24598
# 287        24690        24482
# 288        24690        24600
# 289        24690        24484
# 290        24690        24598
# 291        24690        24483
# 292        24690        24597
# 293        24675        24482
# 294        24675        24601
# 295        24580        24485
# 296        24580        24592
# 297        24430        24478
# 298        24430        24520
# 299        24430        24412
# 300        24430        24390
# 301        24430        24293
# 302        24430        24351
# 303        24500        24257
# 304        24500        24331
# 305        24490        24239
# 306        24490        24378
# 307        24385        24282
# 308        24385        24389
# 309        24410        24292
# 310        24410        24323
# 311        24390        24231
# 312        24390        24328
# 313        24390        24235
# 314        24390        24314
# 315        24390        24222
# 316        24390        24312
# 317        24380        24221
# 318        24380        24312
# 319        24430        24221
# 320        24430        24305
# 321        24470        24216
# 322        24470        24339
# 323        24410        24247
# 324        24410        24373
# 325        24400        24279
# 326        24400        24335
# 327        24400        24245
# 328        24400        24322
# 329        24400        24233
# 330        24400        24317
# 331        24460        24229
# 332        24460        24317
# 333        24430        24228
# 334        24430        24358
# 335        24410        24266
# 336        24410        24342
# 337        24460        24253
# 338        24460        24327
# 339        24420        24239
# 340        24420        24359
# 341        24420        24268
# 342        24420        24337
# 343        24420        24248
# 344        24420        24332
# 345        24400        24243
# 346        24400        24330
# 347        24430        24241
# 348        24430        24316
# 349        24480        24228
# 350        24480        24335
# 351        24580        24245
# 352        24580        24373
# 353        24580        24281
# 354        24580        24459
# 355        24580        24360
# 356        24580        24484
# 357        24580        24383
# 358        24580        24494
# 359        24670        24393
# 360        24670        24498
# 361        24665        24396
# 362        24665        24562
# 363        24665        24455
# 364        24665        24572
# 365        24670        24464
# 366        24670        24575
# 367        24640        24467
# 368        24640        24575
# 369        24640        24467
# 370        24640        24550
# 371        24640        24444
# 372        24640        24541
# 373        24660        24435
# 374        24660        24536
# 375        24765        24430
# 376        24765        24550
# 377        24810        24442
# 378        24810        24635
# 379        25010        24519
# 380        25010        24696
# 381        24980        24574
# 382        24980        24869
# 383        24980        24729
# 384        24980        24891
# 385        24980        24750
# 386        24980        24903
# 387        25070        24759
# 388        25070        24907
# 389        25092        24761
# 390        25092        24972
# 391        25220        24817
# 392        25220        24999
# 393        25233        24841
# 394        25233        25106
# 395        25197        24934
# 396        25197        25140
# 397        25197        24961
# 398        25197        25122
# 399        25197        24941
# 400        25197        25116
# 401        25194        24934
# 402        25194        25112
# 403        25164        24928
# 404        25164        25110
# 405        25118        24925
# 406        25118        25085
# 407        25090        24903
# 408        25090        25050
# 409        25114        24872
# 410        25114        25011
# 411        25114        24839
# 412        25114        25019
# 413        25114        24846
# 414        25114        25022
# 415        25125        24849
# 416        25125        25030
# 417        25160        24857
# 418        25160        25045
# 419        25170        24870
# 420        25170        25085
# 421        25197        24906
# 422        25197        25103
# 423        25130        24922
# 424        25130        25129
# 425        25130        24944
# 426        25130        25083
# 427        25130        24904
# 428        25130        25072
# 429        25116        24893
# 430        25116        25065
# 431        25160        24887
# 432        25160        25048
# 433        25180        24873
# 434        25180        25075
# 435        25184        24897
# 436        25184        25097
# 437        25190        24916
# 438        25190        25110
# 439        25190        24927
# 440        25190        25120
# 441        25190        24935
# 442        25190        25123
# 443        25200        24937
# 444        25200        25125
# 445        25205        24938
# 446        25205        25135
# 447        25200        24947
# 448        25200        25140
# 449        25200        24951
# 450        25200        25138
# 451        25200        24949
# 452        25200        25133
# 453        25200        24944
# 454        25200        25132
# 455        25200        24943
# 456        25200        25131
# 457        25197        24942
# 458        25197        25131
# 459        25200        24942
# 460        25200        25131
# 461        25200        24942
# 462        25200        25134
# 463        25175        24945
# 464        25175        25135
# 465        25160        24945
# 466        25160        25115
# 467        25160        24928
# 468        25160        25098
# 469        25160        24914
# 470        25160        25093
# 471        25149        24910
# 472        25149        25092
# 473        25170        24909
# 474        25170        25083
# 475        25172        24901
# 476        25172        25097
# 477        25176        24915
# 478        25176        25103
# 479        25164        24920
# 480        25164        25109
# 481        25164        24925
# 482        25164        25102
# 483        25164        24919
# 484        25164        25100
# 485        25157        24917
# 486        25157        25099
# 487        25170        24916
# 488        25170        25093
# 489        25165        24911
# 490        25165        25101
# 491        25171        24918
# 492        25171        25097
# 493        25177        24915
# 494        25177        25101
# 495        25177        24918
# 496        25177        25107
# 497        25177        24923
# 498        25177        25109
# 499        25185        24925
# 500        25185        25109
# 501        25183        24925
# 502        25183        25117
# 503        25191        24932
# 504        25191        25117
# 505        25219        24932
# 506        25219        25124
# 507        25240        24937
# 508        25240        25147
# 509        25240        24957
# 510        25240        25170
# 511        25240        24977
# 512        25240        25177
# 513        25230        24982
# 514        25230        25179
# 515        25223        24984
# 516        25223        25172
# 517        25236        24977
# 518        25236        25164
# 519        25225        24969
# 520        25225        25171
# 521        25238        24975
# 522        25238        25163
# 523        25238        24968
# 524        25238        25172
# 525        25238        24976
# 526        25238        25173
# 527        25243        24977
# 528        25243        25175
# 529        25251        24978
# 530        25251        25179
# 531        25251        24982
# 532        25251        25188
# 533        25259        24989
# 534        25259        25192
# 535        25250        24993
# 536        25250        25201
# 537        25250        25000
# 538        25250        25195
# 539        25250        24995
# 540        25250        25194
# 541        25253        24994
# 542        25253        25192
# 543        25208        24992
# 544        25208        25194
# 545        25186        24994
# 546        25186        25158
# 547        25194        24963
# 548        25194        25131
# 549        25198        24939
# 550        25198        25129
# 551        25198        24939
# 552        25198        25131
# 553        25198        24941
# 554        25198        25132
# 555        25200        24942
# 556        25200        25134
# 557        25203        24944
# 558        25203        25137
# 559        25194        24948
# 560        25194        25141
# 561        25189        24951
# 562        25189        25136
# 563        25150        24947
# 564        25150        25131
# 565        25150        24942
# 566        25150        25098
# 567        25150        24914
# 568        25150        25089
# 569        25150        24906
# 570        25150        25084
# 571        25090        24903
# 572        25090        25080
# 573        24960        24900
# 574        24960        25032
# 575        24960        24857
# 576        24960        24919
# 577        24800        24759
# 578        24800        24889
# 579        24800        24733
# 580        24800        24755
# 581        24800        24615
# 582        24800        24721
# 583        24800        24586
# 584        24800        24710
# 585        24800        24578
# 586        24800        24710
# 587        24800        24579
# 588        24800        24715
# 589        24800        24584
# 590        24800        24721
# 591        24800        24590
# 592        24800        24725
# 593        24800        24594
# 594        24800        24730
# 595        24800        24599
# 596        24800        24732
# 597        25140        24601
# 598        25140        24732
# 599        25000        24602
# 600        25000        24991
# 601        24980        24834
# 602        24980        24940
# 603        25090        24790
# 604        25090        24923
# 605        25110        24774
# 606        25110        24994
# 607        25110        24835
# 608        25110        25024
# 609        25110        24861
# 610        25110        25032
# 611        25200        24866
# 612        25200        25031
# 613        25340        24864
# 614        25340        25099
# 615        25380        24923
# 616        25380        25227
# 617        25300        25032
# 618        25300        25293
# 619        25220        25087
# 620        25220        25250
# 621        25220        25045
# 622        25220        25176
# 623        25220        24977
# 624        25220        25153
# 625        25280        24956
# 626        25280        25156
# 627        25340        24960
# 628        25340        25188
# 629        25340        24988
# 630        25340        25246
# 631        25350        25038
# 632        25350        25271
# 633        25320        25059
# 634        25320        25289
# 635        25320        25073
# 636        25320        25271
# 637        25320        25056
# 638        25320        25269
# 639        25310        25052
# 640        25310        25273
# 641        25330        25056
# 642        25330        25270
# 643        25360        25055
# 644        25360        25283
# 645        25380        25067
# 646        25380        25304
# 647        25370        25084
# 648        25370        25323
# 649        25370        25099
# 650        25370        25323
# 651        25370        25098
# 652        25370        25326
# 653        25420        25099
# 654        25420        25331
# 655        25390        25103
# 656        25390        25375
# 657        25320        25141
# 658        25320        25360
# 659        25300        25127
# 660        25300        25300
# 661        25300        25075
# 662        25300        25265
# 663        25330        25045
# 664        25330        25252
# 665        25330        25036
# 666        25330        25271
# 667        25340        25054
# 668        25340        25276
# 669        25290        25059
# 670        25290        25290
# 671        25280        25071
# 672        25280        25256
# 673        25320        25042
# 674        25320        25241
# 675        25350        25030
# 676        25350        25267
# 677        25350        25053
# 678        25350        25298
# 679        25350        25080
# 680        25350        25308
# 681        25360        25089
# 682        25360        25315
# 683        25350        25094
# 684        25350        25322
# 685        25370        25099
# 686        25370        25312
# 687        25380        25089
# 688        25380        25325
# 689        25400        25100
# 690        25400        25337
# 691        25400        25109
# 692        25400        25358
# 693        25400        25127
# 694        25400        25363
# 695        25450        25131
# 696        25450        25365
# 697        25450        25132
# 698        25450        25404
# 699        25390        25164
# 700        25390        25415
# 701        25390        25171
# 702        25390        25372
# 703        25400        25134
# 704        25400        25362
# 705        25400        25125
# 706        25400        25364
# 707        25400        25127
# 708        25400        25363
# 709        25380        25127
# 710        25380        25363
# 711        25460        25127
# 712        25460        25347
# 713        25460        25113
# 714        25460        25410
# 715        25620        25168
# 716        25620        25428
# 717        25600        25182
# 718        25600        25572
# 719        25600        25304
# 720        25600        25595
# 721        25600        25318
# 722        25600        25610
# 723        25600        25325
# 724        25600        25618
# 725        25780        25327
# 726        25780        25616
# 727        25822        25323
# 728        25822        25767
# 729        25610        25444
# 730        25610        25845
# 731        25560        25500
# 732        25560        25687
# 733        25560        25362
# 734        25560        25605
# 735        25560        25294
# 736        25560        25571
# 737        25640        25269
# 738        25640        25554
# 739        25650        25259
# 740        25650        25621
# 741        25650        25320
# 742        25650        25649
# 743        25700        25343
# 744        25700        25672
# 745        25760        25364
# 746        25760        25722
# 747        25760        25404
# 748        25760        25791
# 749        25760        25458
# 750        25760        25815
# 751        25700        25472
# 752        25700        25828
# 753        25755        25477
# 754        25755        25790
# 755        25781        25445
# 756        25781        25823
# 757        25814        25472
# 758        25814        25834
# 759        25835        25476
