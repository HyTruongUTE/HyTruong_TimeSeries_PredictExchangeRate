# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler #chuẩn hóa dữ liệu
from keras.callbacks import ModelCheckpoint #lưu lại huấn luyện tốt nhất
from tensorflow.keras.models import load_model #tải mô hình
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import ModelCheckpoint

import random
import tensorflow as tf

#các lớp để xây dựng mô hình
from keras.models import Sequential #đầu vào
from keras.layers import LSTM #học phụ thuộc
from keras.layers import Dropout, BatchNormalization #tránh học tủ
from keras.layers import Dense #đầu ra

#kiểm tra độ chính xác của mô hình
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
random.seed(42)
np.random.seed(42)
tf.random.set_seed(42)

# %%
df_usd = pd.read_parquet("./minio/usd/part-00000-18b834c3-cd6d-42ae-82c3-638999ff6d84-c000.snappy.parquet", engine="pyarrow")
df_usd.head()
# Out:
#         ngay ma_ngoai_te ten_ngoai_te  mua_chuyen_khoan      ban
# 0 2020-02-01         USD    US DOLLAR           23165.0  23305.0
# 1 2020-02-02         USD    US DOLLAR           23165.0  23305.0
# 2 2020-02-03         USD    US DOLLAR           23200.0  23340.0
# 3 2020-02-04         USD    US DOLLAR           23170.0  23310.0
# 4 2020-02-05         USD    US DOLLAR           23160.0  23300.0

# %%
df_usd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1911 entries, 0 to 1910
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ngay              1911 non-null   datetime64[ns]
#  1   ma_ngoai_te       1911 non-null   object
#  2   ten_ngoai_te      1911 non-null   object
#  3   mua_chuyen_khoan  1911 non-null   float64
#  4   ban               1911 non-null   float64
# dtypes: datetime64[ns](1), float64(2), object(2)
# memory usage: 74.8+ KB

# %%
df_usd.describe()
# Out:
#                       ngay  mua_chuyen_khoan           ban
# count                 1911       1911.000000   1911.000000
# mean   2022-09-13 00:00:00      23666.414443  23934.197279
# min    2020-02-01 00:00:00      22480.000000  22745.000000
# 25%    2021-05-23 12:00:00      22985.000000  23170.000000
# 50%    2022-09-13 00:00:00      23300.000000  23620.000000
# 75%    2024-01-03 12:00:00      24390.000000  24730.000000
# max    2025-04-25 00:00:00      25835.000000  26195.000000
# std                    NaN        885.147984    926.810272

# %%
print(df_usd.dtypes)
# Out:
# ngay                datetime64[ns]
# ma_ngoai_te                 object
# ten_ngoai_te                object
# mua_chuyen_khoan           float64
# ban                        float64
# dtype: object

# %%
import matplotlib.pyplot as plt
from matplotlib.dates import YearLocator, DateFormatter, MonthLocator

# Vẽ biểu đồ
plt.figure(figsize=(10, 5))
plt.plot(df_usd['ngay'].values, df_usd['mua_chuyen_khoan'].values, label='Giá mua chuyển khoản', color='red')

plt.xlabel('Năm')
plt.ylabel('Giá mua chuyển khoản')
plt.title('Biểu đồ tỷ giá VND_USD mua chuyển khoảng qua các năm')
plt.legend(loc='best')

# Định dạng trục x
plt.gca().xaxis.set_major_locator(YearLocator())
plt.gca().xaxis.set_major_formatter(DateFormatter('%Y'))
plt.gca().xaxis.set_minor_locator(MonthLocator())

plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
df_usd_ML = pd.DataFrame(df_usd, columns=['ngay','mua_chuyen_khoan'])
df_usd_ML.index = df_usd_ML.ngay
df_usd_ML.drop('ngay', axis = 1, inplace=True)
df_usd_ML.head()
# Out:
#             mua_chuyen_khoan
# ngay
# 2020-02-01           23165.0
# 2020-02-02           23165.0
# 2020-02-03           23200.0
# 2020-02-04           23170.0
# 2020-02-05           23160.0

# %%
print(df_usd_ML.columns)
# Out:
# Index(['mua_chuyen_khoan'], dtype='object')

# %%
data = df_usd_ML.values

# %%
data
# Out:
# array([[23165.],
#        [23165.],
#        [23200.],
#        ...,
#        [25781.],
#        [25814.],
#        [25835.]])

# %%
#hàm hóa dữ liệu
sc = MinMaxScaler(feature_range=(0,1))

#chuẩn hóa dữ train
scale_data = sc.fit_transform(data)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))

plt.plot(scale_data, label="Dữ liệu sau chuẩn hóa", color="red")

plt.xlabel("Thời gian (Index)")
plt.ylabel("Giá trị sau chuẩn hóa")
plt.title("Biểu đồ dữ liệu sau khi chuẩn hóa bằng MinMaxScaler")
plt.legend()
plt.show()

# %%
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Bidirectional, LSTM, Dense, Dropout

# Chọn window
window_size = 7
X_train, Y_train = [], []

for i in range(len(scale_data) - window_size):
    X_train.append(scale_data[i:i + window_size])
    Y_train.append(scale_data[i + window_size])

X_train = np.array(X_train)
Y_train = np.array(Y_train)

# Phân chia tập dữ liệu thành tập train và test 80 - 20
split_index = int(0.8 * len(X_train))

X_train, X_test = X_train[:split_index], X_train[split_index:]
Y_train, Y_test = Y_train[:split_index], Y_train[split_index:]

# Đảm bảo dữ liệu có đúng shape cho mô hình BiLSTM
X_train = X_train.reshape((X_train.shape[0], window_size, -1))
X_test = X_test.reshape((X_test.shape[0], window_size, -1))

# %%
print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
print("y_train shape:", Y_train.shape)
print("y_test shape:", Y_test.shape)
# Out:
# X_train shape: (1523, 7, 1)
# X_test shape: (381, 7, 1)
# y_train shape: (1523, 1)
# y_test shape: (381, 1)

# %%
print("Shape of X_train:", X_train.shape)
# Out:
# Shape of X_train: (1523, 7, 1)

# %% [markdown]
# # MODEL

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Bidirectional, BatchNormalization

# Xây dựng mô hình BiLSTM
model = Sequential()

# Lớp BiLSTM đầu tiên (return_sequences=True để kết nối lớp tiếp theo)
model.add(Bidirectional(LSTM(units=64, return_sequences=True, input_shape=(X_train.shape[1], 1))))
model.add(BatchNormalization())  # Ổn định dữ liệu đầu ra

# Lớp BiLSTM thứ hai
model.add(Bidirectional(LSTM(units=64)))
model.add(BatchNormalization())

# Dropout để giảm overfitting
model.add(Dropout(0.5))

# Lớp Dense đầu ra
model.add(Dense(1))

# Compile mô hình
model.compile(loss='mean_absolute_error', optimizer='adam')

# %% [markdown]
# # huấn luyện mô hình

# %%
save_model = "./Model/case_2/BiLSTM/model_8020/save_model.hdf5"
best_model = ModelCheckpoint(save_model,monitor='loss',verbose=2,save_best_only=True,mode='auto')

import time
start_model = time.time()  # Bắt đầu đo thời gian
model.fit(X_train,Y_train,epochs=100,batch_size=50,validation_split=0.4,verbose=2,callbacks=[best_model])
end_model = time.time()  # Kết thúc đo thời gian
print(f"Thời gian thực thi mô hình: {end_model - start_model:.2f} giây")
# Out:
# Epoch 1/100
#
# Epoch 1: loss improved from inf to 0.93743, saving model to ./Model/case_2/BiLSTM/model_8020\save_model.hdf5
# 19/19 - 6s - loss: 0.9374 - val_loss: 0.3165 - 6s/epoch - 306ms/step
# Epoch 2/100
#
# Epoch 2: loss improved from 0.93743 to 0.77002, saving model to ./Model/case_2/BiLSTM/model_8020\save_model.hdf5
# 19/19 - 0s - loss: 0.7700 - val_loss: 0.2558 - 306ms/epoch - 16ms/step
# Epoch 3/100
#
# Epoch 3: loss did not improve from 0.77002
# 19/19 - 0s - loss: 0.8250 - val_loss: 0.2594 - 271ms/epoch - 14ms/step
# Epoch 4/100
#
# Epoch 4: loss improved from 0.77002 to 0.68586, saving model to ./Model/case_2/BiLSTM/model_8020\save_model.hdf5
# 19/19 - 0s - loss: 0.6859 - val_loss: 0.3172 - 330ms/epoch - 17ms/step
# Epoch 5/100
#
# Epoch 5: loss improved from 0.68586 to 0.59920, saving model to ./Model/case_2/BiLSTM/model_8020\save_model.hdf5
# 19/19 - 0s - loss: 0.5992 - val_loss: 0.3041 - 324ms/epoch - 17ms/step
# Epoch 6/100
#
# Epoch 6: loss improved from 0.59920 to 0.53716, saving model to ./Model/case_2/BiLSTM/model_8020\save_model.hdf5
# 19/19 - 0s - loss: 0.5372 - val_loss: 0.3476 - 302ms/epoch - 16ms/step
# Epoch 7/100
#
# Epoch 7: loss improved from 0.53716 to 0.37093, saving model to ./Model/case_2/BiLSTM/model_8020\save_model.hdf5
# 19/19 - 0s - loss: 0.3709 - val_loss: 0.3222 - 308ms/epoch - 16ms/step
# Epoch 8/100
#
# Epoch 8: loss improved from 0.37093 to 0.25622, saving model to ./Model/case_2/BiLSTM/model_8020\save_model.hdf5
# 19/19 - 0s - loss: 0.2562 - val_loss: 0.3331 - 326ms/epoch - 17ms/step
# Epoch 9/100
#
# Epoch 9: loss improved from 0.25622 to 0.12366, saving model to ./Model/case_2/BiLSTM/model_8020\save_model.hdf5
# 19/19 - 0s - loss: 0.1237 - val_loss: 0.2880 - 295ms/epoch - 16ms/step
# Epoch 10/100
#
# Epoch 10: loss improved from 0.12366 to 0.04346, saving model to ./Model/case_2/BiLSTM/model_8020\save_model.hdf5
# 19/19 - 0s - loss: 0.0435 - val_loss: 0.2637 - 322ms/epoch - 17ms/step
# Epoch 11/100
#
# Epoch 11: loss improved from 0.04346 to 0.02315, saving model to ./Model/case_2/BiLSTM/model_8020\save_model.hdf5
# 19/19 - 0s - loss: 0.0232 - val_loss: 0.2333 - 310ms/epoch - 16ms/step
# Epoch 12/100
#
# Epoch 12: loss improved from 0.02315 to 0.01816, saving model to ./Model/case_2/BiLSTM/model_8020\save_model.hdf5
# 19/19 - 0s - loss: 0.0182 - val_loss: 0.1953 - 302ms/epoch - 16ms/step
# Epoch 13/100
#
# Epoch 13: loss did not improve from 0.01816
# 19/19 - 0s - loss: 0.0192 - val_loss: 0.1589 - 278ms/epoch - 15ms/step
# Epoch 14/100
#
# Epoch 14: loss improved from 0.01816 to 0.01637, saving model to ./Model/case_2/BiLSTM/model_8020\save_model.hdf5
# 19/19 - 0s - loss: 0.0164 - val_loss: 0.1292 - 314ms/epoch - 17ms/step
# Epoch 15/100
#
# Epoch 15: loss improved from 0.01637 to 0.01563, saving model to ./Model/case_2/BiLSTM/model_8020\save_model.hdf5
# 19/19 - 0s - loss: 0.0156 - val_loss: 0.1067 - 323ms/epoch - 17ms/step
# Epoch 16/100
#
# Epoch 16: loss did not improve from 0.01563
# 19/19 - 0s - loss: 0.0181 - val_loss: 0.0974 - 265ms/epoch - 14ms/step
# Epoch 17/100
#
# Epoch 17: loss improved from 0.01563 to 0.01507, saving model to ./Model/case_2/BiLSTM/model_8020\save_model.hdf5
# 19/19 - 0s - loss: 0.0151 - val_loss: 0.0958 - 295ms/epoch - 16ms/step
# Epoch 18/100
#
# Epoch 18: loss did not improve from 0.01507
# 19/19 - 0s - loss: 0.0163 - val_loss: 0.1237 - 268ms/epoch - 14ms/step
# Epoch 19/100
#
# Epoch 19: loss improved from 0.01507 to 0.01440, saving model to ./Model/case_2/BiLSTM/model_8020\save_model.hdf5
# 19/19 - 0s - loss: 0.0144 - val_loss: 0.1857 - 305ms/epoch - 16ms/step
# Epoch 20/100
#
# Epoch 20: loss improved from 0.01440 to 0.01207, saving model to ./Model/case_2/BiLSTM/model_8020\save_model.hdf5
# 19/19 - 0s - loss: 0.0121 - val_loss: 0.2356 - 297ms/epoch - 16ms/step
# Epoch 21/100
#
# Epoch 21: loss did not improve from 0.01207
# 19/19 - 0s - loss: 0.0127 - val_loss: 0.2953 - 277ms/epoch - 15ms/step
# Epoch 22/100
#
# Epoch 22: loss did not improve from 0.01207
# 19/19 - 0s - loss: 0.0146 - val_loss: 0.3639 - 258ms/epoch - 14ms/step
# Epoch 23/100
#
# Epoch 23: loss did not improve from 0.01207
# 19/19 - 0s - loss: 0.0142 - val_loss: 0.4323 - 261ms/epoch - 14ms/step
# Epoch 24/100
#
# Epoch 24: loss did not improve from 0.01207
# 19/19 - 0s - loss: 0.0160 - val_loss: 0.4559 - 279ms/epoch - 15ms/step
# Epoch 25/100
#
# Epoch 25: loss did not improve from 0.01207
# 19/19 - 0s - loss: 0.0141 - val_loss: 0.4804 - 256ms/epoch - 13ms/step
# Epoch 26/100
#
# Epoch 26: loss did not improve from 0.01207
# 19/19 - 0s - loss: 0.0128 - val_loss: 0.5187 - 260ms/epoch - 14ms/step
# Epoch 27/100
#
# Epoch 27: loss did not improve from 0.01207
# 19/19 - 0s - loss: 0.0132 - val_loss: 0.5726 - 249ms/epoch - 13ms/step
# Epoch 28/100
#
# Epoch 28: loss did not improve from 0.01207
# 19/19 - 0s - loss: 0.0144 - val_loss: 0.6058 - 262ms/epoch - 14ms/step
# Epoch 29/100
#
# Epoch 29: loss did not improve from 0.01207
# 19/19 - 0s - loss: 0.0131 - val_loss: 0.5581 - 256ms/epoch - 13ms/step
# Epoch 30/100
#
# Epoch 30: loss did not improve from 0.01207
# 19/19 - 0s - loss: 0.0132 - val_loss: 0.5062 - 256ms/epoch - 13ms/step
# Epoch 31/100
#
# Epoch 31: loss did not improve from 0.01207
# 19/19 - 0s - loss: 0.0157 - val_loss: 0.4645 - 247ms/epoch - 13ms/step
# Epoch 32/100
#
# Epoch 32: loss did not improve from 0.01207
# 19/19 - 0s - loss: 0.0160 - val_loss: 0.4945 - 256ms/epoch - 13ms/step
# Epoch 33/100
#
# Epoch 33: loss did not improve from 0.01207
# 19/19 - 0s - loss: 0.0124 - val_loss: 0.3632 - 250ms/epoch - 13ms/step
# Epoch 34/100
#
# Epoch 34: loss did not improve from 0.01207
# 19/19 - 0s - loss: 0.0140 - val_loss: 0.3441 - 242ms/epoch - 13ms/step
# Epoch 35/100
#
# Epoch 35: loss did not improve from 0.01207
# 19/19 - 0s - loss: 0.0167 - val_loss: 0.2679 - 232ms/epoch - 12ms/step
# Epoch 36/100
#
# Epoch 36: loss did not improve from 0.01207
# 19/19 - 0s - loss: 0.0130 - val_loss: 0.2405 - 234ms/epoch - 12ms/step
# Epoch 37/100
#
# Epoch 37: loss did not improve from 0.01207
# 19/19 - 0s - loss: 0.0151 - val_loss: 0.2175 - 245ms/epoch - 13ms/step
# Epoch 38/100
#
# Epoch 38: loss improved from 0.01207 to 0.01158, saving model to ./Model/case_2/BiLSTM/model_8020\save_model.hdf5
# 19/19 - 0s - loss: 0.0116 - val_loss: 0.1742 - 270ms/epoch - 14ms/step
# Epoch 39/100
#
# Epoch 39: loss did not improve from 0.01158
# 19/19 - 0s - loss: 0.0131 - val_loss: 0.1331 - 229ms/epoch - 12ms/step
# Epoch 40/100
#
# Epoch 40: loss did not improve from 0.01158
# 19/19 - 0s - loss: 0.0165 - val_loss: 0.0591 - 242ms/epoch - 13ms/step
# Epoch 41/100
#
# Epoch 41: loss did not improve from 0.01158
# 19/19 - 0s - loss: 0.0141 - val_loss: 0.0631 - 238ms/epoch - 13ms/step
# Epoch 42/100
#
# Epoch 42: loss did not improve from 0.01158
# 19/19 - 0s - loss: 0.0156 - val_loss: 0.0749 - 241ms/epoch - 13ms/step
# Epoch 43/100
#
# Epoch 43: loss did not improve from 0.01158
# 19/19 - 0s - loss: 0.0135 - val_loss: 0.0282 - 250ms/epoch - 13ms/step
# Epoch 44/100
#
# Epoch 44: loss did not improve from 0.01158
# 19/19 - 0s - loss: 0.0124 - val_loss: 0.0495 - 235ms/epoch - 12ms/step
# Epoch 45/100
#
# Epoch 45: loss did not improve from 0.01158
# 19/19 - 0s - loss: 0.0133 - val_loss: 0.0194 - 261ms/epoch - 14ms/step
# Epoch 46/100
#
# Epoch 46: loss did not improve from 0.01158
# 19/19 - 0s - loss: 0.0118 - val_loss: 0.0108 - 228ms/epoch - 12ms/step
# Epoch 47/100
#
# Epoch 47: loss did not improve from 0.01158
# 19/19 - 0s - loss: 0.0144 - val_loss: 0.1298 - 230ms/epoch - 12ms/step
# Epoch 48/100
#
# Epoch 48: loss did not improve from 0.01158
# 19/19 - 0s - loss: 0.0205 - val_loss: 0.0665 - 232ms/epoch - 12ms/step
# Epoch 49/100
#
# Epoch 49: loss did not improve from 0.01158
# 19/19 - 0s - loss: 0.0130 - val_loss: 0.0242 - 247ms/epoch - 13ms/step
# Epoch 50/100
#
# Epoch 50: loss did not improve from 0.01158
# 19/19 - 0s - loss: 0.0119 - val_loss: 0.0388 - 259ms/epoch - 14ms/step
# Epoch 51/100
#
# Epoch 51: loss did not improve from 0.01158
# 19/19 - 0s - loss: 0.0158 - val_loss: 0.0320 - 257ms/epoch - 14ms/step
# Epoch 52/100
#
# Epoch 52: loss improved from 0.01158 to 0.01133, saving model to ./Model/case_2/BiLSTM/model_8020\save_model.hdf5
# 19/19 - 0s - loss: 0.0113 - val_loss: 0.0391 - 283ms/epoch - 15ms/step
# Epoch 53/100
#
# Epoch 53: loss did not improve from 0.01133
# 19/19 - 0s - loss: 0.0128 - val_loss: 0.0179 - 247ms/epoch - 13ms/step
# Epoch 54/100
#
# Epoch 54: loss improved from 0.01133 to 0.01086, saving model to ./Model/case_2/BiLSTM/model_8020\save_model.hdf5
# 19/19 - 0s - loss: 0.0109 - val_loss: 0.0142 - 286ms/epoch - 15ms/step
# Epoch 55/100
#
# Epoch 55: loss improved from 0.01086 to 0.00987, saving model to ./Model/case_2/BiLSTM/model_8020\save_model.hdf5
# 19/19 - 0s - loss: 0.0099 - val_loss: 0.0364 - 264ms/epoch - 14ms/step
# Epoch 56/100
#
# Epoch 56: loss did not improve from 0.00987
# 19/19 - 0s - loss: 0.0113 - val_loss: 0.0602 - 225ms/epoch - 12ms/step
# Epoch 57/100
#
# Epoch 57: loss did not improve from 0.00987
# 19/19 - 0s - loss: 0.0139 - val_loss: 0.0261 - 238ms/epoch - 13ms/step
# Epoch 58/100
#
# Epoch 58: loss did not improve from 0.00987
# 19/19 - 0s - loss: 0.0120 - val_loss: 0.0284 - 243ms/epoch - 13ms/step
# Epoch 59/100
#
# Epoch 59: loss did not improve from 0.00987
# 19/19 - 0s - loss: 0.0113 - val_loss: 0.0101 - 245ms/epoch - 13ms/step
# Epoch 60/100
#
# Epoch 60: loss did not improve from 0.00987
# 19/19 - 0s - loss: 0.0127 - val_loss: 0.0564 - 246ms/epoch - 13ms/step
# Epoch 61/100
#
# Epoch 61: loss did not improve from 0.00987
# 19/19 - 0s - loss: 0.0131 - val_loss: 0.0214 - 245ms/epoch - 13ms/step
# Epoch 62/100
#
# Epoch 62: loss did not improve from 0.00987
# 19/19 - 0s - loss: 0.0135 - val_loss: 0.0862 - 244ms/epoch - 13ms/step
# Epoch 63/100
#
# Epoch 63: loss did not improve from 0.00987
# 19/19 - 0s - loss: 0.0119 - val_loss: 0.0915 - 248ms/epoch - 13ms/step
# Epoch 64/100
#
# Epoch 64: loss did not improve from 0.00987
# 19/19 - 0s - loss: 0.0125 - val_loss: 0.0835 - 238ms/epoch - 13ms/step
# Epoch 65/100
#
# Epoch 65: loss did not improve from 0.00987
# 19/19 - 0s - loss: 0.0128 - val_loss: 0.0890 - 242ms/epoch - 13ms/step
# Epoch 66/100
#
# Epoch 66: loss did not improve from 0.00987
# 19/19 - 0s - loss: 0.0149 - val_loss: 0.0193 - 240ms/epoch - 13ms/step
# Epoch 67/100
#
# Epoch 67: loss did not improve from 0.00987
# 19/19 - 0s - loss: 0.0132 - val_loss: 0.0122 - 239ms/epoch - 13ms/step
# Epoch 68/100
#
# Epoch 68: loss did not improve from 0.00987
# 19/19 - 0s - loss: 0.0111 - val_loss: 0.0145 - 252ms/epoch - 13ms/step
# Epoch 69/100
#
# Epoch 69: loss did not improve from 0.00987
# 19/19 - 0s - loss: 0.0122 - val_loss: 0.0386 - 230ms/epoch - 12ms/step
# Epoch 70/100
#
# Epoch 70: loss did not improve from 0.00987
# 19/19 - 0s - loss: 0.0163 - val_loss: 0.0557 - 260ms/epoch - 14ms/step
# Epoch 71/100
#
# Epoch 71: loss did not improve from 0.00987
# 19/19 - 0s - loss: 0.0122 - val_loss: 0.0276 - 265ms/epoch - 14ms/step
# Epoch 72/100
#
# Epoch 72: loss improved from 0.00987 to 0.00943, saving model to ./Model/case_2/BiLSTM/model_8020\save_model.hdf5
# 19/19 - 0s - loss: 0.0094 - val_loss: 0.0203 - 319ms/epoch - 17ms/step
# Epoch 73/100
#
# Epoch 73: loss did not improve from 0.00943
# 19/19 - 0s - loss: 0.0117 - val_loss: 0.0094 - 247ms/epoch - 13ms/step
# Epoch 74/100
#
# Epoch 74: loss did not improve from 0.00943
# 19/19 - 0s - loss: 0.0123 - val_loss: 0.0111 - 262ms/epoch - 14ms/step
# Epoch 75/100
#
# Epoch 75: loss did not improve from 0.00943
# 19/19 - 0s - loss: 0.0125 - val_loss: 0.0653 - 257ms/epoch - 14ms/step
# Epoch 76/100
#
# Epoch 76: loss did not improve from 0.00943
# 19/19 - 0s - loss: 0.0109 - val_loss: 0.0100 - 288ms/epoch - 15ms/step
# Epoch 77/100
#
# Epoch 77: loss did not improve from 0.00943
# 19/19 - 0s - loss: 0.0136 - val_loss: 0.0213 - 272ms/epoch - 14ms/step
# Epoch 78/100
#
# Epoch 78: loss did not improve from 0.00943
# 19/19 - 0s - loss: 0.0121 - val_loss: 0.0717 - 279ms/epoch - 15ms/step
# Epoch 79/100
#
# Epoch 79: loss did not improve from 0.00943
# 19/19 - 0s - loss: 0.0119 - val_loss: 0.0373 - 283ms/epoch - 15ms/step
# Epoch 80/100
#
# Epoch 80: loss did not improve from 0.00943
# 19/19 - 0s - loss: 0.0153 - val_loss: 0.0454 - 275ms/epoch - 14ms/step
# Epoch 81/100
#
# Epoch 81: loss did not improve from 0.00943
# 19/19 - 0s - loss: 0.0137 - val_loss: 0.0184 - 267ms/epoch - 14ms/step
# Epoch 82/100
#
# Epoch 82: loss did not improve from 0.00943
# 19/19 - 0s - loss: 0.0127 - val_loss: 0.0162 - 260ms/epoch - 14ms/step
# Epoch 83/100
#
# Epoch 83: loss did not improve from 0.00943
# 19/19 - 0s - loss: 0.0097 - val_loss: 0.0560 - 275ms/epoch - 14ms/step
# Epoch 84/100
#
# Epoch 84: loss did not improve from 0.00943
# 19/19 - 0s - loss: 0.0131 - val_loss: 0.0553 - 281ms/epoch - 15ms/step
# Epoch 85/100
#
# Epoch 85: loss did not improve from 0.00943
# 19/19 - 0s - loss: 0.0124 - val_loss: 0.0183 - 252ms/epoch - 13ms/step
# Epoch 86/100
#
# Epoch 86: loss did not improve from 0.00943
# 19/19 - 0s - loss: 0.0111 - val_loss: 0.0617 - 278ms/epoch - 15ms/step
# Epoch 87/100
#
# Epoch 87: loss did not improve from 0.00943
# 19/19 - 0s - loss: 0.0132 - val_loss: 0.0133 - 276ms/epoch - 15ms/step
# Epoch 88/100
#
# Epoch 88: loss did not improve from 0.00943
# 19/19 - 0s - loss: 0.0134 - val_loss: 0.0627 - 276ms/epoch - 15ms/step
# Epoch 89/100
#
# Epoch 89: loss did not improve from 0.00943
# 19/19 - 0s - loss: 0.0121 - val_loss: 0.0339 - 253ms/epoch - 13ms/step
# Epoch 90/100
#
# Epoch 90: loss did not improve from 0.00943
# 19/19 - 0s - loss: 0.0129 - val_loss: 0.0367 - 261ms/epoch - 14ms/step
# Epoch 91/100
#
# Epoch 91: loss did not improve from 0.00943
# 19/19 - 0s - loss: 0.0128 - val_loss: 0.0755 - 276ms/epoch - 15ms/step
# Epoch 92/100
#
# Epoch 92: loss did not improve from 0.00943
# 19/19 - 0s - loss: 0.0129 - val_loss: 0.0128 - 254ms/epoch - 13ms/step
# Epoch 93/100
#
# Epoch 93: loss did not improve from 0.00943
# 19/19 - 0s - loss: 0.0121 - val_loss: 0.0257 - 251ms/epoch - 13ms/step
# Epoch 94/100
#
# Epoch 94: loss did not improve from 0.00943
# 19/19 - 0s - loss: 0.0120 - val_loss: 0.0139 - 253ms/epoch - 13ms/step
# Epoch 95/100
#
# Epoch 95: loss did not improve from 0.00943
# 19/19 - 0s - loss: 0.0114 - val_loss: 0.0307 - 267ms/epoch - 14ms/step
# Epoch 96/100
#
# Epoch 96: loss did not improve from 0.00943
# 19/19 - 0s - loss: 0.0110 - val_loss: 0.0421 - 271ms/epoch - 14ms/step
# Epoch 97/100
#
# Epoch 97: loss did not improve from 0.00943
# 19/19 - 0s - loss: 0.0138 - val_loss: 0.0727 - 265ms/epoch - 14ms/step
# Epoch 98/100
#
# Epoch 98: loss did not improve from 0.00943
# 19/19 - 0s - loss: 0.0112 - val_loss: 0.0489 - 261ms/epoch - 14ms/step
# Epoch 99/100
#
# Epoch 99: loss did not improve from 0.00943
# 19/19 - 0s - loss: 0.0105 - val_loss: 0.0385 - 267ms/epoch - 14ms/step
# Epoch 100/100
#
# Epoch 100: loss did not improve from 0.00943
# 19/19 - 0s - loss: 0.0109 - val_loss: 0.0617 - 286ms/epoch - 15ms/step
# Thời gian thực thi mô hình: 32.31 giây

# %%
#Model
final_model = load_model("./Model/case_2/BiLSTM/model_8020/save_model.hdf5")

# %%
#dữ liệu train
Y_train_predict = final_model.predict(X_train) #dự đoán trên tập đã train
Y_train_predict = sc.inverse_transform(Y_train_predict) #giá thực dự đoán
Y_train = sc.inverse_transform(Y_train) #giá thực train
# Out:
# 48/48 [==============================] - 1s 2ms/step

# %% [markdown]
# # DỰ ĐOÁN TRÊN TẬP TEST

# %%
#dữ liệu test
import time
start_model = time.time()  # Bắt đầu đo thời gian
Y_test_predict = final_model.predict(X_test)
end_model = time.time()  # Kết thúc đo thời gian
print(f"Thời gian thực thi mô hình: {end_model - start_model:.2f} giây")
Y_test_predict = sc.inverse_transform(Y_test_predict) #giá dự đoán
Y_test = sc.inverse_transform(Y_test) #giá thực
# Out:
# 12/12 [==============================] - 0s 4ms/step
# Thời gian thực thi mô hình: 0.09 giây

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import mean_absolute_error, mean_squared_error

# Tính toán các giá trị cho tập Train
mae_train = round(mean_absolute_error(Y_train, Y_train_predict), 3)
mse_train = round(mean_squared_error(Y_train, Y_train_predict), 3)
rmse_train = round(np.sqrt(mse_train), 3)

# Tính toán các giá trị cho tập Test
mae_test = round(mean_absolute_error(Y_test, Y_test_predict), 3)
mse_test = round(mean_squared_error(Y_test, Y_test_predict), 3)
rmse_test = round(np.sqrt(mse_test), 3)

# Tạo DataFrame để hiển thị kết quả
metrics = pd.DataFrame({
    "Tập dữ liệu": ["Train", "Test"],
    "MAE": [mae_train, mae_test],
    "MSE": [mse_train, mse_test],
    "RMSE": [rmse_train, rmse_test]
})

# In kết quả
print(metrics)
print(f"Thời gian thực thi mô hình: {end_model - start_model:.2f} giây")
# Out:
#   Tập dữ liệu     MAE       MSE    RMSE
# 0       Train  59.094  4349.982  65.954
# 1        Test  38.447  3277.232  57.247
# Thời gian thực thi mô hình: 0.09 giây

# %%
# Xác định 80% dữ liệu làm tập train
train_size = int(len(df_usd_ML) * 0.8)

# Cắt lại cho đúng chiều dài:
train_data1 = df_usd_ML[6:train_size-1].copy()
test_data1 = df_usd_ML[train_size+3:].copy()


print(len(train_data1), len(Y_train_predict))
print(len(test_data1), len(Y_test_predict))

# Cắt dữ liệu dự đoán để khớp với dữ liệu gốc
Y_train_predict = Y_train_predict[:len(train_data1)]
Y_test_predict = Y_test_predict[:len(test_data1)]

# Đảm bảo test_data1 có số lượng dòng khớp với Y_test_predict
test_data1 = test_data1.iloc[:len(Y_test_predict)]

plt.figure(figsize=(24,8))
plt.plot(df_usd_ML, label='Giá thực tế', color='red')  # đường giá thực

# Thêm dữ liệu dự đoán vào train_data1 và test_data1
train_data1["Dự đoán"] = Y_train_predict
plt.plot(train_data1["Dự đoán"], label='Giá dự đoán train', color='green')

test_data1["Dự đoán"] = Y_test_predict
plt.plot(test_data1["Dự đoán"], label='Giá dự đoán test', color='blue')

plt.title('So sánh giá dự báo và giá thực tế')
plt.xlabel('Thời gian')
plt.ylabel('Giá mua chuyển khoản (VNĐ)')
plt.legend()
plt.show()
# Out:
# 1521 1523
# 380 381

# %%
from tensorflow.keras.models import load_model

# Gọi lại mô hình đã lưu
loaded_model = load_model("./Model/case_2/BiLSTM/model_8020/save_model.hdf5")
# Dự đoán lại trên tập test
Y_test_predict = loaded_model.predict(X_test)
# Đảo chuẩn hóa (inverse transform)
Y_test_predict = sc.inverse_transform(Y_test_predict)

# Tạo bảng so sánh
compare_df = pd.DataFrame({
    "Giá thực tế": Y_test.flatten(),
    "Giá dự đoán": Y_test_predict.flatten()
})

# Làm tròn về số nguyên
compare_df = compare_df.astype(int)
pd.set_option('display.max_rows', None)
# Hiển thị toàn bộ bảng
display(compare_df)
compare_df.to_csv("./Model/case_2/BiLSTM/model_8020/predict.csv", index=False)
# Out:
# 12/12 [==============================] - 1s 2ms/step
#      Giá thực tế  Giá dự đoán
# 0          24790        24746
# 1          24830        24744
# 2          24840        24778
# 3          24840        24789
# 4          24840        24790
# 5          24960        24791
# 6          25008        24893
# 7          25130        24942
# 8          25130        25058
# 9          25163        25063
# 10         25163        25089
# 11         25163        25088
# 12         25175        25105
# 13         25178        25124
# 14         25177        25149
# 15         25167        25149
# 16         25118        25146
# 17         25118        25104
# 18         25118        25102
# 19         25118        25105
# 20         25118        25106
# 21         25118        25106
# 22         25144        25103
# 23         25143        25116
# 24         25147        25117
# 25         25147        25120
# 26         25157        25119
# 27         25155        25128
# 28         25161        25127
# 29         25178        25137
# 30         25184        25151
# 31         25184        25158
# 32         25184        25158
# 33         25179        25159
# 34         25182        25155
# 35         25182        25158
# 36         25152        25162
# 37         25250        25138
# 38         25250        25220
# 39         25250        25225
# 40         25259        25224
# 41         25263        25230
# 42         25266        25233
# 43         25250        25231
# 44         25277        25236
# 45         25277        25259
# 46         25277        25260
# 47         25281        25262
# 48         25268        25266
# 49         25265        25255
# 50         25250        25249
# 51         25254        25242
# 52         25254        25245
# 53         25254        25245
# 54         25234        25246
# 55         25218        25226
# 56         25213        25211
# 57         25213        25203
# 58         25213        25204
# 59         25213        25205
# 60         25213        25205
# 61         25214        25200
# 62         25222        25198
# 63         25226        25204
# 64         25217        25208
# 65         25221        25200
# 66         25221        25203
# 67         25221        25203
# 68         25231        25203
# 69         25251        25214
# 70         25249        25232
# 71         25247        25229
# 72         25248        25228
# 73         25248        25228
# 74         25248        25228
# 75         25255        25231
# 76         25245        25241
# 77         25250        25232
