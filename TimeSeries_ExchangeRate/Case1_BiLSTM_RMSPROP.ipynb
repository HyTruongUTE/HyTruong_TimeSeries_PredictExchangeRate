# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler #chuẩn hóa dữ liệu
from keras.callbacks import ModelCheckpoint #lưu lại huấn luyện tốt nhất
from tensorflow.keras.models import load_model #tải mô hình
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import ModelCheckpoint

import random
import tensorflow as tf

#các lớp để xây dựng mô hình
from keras.models import Sequential #đầu vào
from keras.layers import LSTM #học phụ thuộc
from keras.layers import Dropout, BatchNormalization #tránh học tủ
from keras.layers import Dense #đầu ra

#kiểm tra độ chính xác của mô hình
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
random.seed(42)
np.random.seed(42)
tf.random.set_seed(42)

# %%
df_usd = pd.read_parquet("./minio/usd/part-00000-18b834c3-cd6d-42ae-82c3-638999ff6d84-c000.snappy.parquet", engine="pyarrow")
df_usd.head()
# Out:
#         ngay ma_ngoai_te ten_ngoai_te  mua_chuyen_khoan      ban
# 0 2020-02-01         USD    US DOLLAR           23165.0  23305.0
# 1 2020-02-02         USD    US DOLLAR           23165.0  23305.0
# 2 2020-02-03         USD    US DOLLAR           23200.0  23340.0
# 3 2020-02-04         USD    US DOLLAR           23170.0  23310.0
# 4 2020-02-05         USD    US DOLLAR           23160.0  23300.0

# %%
df_usd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1911 entries, 0 to 1910
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ngay              1911 non-null   datetime64[ns]
#  1   ma_ngoai_te       1911 non-null   object
#  2   ten_ngoai_te      1911 non-null   object
#  3   mua_chuyen_khoan  1911 non-null   float64
#  4   ban               1911 non-null   float64
# dtypes: datetime64[ns](1), float64(2), object(2)
# memory usage: 74.8+ KB

# %%
df_usd.describe()
# Out:
#                       ngay  mua_chuyen_khoan           ban
# count                 1911       1911.000000   1911.000000
# mean   2022-09-13 00:00:00      23666.414443  23934.197279
# min    2020-02-01 00:00:00      22480.000000  22745.000000
# 25%    2021-05-23 12:00:00      22985.000000  23170.000000
# 50%    2022-09-13 00:00:00      23300.000000  23620.000000
# 75%    2024-01-03 12:00:00      24390.000000  24730.000000
# max    2025-04-25 00:00:00      25835.000000  26195.000000
# std                    NaN        885.147984    926.810272

# %%
print(df_usd.dtypes)
# Out:
# ngay                datetime64[ns]
# ma_ngoai_te                 object
# ten_ngoai_te                object
# mua_chuyen_khoan           float64
# ban                        float64
# dtype: object

# %%
import matplotlib.pyplot as plt
from matplotlib.dates import YearLocator, DateFormatter, MonthLocator

# Vẽ biểu đồ
plt.figure(figsize=(10, 5))
plt.plot(df_usd['ngay'].values, df_usd['mua_chuyen_khoan'].values, label='Giá mua chuyển khoản', color='red')

plt.xlabel('Năm')
plt.ylabel('Giá mua chuyển khoản')
plt.title('Biểu đồ tỷ giá VND_USD mua chuyển khoảng qua các năm')
plt.legend(loc='best')

# Định dạng trục x
plt.gca().xaxis.set_major_locator(YearLocator())
plt.gca().xaxis.set_major_formatter(DateFormatter('%Y'))
plt.gca().xaxis.set_minor_locator(MonthLocator())

plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
df_usd_ML = pd.DataFrame(df_usd, columns=['ngay','mua_chuyen_khoan'])
df_usd_ML.index = df_usd_ML.ngay
df_usd_ML.drop('ngay', axis = 1, inplace=True)
df_usd_ML.head()
# Out:
#             mua_chuyen_khoan
# ngay
# 2020-02-01           23165.0
# 2020-02-02           23165.0
# 2020-02-03           23200.0
# 2020-02-04           23170.0
# 2020-02-05           23160.0

# %%
print(df_usd_ML.columns)
# Out:
# Index(['mua_chuyen_khoan'], dtype='object')

# %%
data = df_usd_ML.values

# %%
data
# Out:
# array([[23165.],
#        [23165.],
#        [23200.],
#        ...,
#        [25781.],
#        [25814.],
#        [25835.]])

# %%
#hàm hóa dữ liệu
sc = MinMaxScaler(feature_range=(0,1))

#chuẩn hóa dữ train
scale_data = sc.fit_transform(data)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))

plt.plot(scale_data, label="Dữ liệu sau chuẩn hóa", color="red")

plt.xlabel("Thời gian (Index)")
plt.ylabel("Giá trị sau chuẩn hóa")
plt.title("Biểu đồ dữ liệu sau khi chuẩn hóa bằng MinMaxScaler")
plt.legend()
plt.show()

# %%
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Bidirectional, LSTM, Dense, Dropout

# Chọn window
window_size = 7
X_train, Y_train = [], []

for i in range(len(scale_data) - window_size):
    X_train.append(scale_data[i:i + window_size])
    Y_train.append(scale_data[i + window_size])

X_train = np.array(X_train)
Y_train = np.array(Y_train)

# Phân chia tập dữ liệu thành tập train và test
split_index = int(0.8 * len(X_train))

X_train, X_test = X_train[:split_index], X_train[split_index:]
Y_train, Y_test = Y_train[:split_index], Y_train[split_index:]

# Đảm bảo dữ liệu có đúng shape cho mô hình BiLSTM
X_train = X_train.reshape((X_train.shape[0], window_size, -1))
X_test = X_test.reshape((X_test.shape[0], window_size, -1))

# %%
print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
print("y_train shape:", Y_train.shape)
print("y_test shape:", Y_test.shape)
# Out:
# X_train shape: (1523, 7, 1)
# X_test shape: (381, 7, 1)
# y_train shape: (1523, 1)
# y_test shape: (381, 1)

# %%
print("Shape of X_train:", X_train.shape)
# Out:
# Shape of X_train: (1523, 7, 1)

# %% [markdown]
# # MODEL

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Bidirectional, BatchNormalization

# Xây dựng mô hình BiLSTM
model = Sequential()

# Lớp BiLSTM đầu tiên (return_sequences=True để kết nối lớp tiếp theo)
model.add(Bidirectional(LSTM(units=64, return_sequences=True, input_shape=(X_train.shape[1], 1))))
model.add(BatchNormalization())  # Ổn định dữ liệu đầu ra

# Lớp BiLSTM thứ hai
model.add(Bidirectional(LSTM(units=64)))
model.add(BatchNormalization())

# Dropout để giảm overfitting
model.add(Dropout(0.5))

# Lớp Dense đầu ra
model.add(Dense(1))

# Compile mô hình
model.compile(loss='mean_absolute_error', optimizer='rmsprop')

# %% [markdown]
# # huấn luyện mô hình

# %%
save_model = "./Model/case_1/BiLSTM/model_RMSPROP/save_model.hdf5"
best_model = ModelCheckpoint(save_model,monitor='loss',verbose=2,save_best_only=True,mode='auto')

import time
start_model = time.time()  # Bắt đầu đo thời gian
model.fit(X_train,Y_train,epochs=100,batch_size=50,validation_split=0.4,verbose=2,callbacks=[best_model])
end_model = time.time()  # Kết thúc đo thời gian
print(f"Thời gian thực thi mô hình: {end_model - start_model:.2f} giây")
# Out:
# Epoch 1/100
#
# Epoch 1: loss improved from inf to 1.05777, saving model to ./Model/case_1/BiLSTM/model_RMSPROP\save_model.hdf5
# 19/19 - 5s - loss: 1.0578 - val_loss: 0.2843 - 5s/epoch - 286ms/step
# Epoch 2/100
#
# Epoch 2: loss improved from 1.05777 to 0.83801, saving model to ./Model/case_1/BiLSTM/model_RMSPROP\save_model.hdf5
# 19/19 - 0s - loss: 0.8380 - val_loss: 0.2578 - 260ms/epoch - 14ms/step
# Epoch 3/100
#
# Epoch 3: loss improved from 0.83801 to 0.80119, saving model to ./Model/case_1/BiLSTM/model_RMSPROP\save_model.hdf5
# 19/19 - 0s - loss: 0.8012 - val_loss: 0.2712 - 253ms/epoch - 13ms/step
# Epoch 4/100
#
# Epoch 4: loss improved from 0.80119 to 0.78047, saving model to ./Model/case_1/BiLSTM/model_RMSPROP\save_model.hdf5
# 19/19 - 0s - loss: 0.7805 - val_loss: 0.2732 - 267ms/epoch - 14ms/step
# Epoch 5/100
#
# Epoch 5: loss improved from 0.78047 to 0.64657, saving model to ./Model/case_1/BiLSTM/model_RMSPROP\save_model.hdf5
# 19/19 - 0s - loss: 0.6466 - val_loss: 0.2788 - 255ms/epoch - 13ms/step
# Epoch 6/100
#
# Epoch 6: loss improved from 0.64657 to 0.52287, saving model to ./Model/case_1/BiLSTM/model_RMSPROP\save_model.hdf5
# 19/19 - 0s - loss: 0.5229 - val_loss: 0.3068 - 255ms/epoch - 13ms/step
# Epoch 7/100
#
# Epoch 7: loss improved from 0.52287 to 0.43608, saving model to ./Model/case_1/BiLSTM/model_RMSPROP\save_model.hdf5
# 19/19 - 0s - loss: 0.4361 - val_loss: 0.2918 - 260ms/epoch - 14ms/step
# Epoch 8/100
#
# Epoch 8: loss improved from 0.43608 to 0.28050, saving model to ./Model/case_1/BiLSTM/model_RMSPROP\save_model.hdf5
# 19/19 - 0s - loss: 0.2805 - val_loss: 0.3247 - 270ms/epoch - 14ms/step
# Epoch 9/100
#
# Epoch 9: loss improved from 0.28050 to 0.12690, saving model to ./Model/case_1/BiLSTM/model_RMSPROP\save_model.hdf5
# 19/19 - 0s - loss: 0.1269 - val_loss: 0.2772 - 256ms/epoch - 13ms/step
# Epoch 10/100
#
# Epoch 10: loss improved from 0.12690 to 0.06082, saving model to ./Model/case_1/BiLSTM/model_RMSPROP\save_model.hdf5
# 19/19 - 0s - loss: 0.0608 - val_loss: 0.2712 - 270ms/epoch - 14ms/step
# Epoch 11/100
#
# Epoch 11: loss improved from 0.06082 to 0.03087, saving model to ./Model/case_1/BiLSTM/model_RMSPROP\save_model.hdf5
# 19/19 - 0s - loss: 0.0309 - val_loss: 0.2202 - 260ms/epoch - 14ms/step
# Epoch 12/100
#
# Epoch 12: loss improved from 0.03087 to 0.02093, saving model to ./Model/case_1/BiLSTM/model_RMSPROP\save_model.hdf5
# 19/19 - 0s - loss: 0.0209 - val_loss: 0.1935 - 250ms/epoch - 13ms/step
# Epoch 13/100
#
# Epoch 13: loss did not improve from 0.02093
# 19/19 - 0s - loss: 0.0218 - val_loss: 0.1832 - 240ms/epoch - 13ms/step
# Epoch 14/100
#
# Epoch 14: loss did not improve from 0.02093
# 19/19 - 0s - loss: 0.0214 - val_loss: 0.1354 - 240ms/epoch - 13ms/step
# Epoch 15/100
#
# Epoch 15: loss improved from 0.02093 to 0.01769, saving model to ./Model/case_1/BiLSTM/model_RMSPROP\save_model.hdf5
# 19/19 - 0s - loss: 0.0177 - val_loss: 0.1126 - 258ms/epoch - 14ms/step
# Epoch 16/100
#
# Epoch 16: loss improved from 0.01769 to 0.01718, saving model to ./Model/case_1/BiLSTM/model_RMSPROP\save_model.hdf5
# 19/19 - 0s - loss: 0.0172 - val_loss: 0.0974 - 279ms/epoch - 15ms/step
# Epoch 17/100
#
# Epoch 17: loss improved from 0.01718 to 0.01702, saving model to ./Model/case_1/BiLSTM/model_RMSPROP\save_model.hdf5
# 19/19 - 0s - loss: 0.0170 - val_loss: 0.0907 - 324ms/epoch - 17ms/step
# Epoch 18/100
#
# Epoch 18: loss did not improve from 0.01702
# 19/19 - 0s - loss: 0.0195 - val_loss: 0.0854 - 276ms/epoch - 15ms/step
# Epoch 19/100
#
# Epoch 19: loss improved from 0.01702 to 0.01683, saving model to ./Model/case_1/BiLSTM/model_RMSPROP\save_model.hdf5
# 19/19 - 0s - loss: 0.0168 - val_loss: 0.1149 - 264ms/epoch - 14ms/step
# Epoch 20/100
#
# Epoch 20: loss did not improve from 0.01683
# 19/19 - 0s - loss: 0.0172 - val_loss: 0.1034 - 267ms/epoch - 14ms/step
# Epoch 21/100
#
# Epoch 21: loss improved from 0.01683 to 0.01550, saving model to ./Model/case_1/BiLSTM/model_RMSPROP\save_model.hdf5
# 19/19 - 0s - loss: 0.0155 - val_loss: 0.0861 - 305ms/epoch - 16ms/step
# Epoch 22/100
#
# Epoch 22: loss did not improve from 0.01550
# 19/19 - 0s - loss: 0.0178 - val_loss: 0.1638 - 250ms/epoch - 13ms/step
# Epoch 23/100
#
# Epoch 23: loss did not improve from 0.01550
# 19/19 - 0s - loss: 0.0164 - val_loss: 0.1352 - 251ms/epoch - 13ms/step
# Epoch 24/100
#
# Epoch 24: loss did not improve from 0.01550
# 19/19 - 0s - loss: 0.0158 - val_loss: 0.1356 - 250ms/epoch - 13ms/step
# Epoch 25/100
#
# Epoch 25: loss did not improve from 0.01550
# 19/19 - 0s - loss: 0.0175 - val_loss: 0.1028 - 264ms/epoch - 14ms/step
# Epoch 26/100
#
# Epoch 26: loss improved from 0.01550 to 0.01498, saving model to ./Model/case_1/BiLSTM/model_RMSPROP\save_model.hdf5
# 19/19 - 0s - loss: 0.0150 - val_loss: 0.1526 - 262ms/epoch - 14ms/step
# Epoch 27/100
#
# Epoch 27: loss did not improve from 0.01498
# 19/19 - 0s - loss: 0.0158 - val_loss: 0.1112 - 237ms/epoch - 12ms/step
# Epoch 28/100
#
# Epoch 28: loss did not improve from 0.01498
# 19/19 - 0s - loss: 0.0162 - val_loss: 0.0604 - 230ms/epoch - 12ms/step
# Epoch 29/100
#
# Epoch 29: loss improved from 0.01498 to 0.01456, saving model to ./Model/case_1/BiLSTM/model_RMSPROP\save_model.hdf5
# 19/19 - 0s - loss: 0.0146 - val_loss: 0.0523 - 260ms/epoch - 14ms/step
# Epoch 30/100
#
# Epoch 30: loss did not improve from 0.01456
# 19/19 - 0s - loss: 0.0159 - val_loss: 0.0386 - 243ms/epoch - 13ms/step
# Epoch 31/100
#
# Epoch 31: loss did not improve from 0.01456
# 19/19 - 0s - loss: 0.0178 - val_loss: 0.0519 - 258ms/epoch - 14ms/step
# Epoch 32/100
#
# Epoch 32: loss did not improve from 0.01456
# 19/19 - 0s - loss: 0.0165 - val_loss: 0.0470 - 270ms/epoch - 14ms/step
# Epoch 33/100
#
# Epoch 33: loss improved from 0.01456 to 0.01423, saving model to ./Model/case_1/BiLSTM/model_RMSPROP\save_model.hdf5
# 19/19 - 0s - loss: 0.0142 - val_loss: 0.0697 - 280ms/epoch - 15ms/step
# Epoch 34/100
#
# Epoch 34: loss did not improve from 0.01423
# 19/19 - 0s - loss: 0.0174 - val_loss: 0.0350 - 264ms/epoch - 14ms/step
# Epoch 35/100
#
# Epoch 35: loss did not improve from 0.01423
# 19/19 - 0s - loss: 0.0164 - val_loss: 0.0291 - 275ms/epoch - 14ms/step
# Epoch 36/100
#
# Epoch 36: loss did not improve from 0.01423
# 19/19 - 0s - loss: 0.0146 - val_loss: 0.0341 - 260ms/epoch - 14ms/step
# Epoch 37/100
#
# Epoch 37: loss did not improve from 0.01423
# 19/19 - 0s - loss: 0.0165 - val_loss: 0.0723 - 292ms/epoch - 15ms/step
# Epoch 38/100
#
# Epoch 38: loss did not improve from 0.01423
# 19/19 - 0s - loss: 0.0145 - val_loss: 0.0988 - 300ms/epoch - 16ms/step
# Epoch 39/100
#
# Epoch 39: loss did not improve from 0.01423
# 19/19 - 0s - loss: 0.0154 - val_loss: 0.0299 - 248ms/epoch - 13ms/step
# Epoch 40/100
#
# Epoch 40: loss did not improve from 0.01423
# 19/19 - 0s - loss: 0.0159 - val_loss: 0.0754 - 262ms/epoch - 14ms/step
# Epoch 41/100
#
# Epoch 41: loss improved from 0.01423 to 0.01406, saving model to ./Model/case_1/BiLSTM/model_RMSPROP\save_model.hdf5
# 19/19 - 0s - loss: 0.0141 - val_loss: 0.0544 - 268ms/epoch - 14ms/step
# Epoch 42/100
#
# Epoch 42: loss did not improve from 0.01406
# 19/19 - 0s - loss: 0.0167 - val_loss: 0.0401 - 240ms/epoch - 13ms/step
# Epoch 43/100
#
# Epoch 43: loss did not improve from 0.01406
# 19/19 - 0s - loss: 0.0147 - val_loss: 0.0447 - 291ms/epoch - 15ms/step
# Epoch 44/100
#
# Epoch 44: loss improved from 0.01406 to 0.01356, saving model to ./Model/case_1/BiLSTM/model_RMSPROP\save_model.hdf5
# 19/19 - 0s - loss: 0.0136 - val_loss: 0.0873 - 290ms/epoch - 15ms/step
# Epoch 45/100
#
# Epoch 45: loss did not improve from 0.01356
# 19/19 - 0s - loss: 0.0163 - val_loss: 0.0281 - 270ms/epoch - 14ms/step
# Epoch 46/100
#
# Epoch 46: loss improved from 0.01356 to 0.01334, saving model to ./Model/case_1/BiLSTM/model_RMSPROP\save_model.hdf5
# 19/19 - 0s - loss: 0.0133 - val_loss: 0.0661 - 281ms/epoch - 15ms/step
# Epoch 47/100
#
# Epoch 47: loss did not improve from 0.01334
# 19/19 - 0s - loss: 0.0135 - val_loss: 0.0209 - 250ms/epoch - 13ms/step
# Epoch 48/100
#
# Epoch 48: loss did not improve from 0.01334
# 19/19 - 0s - loss: 0.0155 - val_loss: 0.0112 - 270ms/epoch - 14ms/step
# Epoch 49/100
#
# Epoch 49: loss did not improve from 0.01334
# 19/19 - 0s - loss: 0.0141 - val_loss: 0.0501 - 265ms/epoch - 14ms/step
# Epoch 50/100
#
# Epoch 50: loss did not improve from 0.01334
# 19/19 - 0s - loss: 0.0149 - val_loss: 0.0282 - 253ms/epoch - 13ms/step
# Epoch 51/100
#
# Epoch 51: loss did not improve from 0.01334
# 19/19 - 0s - loss: 0.0166 - val_loss: 0.0154 - 240ms/epoch - 13ms/step
# Epoch 52/100
#
# Epoch 52: loss did not improve from 0.01334
# 19/19 - 0s - loss: 0.0141 - val_loss: 0.0564 - 251ms/epoch - 13ms/step
# Epoch 53/100
#
# Epoch 53: loss did not improve from 0.01334
# 19/19 - 0s - loss: 0.0153 - val_loss: 0.0288 - 271ms/epoch - 14ms/step
# Epoch 54/100
#
# Epoch 54: loss improved from 0.01334 to 0.01225, saving model to ./Model/case_1/BiLSTM/model_RMSPROP\save_model.hdf5
# 19/19 - 0s - loss: 0.0123 - val_loss: 0.0801 - 288ms/epoch - 15ms/step
# Epoch 55/100
#
# Epoch 55: loss did not improve from 0.01225
# 19/19 - 0s - loss: 0.0136 - val_loss: 0.0854 - 260ms/epoch - 14ms/step
# Epoch 56/100
#
# Epoch 56: loss did not improve from 0.01225
# 19/19 - 0s - loss: 0.0138 - val_loss: 0.0225 - 281ms/epoch - 15ms/step
# Epoch 57/100
#
# Epoch 57: loss did not improve from 0.01225
# 19/19 - 0s - loss: 0.0142 - val_loss: 0.0129 - 255ms/epoch - 13ms/step
# Epoch 58/100
#
# Epoch 58: loss did not improve from 0.01225
# 19/19 - 0s - loss: 0.0134 - val_loss: 0.0470 - 250ms/epoch - 13ms/step
# Epoch 59/100
#
# Epoch 59: loss did not improve from 0.01225
# 19/19 - 0s - loss: 0.0139 - val_loss: 0.0175 - 250ms/epoch - 13ms/step
# Epoch 60/100
#
# Epoch 60: loss did not improve from 0.01225
# 19/19 - 0s - loss: 0.0135 - val_loss: 0.0417 - 262ms/epoch - 14ms/step
# Epoch 61/100
#
# Epoch 61: loss did not improve from 0.01225
# 19/19 - 0s - loss: 0.0137 - val_loss: 0.0200 - 270ms/epoch - 14ms/step
# Epoch 62/100
#
# Epoch 62: loss did not improve from 0.01225
# 19/19 - 0s - loss: 0.0135 - val_loss: 0.1042 - 280ms/epoch - 15ms/step
# Epoch 63/100
#
# Epoch 63: loss did not improve from 0.01225
# 19/19 - 0s - loss: 0.0137 - val_loss: 0.0753 - 270ms/epoch - 14ms/step
# Epoch 64/100
#
# Epoch 64: loss did not improve from 0.01225
# 19/19 - 0s - loss: 0.0143 - val_loss: 0.1026 - 251ms/epoch - 13ms/step
# Epoch 65/100
#
# Epoch 65: loss did not improve from 0.01225
# 19/19 - 0s - loss: 0.0134 - val_loss: 0.0347 - 250ms/epoch - 13ms/step
# Epoch 66/100
#
# Epoch 66: loss did not improve from 0.01225
# 19/19 - 0s - loss: 0.0137 - val_loss: 0.0540 - 250ms/epoch - 13ms/step
# Epoch 67/100
#
# Epoch 67: loss improved from 0.01225 to 0.01103, saving model to ./Model/case_1/BiLSTM/model_RMSPROP\save_model.hdf5
# 19/19 - 0s - loss: 0.0110 - val_loss: 0.2473 - 280ms/epoch - 15ms/step
# Epoch 68/100
#
# Epoch 68: loss did not improve from 0.01103
# 19/19 - 0s - loss: 0.0136 - val_loss: 0.0618 - 250ms/epoch - 13ms/step
# Epoch 69/100
#
# Epoch 69: loss did not improve from 0.01103
# 19/19 - 0s - loss: 0.0124 - val_loss: 0.0546 - 260ms/epoch - 14ms/step
# Epoch 70/100
#
# Epoch 70: loss did not improve from 0.01103
# 19/19 - 0s - loss: 0.0137 - val_loss: 0.0521 - 248ms/epoch - 13ms/step
# Epoch 71/100
#
# Epoch 71: loss did not improve from 0.01103
# 19/19 - 0s - loss: 0.0128 - val_loss: 0.0674 - 247ms/epoch - 13ms/step
# Epoch 72/100
#
# Epoch 72: loss did not improve from 0.01103
# 19/19 - 0s - loss: 0.0115 - val_loss: 0.0669 - 262ms/epoch - 14ms/step
# Epoch 73/100
#
# Epoch 73: loss did not improve from 0.01103
# 19/19 - 0s - loss: 0.0136 - val_loss: 0.0255 - 263ms/epoch - 14ms/step
# Epoch 74/100
#
# Epoch 74: loss did not improve from 0.01103
# 19/19 - 0s - loss: 0.0136 - val_loss: 0.0636 - 261ms/epoch - 14ms/step
# Epoch 75/100
#
# Epoch 75: loss did not improve from 0.01103
# 19/19 - 0s - loss: 0.0119 - val_loss: 0.0189 - 292ms/epoch - 15ms/step
# Epoch 76/100
#
# Epoch 76: loss did not improve from 0.01103
# 19/19 - 0s - loss: 0.0117 - val_loss: 0.0083 - 270ms/epoch - 14ms/step
# Epoch 77/100
#
# Epoch 77: loss did not improve from 0.01103
# 19/19 - 0s - loss: 0.0157 - val_loss: 0.0167 - 241ms/epoch - 13ms/step
# Epoch 78/100
#
# Epoch 78: loss did not improve from 0.01103
# 19/19 - 0s - loss: 0.0135 - val_loss: 0.0133 - 244ms/epoch - 13ms/step
# Epoch 79/100
#
# Epoch 79: loss did not improve from 0.01103
# 19/19 - 0s - loss: 0.0138 - val_loss: 0.0382 - 240ms/epoch - 13ms/step
# Epoch 80/100
#
# Epoch 80: loss did not improve from 0.01103
# 19/19 - 0s - loss: 0.0128 - val_loss: 0.0478 - 250ms/epoch - 13ms/step
# Epoch 81/100
#
# Epoch 81: loss did not improve from 0.01103
# 19/19 - 0s - loss: 0.0145 - val_loss: 0.0714 - 260ms/epoch - 14ms/step
# Epoch 82/100
#
# Epoch 82: loss did not improve from 0.01103
# 19/19 - 0s - loss: 0.0129 - val_loss: 0.0513 - 250ms/epoch - 13ms/step
# Epoch 83/100
#
# Epoch 83: loss did not improve from 0.01103
# 19/19 - 0s - loss: 0.0119 - val_loss: 0.0167 - 252ms/epoch - 13ms/step
# Epoch 84/100
#
# Epoch 84: loss did not improve from 0.01103
# 19/19 - 0s - loss: 0.0146 - val_loss: 0.2710 - 258ms/epoch - 14ms/step
# Epoch 85/100
#
# Epoch 85: loss did not improve from 0.01103
# 19/19 - 0s - loss: 0.0142 - val_loss: 0.0453 - 250ms/epoch - 13ms/step
# Epoch 86/100
#
# Epoch 86: loss did not improve from 0.01103
# 19/19 - 0s - loss: 0.0130 - val_loss: 0.0177 - 253ms/epoch - 13ms/step
# Epoch 87/100
#
# Epoch 87: loss did not improve from 0.01103
# 19/19 - 0s - loss: 0.0130 - val_loss: 0.0167 - 240ms/epoch - 13ms/step
# Epoch 88/100
#
# Epoch 88: loss did not improve from 0.01103
# 19/19 - 0s - loss: 0.0156 - val_loss: 0.0365 - 264ms/epoch - 14ms/step
# Epoch 89/100
#
# Epoch 89: loss did not improve from 0.01103
# 19/19 - 0s - loss: 0.0128 - val_loss: 0.0812 - 244ms/epoch - 13ms/step
# Epoch 90/100
#
# Epoch 90: loss did not improve from 0.01103
# 19/19 - 0s - loss: 0.0135 - val_loss: 0.1732 - 270ms/epoch - 14ms/step
# Epoch 91/100
#
# Epoch 91: loss improved from 0.01103 to 0.01094, saving model to ./Model/case_1/BiLSTM/model_RMSPROP\save_model.hdf5
# 19/19 - 0s - loss: 0.0109 - val_loss: 0.1324 - 280ms/epoch - 15ms/step
# Epoch 92/100
#
# Epoch 92: loss did not improve from 0.01094
# 19/19 - 0s - loss: 0.0126 - val_loss: 0.0198 - 254ms/epoch - 13ms/step
# Epoch 93/100
#
# Epoch 93: loss did not improve from 0.01094
# 19/19 - 0s - loss: 0.0129 - val_loss: 0.0940 - 250ms/epoch - 13ms/step
# Epoch 94/100
#
# Epoch 94: loss did not improve from 0.01094
# 19/19 - 0s - loss: 0.0134 - val_loss: 0.0292 - 260ms/epoch - 14ms/step
# Epoch 95/100
#
# Epoch 95: loss did not improve from 0.01094
# 19/19 - 0s - loss: 0.0124 - val_loss: 0.0197 - 270ms/epoch - 14ms/step
# Epoch 96/100
#
# Epoch 96: loss did not improve from 0.01094
# 19/19 - 0s - loss: 0.0120 - val_loss: 0.0790 - 261ms/epoch - 14ms/step
# Epoch 97/100
#
# Epoch 97: loss did not improve from 0.01094
# 19/19 - 0s - loss: 0.0148 - val_loss: 0.0829 - 259ms/epoch - 14ms/step
# Epoch 98/100
#
# Epoch 98: loss did not improve from 0.01094
# 19/19 - 0s - loss: 0.0121 - val_loss: 0.0167 - 255ms/epoch - 13ms/step
# Epoch 99/100
#
# Epoch 99: loss improved from 0.01094 to 0.01088, saving model to ./Model/case_1/BiLSTM/model_RMSPROP\save_model.hdf5
# 19/19 - 0s - loss: 0.0109 - val_loss: 0.0739 - 280ms/epoch - 15ms/step
# Epoch 100/100
#
# Epoch 100: loss did not improve from 0.01088
# 19/19 - 0s - loss: 0.0115 - val_loss: 0.0177 - 250ms/epoch - 13ms/step
# Thời gian thực thi mô hình: 31.56 giây

# %%
#Model
final_model = load_model("./Model/case_1/BiLSTM/model_RMSPROP/save_model.hdf5")

# %%
#dữ liệu train
Y_train_predict = final_model.predict(X_train) #dự đoán trên tập đã train
Y_train_predict = sc.inverse_transform(Y_train_predict) #giá thực dự đoán
Y_train = sc.inverse_transform(Y_train) #giá thực train
# Out:
# 48/48 [==============================] - 1s 2ms/step

# %% [markdown]
# # DỰ ĐOÁN TRÊN TẬP TEST

# %%
#dữ liệu test
import time
start_model = time.time()  # Bắt đầu đo thời gian
Y_test_predict = final_model.predict(X_test)
end_model = time.time()  # Kết thúc đo thời gian
print(f"Thời gian thực thi mô hình: {end_model - start_model:.2f} giây")
Y_test_predict = sc.inverse_transform(Y_test_predict) #giá dự đoán
Y_test = sc.inverse_transform(Y_test) #giá thực
# Out:
# 12/12 [==============================] - 0s 3ms/step
# Thời gian thực thi mô hình: 0.09 giây

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import mean_absolute_error, mean_squared_error

# Tính toán các giá trị cho tập Train
mae_train = round(mean_absolute_error(Y_train, Y_train_predict), 3)
mse_train = round(mean_squared_error(Y_train, Y_train_predict), 3)
rmse_train = round(np.sqrt(mse_train), 3)

# Tính toán các giá trị cho tập Test
mae_test = round(mean_absolute_error(Y_test, Y_test_predict), 3)
mse_test = round(mean_squared_error(Y_test, Y_test_predict), 3)
rmse_test = round(np.sqrt(mse_test), 3)

# Tạo DataFrame để hiển thị kết quả
metrics = pd.DataFrame({
    "Tập dữ liệu": ["Train", "Test"],
    "MAE": [mae_train, mae_test],
    "MSE": [mse_train, mse_test],
    "RMSE": [rmse_train, rmse_test]
})

# In kết quả
print(metrics)
print(f"Thời gian thực thi mô hình: {end_model - start_model:.2f} giây")
# Out:
#   Tập dữ liệu      MAE         MSE     RMSE
# 0       Train  147.853   34133.104  184.751
# 1        Test  514.195  269871.937  519.492
# Thời gian thực thi mô hình: 0.09 giây

# %%
# Xác định 80% dữ liệu làm tập train
train_size = int(len(df_usd_ML) * 0.8)

# Cắt lại cho đúng chiều dài:
train_data1 = df_usd_ML[6:train_size+1].copy()
test_data1 = df_usd_ML[train_size+2:].copy()

print(len(train_data1), len(Y_train_predict))
print(len(test_data1), len(Y_test_predict))


plt.figure(figsize=(24,8))
plt.plot(df_usd_ML,label='Giá thực tế',color='red') #đường giá thực
train_data1['Dự đoán'] = Y_train_predict #thêm dữ liệu
plt.plot(train_data1['Dự đoán'],label='Giá dự đoán train',color='green') #đường giá dự báo train
test_data1['Dự đoán'] = Y_test_predict #thêm dữ liệu
plt.plot(test_data1['Dự đoán'],label='Giá dự đoán test',color='blue') #đường giá dự báo test
plt.title('So sánh giá dự báo và giá thực tế') #đặt tên biểu đồ
plt.xlabel('Thời gian') #đặt tên hàm x
plt.ylabel('Giá mua chuyển khoản (VNĐ)') #đặt tên hàm y
plt.legend() #chú thích
plt.show()
# Out:
# 1523 1523
# 381 381

# %%
from tensorflow.keras.models import load_model

# Gọi lại mô hình đã lưu
loaded_model = load_model("./Model/case_1/BiLSTM/model_RMSPROP/save_model.hdf5")
# Dự đoán lại trên tập test
Y_test_predict = loaded_model.predict(X_test)
# Đảo chuẩn hóa (inverse transform)
Y_test_predict = sc.inverse_transform(Y_test_predict)

# Tạo bảng so sánh
compare_df = pd.DataFrame({
    "Giá thực tế": Y_test.flatten(),
    "Giá dự đoán": Y_test_predict.flatten()
})

# Làm tròn về số nguyên
compare_df = compare_df.astype(int)
pd.set_option('display.max_rows', None)
# Hiển thị toàn bộ bảng
display(compare_df)
compare_df.to_csv("./Model/case_1/BiLSTM/model_RMSPROP/predict.csv", index=False)
# Out:
# 12/12 [==============================] - 1s 3ms/step
#      Giá thực tế  Giá dự đoán
# 0          24790        24344
# 1          24830        24344
# 2          24840        24370
# 3          24840        24380
# 4          24840        24382
# 5          24960        24383
# 6          25008        24463
# 7          25130        24503
# 8          25130        24594
# 9          25163        24607
# 10         25163        24634
# 11         25163        24637
# 12         25175        24639
# 13         25178        24646
# 14         25177        24651
# 15         25167        24651
# 16         25118        24645
# 17         25118        24611
# 18         25118        24607
# 19         25118        24605
# 20         25118        24605
# 21         25118        24605
# 22         25144        24605
# 23         25143        24622
# 24         25147        24623
# 25         25147        24627
# 26         25157        24627
# 27         25155        24634
# 28         25161        24633
# 29         25178        24638
# 30         25184        24650
# 31         25184        24655
# 32         25184        24656
# 33         25179        24657
# 34         25182        24654
# 35         25182        24655
# 36         25152        24655
# 37         25250        24635
# 38         25250        24699
# 39         25250        24705
# 40         25259        24709
# 41         25263        24716
# 42         25266        24719
# 43         25250        24721
# 44         25277        24712
# 45         25277        24729
# 46         25277        24730
# 47         25281        24731
# 48         25268        24734
# 49         25265        24726
# 50         25250        24723
# 51         25254        24712
# 52         25254        24713
# 53         25254        24713
# 54         25234        24713
# 55         25218        24700
