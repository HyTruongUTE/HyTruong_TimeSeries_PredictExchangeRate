# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler #chuẩn hóa dữ liệu
from keras.callbacks import ModelCheckpoint #lưu lại huấn luyện tốt nhất
from tensorflow.keras.models import load_model #tải mô hình
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import ModelCheckpoint

import random
import tensorflow as tf

#các lớp để xây dựng mô hình
from keras.models import Sequential #đầu vào
from keras.layers import LSTM #học phụ thuộc
from keras.layers import Dropout, BatchNormalization #tránh học tủ
from keras.layers import Dense #đầu ra

#kiểm tra độ chính xác của mô hình
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
random.seed(42)
np.random.seed(42)
tf.random.set_seed(42)

# %%
df_usd = pd.read_parquet("./minio/usd/part-00000-18b834c3-cd6d-42ae-82c3-638999ff6d84-c000.snappy.parquet", engine="pyarrow")
df_usd.head()
# Out:
#         ngay ma_ngoai_te ten_ngoai_te  mua_chuyen_khoan      ban
# 0 2020-02-01         USD    US DOLLAR           23165.0  23305.0
# 1 2020-02-02         USD    US DOLLAR           23165.0  23305.0
# 2 2020-02-03         USD    US DOLLAR           23200.0  23340.0
# 3 2020-02-04         USD    US DOLLAR           23170.0  23310.0
# 4 2020-02-05         USD    US DOLLAR           23160.0  23300.0

# %%
df_usd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1911 entries, 0 to 1910
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ngay              1911 non-null   datetime64[ns]
#  1   ma_ngoai_te       1911 non-null   object
#  2   ten_ngoai_te      1911 non-null   object
#  3   mua_chuyen_khoan  1911 non-null   float64
#  4   ban               1911 non-null   float64
# dtypes: datetime64[ns](1), float64(2), object(2)
# memory usage: 74.8+ KB

# %%
df_usd.describe()
# Out:
#                       ngay  mua_chuyen_khoan           ban
# count                 1911       1911.000000   1911.000000
# mean   2022-09-13 00:00:00      23666.414443  23934.197279
# min    2020-02-01 00:00:00      22480.000000  22745.000000
# 25%    2021-05-23 12:00:00      22985.000000  23170.000000
# 50%    2022-09-13 00:00:00      23300.000000  23620.000000
# 75%    2024-01-03 12:00:00      24390.000000  24730.000000
# max    2025-04-25 00:00:00      25835.000000  26195.000000
# std                    NaN        885.147984    926.810272

# %%
print(df_usd.dtypes)
# Out:
# ngay                datetime64[ns]
# ma_ngoai_te                 object
# ten_ngoai_te                object
# mua_chuyen_khoan           float64
# ban                        float64
# dtype: object

# %%
import matplotlib.pyplot as plt
from matplotlib.dates import YearLocator, DateFormatter, MonthLocator

# Vẽ biểu đồ
plt.figure(figsize=(10, 5))
plt.plot(df_usd['ngay'].values, df_usd['mua_chuyen_khoan'].values, label='Giá mua chuyển khoản', color='red')

plt.xlabel('Năm')
plt.ylabel('Giá mua chuyển khoản')
plt.title('Biểu đồ tỷ giá VND_USD mua chuyển khoảng qua các năm')
plt.legend(loc='best')

# Định dạng trục x
plt.gca().xaxis.set_major_locator(YearLocator())
plt.gca().xaxis.set_major_formatter(DateFormatter('%Y'))
plt.gca().xaxis.set_minor_locator(MonthLocator())

plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
df_usd_ML = pd.DataFrame(df_usd, columns=['ngay','mua_chuyen_khoan'])
df_usd_ML.index = df_usd_ML.ngay
df_usd_ML.drop('ngay', axis = 1, inplace=True)
df_usd_ML.head()
# Out:
#             mua_chuyen_khoan
# ngay
# 2020-02-01           23165.0
# 2020-02-02           23165.0
# 2020-02-03           23200.0
# 2020-02-04           23170.0
# 2020-02-05           23160.0

# %%
print(df_usd_ML.columns)
# Out:
# Index(['mua_chuyen_khoan'], dtype='object')

# %%
data = df_usd_ML.values

# %%
data
# Out:
# array([[23165.],
#        [23165.],
#        [23200.],
#        ...,
#        [25781.],
#        [25814.],
#        [25835.]])

# %%
#hàm hóa dữ liệu
sc = MinMaxScaler(feature_range=(0,1))

#chuẩn hóa dữ train
scale_data = sc.fit_transform(data)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))

plt.plot(scale_data, label="Dữ liệu sau chuẩn hóa", color="red")

plt.xlabel("Thời gian (Index)")
plt.ylabel("Giá trị sau chuẩn hóa")
plt.title("Biểu đồ dữ liệu sau khi chuẩn hóa bằng MinMaxScaler")
plt.legend()
plt.show()

# %%
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Bidirectional, LSTM, Dense, Dropout

# Chọn window
window_size = 7
X_train, Y_train = [], []

for i in range(len(scale_data) - window_size):
    X_train.append(scale_data[i:i + window_size])
    Y_train.append(scale_data[i + window_size])

X_train = np.array(X_train)
Y_train = np.array(Y_train)

# Phân chia tập dữ liệu thành tập train và test 80 - 20
split_index = int(0.8 * len(X_train))

X_train, X_test = X_train[:split_index], X_train[split_index:]
Y_train, Y_test = Y_train[:split_index], Y_train[split_index:]

# Đảm bảo dữ liệu có đúng shape cho mô hình BiLSTM
X_train = X_train.reshape((X_train.shape[0], window_size, -1))
X_test = X_test.reshape((X_test.shape[0], window_size, -1))

# %%
print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
print("y_train shape:", Y_train.shape)
print("y_test shape:", Y_test.shape)
# Out:
# X_train shape: (1523, 7, 1)
# X_test shape: (381, 7, 1)
# y_train shape: (1523, 1)
# y_test shape: (381, 1)

# %% [markdown]
# # MODEL

# %%
#xây dựng mô hình
model = Sequential() #tạo lớp mạng cho dữ liệu đầu vào
#2 lớp LSTM
model.add(LSTM(units=128,input_shape=(X_train.shape[1],1),return_sequences=True))
model.add(LSTM(units=64))
model.add(Dropout(0.5)) #loại bỏ 1 số đơn vị tránh học tủ (overfitting)
model.add(Dense(1)) #output đầu ra 1 chiều
#đo sai số tuyệt đối trung bình có sử dụng trình tối ưu hóa rmsprop
model.compile(loss='mean_absolute_error',optimizer='rmsprop')

# %% [markdown]
# # huấn luyện mô hình

# %%
#huấn luyện mô hình
save_model = "./Model/case_2/LSTM/model_8020/save_model.hdf5"
best_model = ModelCheckpoint(save_model,monitor='loss',verbose=2,save_best_only=True,mode='auto')

import time
start_model = time.time()  # Bắt đầu đo thời gian
model.fit(X_train,Y_train,epochs=100,batch_size=50,validation_split=0.4,verbose=2,callbacks=[best_model])
end_model = time.time()  # Kết thúc đo thời gian
print(f"Thời gian thực thi mô hình: {end_model - start_model:.2f} giây")
# Out:
# Epoch 1/100
#
# Epoch 1: loss improved from inf to 0.04575, saving model to ./Model/case_2/LSTM/model_8020\save_model.hdf5
# 19/19 - 3s - loss: 0.0458 - val_loss: 0.1227 - 3s/epoch - 144ms/step
# Epoch 2/100
#
# Epoch 2: loss improved from 0.04575 to 0.02802, saving model to ./Model/case_2/LSTM/model_8020\save_model.hdf5
# 19/19 - 0s - loss: 0.0280 - val_loss: 0.0310 - 215ms/epoch - 11ms/step
# Epoch 3/100
#
# Epoch 3: loss improved from 0.02802 to 0.02373, saving model to ./Model/case_2/LSTM/model_8020\save_model.hdf5
# 19/19 - 0s - loss: 0.0237 - val_loss: 0.0645 - 220ms/epoch - 12ms/step
# Epoch 4/100
#
# Epoch 4: loss did not improve from 0.02373
# 19/19 - 0s - loss: 0.0239 - val_loss: 0.0190 - 201ms/epoch - 11ms/step
# Epoch 5/100
#
# Epoch 5: loss improved from 0.02373 to 0.02330, saving model to ./Model/case_2/LSTM/model_8020\save_model.hdf5
# 19/19 - 0s - loss: 0.0233 - val_loss: 0.0207 - 217ms/epoch - 11ms/step
# Epoch 6/100
#
# Epoch 6: loss improved from 0.02330 to 0.02120, saving model to ./Model/case_2/LSTM/model_8020\save_model.hdf5
# 19/19 - 0s - loss: 0.0212 - val_loss: 0.0169 - 218ms/epoch - 11ms/step
# Epoch 7/100
#
# Epoch 7: loss did not improve from 0.02120
# 19/19 - 0s - loss: 0.0230 - val_loss: 0.0453 - 213ms/epoch - 11ms/step
# Epoch 8/100
#
# Epoch 8: loss improved from 0.02120 to 0.02060, saving model to ./Model/case_2/LSTM/model_8020\save_model.hdf5
# 19/19 - 0s - loss: 0.0206 - val_loss: 0.0259 - 222ms/epoch - 12ms/step
# Epoch 9/100
#
# Epoch 9: loss did not improve from 0.02060
# 19/19 - 0s - loss: 0.0220 - val_loss: 0.0252 - 209ms/epoch - 11ms/step
# Epoch 10/100
#
# Epoch 10: loss improved from 0.02060 to 0.01946, saving model to ./Model/case_2/LSTM/model_8020\save_model.hdf5
# 19/19 - 0s - loss: 0.0195 - val_loss: 0.0284 - 221ms/epoch - 12ms/step
# Epoch 11/100
#
# Epoch 11: loss did not improve from 0.01946
# 19/19 - 0s - loss: 0.0206 - val_loss: 0.0514 - 211ms/epoch - 11ms/step
# Epoch 12/100
#
# Epoch 12: loss did not improve from 0.01946
# 19/19 - 0s - loss: 0.0200 - val_loss: 0.0911 - 208ms/epoch - 11ms/step
# Epoch 13/100
#
# Epoch 13: loss improved from 0.01946 to 0.01804, saving model to ./Model/case_2/LSTM/model_8020\save_model.hdf5
# 19/19 - 0s - loss: 0.0180 - val_loss: 0.0166 - 245ms/epoch - 13ms/step
# Epoch 14/100
#
# Epoch 14: loss did not improve from 0.01804
# 19/19 - 0s - loss: 0.0191 - val_loss: 0.0438 - 219ms/epoch - 12ms/step
# Epoch 15/100
#
# Epoch 15: loss improved from 0.01804 to 0.01765, saving model to ./Model/case_2/LSTM/model_8020\save_model.hdf5
# 19/19 - 0s - loss: 0.0176 - val_loss: 0.0386 - 231ms/epoch - 12ms/step
# Epoch 16/100
#
# Epoch 16: loss did not improve from 0.01765
# 19/19 - 0s - loss: 0.0180 - val_loss: 0.0437 - 219ms/epoch - 12ms/step
# Epoch 17/100
#
# Epoch 17: loss improved from 0.01765 to 0.01730, saving model to ./Model/case_2/LSTM/model_8020\save_model.hdf5
# 19/19 - 0s - loss: 0.0173 - val_loss: 0.0161 - 227ms/epoch - 12ms/step
# Epoch 18/100
#
# Epoch 18: loss did not improve from 0.01730
# 19/19 - 0s - loss: 0.0182 - val_loss: 0.0154 - 225ms/epoch - 12ms/step
# Epoch 19/100
#
# Epoch 19: loss improved from 0.01730 to 0.01697, saving model to ./Model/case_2/LSTM/model_8020\save_model.hdf5
# 19/19 - 0s - loss: 0.0170 - val_loss: 0.0451 - 234ms/epoch - 12ms/step
# Epoch 20/100
#
# Epoch 20: loss did not improve from 0.01697
# 19/19 - 0s - loss: 0.0171 - val_loss: 0.0247 - 227ms/epoch - 12ms/step
# Epoch 21/100
#
# Epoch 21: loss improved from 0.01697 to 0.01567, saving model to ./Model/case_2/LSTM/model_8020\save_model.hdf5
# 19/19 - 0s - loss: 0.0157 - val_loss: 0.0170 - 235ms/epoch - 12ms/step
# Epoch 22/100
#
# Epoch 22: loss did not improve from 0.01567
# 19/19 - 0s - loss: 0.0158 - val_loss: 0.0204 - 228ms/epoch - 12ms/step
# Epoch 23/100
#
# Epoch 23: loss did not improve from 0.01567
# 19/19 - 0s - loss: 0.0162 - val_loss: 0.0156 - 218ms/epoch - 11ms/step
# Epoch 24/100
#
# Epoch 24: loss improved from 0.01567 to 0.01550, saving model to ./Model/case_2/LSTM/model_8020\save_model.hdf5
# 19/19 - 0s - loss: 0.0155 - val_loss: 0.0442 - 247ms/epoch - 13ms/step
# Epoch 25/100
#
# Epoch 25: loss did not improve from 0.01550
# 19/19 - 0s - loss: 0.0161 - val_loss: 0.0176 - 236ms/epoch - 12ms/step
# Epoch 26/100
#
# Epoch 26: loss improved from 0.01550 to 0.01550, saving model to ./Model/case_2/LSTM/model_8020\save_model.hdf5
# 19/19 - 0s - loss: 0.0155 - val_loss: 0.0485 - 242ms/epoch - 13ms/step
# Epoch 27/100
#
# Epoch 27: loss improved from 0.01550 to 0.01496, saving model to ./Model/case_2/LSTM/model_8020\save_model.hdf5
# 19/19 - 0s - loss: 0.0150 - val_loss: 0.0489 - 249ms/epoch - 13ms/step
# Epoch 28/100
#
# Epoch 28: loss did not improve from 0.01496
# 19/19 - 0s - loss: 0.0151 - val_loss: 0.0474 - 219ms/epoch - 12ms/step
# Epoch 29/100
#
# Epoch 29: loss improved from 0.01496 to 0.01469, saving model to ./Model/case_2/LSTM/model_8020\save_model.hdf5
# 19/19 - 0s - loss: 0.0147 - val_loss: 0.0396 - 225ms/epoch - 12ms/step
# Epoch 30/100
#
# Epoch 30: loss did not improve from 0.01469
# 19/19 - 0s - loss: 0.0153 - val_loss: 0.0261 - 214ms/epoch - 11ms/step
# Epoch 31/100
#
# Epoch 31: loss improved from 0.01469 to 0.01329, saving model to ./Model/case_2/LSTM/model_8020\save_model.hdf5
# 19/19 - 0s - loss: 0.0133 - val_loss: 0.0383 - 232ms/epoch - 12ms/step
# Epoch 32/100
#
# Epoch 32: loss did not improve from 0.01329
# 19/19 - 0s - loss: 0.0150 - val_loss: 0.0313 - 227ms/epoch - 12ms/step
# Epoch 33/100
#
# Epoch 33: loss did not improve from 0.01329
# 19/19 - 0s - loss: 0.0144 - val_loss: 0.0270 - 231ms/epoch - 12ms/step
# Epoch 34/100
#
# Epoch 34: loss did not improve from 0.01329
# 19/19 - 0s - loss: 0.0142 - val_loss: 0.0243 - 223ms/epoch - 12ms/step
# Epoch 35/100
#
# Epoch 35: loss improved from 0.01329 to 0.01283, saving model to ./Model/case_2/LSTM/model_8020\save_model.hdf5
# 19/19 - 0s - loss: 0.0128 - val_loss: 0.0159 - 228ms/epoch - 12ms/step
# Epoch 36/100
#
# Epoch 36: loss did not improve from 0.01283
# 19/19 - 0s - loss: 0.0134 - val_loss: 0.0571 - 222ms/epoch - 12ms/step
# Epoch 37/100
#
# Epoch 37: loss did not improve from 0.01283
# 19/19 - 0s - loss: 0.0131 - val_loss: 0.0405 - 222ms/epoch - 12ms/step
# Epoch 38/100
#
# Epoch 38: loss did not improve from 0.01283
# 19/19 - 0s - loss: 0.0132 - val_loss: 0.0525 - 205ms/epoch - 11ms/step
# Epoch 39/100
#
# Epoch 39: loss did not improve from 0.01283
# 19/19 - 0s - loss: 0.0136 - val_loss: 0.0137 - 209ms/epoch - 11ms/step
# Epoch 40/100
#
# Epoch 40: loss improved from 0.01283 to 0.01219, saving model to ./Model/case_2/LSTM/model_8020\save_model.hdf5
# 19/19 - 0s - loss: 0.0122 - val_loss: 0.0240 - 234ms/epoch - 12ms/step
# Epoch 41/100
#
# Epoch 41: loss did not improve from 0.01219
# 19/19 - 0s - loss: 0.0135 - val_loss: 0.0152 - 217ms/epoch - 11ms/step
# Epoch 42/100
#
# Epoch 42: loss did not improve from 0.01219
# 19/19 - 0s - loss: 0.0129 - val_loss: 0.0154 - 210ms/epoch - 11ms/step
# Epoch 43/100
#
# Epoch 43: loss improved from 0.01219 to 0.01166, saving model to ./Model/case_2/LSTM/model_8020\save_model.hdf5
# 19/19 - 0s - loss: 0.0117 - val_loss: 0.0150 - 243ms/epoch - 13ms/step
# Epoch 44/100
#
# Epoch 44: loss did not improve from 0.01166
# 19/19 - 0s - loss: 0.0118 - val_loss: 0.0258 - 220ms/epoch - 12ms/step
# Epoch 45/100
#
# Epoch 45: loss did not improve from 0.01166
# 19/19 - 0s - loss: 0.0117 - val_loss: 0.0345 - 216ms/epoch - 11ms/step
# Epoch 46/100
#
# Epoch 46: loss did not improve from 0.01166
# 19/19 - 0s - loss: 0.0127 - val_loss: 0.0161 - 223ms/epoch - 12ms/step
# Epoch 47/100
#
# Epoch 47: loss did not improve from 0.01166
# 19/19 - 0s - loss: 0.0119 - val_loss: 0.0202 - 214ms/epoch - 11ms/step
# Epoch 48/100
#
# Epoch 48: loss improved from 0.01166 to 0.01103, saving model to ./Model/case_2/LSTM/model_8020\save_model.hdf5
# 19/19 - 0s - loss: 0.0110 - val_loss: 0.0175 - 238ms/epoch - 13ms/step
# Epoch 49/100
#
# Epoch 49: loss did not improve from 0.01103
# 19/19 - 0s - loss: 0.0132 - val_loss: 0.0186 - 226ms/epoch - 12ms/step
# Epoch 50/100
#
# Epoch 50: loss did not improve from 0.01103
# 19/19 - 0s - loss: 0.0119 - val_loss: 0.0154 - 224ms/epoch - 12ms/step
# Epoch 51/100
#
# Epoch 51: loss did not improve from 0.01103
# 19/19 - 0s - loss: 0.0124 - val_loss: 0.0176 - 213ms/epoch - 11ms/step
# Epoch 52/100
#
# Epoch 52: loss did not improve from 0.01103
# 19/19 - 0s - loss: 0.0117 - val_loss: 0.0308 - 218ms/epoch - 11ms/step
# Epoch 53/100
#
# Epoch 53: loss did not improve from 0.01103
# 19/19 - 0s - loss: 0.0119 - val_loss: 0.0255 - 225ms/epoch - 12ms/step
# Epoch 54/100
#
# Epoch 54: loss did not improve from 0.01103
# 19/19 - 0s - loss: 0.0115 - val_loss: 0.0218 - 223ms/epoch - 12ms/step
# Epoch 55/100
#
# Epoch 55: loss did not improve from 0.01103
# 19/19 - 0s - loss: 0.0111 - val_loss: 0.0228 - 236ms/epoch - 12ms/step
# Epoch 56/100
#
# Epoch 56: loss did not improve from 0.01103
# 19/19 - 0s - loss: 0.0120 - val_loss: 0.0151 - 222ms/epoch - 12ms/step
# Epoch 57/100
#
# Epoch 57: loss improved from 0.01103 to 0.01046, saving model to ./Model/case_2/LSTM/model_8020\save_model.hdf5
# 19/19 - 0s - loss: 0.0105 - val_loss: 0.0241 - 268ms/epoch - 14ms/step
# Epoch 58/100
#
# Epoch 58: loss did not improve from 0.01046
# 19/19 - 0s - loss: 0.0115 - val_loss: 0.0167 - 223ms/epoch - 12ms/step
# Epoch 59/100
#
# Epoch 59: loss did not improve from 0.01046
# 19/19 - 0s - loss: 0.0110 - val_loss: 0.0198 - 210ms/epoch - 11ms/step
# Epoch 60/100
#
# Epoch 60: loss did not improve from 0.01046
# 19/19 - 0s - loss: 0.0108 - val_loss: 0.0213 - 211ms/epoch - 11ms/step
# Epoch 61/100
#
# Epoch 61: loss did not improve from 0.01046
# 19/19 - 0s - loss: 0.0105 - val_loss: 0.0284 - 228ms/epoch - 12ms/step
# Epoch 62/100
#
# Epoch 62: loss did not improve from 0.01046
# 19/19 - 0s - loss: 0.0112 - val_loss: 0.0137 - 224ms/epoch - 12ms/step
# Epoch 63/100
#
# Epoch 63: loss did not improve from 0.01046
# 19/19 - 0s - loss: 0.0109 - val_loss: 0.0391 - 225ms/epoch - 12ms/step
# Epoch 64/100
#
# Epoch 64: loss did not improve from 0.01046
# 19/19 - 0s - loss: 0.0109 - val_loss: 0.0223 - 228ms/epoch - 12ms/step
# Epoch 65/100
#
# Epoch 65: loss did not improve from 0.01046
# 19/19 - 0s - loss: 0.0112 - val_loss: 0.0243 - 220ms/epoch - 12ms/step
# Epoch 66/100
#
# Epoch 66: loss did not improve from 0.01046
# 19/19 - 0s - loss: 0.0108 - val_loss: 0.0218 - 232ms/epoch - 12ms/step
# Epoch 67/100
#
# Epoch 67: loss did not improve from 0.01046
# 19/19 - 0s - loss: 0.0105 - val_loss: 0.0158 - 220ms/epoch - 12ms/step
# Epoch 68/100
#
# Epoch 68: loss did not improve from 0.01046
# 19/19 - 0s - loss: 0.0111 - val_loss: 0.0156 - 214ms/epoch - 11ms/step
# Epoch 69/100
#
# Epoch 69: loss did not improve from 0.01046
# 19/19 - 0s - loss: 0.0108 - val_loss: 0.0128 - 216ms/epoch - 11ms/step
# Epoch 70/100
#
# Epoch 70: loss did not improve from 0.01046
# 19/19 - 0s - loss: 0.0105 - val_loss: 0.0134 - 212ms/epoch - 11ms/step
# Epoch 71/100
#
# Epoch 71: loss did not improve from 0.01046
# 19/19 - 0s - loss: 0.0110 - val_loss: 0.0510 - 222ms/epoch - 12ms/step
# Epoch 72/100
#
# Epoch 72: loss did not improve from 0.01046
# 19/19 - 0s - loss: 0.0105 - val_loss: 0.0157 - 229ms/epoch - 12ms/step
# Epoch 73/100
#
# Epoch 73: loss improved from 0.01046 to 0.01023, saving model to ./Model/case_2/LSTM/model_8020\save_model.hdf5
# 19/19 - 0s - loss: 0.0102 - val_loss: 0.0137 - 241ms/epoch - 13ms/step
# Epoch 74/100
#
# Epoch 74: loss improved from 0.01023 to 0.00988, saving model to ./Model/case_2/LSTM/model_8020\save_model.hdf5
# 19/19 - 0s - loss: 0.0099 - val_loss: 0.0198 - 230ms/epoch - 12ms/step
# Epoch 75/100
#
# Epoch 75: loss did not improve from 0.00988
# 19/19 - 0s - loss: 0.0103 - val_loss: 0.0152 - 227ms/epoch - 12ms/step
# Epoch 76/100
#
# Epoch 76: loss did not improve from 0.00988
# 19/19 - 0s - loss: 0.0104 - val_loss: 0.0131 - 227ms/epoch - 12ms/step
# Epoch 77/100
#
# Epoch 77: loss did not improve from 0.00988
# 19/19 - 0s - loss: 0.0099 - val_loss: 0.0119 - 240ms/epoch - 13ms/step
# Epoch 78/100
#
# Epoch 78: loss did not improve from 0.00988
# 19/19 - 0s - loss: 0.0104 - val_loss: 0.0281 - 233ms/epoch - 12ms/step
# Epoch 79/100
#
# Epoch 79: loss did not improve from 0.00988
# 19/19 - 0s - loss: 0.0102 - val_loss: 0.0249 - 234ms/epoch - 12ms/step
# Epoch 80/100
#
# Epoch 80: loss improved from 0.00988 to 0.00970, saving model to ./Model/case_2/LSTM/model_8020\save_model.hdf5
# 19/19 - 0s - loss: 0.0097 - val_loss: 0.0142 - 254ms/epoch - 13ms/step
# Epoch 81/100
#
# Epoch 81: loss did not improve from 0.00970
# 19/19 - 0s - loss: 0.0106 - val_loss: 0.0405 - 220ms/epoch - 12ms/step
# Epoch 82/100
#
# Epoch 82: loss did not improve from 0.00970
# 19/19 - 0s - loss: 0.0101 - val_loss: 0.0207 - 236ms/epoch - 12ms/step
# Epoch 83/100
#
# Epoch 83: loss did not improve from 0.00970
# 19/19 - 0s - loss: 0.0097 - val_loss: 0.0422 - 231ms/epoch - 12ms/step
# Epoch 84/100
#
# Epoch 84: loss did not improve from 0.00970
# 19/19 - 0s - loss: 0.0104 - val_loss: 0.0136 - 227ms/epoch - 12ms/step
# Epoch 85/100
#
# Epoch 85: loss did not improve from 0.00970
# 19/19 - 0s - loss: 0.0097 - val_loss: 0.0307 - 230ms/epoch - 12ms/step
# Epoch 86/100
#
# Epoch 86: loss did not improve from 0.00970
# 19/19 - 0s - loss: 0.0099 - val_loss: 0.0194 - 222ms/epoch - 12ms/step
# Epoch 87/100
#
# Epoch 87: loss did not improve from 0.00970
# 19/19 - 0s - loss: 0.0098 - val_loss: 0.0361 - 211ms/epoch - 11ms/step
# Epoch 88/100
#
# Epoch 88: loss did not improve from 0.00970
# 19/19 - 0s - loss: 0.0107 - val_loss: 0.0184 - 220ms/epoch - 12ms/step
# Epoch 89/100
#
# Epoch 89: loss did not improve from 0.00970
# 19/19 - 0s - loss: 0.0098 - val_loss: 0.0258 - 229ms/epoch - 12ms/step
# Epoch 90/100
#
# Epoch 90: loss improved from 0.00970 to 0.00959, saving model to ./Model/case_2/LSTM/model_8020\save_model.hdf5
# 19/19 - 0s - loss: 0.0096 - val_loss: 0.0282 - 255ms/epoch - 13ms/step
# Epoch 91/100
#
# Epoch 91: loss improved from 0.00959 to 0.00944, saving model to ./Model/case_2/LSTM/model_8020\save_model.hdf5
# 19/19 - 0s - loss: 0.0094 - val_loss: 0.0122 - 232ms/epoch - 12ms/step
# Epoch 92/100
#
# Epoch 92: loss did not improve from 0.00944
# 19/19 - 0s - loss: 0.0097 - val_loss: 0.0270 - 217ms/epoch - 11ms/step
# Epoch 93/100
#
# Epoch 93: loss did not improve from 0.00944
# 19/19 - 0s - loss: 0.0101 - val_loss: 0.0126 - 226ms/epoch - 12ms/step
# Epoch 94/100
#
# Epoch 94: loss improved from 0.00944 to 0.00941, saving model to ./Model/case_2/LSTM/model_8020\save_model.hdf5
# 19/19 - 0s - loss: 0.0094 - val_loss: 0.0378 - 239ms/epoch - 13ms/step
# Epoch 95/100
#
# Epoch 95: loss did not improve from 0.00941
# 19/19 - 0s - loss: 0.0097 - val_loss: 0.0129 - 215ms/epoch - 11ms/step
# Epoch 96/100
#
# Epoch 96: loss did not improve from 0.00941
# 19/19 - 0s - loss: 0.0097 - val_loss: 0.0160 - 229ms/epoch - 12ms/step
# Epoch 97/100
#
# Epoch 97: loss did not improve from 0.00941
# 19/19 - 0s - loss: 0.0098 - val_loss: 0.0122 - 224ms/epoch - 12ms/step
# Epoch 98/100
#
# Epoch 98: loss did not improve from 0.00941
# 19/19 - 0s - loss: 0.0098 - val_loss: 0.0259 - 236ms/epoch - 12ms/step
# Epoch 99/100
#
# Epoch 99: loss did not improve from 0.00941
# 19/19 - 0s - loss: 0.0096 - val_loss: 0.0194 - 233ms/epoch - 12ms/step
# Epoch 100/100
#
# Epoch 100: loss did not improve from 0.00941
# 19/19 - 0s - loss: 0.0098 - val_loss: 0.0121 - 215ms/epoch - 11ms/step
# Thời gian thực thi mô hình: 25.23 giây

# %%
#Model
final_model = load_model("./Model/case_2/LSTM/model_8020/save_model.hdf5")

# %%
#dữ liệu train
Y_train_predict = final_model.predict(X_train) #dự đoán trên tập đã train
Y_train_predict = sc.inverse_transform(Y_train_predict) #giá thực dự đoán
Y_train = sc.inverse_transform(Y_train) #giá thực train
# Out:
# 48/48 [==============================] - 1s 2ms/step

# %% [markdown]
# # DỰ ĐOÁN TRÊN TẬP TEST

# %%
#dữ liệu test
import time
start_model = time.time()  # Bắt đầu đo thời gian
Y_test_predict = final_model.predict(X_test)
end_model = time.time()  # Kết thúc đo thời gian
print(f"Thời gian thực thi mô hình: {end_model - start_model:.2f} giây")
Y_test_predict = sc.inverse_transform(Y_test_predict) #giá dự đoán
Y_test = sc.inverse_transform(Y_test) #giá thực
# Out:
# 12/12 [==============================] - 0s 2ms/step
# Thời gian thực thi mô hình: 0.07 giây

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import mean_absolute_error, mean_squared_error

# Tính toán các giá trị cho tập Train
mae_train = round(mean_absolute_error(Y_train, Y_train_predict), 3)
mse_train = round(mean_squared_error(Y_train, Y_train_predict), 3)
rmse_train = round(np.sqrt(mse_train), 3)

# Tính toán các giá trị cho tập Test
mae_test = round(mean_absolute_error(Y_test, Y_test_predict), 3)
mse_test = round(mean_squared_error(Y_test, Y_test_predict), 3)
rmse_test = round(np.sqrt(mse_test), 3)

# Tạo DataFrame để hiển thị kết quả
metrics = pd.DataFrame({
    "Tập dữ liệu": ["Train", "Test"],
    "MAE": [mae_train, mae_test],
    "MSE": [mse_train, mse_test],
    "RMSE": [rmse_train, rmse_test]
})

# In kết quả
print(metrics)
print(f"Thời gian thực thi mô hình: {end_model - start_model:.2f} giây")
# Out:
#   Tập dữ liệu      MAE        MSE     RMSE
# 0       Train   68.749   9797.562   98.983
# 1        Test  294.570  92108.242  303.493
# Thời gian thực thi mô hình: 0.07 giây

# %%
# Xác định 80% dữ liệu làm tập train
train_size = int(len(df_usd_ML) * 0.8)

# Cắt lại cho đúng chiều dài:
train_data1 = df_usd_ML[6:train_size+1].copy()
test_data1 = df_usd_ML[train_size+2:].copy()


print(len(train_data1), len(Y_train_predict))
print(len(test_data1), len(Y_test_predict))

# Cắt dữ liệu dự đoán để khớp với dữ liệu gốc
Y_train_predict = Y_train_predict[:len(train_data1)]
Y_test_predict = Y_test_predict[:len(test_data1)]

# Đảm bảo test_data1 có số lượng dòng khớp với Y_test_predict
test_data1 = test_data1.iloc[:len(Y_test_predict)]

plt.figure(figsize=(24,8))
plt.plot(df_usd_ML, label='Giá thực tế', color='red')  # đường giá thực

# Thêm dữ liệu dự đoán vào train_data1 và test_data1
train_data1["Dự đoán"] = Y_train_predict
plt.plot(train_data1["Dự đoán"], label='Giá dự đoán train', color='green')

test_data1["Dự đoán"] = Y_test_predict
plt.plot(test_data1["Dự đoán"], label='Giá dự đoán test', color='blue')

plt.title('So sánh giá dự báo và giá thực tế')
plt.xlabel('Thời gian')
plt.ylabel('Giá mua chuyển khoản (VNĐ)')
plt.legend()
plt.show()
# Out:
# 1523 1523
# 381 381

# %%
from tensorflow.keras.models import load_model

# Gọi lại mô hình đã lưu
loaded_model = load_model("./Model/case_2/LSTM/model_8020/save_model.hdf5")
# Dự đoán lại trên tập test
Y_test_predict = loaded_model.predict(X_test)
# Đảo chuẩn hóa (inverse transform)
Y_test_predict = sc.inverse_transform(Y_test_predict)

# Tạo bảng so sánh
compare_df = pd.DataFrame({
    "Giá thực tế": Y_test.flatten(),
    "Giá dự đoán": Y_test_predict.flatten()
})

# Làm tròn về số nguyên
compare_df = compare_df.astype(int)
pd.set_option('display.max_rows', None)
# Hiển thị toàn bộ bảng
display(compare_df)
compare_df.to_csv("./Model/case_2/LSTM/model_8020/predict.csv", index=False)
# Out:
# 12/12 [==============================] - 0s 2ms/step
#      Giá thực tế  Giá dự đoán
# 0          24790        24546
# 1          24830        24548
# 2          24840        24559
# 3          24840        24572
# 4          24840        24582
# 5          24960        24589
# 6          25008        24622
# 7          25130        24665
# 8          25130        24728
# 9          25163        24780
# 10         25163        24823
# 11         25163        24849
# 12         25175        24861
# 13         25178        24869
# 14         25177        24874
# 15         25167        24877
# 16         25118        24876
# 17         25118        24862
# 18         25118        24849
# 19         25118        24839
# 20         25118        24832
# 21         25118        24830
# 22         25144        24829
# 23         25143        24836
# 24         25147        24842
# 25         25147        24847
# 26         25157        24851
# 27         25155        24855
# 28         25161        24858
# 29         25178        24861
# 30         25184        24867
# 31         25184        24875
# 32         25184        24880
# 33         25179        24883
# 34         25182        24883
# 35         25182        24884
# 36         25152        24883
# 37         25250        24876
# 38         25250        24892
# 39         25250        24911
# 40         25259        24926
# 41         25263        24937
# 42         25266        24945
# 43         25250        24950
# 44         25277        24948
# 45         25277        24952
# 46         25277        24957
# 47         25281        24960
# 48         25268        24963
# 49         25265        24962
# 50         25250        24959
# 51         25254        24953
# 52         25254        24948
# 53         25254        24946
# 54         25234        24944
# 55         25218        24939
# 56         25213        24930
# 57         25213        24922
# 58         25213        24915
# 59         25213        24912
# 60         25213        24910
# 61         25214        24909
# 62         25222        24910
# 63         25226        24912
# 64         25217        24915
# 65         25221        24915
# 66         25221        24916
# 67         25221        24916
# 68         25231        24916
# 69         25251        24919
# 70         25249        24926
# 71         25247        24932
# 72         25248        24936
# 73         25248        24938
# 74         25248        24939
# 75         25255        24939
# 76         25245        24941
# 77         25250        24940
# 78         25257        24940
# 79         25253        24942
# 80         25253        24943
# 81         25253        24943
# 82         25244        24943
# 83         25245        24941
# 84         25250        24939
