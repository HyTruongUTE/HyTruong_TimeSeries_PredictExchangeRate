# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler #chuẩn hóa dữ liệu
from keras.callbacks import ModelCheckpoint #lưu lại huấn luyện tốt nhất
from tensorflow.keras.models import load_model #tải mô hình
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import ModelCheckpoint

import random
import tensorflow as tf

#các lớp để xây dựng mô hình
from keras.models import Sequential #đầu vào
from keras.layers import LSTM #học phụ thuộc
from keras.layers import Dropout, BatchNormalization #tránh học tủ
from keras.layers import Dense #đầu ra

#kiểm tra độ chính xác của mô hình
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
random.seed(42)
np.random.seed(42)
tf.random.set_seed(42)

# %%
df_usd = pd.read_parquet("./minio/usd/part-00000-18b834c3-cd6d-42ae-82c3-638999ff6d84-c000.snappy.parquet", engine="pyarrow")
df_usd.head()
# Out:
#         ngay ma_ngoai_te ten_ngoai_te  mua_chuyen_khoan      ban
# 0 2020-02-01         USD    US DOLLAR           23165.0  23305.0
# 1 2020-02-02         USD    US DOLLAR           23165.0  23305.0
# 2 2020-02-03         USD    US DOLLAR           23200.0  23340.0
# 3 2020-02-04         USD    US DOLLAR           23170.0  23310.0
# 4 2020-02-05         USD    US DOLLAR           23160.0  23300.0

# %%
df_usd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1911 entries, 0 to 1910
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ngay              1911 non-null   datetime64[ns]
#  1   ma_ngoai_te       1911 non-null   object
#  2   ten_ngoai_te      1911 non-null   object
#  3   mua_chuyen_khoan  1911 non-null   float64
#  4   ban               1911 non-null   float64
# dtypes: datetime64[ns](1), float64(2), object(2)
# memory usage: 74.8+ KB

# %%
df_usd.describe()
# Out:
#                       ngay  mua_chuyen_khoan           ban
# count                 1911       1911.000000   1911.000000
# mean   2022-09-13 00:00:00      23666.414443  23934.197279
# min    2020-02-01 00:00:00      22480.000000  22745.000000
# 25%    2021-05-23 12:00:00      22985.000000  23170.000000
# 50%    2022-09-13 00:00:00      23300.000000  23620.000000
# 75%    2024-01-03 12:00:00      24390.000000  24730.000000
# max    2025-04-25 00:00:00      25835.000000  26195.000000
# std                    NaN        885.147984    926.810272

# %%
print(df_usd.dtypes)
# Out:
# ngay                datetime64[ns]
# ma_ngoai_te                 object
# ten_ngoai_te                object
# mua_chuyen_khoan           float64
# ban                        float64
# dtype: object

# %%
import matplotlib.pyplot as plt
from matplotlib.dates import YearLocator, DateFormatter, MonthLocator

# Vẽ biểu đồ
plt.figure(figsize=(10, 5))
plt.plot(df_usd['ngay'].values, df_usd['mua_chuyen_khoan'].values, label='Giá mua chuyển khoản', color='red')

plt.xlabel('Năm')
plt.ylabel('Giá mua chuyển khoản')
plt.title('Biểu đồ tỷ giá VND_USD mua chuyển khoảng qua các năm')
plt.legend(loc='best')

# Định dạng trục x
plt.gca().xaxis.set_major_locator(YearLocator())
plt.gca().xaxis.set_major_formatter(DateFormatter('%Y'))
plt.gca().xaxis.set_minor_locator(MonthLocator())

plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
df_usd_ML = pd.DataFrame(df_usd, columns=['ngay','mua_chuyen_khoan'])
df_usd_ML.index = df_usd_ML.ngay
df_usd_ML.drop('ngay', axis = 1, inplace=True)
df_usd_ML.head()
# Out:
#             mua_chuyen_khoan
# ngay
# 2020-02-01           23165.0
# 2020-02-02           23165.0
# 2020-02-03           23200.0
# 2020-02-04           23170.0
# 2020-02-05           23160.0

# %%
print(df_usd_ML.columns)
# Out:
# Index(['mua_chuyen_khoan'], dtype='object')

# %%
data = df_usd_ML.values

# %%
data
# Out:
# array([[23165.],
#        [23165.],
#        [23200.],
#        ...,
#        [25781.],
#        [25814.],
#        [25835.]])

# %%
#hàm hóa dữ liệu
sc = MinMaxScaler(feature_range=(0,1))

#chuẩn hóa dữ train
scale_data = sc.fit_transform(data)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))

plt.plot(scale_data, label="Dữ liệu sau chuẩn hóa", color="red")

plt.xlabel("Thời gian (Index)")
plt.ylabel("Giá trị sau chuẩn hóa")
plt.title("Biểu đồ dữ liệu sau khi chuẩn hóa bằng MinMaxScaler")
plt.legend()
plt.show()

# %%
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Bidirectional, LSTM, Dense, Dropout

# Chọn window
window_size = 7
X_train, Y_train = [], []

for i in range(len(scale_data) - window_size):
    X_train.append(scale_data[i:i + window_size])
    Y_train.append(scale_data[i + window_size])

X_train = np.array(X_train)
Y_train = np.array(Y_train)

# Phân chia tập dữ liệu thành tập train và test 90 - 10
split_index = int(0.9 * len(X_train))

X_train, X_test = X_train[:split_index], X_train[split_index:]
Y_train, Y_test = Y_train[:split_index], Y_train[split_index:]

# Đảm bảo dữ liệu có đúng shape cho mô hình BiLSTM
X_train = X_train.reshape((X_train.shape[0], window_size, -1))
X_test = X_test.reshape((X_test.shape[0], window_size, -1))

# %%
print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
print("y_train shape:", Y_train.shape)
print("y_test shape:", Y_test.shape)
# Out:
# X_train shape: (1713, 7, 1)
# X_test shape: (191, 7, 1)
# y_train shape: (1713, 1)
# y_test shape: (191, 1)

# %%
print("Shape of X_train:", X_train.shape)
# Out:
# Shape of X_train: (1713, 7, 1)

# %% [markdown]
# # MODEL

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Bidirectional, BatchNormalization

# Xây dựng mô hình BiLSTM
model = Sequential()

# Lớp BiLSTM đầu tiên (return_sequences=True để kết nối lớp tiếp theo)
model.add(Bidirectional(LSTM(units=64, return_sequences=True, input_shape=(X_train.shape[1], 1))))
model.add(BatchNormalization())  # Ổn định dữ liệu đầu ra

# Lớp BiLSTM thứ hai
model.add(Bidirectional(LSTM(units=64)))
model.add(BatchNormalization())

# Dropout để giảm overfitting
model.add(Dropout(0.5))

# Lớp Dense đầu ra
model.add(Dense(1))

# Compile mô hình
model.compile(loss='mean_absolute_error', optimizer='adam')

# %% [markdown]
# # huấn luyện mô hình

# %%
save_model = "./Model/case_2/BiLSTM/model_9010/save_model.hdf5"
best_model = ModelCheckpoint(save_model,monitor='loss',verbose=2,save_best_only=True,mode='auto')

import time
start_model = time.time()  # Bắt đầu đo thời gian
model.fit(X_train,Y_train,epochs=100,batch_size=50,validation_split=0.4,verbose=2,callbacks=[best_model])
end_model = time.time()  # Kết thúc đo thời gian
print(f"Thời gian thực thi mô hình: {end_model - start_model:.2f} giây")
# Out:
# Epoch 1/100
#
# Epoch 1: loss improved from inf to 0.83751, saving model to ./Model/case_2/BiLSTM/model_9010\save_model.hdf5
# 21/21 - 6s - loss: 0.8375 - val_loss: 0.4023 - 6s/epoch - 285ms/step
# Epoch 2/100
#
# Epoch 2: loss improved from 0.83751 to 0.75189, saving model to ./Model/case_2/BiLSTM/model_9010\save_model.hdf5
# 21/21 - 0s - loss: 0.7519 - val_loss: 0.3497 - 286ms/epoch - 14ms/step
# Epoch 3/100
#
# Epoch 3: loss improved from 0.75189 to 0.66207, saving model to ./Model/case_2/BiLSTM/model_9010\save_model.hdf5
# 21/21 - 0s - loss: 0.6621 - val_loss: 0.4013 - 284ms/epoch - 14ms/step
# Epoch 4/100
#
# Epoch 4: loss improved from 0.66207 to 0.64074, saving model to ./Model/case_2/BiLSTM/model_9010\save_model.hdf5
# 21/21 - 0s - loss: 0.6407 - val_loss: 0.3722 - 301ms/epoch - 14ms/step
# Epoch 5/100
#
# Epoch 5: loss improved from 0.64074 to 0.50312, saving model to ./Model/case_2/BiLSTM/model_9010\save_model.hdf5
# 21/21 - 0s - loss: 0.5031 - val_loss: 0.3245 - 302ms/epoch - 14ms/step
# Epoch 6/100
#
# Epoch 6: loss improved from 0.50312 to 0.49639, saving model to ./Model/case_2/BiLSTM/model_9010\save_model.hdf5
# 21/21 - 0s - loss: 0.4964 - val_loss: 0.3845 - 303ms/epoch - 14ms/step
# Epoch 7/100
#
# Epoch 7: loss improved from 0.49639 to 0.44804, saving model to ./Model/case_2/BiLSTM/model_9010\save_model.hdf5
# 21/21 - 0s - loss: 0.4480 - val_loss: 0.3706 - 302ms/epoch - 14ms/step
# Epoch 8/100
#
# Epoch 8: loss improved from 0.44804 to 0.42369, saving model to ./Model/case_2/BiLSTM/model_9010\save_model.hdf5
# 21/21 - 0s - loss: 0.4237 - val_loss: 0.3586 - 318ms/epoch - 15ms/step
# Epoch 9/100
#
# Epoch 9: loss improved from 0.42369 to 0.41799, saving model to ./Model/case_2/BiLSTM/model_9010\save_model.hdf5
# 21/21 - 0s - loss: 0.4180 - val_loss: 0.2493 - 318ms/epoch - 15ms/step
# Epoch 10/100
#
# Epoch 10: loss improved from 0.41799 to 0.31177, saving model to ./Model/case_2/BiLSTM/model_9010\save_model.hdf5
# 21/21 - 0s - loss: 0.3118 - val_loss: 0.2964 - 305ms/epoch - 15ms/step
# Epoch 11/100
#
# Epoch 11: loss improved from 0.31177 to 0.17935, saving model to ./Model/case_2/BiLSTM/model_9010\save_model.hdf5
# 21/21 - 0s - loss: 0.1794 - val_loss: 0.2691 - 308ms/epoch - 15ms/step
# Epoch 12/100
#
# Epoch 12: loss improved from 0.17935 to 0.08470, saving model to ./Model/case_2/BiLSTM/model_9010\save_model.hdf5
# 21/21 - 0s - loss: 0.0847 - val_loss: 0.2539 - 301ms/epoch - 14ms/step
# Epoch 13/100
#
# Epoch 13: loss improved from 0.08470 to 0.05406, saving model to ./Model/case_2/BiLSTM/model_9010\save_model.hdf5
# 21/21 - 0s - loss: 0.0541 - val_loss: 0.2285 - 297ms/epoch - 14ms/step
# Epoch 14/100
#
# Epoch 14: loss improved from 0.05406 to 0.03261, saving model to ./Model/case_2/BiLSTM/model_9010\save_model.hdf5
# 21/21 - 0s - loss: 0.0326 - val_loss: 0.2097 - 300ms/epoch - 14ms/step
# Epoch 15/100
#
# Epoch 15: loss improved from 0.03261 to 0.03013, saving model to ./Model/case_2/BiLSTM/model_9010\save_model.hdf5
# 21/21 - 0s - loss: 0.0301 - val_loss: 0.1975 - 301ms/epoch - 14ms/step
# Epoch 16/100
#
# Epoch 16: loss improved from 0.03013 to 0.02368, saving model to ./Model/case_2/BiLSTM/model_9010\save_model.hdf5
# 21/21 - 0s - loss: 0.0237 - val_loss: 0.1986 - 293ms/epoch - 14ms/step
# Epoch 17/100
#
# Epoch 17: loss did not improve from 0.02368
# 21/21 - 0s - loss: 0.0238 - val_loss: 0.1915 - 315ms/epoch - 15ms/step
# Epoch 18/100
#
# Epoch 18: loss improved from 0.02368 to 0.02358, saving model to ./Model/case_2/BiLSTM/model_9010\save_model.hdf5
# 21/21 - 0s - loss: 0.0236 - val_loss: 0.1946 - 298ms/epoch - 14ms/step
# Epoch 19/100
#
# Epoch 19: loss improved from 0.02358 to 0.02309, saving model to ./Model/case_2/BiLSTM/model_9010\save_model.hdf5
# 21/21 - 0s - loss: 0.0231 - val_loss: 0.1811 - 293ms/epoch - 14ms/step
# Epoch 20/100
#
# Epoch 20: loss did not improve from 0.02309
# 21/21 - 0s - loss: 0.0241 - val_loss: 0.2008 - 256ms/epoch - 12ms/step
# Epoch 21/100
#
# Epoch 21: loss did not improve from 0.02309
# 21/21 - 0s - loss: 0.0241 - val_loss: 0.1750 - 265ms/epoch - 13ms/step
# Epoch 22/100
#
# Epoch 22: loss improved from 0.02309 to 0.02247, saving model to ./Model/case_2/BiLSTM/model_9010\save_model.hdf5
# 21/21 - 0s - loss: 0.0225 - val_loss: 0.1647 - 301ms/epoch - 14ms/step
# Epoch 23/100
#
# Epoch 23: loss did not improve from 0.02247
# 21/21 - 0s - loss: 0.0238 - val_loss: 0.1340 - 268ms/epoch - 13ms/step
# Epoch 24/100
#
# Epoch 24: loss did not improve from 0.02247
# 21/21 - 0s - loss: 0.0268 - val_loss: 0.1250 - 263ms/epoch - 13ms/step
# Epoch 25/100
#
# Epoch 25: loss did not improve from 0.02247
# 21/21 - 0s - loss: 0.0240 - val_loss: 0.1188 - 280ms/epoch - 13ms/step
# Epoch 26/100
#
# Epoch 26: loss improved from 0.02247 to 0.02220, saving model to ./Model/case_2/BiLSTM/model_9010\save_model.hdf5
# 21/21 - 0s - loss: 0.0222 - val_loss: 0.1172 - 299ms/epoch - 14ms/step
# Epoch 27/100
#
# Epoch 27: loss did not improve from 0.02220
# 21/21 - 0s - loss: 0.0222 - val_loss: 0.1020 - 271ms/epoch - 13ms/step
# Epoch 28/100
#
# Epoch 28: loss improved from 0.02220 to 0.01981, saving model to ./Model/case_2/BiLSTM/model_9010\save_model.hdf5
# 21/21 - 0s - loss: 0.0198 - val_loss: 0.0632 - 302ms/epoch - 14ms/step
# Epoch 29/100
#
# Epoch 29: loss did not improve from 0.01981
# 21/21 - 0s - loss: 0.0230 - val_loss: 0.0813 - 268ms/epoch - 13ms/step
# Epoch 30/100
#
# Epoch 30: loss improved from 0.01981 to 0.01967, saving model to ./Model/case_2/BiLSTM/model_9010\save_model.hdf5
# 21/21 - 0s - loss: 0.0197 - val_loss: 0.0999 - 292ms/epoch - 14ms/step
# Epoch 31/100
#
# Epoch 31: loss did not improve from 0.01967
# 21/21 - 0s - loss: 0.0215 - val_loss: 0.1113 - 266ms/epoch - 13ms/step
# Epoch 32/100
#
# Epoch 32: loss did not improve from 0.01967
# 21/21 - 0s - loss: 0.0263 - val_loss: 0.0710 - 266ms/epoch - 13ms/step
# Epoch 33/100
#
# Epoch 33: loss did not improve from 0.01967
# 21/21 - 0s - loss: 0.0214 - val_loss: 0.0781 - 257ms/epoch - 12ms/step
# Epoch 34/100
#
# Epoch 34: loss did not improve from 0.01967
# 21/21 - 0s - loss: 0.0220 - val_loss: 0.1113 - 284ms/epoch - 14ms/step
# Epoch 35/100
#
# Epoch 35: loss did not improve from 0.01967
# 21/21 - 0s - loss: 0.0221 - val_loss: 0.0381 - 251ms/epoch - 12ms/step
# Epoch 36/100
#
# Epoch 36: loss did not improve from 0.01967
# 21/21 - 0s - loss: 0.0202 - val_loss: 0.0519 - 258ms/epoch - 12ms/step
# Epoch 37/100
#
# Epoch 37: loss did not improve from 0.01967
# 21/21 - 0s - loss: 0.0227 - val_loss: 0.0626 - 260ms/epoch - 12ms/step
# Epoch 38/100
#
# Epoch 38: loss improved from 0.01967 to 0.01821, saving model to ./Model/case_2/BiLSTM/model_9010\save_model.hdf5
# 21/21 - 0s - loss: 0.0182 - val_loss: 0.0688 - 292ms/epoch - 14ms/step
# Epoch 39/100
#
# Epoch 39: loss did not improve from 0.01821
# 21/21 - 0s - loss: 0.0207 - val_loss: 0.0131 - 257ms/epoch - 12ms/step
# Epoch 40/100
#
# Epoch 40: loss improved from 0.01821 to 0.01737, saving model to ./Model/case_2/BiLSTM/model_9010\save_model.hdf5
# 21/21 - 0s - loss: 0.0174 - val_loss: 0.0223 - 294ms/epoch - 14ms/step
# Epoch 41/100
#
# Epoch 41: loss did not improve from 0.01737
# 21/21 - 0s - loss: 0.0191 - val_loss: 0.0354 - 254ms/epoch - 12ms/step
# Epoch 42/100
#
# Epoch 42: loss did not improve from 0.01737
# 21/21 - 0s - loss: 0.0195 - val_loss: 0.0176 - 252ms/epoch - 12ms/step
# Epoch 43/100
#
# Epoch 43: loss did not improve from 0.01737
# 21/21 - 0s - loss: 0.0177 - val_loss: 0.0558 - 255ms/epoch - 12ms/step
# Epoch 44/100
#
# Epoch 44: loss improved from 0.01737 to 0.01670, saving model to ./Model/case_2/BiLSTM/model_9010\save_model.hdf5
# 21/21 - 0s - loss: 0.0167 - val_loss: 0.0185 - 288ms/epoch - 14ms/step
# Epoch 45/100
#
# Epoch 45: loss did not improve from 0.01670
# 21/21 - 0s - loss: 0.0179 - val_loss: 0.0862 - 244ms/epoch - 12ms/step
# Epoch 46/100
#
# Epoch 46: loss did not improve from 0.01670
# 21/21 - 0s - loss: 0.0221 - val_loss: 0.0152 - 251ms/epoch - 12ms/step
# Epoch 47/100
#
# Epoch 47: loss did not improve from 0.01670
# 21/21 - 0s - loss: 0.0209 - val_loss: 0.0714 - 252ms/epoch - 12ms/step
# Epoch 48/100
#
# Epoch 48: loss improved from 0.01670 to 0.01606, saving model to ./Model/case_2/BiLSTM/model_9010\save_model.hdf5
# 21/21 - 0s - loss: 0.0161 - val_loss: 0.0150 - 271ms/epoch - 13ms/step
# Epoch 49/100
#
# Epoch 49: loss did not improve from 0.01606
# 21/21 - 0s - loss: 0.0204 - val_loss: 0.0365 - 241ms/epoch - 11ms/step
# Epoch 50/100
#
# Epoch 50: loss did not improve from 0.01606
# 21/21 - 0s - loss: 0.0170 - val_loss: 0.0565 - 254ms/epoch - 12ms/step
# Epoch 51/100
#
# Epoch 51: loss did not improve from 0.01606
# 21/21 - 0s - loss: 0.0223 - val_loss: 0.0295 - 249ms/epoch - 12ms/step
# Epoch 52/100
#
# Epoch 52: loss did not improve from 0.01606
# 21/21 - 0s - loss: 0.0194 - val_loss: 0.0363 - 244ms/epoch - 12ms/step
# Epoch 53/100
#
# Epoch 53: loss did not improve from 0.01606
# 21/21 - 0s - loss: 0.0210 - val_loss: 0.0392 - 263ms/epoch - 13ms/step
# Epoch 54/100
#
# Epoch 54: loss did not improve from 0.01606
# 21/21 - 0s - loss: 0.0210 - val_loss: 0.0309 - 264ms/epoch - 13ms/step
# Epoch 55/100
#
# Epoch 55: loss did not improve from 0.01606
# 21/21 - 0s - loss: 0.0169 - val_loss: 0.0238 - 248ms/epoch - 12ms/step
# Epoch 56/100
#
# Epoch 56: loss did not improve from 0.01606
# 21/21 - 0s - loss: 0.0172 - val_loss: 0.0112 - 274ms/epoch - 13ms/step
# Epoch 57/100
#
# Epoch 57: loss did not improve from 0.01606
# 21/21 - 0s - loss: 0.0219 - val_loss: 0.0975 - 263ms/epoch - 13ms/step
# Epoch 58/100
#
# Epoch 58: loss did not improve from 0.01606
# 21/21 - 0s - loss: 0.0251 - val_loss: 0.0986 - 285ms/epoch - 14ms/step
# Epoch 59/100
#
# Epoch 59: loss did not improve from 0.01606
# 21/21 - 0s - loss: 0.0219 - val_loss: 0.0405 - 269ms/epoch - 13ms/step
# Epoch 60/100
#
# Epoch 60: loss did not improve from 0.01606
# 21/21 - 0s - loss: 0.0185 - val_loss: 0.1057 - 276ms/epoch - 13ms/step
# Epoch 61/100
#
# Epoch 61: loss did not improve from 0.01606
# 21/21 - 0s - loss: 0.0205 - val_loss: 0.0658 - 274ms/epoch - 13ms/step
# Epoch 62/100
#
# Epoch 62: loss did not improve from 0.01606
# 21/21 - 0s - loss: 0.0223 - val_loss: 0.0909 - 252ms/epoch - 12ms/step
# Epoch 63/100
#
# Epoch 63: loss did not improve from 0.01606
# 21/21 - 0s - loss: 0.0230 - val_loss: 0.0175 - 272ms/epoch - 13ms/step
# Epoch 64/100
#
# Epoch 64: loss did not improve from 0.01606
# 21/21 - 0s - loss: 0.0195 - val_loss: 0.0373 - 263ms/epoch - 13ms/step
# Epoch 65/100
#
# Epoch 65: loss did not improve from 0.01606
# 21/21 - 0s - loss: 0.0191 - val_loss: 0.0505 - 260ms/epoch - 12ms/step
# Epoch 66/100
#
# Epoch 66: loss did not improve from 0.01606
# 21/21 - 0s - loss: 0.0188 - val_loss: 0.0180 - 255ms/epoch - 12ms/step
# Epoch 67/100
#
# Epoch 67: loss did not improve from 0.01606
# 21/21 - 0s - loss: 0.0195 - val_loss: 0.0224 - 265ms/epoch - 13ms/step
# Epoch 68/100
#
# Epoch 68: loss did not improve from 0.01606
# 21/21 - 0s - loss: 0.0191 - val_loss: 0.0426 - 251ms/epoch - 12ms/step
# Epoch 69/100
#
# Epoch 69: loss did not improve from 0.01606
# 21/21 - 0s - loss: 0.0187 - val_loss: 0.0502 - 246ms/epoch - 12ms/step
# Epoch 70/100
#
# Epoch 70: loss did not improve from 0.01606
# 21/21 - 0s - loss: 0.0206 - val_loss: 0.0467 - 250ms/epoch - 12ms/step
# Epoch 71/100
#
# Epoch 71: loss did not improve from 0.01606
# 21/21 - 0s - loss: 0.0223 - val_loss: 0.0395 - 247ms/epoch - 12ms/step
# Epoch 72/100
#
# Epoch 72: loss did not improve from 0.01606
# 21/21 - 0s - loss: 0.0175 - val_loss: 0.0472 - 289ms/epoch - 14ms/step
# Epoch 73/100
#
# Epoch 73: loss did not improve from 0.01606
# 21/21 - 0s - loss: 0.0185 - val_loss: 0.0228 - 245ms/epoch - 12ms/step
# Epoch 74/100
#
# Epoch 74: loss did not improve from 0.01606
# 21/21 - 0s - loss: 0.0187 - val_loss: 0.0338 - 259ms/epoch - 12ms/step
# Epoch 75/100
#
# Epoch 75: loss did not improve from 0.01606
# 21/21 - 0s - loss: 0.0215 - val_loss: 0.0103 - 253ms/epoch - 12ms/step
# Epoch 76/100
#
# Epoch 76: loss did not improve from 0.01606
# 21/21 - 0s - loss: 0.0182 - val_loss: 0.0312 - 246ms/epoch - 12ms/step
# Epoch 77/100
#
# Epoch 77: loss did not improve from 0.01606
# 21/21 - 0s - loss: 0.0169 - val_loss: 0.0195 - 252ms/epoch - 12ms/step
# Epoch 78/100
#
# Epoch 78: loss did not improve from 0.01606
# 21/21 - 0s - loss: 0.0166 - val_loss: 0.0314 - 246ms/epoch - 12ms/step
# Epoch 79/100
#
# Epoch 79: loss did not improve from 0.01606
# 21/21 - 0s - loss: 0.0263 - val_loss: 0.0610 - 257ms/epoch - 12ms/step
# Epoch 80/100
#
# Epoch 80: loss did not improve from 0.01606
# 21/21 - 0s - loss: 0.0227 - val_loss: 0.0727 - 257ms/epoch - 12ms/step
# Epoch 81/100
#
# Epoch 81: loss did not improve from 0.01606
# 21/21 - 0s - loss: 0.0217 - val_loss: 0.0348 - 263ms/epoch - 13ms/step
# Epoch 82/100
#
# Epoch 82: loss did not improve from 0.01606
# 21/21 - 0s - loss: 0.0171 - val_loss: 0.0179 - 273ms/epoch - 13ms/step
# Epoch 83/100
#
# Epoch 83: loss did not improve from 0.01606
# 21/21 - 0s - loss: 0.0230 - val_loss: 0.0712 - 275ms/epoch - 13ms/step
# Epoch 84/100
#
# Epoch 84: loss did not improve from 0.01606
# 21/21 - 0s - loss: 0.0218 - val_loss: 0.0487 - 257ms/epoch - 12ms/step
# Epoch 85/100
#
# Epoch 85: loss did not improve from 0.01606
# 21/21 - 0s - loss: 0.0254 - val_loss: 0.0111 - 259ms/epoch - 12ms/step
# Epoch 86/100
#
# Epoch 86: loss did not improve from 0.01606
# 21/21 - 0s - loss: 0.0181 - val_loss: 0.1181 - 246ms/epoch - 12ms/step
# Epoch 87/100
#
# Epoch 87: loss did not improve from 0.01606
# 21/21 - 0s - loss: 0.0223 - val_loss: 0.0950 - 246ms/epoch - 12ms/step
# Epoch 88/100
#
# Epoch 88: loss did not improve from 0.01606
# 21/21 - 0s - loss: 0.0184 - val_loss: 0.0165 - 244ms/epoch - 12ms/step
# Epoch 89/100
#
# Epoch 89: loss did not improve from 0.01606
# 21/21 - 0s - loss: 0.0226 - val_loss: 0.0203 - 245ms/epoch - 12ms/step
# Epoch 90/100
#
# Epoch 90: loss did not improve from 0.01606
# 21/21 - 0s - loss: 0.0182 - val_loss: 0.0160 - 249ms/epoch - 12ms/step
# Epoch 91/100
#
# Epoch 91: loss did not improve from 0.01606
# 21/21 - 0s - loss: 0.0194 - val_loss: 0.0180 - 245ms/epoch - 12ms/step
# Epoch 92/100
#
# Epoch 92: loss did not improve from 0.01606
# 21/21 - 0s - loss: 0.0170 - val_loss: 0.0496 - 258ms/epoch - 12ms/step
# Epoch 93/100
#
# Epoch 93: loss did not improve from 0.01606
# 21/21 - 0s - loss: 0.0194 - val_loss: 0.0238 - 267ms/epoch - 13ms/step
# Epoch 94/100
#
# Epoch 94: loss did not improve from 0.01606
# 21/21 - 0s - loss: 0.0218 - val_loss: 0.0938 - 254ms/epoch - 12ms/step
# Epoch 95/100
#
# Epoch 95: loss did not improve from 0.01606
# 21/21 - 0s - loss: 0.0195 - val_loss: 0.0503 - 274ms/epoch - 13ms/step
# Epoch 96/100
#
# Epoch 96: loss did not improve from 0.01606
# 21/21 - 0s - loss: 0.0176 - val_loss: 0.0101 - 262ms/epoch - 12ms/step
# Epoch 97/100
#
# Epoch 97: loss did not improve from 0.01606
# 21/21 - 0s - loss: 0.0197 - val_loss: 0.0125 - 242ms/epoch - 12ms/step
# Epoch 98/100
#
# Epoch 98: loss did not improve from 0.01606
# 21/21 - 0s - loss: 0.0198 - val_loss: 0.0173 - 241ms/epoch - 11ms/step
# Epoch 99/100
#
# Epoch 99: loss did not improve from 0.01606
# 21/21 - 0s - loss: 0.0177 - val_loss: 0.0200 - 245ms/epoch - 12ms/step
# Epoch 100/100
#
# Epoch 100: loss did not improve from 0.01606
# 21/21 - 0s - loss: 0.0182 - val_loss: 0.0434 - 258ms/epoch - 12ms/step
# Thời gian thực thi mô hình: 32.81 giây

# %%
#Model
final_model = load_model("./Model/case_2/BiLSTM/model_9010/save_model.hdf5")

# %%
#dữ liệu train
Y_train_predict = final_model.predict(X_train) #dự đoán trên tập đã train
Y_train_predict = sc.inverse_transform(Y_train_predict) #giá thực dự đoán
Y_train = sc.inverse_transform(Y_train) #giá thực train
# Out:
# 54/54 [==============================] - 1s 2ms/step

# %% [markdown]
# # DỰ ĐOÁN TRÊN TẬP TEST

# %%
#dữ liệu test
import time
start_model = time.time()  # Bắt đầu đo thời gian
Y_test_predict = final_model.predict(X_test)
end_model = time.time()  # Kết thúc đo thời gian
print(f"Thời gian thực thi mô hình: {end_model - start_model:.2f} giây")
Y_test_predict = sc.inverse_transform(Y_test_predict) #giá dự đoán
Y_test = sc.inverse_transform(Y_test) #giá thực
# Out:
# 6/6 [==============================] - 0s 2ms/step
# Thời gian thực thi mô hình: 0.06 giây

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import mean_absolute_error, mean_squared_error

# Tính toán các giá trị cho tập Train
mae_train = round(mean_absolute_error(Y_train, Y_train_predict), 3)
mse_train = round(mean_squared_error(Y_train, Y_train_predict), 3)
rmse_train = round(np.sqrt(mse_train), 3)

# Tính toán các giá trị cho tập Test
mae_test = round(mean_absolute_error(Y_test, Y_test_predict), 3)
mse_test = round(mean_squared_error(Y_test, Y_test_predict), 3)
rmse_test = round(np.sqrt(mse_test), 3)

# Tạo DataFrame để hiển thị kết quả
metrics = pd.DataFrame({
    "Tập dữ liệu": ["Train", "Test"],
    "MAE": [mae_train, mae_test],
    "MSE": [mse_train, mse_test],
    "RMSE": [rmse_train, rmse_test]
})

# In kết quả
print(metrics)
print(f"Thời gian thực thi mô hình: {end_model - start_model:.2f} giây")
# Out:
#   Tập dữ liệu     MAE       MSE    RMSE
# 0       Train  67.103  5857.701  76.536
# 1        Test  43.542  4158.446  64.486
# Thời gian thực thi mô hình: 0.06 giây

# %%
# Xác định 60% dữ liệu làm tập train
train_size = int(len(df_usd_ML) * 0.9)

# Lấy dữ liệu train và test
train_data1 = df_usd_ML[7:train_size].copy()  # .copy() để tránh cảnh báo SettingWithCopyWarning
test_data1 = df_usd_ML[train_size+1:].copy()


print(len(train_data1), len(Y_train_predict))
print(len(test_data1), len(Y_test_predict))


# Cắt dữ liệu dự đoán để khớp với dữ liệu gốc
Y_train_predict = Y_train_predict[:len(train_data1)]
Y_test_predict = Y_test_predict[:len(test_data1)]

# Đảm bảo test_data1 có số lượng dòng khớp với Y_test_predict
test_data1 = test_data1.iloc[:len(Y_test_predict)]

plt.figure(figsize=(24,8))
plt.plot(df_usd_ML, label='Giá thực tế', color='red')  # đường giá thực

# Thêm dữ liệu dự đoán vào train_data1 và test_data1
train_data1["Dự đoán"] = Y_train_predict
plt.plot(train_data1["Dự đoán"], label='Giá dự đoán train', color='green')

test_data1["Dự đoán"] = Y_test_predict
plt.plot(test_data1["Dự đoán"], label='Giá dự đoán test', color='blue')

plt.title('So sánh giá dự báo và giá thực tế')
plt.xlabel('Thời gian')
plt.ylabel('Giá mua chuyển khoản (VNĐ)')
plt.legend()
plt.show()
# Out:
# 1712 1713
# 191 191

# %%
from tensorflow.keras.models import load_model

# Gọi lại mô hình đã lưu
loaded_model = load_model("./Model/case_2/BiLSTM/model_9010/save_model.hdf5")
# Dự đoán lại trên tập test
Y_test_predict = loaded_model.predict(X_test)
# Đảo chuẩn hóa (inverse transform)
Y_test_predict = sc.inverse_transform(Y_test_predict)

# Tạo bảng so sánh
compare_df = pd.DataFrame({
    "Giá thực tế": Y_test.flatten(),
    "Giá dự đoán": Y_test_predict.flatten()
})

# Làm tròn về số nguyên
compare_df = compare_df.astype(int)
pd.set_option('display.max_rows', None)
# Hiển thị toàn bộ bảng
display(compare_df)
compare_df.to_csv("./Model/case_2/BiLSTM/model_9010/predict.csv", index=False)
# Out:
# 6/6 [==============================] - 1s 3ms/step
#      Giá thực tế  Giá dự đoán
# 0          25010        24745
# 1          24980        24892
# 2          24980        24913
# 3          24980        24929
# 4          25070        24936
# 5          25092        25002
# 6          25220        25034
# 7          25233        25138
# 8          25197        25170
# 9          25197        25159
# 10         25197        25160
# 11         25194        25166
# 12         25164        25166
# 13         25118        25156
# 14         25090        25123
# 15         25114        25094
# 16         25114        25100
# 17         25114        25099
# 18         25125        25098
# 19         25160        25103
# 20         25170        25123
# 21         25197        25134
# 22         25130        25158
# 23         25130        25121
# 24         25130        25114
# 25         25116        25112
# 26         25160        25104
# 27         25180        25129
# 28         25184        25149
# 29         25190        25152
# 30         25190        25159
# 31         25190        25162
# 32         25200        25162
# 33         25205        25172
# 34         25200        25179
# 35         25200        25177
# 36         25200        25178
# 37         25200        25178
# 38         25200        25178
# 39         25197        25179
# 40         25200        25177
# 41         25200        25178
# 42         25175        25178
# 43         25160        25162
# 44         25160        25149
# 45         25160        25145
# 46         25149        25143
# 47         25170        25135
# 48         25172        25147
# 49         25176        25148
# 50         25164        25151
# 51         25164        25144
# 52         25164        25143
# 53         25157        25142
# 54         25170        25139
# 55         25165        25146
# 56         25171        25144
# 57         25177        25147
# 58         25177        25152
# 59         25177        25153
# 60         25185        25153
# 61         25183        25160
# 62         25191        25159
# 63         25219        25165
# 64         25240        25185
# 65         25240        25203
# 66         25240        25209
# 67         25230        25212
# 68         25223        25207
# 69         25236        25202
# 70         25225        25211
# 71         25238        25207
# 72         25238        25214
# 73         25238        25215
# 74         25243        25215
# 75         25251        25218
# 76         25251        25225
# 77         25259        25226
# 78         25250        25233
# 79         25250        25229
# 80         25250        25228
# 81         25253        25228
# 82         25208        25231
# 83         25186        25202
# 84         25194        25183
# 85         25198        25181
# 86         25198        25182
# 87         25198        25181
# 88         25200        25181
# 89         25203        25178
# 90         25194        25179
# 91         25189        25175
# 92         25150        25171
# 93         25150        25145
# 94         25150        25138
# 95         25150        25135
# 96         25090        25134
# 97         24960        25094
# 98         24960        25004
# 99         24800        24977
# 100        24800        24867
# 101        24800        24835
# 102        24800        24817
# 103        24800        24801
# 104        24800        24788
# 105        24800        24785
# 106        24800        24776
# 107        24800        24776
# 108        24800        24776
# 109        25140        24776
# 110        25000        24996
# 111        24980        24958
# 112        25090        24950
# 113        25110        25021
# 114        25110        25050
# 115        25110        25061
# 116        25200        25085
# 117        25340        25137
# 118        25380        25243
# 119        25300        25304
# 120        25220        25270
# 121        25220        25215
# 122        25220        25202
# 123        25280        25204
# 124        25340        25251
# 125        25340        25299
# 126        25350        25304
# 127        25320        25310
# 128        25320        25295
# 129        25320        25292
# 130        25310        25297
# 131        25330        25295
# 132        25360        25306
# 133        25380        25328
# 134        25370        25343
# 135        25370        25342
# 136        25370        25343
# 137        25420        25343
# 138        25390        25377
# 139        25320        25368
# 140        25300        25324
# 141        25300        25300
# 142        25330        25292
# 143        25330        25308
# 144        25340        25315
# 145        25290        25319
# 146        25280        25283
# 147        25320        25269
# 148        25350        25290
# 149        25350        25316
# 150        25350        25322
# 151        25360        25325
# 152        25350        25328
# 153        25370        25323
# 154        25380        25339
# 155        25400        25351
# 156        25400        25367
# 157        25400        25371
# 158        25450        25373
# 159        25450        25406
# 160        25390        25415
# 161        25390        25380
# 162        25400        25375
# 163        25400        25379
# 164        25400        25379
# 165        25380        25384
# 166        25460        25371
# 167        25460        25414
# 168        25620        25424
# 169        25600        25535
# 170        25600        25545
# 171        25600        25552
# 172        25600        25553
# 173        25780        25562
# 174        25822        25682
# 175        25610        25751
# 176        25560        25623
# 177        25560        25569
# 178        25560        25555
# 179        25640        25551
# 180        25650        25622
# 181        25650        25640
# 182        25700        25619
# 183        25760        25649
# 184        25760        25696
# 185        25760        25707
# 186        25700        25720
# 187        25755        25683
# 188        25781        25712
# 189        25814        25740
# 190        25835        25774
