# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler #chuẩn hóa dữ liệu
from keras.callbacks import ModelCheckpoint #lưu lại huấn luyện tốt nhất
from tensorflow.keras.models import load_model #tải mô hình
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import ModelCheckpoint

import random
import tensorflow as tf

#các lớp để xây dựng mô hình
from keras.models import Sequential #đầu vào
from keras.layers import LSTM #học phụ thuộc
from keras.layers import Dropout, BatchNormalization #tránh học tủ
from keras.layers import Dense #đầu ra

#kiểm tra độ chính xác của mô hình
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
random.seed(42)
np.random.seed(42)
tf.random.set_seed(42)

# %%
df_usd = pd.read_parquet("./minio/usd/part-00000-18b834c3-cd6d-42ae-82c3-638999ff6d84-c000.snappy.parquet", engine="pyarrow")
df_usd.head()
# Out:
#         ngay ma_ngoai_te ten_ngoai_te  mua_chuyen_khoan      ban
# 0 2020-02-01         USD    US DOLLAR           23165.0  23305.0
# 1 2020-02-02         USD    US DOLLAR           23165.0  23305.0
# 2 2020-02-03         USD    US DOLLAR           23200.0  23340.0
# 3 2020-02-04         USD    US DOLLAR           23170.0  23310.0
# 4 2020-02-05         USD    US DOLLAR           23160.0  23300.0

# %%
df_usd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1911 entries, 0 to 1910
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ngay              1911 non-null   datetime64[ns]
#  1   ma_ngoai_te       1911 non-null   object
#  2   ten_ngoai_te      1911 non-null   object
#  3   mua_chuyen_khoan  1911 non-null   float64
#  4   ban               1911 non-null   float64
# dtypes: datetime64[ns](1), float64(2), object(2)
# memory usage: 74.8+ KB

# %%
df_usd.describe()
# Out:
#                       ngay  mua_chuyen_khoan           ban
# count                 1911       1911.000000   1911.000000
# mean   2022-09-13 00:00:00      23666.414443  23934.197279
# min    2020-02-01 00:00:00      22480.000000  22745.000000
# 25%    2021-05-23 12:00:00      22985.000000  23170.000000
# 50%    2022-09-13 00:00:00      23300.000000  23620.000000
# 75%    2024-01-03 12:00:00      24390.000000  24730.000000
# max    2025-04-25 00:00:00      25835.000000  26195.000000
# std                    NaN        885.147984    926.810272

# %%
print(df_usd.dtypes)
# Out:
# ngay                datetime64[ns]
# ma_ngoai_te                 object
# ten_ngoai_te                object
# mua_chuyen_khoan           float64
# ban                        float64
# dtype: object

# %%
import matplotlib.pyplot as plt
from matplotlib.dates import YearLocator, DateFormatter, MonthLocator

# Vẽ biểu đồ
plt.figure(figsize=(10, 5))
plt.plot(df_usd['ngay'].values, df_usd['mua_chuyen_khoan'].values, label='Giá mua chuyển khoản', color='red')

plt.xlabel('Năm')
plt.ylabel('Giá mua chuyển khoản')
plt.title('Biểu đồ tỷ giá VND_USD mua chuyển khoảng qua các năm')
plt.legend(loc='best')

# Định dạng trục x
plt.gca().xaxis.set_major_locator(YearLocator())
plt.gca().xaxis.set_major_formatter(DateFormatter('%Y'))
plt.gca().xaxis.set_minor_locator(MonthLocator())

plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
df_usd_ML = pd.DataFrame(df_usd, columns=['ngay','mua_chuyen_khoan'])
df_usd_ML.index = df_usd_ML.ngay
df_usd_ML.drop('ngay', axis = 1, inplace=True)
df_usd_ML.head()
# Out:
#             mua_chuyen_khoan
# ngay
# 2020-02-01           23165.0
# 2020-02-02           23165.0
# 2020-02-03           23200.0
# 2020-02-04           23170.0
# 2020-02-05           23160.0

# %%
print(df_usd_ML.columns)
# Out:
# Index(['mua_chuyen_khoan'], dtype='object')

# %%
data = df_usd_ML.values

# %%
data
# Out:
# array([[23165.],
#        [23165.],
#        [23200.],
#        ...,
#        [25781.],
#        [25814.],
#        [25835.]])

# %%
#hàm hóa dữ liệu
sc = MinMaxScaler(feature_range=(0,1))

#chuẩn hóa dữ train
scale_data = sc.fit_transform(data)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))

plt.plot(scale_data, label="Dữ liệu sau chuẩn hóa", color="red")

plt.xlabel("Thời gian (Index)")
plt.ylabel("Giá trị sau chuẩn hóa")
plt.title("Biểu đồ dữ liệu sau khi chuẩn hóa bằng MinMaxScaler")
plt.legend()
plt.show()

# %%
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Bidirectional, LSTM, Dense, Dropout

# Chọn window
window_size = 7
X_train, Y_train = [], []

for i in range(len(scale_data) - window_size):
    X_train.append(scale_data[i:i + window_size])
    Y_train.append(scale_data[i + window_size])

X_train = np.array(X_train)
Y_train = np.array(Y_train)

# Phân chia tập dữ liệu thành tập train và test 60 - 40
split_index = int(0.6 * len(X_train))

X_train, X_test = X_train[:split_index], X_train[split_index:]
Y_train, Y_test = Y_train[:split_index], Y_train[split_index:]

# Đảm bảo dữ liệu có đúng shape cho mô hình BiLSTM
X_train = X_train.reshape((X_train.shape[0], window_size, -1))
X_test = X_test.reshape((X_test.shape[0], window_size, -1))

# %%
print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
print("y_train shape:", Y_train.shape)
print("y_test shape:", Y_test.shape)
# Out:
# X_train shape: (1142, 7, 1)
# X_test shape: (762, 7, 1)
# y_train shape: (1142, 1)
# y_test shape: (762, 1)

# %%
print("Shape of X_train:", X_train.shape)
# Out:
# Shape of X_train: (1142, 7, 1)

# %% [markdown]
# # MODEL

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Bidirectional, BatchNormalization

# Xây dựng mô hình BiLSTM
model = Sequential()

# Lớp BiLSTM đầu tiên (return_sequences=True để kết nối lớp tiếp theo)
model.add(Bidirectional(LSTM(units=64, return_sequences=True, input_shape=(X_train.shape[1], 1))))
model.add(BatchNormalization())  # Ổn định dữ liệu đầu ra

# Lớp BiLSTM thứ hai
model.add(Bidirectional(LSTM(units=64)))
model.add(BatchNormalization())

# Dropout để giảm overfitting
model.add(Dropout(0.5))

# Lớp Dense đầu ra
model.add(Dense(1))

# Compile mô hình
model.compile(loss='mean_absolute_error', optimizer='adam')

# %% [markdown]
# # huấn luyện mô hình

# %%
save_model = "./Model/case_2/BiLSTM/model_6040/save_model.hdf5"
best_model = ModelCheckpoint(save_model,monitor='loss',verbose=2,save_best_only=True,mode='auto')

import time
start_model = time.time()  # Bắt đầu đo thời gian
model.fit(X_train,Y_train,epochs=100,batch_size=50,validation_split=0.4,verbose=2,callbacks=[best_model])
end_model = time.time()  # Kết thúc đo thời gian
print(f"Thời gian thực thi mô hình: {end_model - start_model:.2f} giây")
# Out:
# Epoch 1/100
#
# Epoch 1: loss improved from inf to 0.90286, saving model to ./Model/case_2/BiLSTM/model_6040\save_model.hdf5
# 14/14 - 6s - loss: 0.9029 - val_loss: 0.1966 - 6s/epoch - 406ms/step
# Epoch 2/100
#
# Epoch 2: loss improved from 0.90286 to 0.71409, saving model to ./Model/case_2/BiLSTM/model_6040\save_model.hdf5
# 14/14 - 0s - loss: 0.7141 - val_loss: 0.1755 - 215ms/epoch - 15ms/step
# Epoch 3/100
#
# Epoch 3: loss improved from 0.71409 to 0.64188, saving model to ./Model/case_2/BiLSTM/model_6040\save_model.hdf5
# 14/14 - 0s - loss: 0.6419 - val_loss: 0.1513 - 209ms/epoch - 15ms/step
# Epoch 4/100
#
# Epoch 4: loss did not improve from 0.64188
# 14/14 - 0s - loss: 0.6841 - val_loss: 0.1287 - 169ms/epoch - 12ms/step
# Epoch 5/100
#
# Epoch 5: loss improved from 0.64188 to 0.56119, saving model to ./Model/case_2/BiLSTM/model_6040\save_model.hdf5
# 14/14 - 0s - loss: 0.5612 - val_loss: 0.1427 - 193ms/epoch - 14ms/step
# Epoch 6/100
#
# Epoch 6: loss improved from 0.56119 to 0.49225, saving model to ./Model/case_2/BiLSTM/model_6040\save_model.hdf5
# 14/14 - 0s - loss: 0.4922 - val_loss: 0.1449 - 211ms/epoch - 15ms/step
# Epoch 7/100
#
# Epoch 7: loss improved from 0.49225 to 0.38984, saving model to ./Model/case_2/BiLSTM/model_6040\save_model.hdf5
# 14/14 - 0s - loss: 0.3898 - val_loss: 0.1485 - 194ms/epoch - 14ms/step
# Epoch 8/100
#
# Epoch 8: loss improved from 0.38984 to 0.26446, saving model to ./Model/case_2/BiLSTM/model_6040\save_model.hdf5
# 14/14 - 0s - loss: 0.2645 - val_loss: 0.1520 - 185ms/epoch - 13ms/step
# Epoch 9/100
#
# Epoch 9: loss improved from 0.26446 to 0.17759, saving model to ./Model/case_2/BiLSTM/model_6040\save_model.hdf5
# 14/14 - 0s - loss: 0.1776 - val_loss: 0.1583 - 203ms/epoch - 15ms/step
# Epoch 10/100
#
# Epoch 10: loss improved from 0.17759 to 0.08995, saving model to ./Model/case_2/BiLSTM/model_6040\save_model.hdf5
# 14/14 - 0s - loss: 0.0899 - val_loss: 0.1475 - 223ms/epoch - 16ms/step
# Epoch 11/100
#
# Epoch 11: loss improved from 0.08995 to 0.05346, saving model to ./Model/case_2/BiLSTM/model_6040\save_model.hdf5
# 14/14 - 0s - loss: 0.0535 - val_loss: 0.1361 - 250ms/epoch - 18ms/step
# Epoch 12/100
#
# Epoch 12: loss improved from 0.05346 to 0.03104, saving model to ./Model/case_2/BiLSTM/model_6040\save_model.hdf5
# 14/14 - 0s - loss: 0.0310 - val_loss: 0.1332 - 235ms/epoch - 17ms/step
# Epoch 13/100
#
# Epoch 13: loss improved from 0.03104 to 0.02301, saving model to ./Model/case_2/BiLSTM/model_6040\save_model.hdf5
# 14/14 - 0s - loss: 0.0230 - val_loss: 0.1394 - 202ms/epoch - 14ms/step
# Epoch 14/100
#
# Epoch 14: loss did not improve from 0.02301
# 14/14 - 0s - loss: 0.0244 - val_loss: 0.1314 - 180ms/epoch - 13ms/step
# Epoch 15/100
#
# Epoch 15: loss improved from 0.02301 to 0.01765, saving model to ./Model/case_2/BiLSTM/model_6040\save_model.hdf5
# 14/14 - 0s - loss: 0.0176 - val_loss: 0.1279 - 224ms/epoch - 16ms/step
# Epoch 16/100
#
# Epoch 16: loss improved from 0.01765 to 0.01722, saving model to ./Model/case_2/BiLSTM/model_6040\save_model.hdf5
# 14/14 - 0s - loss: 0.0172 - val_loss: 0.1188 - 200ms/epoch - 14ms/step
# Epoch 17/100
#
# Epoch 17: loss did not improve from 0.01722
# 14/14 - 0s - loss: 0.0189 - val_loss: 0.1169 - 189ms/epoch - 13ms/step
# Epoch 18/100
#
# Epoch 18: loss improved from 0.01722 to 0.01684, saving model to ./Model/case_2/BiLSTM/model_6040\save_model.hdf5
# 14/14 - 0s - loss: 0.0168 - val_loss: 0.1143 - 198ms/epoch - 14ms/step
# Epoch 19/100
#
# Epoch 19: loss improved from 0.01684 to 0.01545, saving model to ./Model/case_2/BiLSTM/model_6040\save_model.hdf5
# 14/14 - 0s - loss: 0.0154 - val_loss: 0.1119 - 216ms/epoch - 15ms/step
# Epoch 20/100
#
# Epoch 20: loss did not improve from 0.01545
# 14/14 - 0s - loss: 0.0167 - val_loss: 0.1066 - 192ms/epoch - 14ms/step
# Epoch 21/100
#
# Epoch 21: loss did not improve from 0.01545
# 14/14 - 0s - loss: 0.0161 - val_loss: 0.1063 - 180ms/epoch - 13ms/step
# Epoch 22/100
#
# Epoch 22: loss did not improve from 0.01545
# 14/14 - 0s - loss: 0.0176 - val_loss: 0.1083 - 208ms/epoch - 15ms/step
# Epoch 23/100
#
# Epoch 23: loss did not improve from 0.01545
# 14/14 - 0s - loss: 0.0172 - val_loss: 0.1078 - 175ms/epoch - 12ms/step
# Epoch 24/100
#
# Epoch 24: loss did not improve from 0.01545
# 14/14 - 0s - loss: 0.0175 - val_loss: 0.1072 - 176ms/epoch - 13ms/step
# Epoch 25/100
#
# Epoch 25: loss improved from 0.01545 to 0.01461, saving model to ./Model/case_2/BiLSTM/model_6040\save_model.hdf5
# 14/14 - 0s - loss: 0.0146 - val_loss: 0.1202 - 214ms/epoch - 15ms/step
# Epoch 26/100
#
# Epoch 26: loss did not improve from 0.01461
# 14/14 - 0s - loss: 0.0166 - val_loss: 0.1219 - 178ms/epoch - 13ms/step
# Epoch 27/100
#
# Epoch 27: loss did not improve from 0.01461
# 14/14 - 0s - loss: 0.0149 - val_loss: 0.1377 - 186ms/epoch - 13ms/step
# Epoch 28/100
#
# Epoch 28: loss did not improve from 0.01461
# 14/14 - 0s - loss: 0.0154 - val_loss: 0.1557 - 178ms/epoch - 13ms/step
# Epoch 29/100
#
# Epoch 29: loss did not improve from 0.01461
# 14/14 - 0s - loss: 0.0161 - val_loss: 0.1607 - 156ms/epoch - 11ms/step
# Epoch 30/100
#
# Epoch 30: loss improved from 0.01461 to 0.01222, saving model to ./Model/case_2/BiLSTM/model_6040\save_model.hdf5
# 14/14 - 0s - loss: 0.0122 - val_loss: 0.1691 - 206ms/epoch - 15ms/step
# Epoch 31/100
#
# Epoch 31: loss did not improve from 0.01222
# 14/14 - 0s - loss: 0.0140 - val_loss: 0.1581 - 200ms/epoch - 14ms/step
# Epoch 32/100
#
# Epoch 32: loss improved from 0.01222 to 0.01173, saving model to ./Model/case_2/BiLSTM/model_6040\save_model.hdf5
# 14/14 - 0s - loss: 0.0117 - val_loss: 0.1774 - 204ms/epoch - 15ms/step
# Epoch 33/100
#
# Epoch 33: loss did not improve from 0.01173
# 14/14 - 0s - loss: 0.0139 - val_loss: 0.2001 - 181ms/epoch - 13ms/step
# Epoch 34/100
#
# Epoch 34: loss did not improve from 0.01173
# 14/14 - 0s - loss: 0.0123 - val_loss: 0.2066 - 171ms/epoch - 12ms/step
# Epoch 35/100
#
# Epoch 35: loss did not improve from 0.01173
# 14/14 - 0s - loss: 0.0121 - val_loss: 0.1960 - 172ms/epoch - 12ms/step
# Epoch 36/100
#
# Epoch 36: loss did not improve from 0.01173
# 14/14 - 0s - loss: 0.0141 - val_loss: 0.1969 - 182ms/epoch - 13ms/step
# Epoch 37/100
#
# Epoch 37: loss did not improve from 0.01173
# 14/14 - 0s - loss: 0.0124 - val_loss: 0.2108 - 170ms/epoch - 12ms/step
# Epoch 38/100
#
# Epoch 38: loss did not improve from 0.01173
# 14/14 - 0s - loss: 0.0125 - val_loss: 0.1780 - 165ms/epoch - 12ms/step
# Epoch 39/100
#
# Epoch 39: loss did not improve from 0.01173
# 14/14 - 0s - loss: 0.0123 - val_loss: 0.1664 - 168ms/epoch - 12ms/step
# Epoch 40/100
#
# Epoch 40: loss did not improve from 0.01173
# 14/14 - 0s - loss: 0.0143 - val_loss: 0.1587 - 178ms/epoch - 13ms/step
# Epoch 41/100
#
# Epoch 41: loss did not improve from 0.01173
# 14/14 - 0s - loss: 0.0143 - val_loss: 0.1460 - 179ms/epoch - 13ms/step
# Epoch 42/100
#
# Epoch 42: loss improved from 0.01173 to 0.01154, saving model to ./Model/case_2/BiLSTM/model_6040\save_model.hdf5
# 14/14 - 0s - loss: 0.0115 - val_loss: 0.1433 - 204ms/epoch - 15ms/step
# Epoch 43/100
#
# Epoch 43: loss did not improve from 0.01154
# 14/14 - 0s - loss: 0.0141 - val_loss: 0.1526 - 172ms/epoch - 12ms/step
# Epoch 44/100
#
# Epoch 44: loss improved from 0.01154 to 0.01067, saving model to ./Model/case_2/BiLSTM/model_6040\save_model.hdf5
# 14/14 - 0s - loss: 0.0107 - val_loss: 0.1470 - 212ms/epoch - 15ms/step
# Epoch 45/100
#
# Epoch 45: loss improved from 0.01067 to 0.01038, saving model to ./Model/case_2/BiLSTM/model_6040\save_model.hdf5
# 14/14 - 0s - loss: 0.0104 - val_loss: 0.1267 - 210ms/epoch - 15ms/step
# Epoch 46/100
#
# Epoch 46: loss did not improve from 0.01038
# 14/14 - 0s - loss: 0.0151 - val_loss: 0.1036 - 177ms/epoch - 13ms/step
# Epoch 47/100
#
# Epoch 47: loss did not improve from 0.01038
# 14/14 - 0s - loss: 0.0152 - val_loss: 0.1084 - 173ms/epoch - 12ms/step
# Epoch 48/100
#
# Epoch 48: loss did not improve from 0.01038
# 14/14 - 0s - loss: 0.0135 - val_loss: 0.1127 - 171ms/epoch - 12ms/step
# Epoch 49/100
#
# Epoch 49: loss did not improve from 0.01038
# 14/14 - 0s - loss: 0.0118 - val_loss: 0.0899 - 189ms/epoch - 14ms/step
# Epoch 50/100
#
# Epoch 50: loss did not improve from 0.01038
# 14/14 - 0s - loss: 0.0114 - val_loss: 0.0512 - 210ms/epoch - 15ms/step
# Epoch 51/100
#
# Epoch 51: loss did not improve from 0.01038
# 14/14 - 0s - loss: 0.0117 - val_loss: 0.0617 - 203ms/epoch - 15ms/step
# Epoch 52/100
#
# Epoch 52: loss did not improve from 0.01038
# 14/14 - 0s - loss: 0.0115 - val_loss: 0.0615 - 180ms/epoch - 13ms/step
# Epoch 53/100
#
# Epoch 53: loss did not improve from 0.01038
# 14/14 - 0s - loss: 0.0127 - val_loss: 0.0504 - 179ms/epoch - 13ms/step
# Epoch 54/100
#
# Epoch 54: loss did not improve from 0.01038
# 14/14 - 0s - loss: 0.0105 - val_loss: 0.0423 - 197ms/epoch - 14ms/step
# Epoch 55/100
#
# Epoch 55: loss did not improve from 0.01038
# 14/14 - 0s - loss: 0.0115 - val_loss: 0.0386 - 192ms/epoch - 14ms/step
# Epoch 56/100
#
# Epoch 56: loss did not improve from 0.01038
# 14/14 - 0s - loss: 0.0120 - val_loss: 0.0250 - 187ms/epoch - 13ms/step
# Epoch 57/100
#
# Epoch 57: loss did not improve from 0.01038
# 14/14 - 0s - loss: 0.0134 - val_loss: 0.0272 - 174ms/epoch - 12ms/step
# Epoch 58/100
#
# Epoch 58: loss did not improve from 0.01038
# 14/14 - 0s - loss: 0.0113 - val_loss: 0.0356 - 179ms/epoch - 13ms/step
# Epoch 59/100
#
# Epoch 59: loss did not improve from 0.01038
# 14/14 - 0s - loss: 0.0132 - val_loss: 0.0249 - 197ms/epoch - 14ms/step
# Epoch 60/100
#
# Epoch 60: loss did not improve from 0.01038
# 14/14 - 0s - loss: 0.0124 - val_loss: 0.0243 - 168ms/epoch - 12ms/step
# Epoch 61/100
#
# Epoch 61: loss did not improve from 0.01038
# 14/14 - 0s - loss: 0.0109 - val_loss: 0.0290 - 165ms/epoch - 12ms/step
# Epoch 62/100
#
# Epoch 62: loss did not improve from 0.01038
# 14/14 - 0s - loss: 0.0146 - val_loss: 0.0320 - 212ms/epoch - 15ms/step
# Epoch 63/100
#
# Epoch 63: loss did not improve from 0.01038
# 14/14 - 0s - loss: 0.0112 - val_loss: 0.0203 - 204ms/epoch - 15ms/step
# Epoch 64/100
#
# Epoch 64: loss improved from 0.01038 to 0.00933, saving model to ./Model/case_2/BiLSTM/model_6040\save_model.hdf5
# 14/14 - 0s - loss: 0.0093 - val_loss: 0.0134 - 213ms/epoch - 15ms/step
# Epoch 65/100
#
# Epoch 65: loss did not improve from 0.00933
# 14/14 - 0s - loss: 0.0129 - val_loss: 0.0143 - 213ms/epoch - 15ms/step
# Epoch 66/100
#
# Epoch 66: loss did not improve from 0.00933
# 14/14 - 0s - loss: 0.0155 - val_loss: 0.0149 - 194ms/epoch - 14ms/step
# Epoch 67/100
#
# Epoch 67: loss did not improve from 0.00933
# 14/14 - 0s - loss: 0.0126 - val_loss: 0.0266 - 203ms/epoch - 14ms/step
# Epoch 68/100
#
# Epoch 68: loss did not improve from 0.00933
# 14/14 - 0s - loss: 0.0119 - val_loss: 0.0191 - 183ms/epoch - 13ms/step
# Epoch 69/100
#
# Epoch 69: loss did not improve from 0.00933
# 14/14 - 0s - loss: 0.0110 - val_loss: 0.0311 - 200ms/epoch - 14ms/step
# Epoch 70/100
#
# Epoch 70: loss did not improve from 0.00933
# 14/14 - 0s - loss: 0.0132 - val_loss: 0.0526 - 186ms/epoch - 13ms/step
# Epoch 71/100
#
# Epoch 71: loss did not improve from 0.00933
# 14/14 - 0s - loss: 0.0108 - val_loss: 0.0380 - 191ms/epoch - 14ms/step
# Epoch 72/100
#
# Epoch 72: loss did not improve from 0.00933
# 14/14 - 0s - loss: 0.0133 - val_loss: 0.0233 - 197ms/epoch - 14ms/step
# Epoch 73/100
#
# Epoch 73: loss did not improve from 0.00933
# 14/14 - 0s - loss: 0.0097 - val_loss: 0.0112 - 205ms/epoch - 15ms/step
# Epoch 74/100
#
# Epoch 74: loss did not improve from 0.00933
# 14/14 - 0s - loss: 0.0113 - val_loss: 0.0345 - 182ms/epoch - 13ms/step
# Epoch 75/100
#
# Epoch 75: loss did not improve from 0.00933
# 14/14 - 0s - loss: 0.0106 - val_loss: 0.0294 - 184ms/epoch - 13ms/step
# Epoch 76/100
#
# Epoch 76: loss did not improve from 0.00933
# 14/14 - 0s - loss: 0.0126 - val_loss: 0.0106 - 181ms/epoch - 13ms/step
# Epoch 77/100
#
# Epoch 77: loss did not improve from 0.00933
# 14/14 - 0s - loss: 0.0125 - val_loss: 0.0256 - 172ms/epoch - 12ms/step
# Epoch 78/100
#
# Epoch 78: loss did not improve from 0.00933
# 14/14 - 0s - loss: 0.0142 - val_loss: 0.0120 - 172ms/epoch - 12ms/step
# Epoch 79/100
#
# Epoch 79: loss did not improve from 0.00933
# 14/14 - 0s - loss: 0.0098 - val_loss: 0.0166 - 203ms/epoch - 14ms/step
# Epoch 80/100
#
# Epoch 80: loss did not improve from 0.00933
# 14/14 - 0s - loss: 0.0109 - val_loss: 0.0333 - 178ms/epoch - 13ms/step
# Epoch 81/100
#
# Epoch 81: loss did not improve from 0.00933
# 14/14 - 0s - loss: 0.0110 - val_loss: 0.0079 - 180ms/epoch - 13ms/step
# Epoch 82/100
#
# Epoch 82: loss did not improve from 0.00933
# 14/14 - 0s - loss: 0.0117 - val_loss: 0.0084 - 178ms/epoch - 13ms/step
# Epoch 83/100
#
# Epoch 83: loss did not improve from 0.00933
# 14/14 - 0s - loss: 0.0127 - val_loss: 0.0119 - 174ms/epoch - 12ms/step
# Epoch 84/100
#
# Epoch 84: loss did not improve from 0.00933
# 14/14 - 0s - loss: 0.0103 - val_loss: 0.0137 - 174ms/epoch - 12ms/step
# Epoch 85/100
#
# Epoch 85: loss did not improve from 0.00933
# 14/14 - 0s - loss: 0.0095 - val_loss: 0.0074 - 173ms/epoch - 12ms/step
# Epoch 86/100
#
# Epoch 86: loss did not improve from 0.00933
# 14/14 - 0s - loss: 0.0096 - val_loss: 0.0092 - 183ms/epoch - 13ms/step
# Epoch 87/100
#
# Epoch 87: loss did not improve from 0.00933
# 14/14 - 0s - loss: 0.0103 - val_loss: 0.0229 - 192ms/epoch - 14ms/step
# Epoch 88/100
#
# Epoch 88: loss did not improve from 0.00933
# 14/14 - 0s - loss: 0.0105 - val_loss: 0.0231 - 218ms/epoch - 16ms/step
# Epoch 89/100
#
# Epoch 89: loss did not improve from 0.00933
# 14/14 - 0s - loss: 0.0110 - val_loss: 0.0185 - 172ms/epoch - 12ms/step
# Epoch 90/100
#
# Epoch 90: loss did not improve from 0.00933
# 14/14 - 0s - loss: 0.0110 - val_loss: 0.0201 - 172ms/epoch - 12ms/step
# Epoch 91/100
#
# Epoch 91: loss did not improve from 0.00933
# 14/14 - 0s - loss: 0.0107 - val_loss: 0.0147 - 180ms/epoch - 13ms/step
# Epoch 92/100
#
# Epoch 92: loss did not improve from 0.00933
# 14/14 - 0s - loss: 0.0114 - val_loss: 0.0163 - 187ms/epoch - 13ms/step
# Epoch 93/100
#
# Epoch 93: loss did not improve from 0.00933
# 14/14 - 0s - loss: 0.0097 - val_loss: 0.0088 - 178ms/epoch - 13ms/step
# Epoch 94/100
#
# Epoch 94: loss did not improve from 0.00933
# 14/14 - 0s - loss: 0.0113 - val_loss: 0.0211 - 224ms/epoch - 16ms/step
# Epoch 95/100
#
# Epoch 95: loss improved from 0.00933 to 0.00838, saving model to ./Model/case_2/BiLSTM/model_6040\save_model.hdf5
# 14/14 - 0s - loss: 0.0084 - val_loss: 0.0180 - 210ms/epoch - 15ms/step
# Epoch 96/100
#
# Epoch 96: loss did not improve from 0.00838
# 14/14 - 0s - loss: 0.0090 - val_loss: 0.0500 - 180ms/epoch - 13ms/step
# Epoch 97/100
#
# Epoch 97: loss did not improve from 0.00838
# 14/14 - 0s - loss: 0.0100 - val_loss: 0.0627 - 192ms/epoch - 14ms/step
# Epoch 98/100
#
# Epoch 98: loss did not improve from 0.00838
# 14/14 - 0s - loss: 0.0122 - val_loss: 0.0868 - 189ms/epoch - 14ms/step
# Epoch 99/100
#
# Epoch 99: loss did not improve from 0.00838
# 14/14 - 0s - loss: 0.0100 - val_loss: 0.0390 - 187ms/epoch - 13ms/step
# Epoch 100/100
#
# Epoch 100: loss did not improve from 0.00838
# 14/14 - 0s - loss: 0.0113 - val_loss: 0.0186 - 201ms/epoch - 14ms/step
# Thời gian thực thi mô hình: 24.78 giây

# %%
#Model
final_model = load_model("./Model/case_2/BiLSTM/model_6040/save_model.hdf5")

# %%
#dữ liệu train
Y_train_predict = final_model.predict(X_train) #dự đoán trên tập đã train
Y_train_predict = sc.inverse_transform(Y_train_predict) #giá thực dự đoán
Y_train = sc.inverse_transform(Y_train) #giá thực train
# Out:
# 36/36 [==============================] - 1s 3ms/step

# %% [markdown]
# # DỰ ĐOÁN TRÊN TẬP TEST

# %%
#dữ liệu test
import time
start_model = time.time()  # Bắt đầu đo thời gian
Y_test_predict = final_model.predict(X_test)
end_model = time.time()  # Kết thúc đo thời gian
print(f"Thời gian thực thi mô hình: {end_model - start_model:.2f} giây")
Y_test_predict = sc.inverse_transform(Y_test_predict) #giá dự đoán
Y_test = sc.inverse_transform(Y_test) #giá thực
# Out:
# 24/24 [==============================] - 0s 3ms/step
# Thời gian thực thi mô hình: 0.14 giây

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import mean_absolute_error, mean_squared_error

# Tính toán các giá trị cho tập Train
mae_train = round(mean_absolute_error(Y_train, Y_train_predict), 3)
mse_train = round(mean_squared_error(Y_train, Y_train_predict), 3)
rmse_train = round(np.sqrt(mse_train), 3)

# Tính toán các giá trị cho tập Test
mae_test = round(mean_absolute_error(Y_test, Y_test_predict), 3)
mse_test = round(mean_squared_error(Y_test, Y_test_predict), 3)
rmse_test = round(np.sqrt(mse_test), 3)

# Tạo DataFrame để hiển thị kết quả
metrics = pd.DataFrame({
    "Tập dữ liệu": ["Train", "Test"],
    "MAE": [mae_train, mae_test],
    "MSE": [mse_train, mse_test],
    "RMSE": [rmse_train, rmse_test]
})

# In kết quả
print(metrics)
print(f"Thời gian thực thi mô hình: {end_model - start_model:.2f} giây")
# Out:
#   Tập dữ liệu     MAE       MSE    RMSE
# 0       Train  54.196  3775.231  61.443
# 1        Test  61.467  4944.640  70.318
# Thời gian thực thi mô hình: 0.14 giây

# %%
# Xác định 60% dữ liệu làm tập train
train_size = int(len(df_usd_ML) * 0.6)

# Cắt lại cho đúng chiều dài:
train_data1 = df_usd_ML[6:train_size-1].copy()
test_data1 = df_usd_ML[train_size+3:].copy()


print(len(train_data1), len(Y_train_predict))
print(len(test_data1), len(Y_test_predict))

# Cắt dữ liệu dự đoán để khớp với dữ liệu gốc
Y_train_predict = Y_train_predict[:len(train_data1)]
Y_test_predict = Y_test_predict[:len(test_data1)]

# Đảm bảo test_data1 có số lượng dòng khớp với Y_test_predict
test_data1 = test_data1.iloc[:len(Y_test_predict)]

plt.figure(figsize=(24,8))
plt.plot(df_usd_ML, label='Giá thực tế', color='red')  # đường giá thực

# Thêm dữ liệu dự đoán vào train_data1 và test_data1
train_data1["Dự đoán"] = Y_train_predict
plt.plot(train_data1["Dự đoán"], label='Giá dự đoán train', color='green')

test_data1["Dự đoán"] = Y_test_predict
plt.plot(test_data1["Dự đoán"], label='Giá dự đoán test', color='blue')

plt.title('So sánh giá dự báo và giá thực tế')
plt.xlabel('Thời gian')
plt.ylabel('Giá mua chuyển khoản (VNĐ)')
plt.legend()
plt.show()
# Out:
# 1139 1142
# 762 762

# %%
from tensorflow.keras.models import load_model

# Gọi lại mô hình đã lưu
loaded_model = load_model("./Model/case_2/BiLSTM/model_6040/save_model.hdf5")
# Dự đoán lại trên tập test
Y_test_predict = loaded_model.predict(X_test)
# Đảo chuẩn hóa (inverse transform)
Y_test_predict = sc.inverse_transform(Y_test_predict)

# Tạo bảng so sánh
compare_df = pd.DataFrame({
    "Giá thực tế": Y_test.flatten(),
    "Giá dự đoán": Y_test_predict.flatten()
})

# Làm tròn về số nguyên
compare_df = compare_df.astype(int)
pd.set_option('display.max_rows', None)
# Hiển thị toàn bộ bảng
display(compare_df)
compare_df.to_csv("./Model/case_2/BiLSTM/model_6040/predict.csv", index=False)
# Out:
# 24/24 [==============================] - 1s 3ms/step
#      Giá thực tế  Giá dự đoán
# 0          23340        23297
# 1          23340        23295
# 2          23320        23295
# 3          23310        23280
# 4          23300        23270
# 5          23290        23260
# 6          23290        23250
# 7          23290        23247
# 8          23310        23246
# 9          23295        23259
# 10         23280        23251
# 11         23280        23239
# 12         23280        23237
# 13         23280        23235
# 14         23280        23235
# 15         23280        23234
# 16         23290        23234
# 17         23290        23241
# 18         23270        23242
# 19         23280        23229
# 20         23280        23234
# 21         23280        23234
# 22         23320        23234
# 23         23360        23262
# 24         23305        23297
# 25         23320        23266
# 26         23320        23273
# 27         23320        23274
# 28         23320        23274
# 29         23310        23274
# 30         23310        23267
# 31         23310        23265
# 32         23290        23265
# 33         23290        23250
# 34         23290        23247
# 35         23290        23246
# 36         23290        23245
# 37         23290        23244
# 38         23290        23244
# 39         23280        23244
# 40         23280        23237
# 41         23280        23235
# 42         23280        23235
# 43         23290        23234
# 44         23290        23241
# 45         23300        23243
# 46         23300        23250
# 47         23300        23252
# 48         23300        23253
# 49         23300        23253
# 50         23280        23254
# 51         23280        23240
# 52         23285        23237
# 53         23280        23239
# 54         23320        23235
# 55         23320        23263
# 56         23320        23268
# 57         23275        23271
# 58         23290        23241
# 59         23320        23246
# 60         23300        23266
# 61         23320        23256
# 62         23320        23269
# 63         23320        23272
# 64         23310        23273
# 65         23315        23266
# 66         23325        23269
# 67         23310        23276
# 68         23310        23267
# 69         23310        23265
# 70         23310        23265
# 71         23330        23264
# 72         23320        23278
# 73         23320        23274
# 74         23320        23274
# 75         23310        23274
# 76         23310        23267
# 77         23310        23265
# 78         23300        23265
# 79         23320        23257
# 80         23330        23270
# 81         23360        23279
# 82         23360        23303
# 83         23360        23308
# 84         23360        23311
# 85         23350        23312
# 86         23350        23306
# 87         23340        23305
# 88         23340        23298
# 89         23350        23296
# 90         23350        23302
# 91         23350        23303
# 92         23360        23303
# 93         23370        23311
# 94         23380        23319
# 95         23390        23329
# 96         23410        23339
# 97         23410        23356
# 98         23410        23360
# 99         23480        23362
# 100        23520        23413
# 101        23580        23453
# 102        23560        23507
# 103        23470        23506
# 104        23470        23444
# 105        23470        23433
# 106        23480        23429
# 107        23520        23434
# 108        23510        23464
# 109        23475        23462
# 110        23470        23437
# 111        23470        23429
# 112        23470        23427
# 113        23460        23425
# 114        23470        23418
# 115        23465        23423
# 116        23470        23420
# 117        23480        23423
# 118        23480        23430
# 119        23480        23432
# 120        23485        23433
# 121        23490        23437
# 122        23495        23441
# 123        23500        23446
# 124        23520        23451
# 125        23520        23467
# 126        23520        23470
# 127        23515        23472
# 128        23520        23469
# 129        23555        23472
# 130        23580        23498
# 131        23550        23522
# 132        23550        23505
# 133        23550        23504
# 134        23550        23504
# 135        23555        23503
# 136        23570        23507
# 137        23570        23519
# 138        23570        23521
# 139        23570        23522
# 140        23570        23523
# 141        23650        23523
# 142        23800        23581
# 143        23785        23704
# 144        23700        23717
# 145        23630        23663
# 146        23630        23605
# 147        23630        23593
# 148        23630        23588
# 149        23730        23589
# 150        23800        23660
# 151        23810        23723
# 152        23810        23744
# 153        23810        23752
# 154        23810        23755
# 155        23920        23756
# 156        24010        23840
# 157        23975        23925
# 158        23900        23915
# 159        23900        23862
# 160        23900        23854
# 161        23900        23849
# 162        23900        23851
# 163        23900        23854
# 164        23880        23853
# 165        23880        23835
# 166        23920        23832
# 167        23920        23861
# 168        23920        23865
# 169        23885        23867
# 170        23920        23843
# 171        23980        23864
# 172        24045        23911
# 173        24085        23970
# 174        24085        24012
# 175        24085        24022
# 176        24190        24024
# 177        24205        24107
# 178        24140        24132
# 179        24120        24091
# 180        24190        24073
# 181        24190        24121
# 182        24190        24126
# 183        24195        24134
# 184        24200        24141
# 185        24200        24142
# 186        24220        24141
# 187        24120        24160
# 188        24120        24087
# 189        24120        24076
# 190        24150        24072
# 191        24210        24093
# 192        24240        24142
# 193        24220        24175
# 194        24210        24162
# 195        24210        24154
# 196        24210        24152
# 197        24210        24152
# 198        24245        24155
# 199        24265        24184
# 200        24270        24202
# 201        24275        24209
# 202        24275        24215
# 203        24275        24216
# 204        24290        24216
# 205        24328        24229
# 206        24350        24262
# 207        24370        24284
# 208        24360        24304
# 209        24360        24300
# 210        24360        24300
# 211        24420        24300
# 212        24390        24348
# 213        24380        24333
# 214        24420        24325
# 215        24390        24355
# 216        24390        24335
# 217        24390        24332
# 218        24385        24336
# 219        24390        24329
# 220        24410        24332
# 221        24410        24350
# 222        24350        24351
# 223        24350        24305
# 224        24350        24299
# 225        24160        24296
# 226        24150        24152
# 227        24190        24125
# 228        24190        24145
# 229        24130        24142
# 230        24130        24097
# 231        24130        24093
# 232        24200        24079
# 233        24190        24130
# 234        24100        24133
# 235        24115        24067
# 236        24075        24066
# 237        24075        24034
# 238        24075        24027
# 239        24005        24029
# 240        23950        23976
# 241        24015        23922
# 242        24050        23961
# 243        24080        23988
# 244        24080        24017
# 245        24080        24024
# 246        24075        24024
# 247        24080        24018
# 248        24045        24024
# 249        24090        23999
# 250        24110        24030
# 251        24110        24049
# 252        24110        24053
# 253        24065        24055
# 254        24090        24022
# 255        24095        24033
# 256        24090        24040
# 257        24050        24038
# 258        24050        24008
# 259        24050        24004
# 260        24060        23999
# 261        24090        24007
# 262        24080        24031
# 263        24080        24027
# 264        24070        24026
# 265        24070        24019
# 266        24070        24017
# 267        24140        24017
# 268        24175        24071
# 269        24170        24106
# 270        24160        24109
# 271        24060        24104
# 272        24060        24028
# 273        24060        24015
# 274        24060        24013
# 275        24130        24013
# 276        24140        24065
# 277        24060        24081
# 278        24080        24020
# 279        24080        24028
# 280        24080        24027
# 281        24080        24026
# 282        24155        24029
# 283        24180        24087
# 284        24190        24111
# 285        24190        24126
# 286        24190        24130
# 287        24190        24131
# 288        24175        24130
# 289        24185        24123
# 290        24215        24130
# 291        24295        24153
# 292        24290        24219
# 293        24290        24225
# 294        24290        24229
# 295        24295        24230
# 296        24370        24233
# 297        24360        24293
# 298        24385        24298
# 299        24375        24319
# 300        24375        24315
# 301        24375        24315
# 302        24365        24314
# 303        24390        24311
# 304        24430        24328
# 305        24430        24363
# 306        24425        24368
# 307        24425        24366
# 308        24425        24366
# 309        24375        24365
# 310        24235        24327
# 311        24255        24218
# 312        24240        24216
# 313        24160        24199
# 314        24160        24136
# 315        24160        24126
# 316        24200        24120
# 317        24190        24140
# 318        24230        24138
# 319        24230        24169
# 320        24230        24170
# 321        24230        24171
# 322        24230        24172
# 323        24230        24174
# 324        24230        24173
# 325        24230        24175
# 326        24270        24175
# 327        24340        24206
# 328        24340        24265
# 329        24340        24274
# 330        24360        24278
# 331        24360        24295
# 332        24340        24296
# 333        24420        24283
# 334        24450        24347
# 335        24450        24379
# 336        24450        24385
# 337        24500        24388
# 338        24460        24428
# 339        24450        24399
# 340        24480        24394
# 341        24470        24417
# 342        24470        24411
# 343        24470        24411
# 344        24500        24415
# 345        24510        24436
# 346        24520        24445
# 347        24530        24458
# 348        24500        24467
# 349        24500        24445
# 350        24500        24442
# 351        24450        24442
# 352        24460        24404
# 353        24480        24407
# 354        24530        24422
# 355        24550        24461
# 356        24550        24484
# 357        24550        24489
# 358        24560        24487
# 359        24590        24495
# 360        24610        24520
# 361        24610        24542
# 362        24610        24547
# 363        24610        24548
# 364        24610        24548
# 365        24590        24548
# 366        24610        24534
# 367        24610        24549
# 368        24610        24551
# 369        24630        24551
# 370        24630        24567
# 371        24630        24570
# 372        24630        24569
# 373        24710        24570
# 374        24790        24634
# 375        24770        24707
# 376        24780        24703
# 377        24780        24712
# 378        24780        24713
# 379        24790        24710
# 380        24790        24723
# 381        24790        24731
# 382        24830        24729
# 383        24840        24763
# 384        24840        24775
# 385        24840        24777
# 386        24960        24778
# 387        25008        24876
# 388        25130        24927
# 389        25130        25042
# 390        25163        25056
# 391        25163        25086
# 392        25163        25084
# 393        25175        25092
# 394        25178        25103
# 395        25177        25118
# 396        25167        25117
# 397        25118        25112
# 398        25118        25070
# 399        25118        25065
# 400        25118        25065
# 401        25118        25065
# 402        25118        25066
# 403        25144        25066
# 404        25143        25083
# 405        25147        25084
# 406        25147        25088
# 407        25157        25089
# 408        25155        25097
# 409        25161        25095
# 410        25178        25103
# 411        25184        25118
# 412        25184        25125
# 413        25184        25125
# 414        25179        25126
# 415        25182        25122
# 416        25182        25124
# 417        25152        25126
# 418        25250        25101
# 419        25250        25181
# 420        25250        25189
# 421        25259        25191
# 422        25263        25199
# 423        25266        25203
# 424        25250        25200
# 425        25277        25197
# 426        25277        25218
# 427        25277        25220
# 428        25281        25222
# 429        25268        25226
# 430        25265        25215
# 431        25250        25209
# 432        25254        25199
# 433        25254        25201
# 434        25254        25201
# 435        25234        25202
# 436        25218        25184
# 437        25213        25169
# 438        25213        25161
# 439        25213        25161
# 440        25213        25161
# 441        25213        25162
# 442        25214        25160
# 443        25222        25159
# 444        25226        25165
# 445        25217        25169
# 446        25221        25162
# 447        25221        25165
# 448        25221        25165
# 449        25231        25165
# 450        25251        25174
# 451        25249        25193
# 452        25247        25192
# 453        25248        25191
# 454        25248        25191
# 455        25248        25191
# 456        25255        25191
# 457        25245        25200
# 458        25250        25192
# 459        25257        25195
# 460        25253        25201
# 461        25253        25198
# 462        25253        25198
# 463        25244        25199
# 464        25245        25190
# 465        25250        25191
# 466        25243        25195
# 467        25238        25190
# 468        25238        25185
# 469        25238        25185
# 470        25235        25183
# 471        25234        25181
# 472        25239        25181
# 473        25245        25184
# 474        25240        25189
# 475        25240        25186
# 476        25240        25185
# 477        25237        25185
# 478        25237        25182
# 479        25168        25182
# 480        25150        25125
# 481        25158        25104
# 482        25158        25107
# 483        25158        25107
# 484        25154        25108
# 485        25157        25107
# 486        25177        25102
# 487        25120        25117
# 488        25121        25072
# 489        25121        25068
# 490        25121        25067
# 491        25115        25066
# 492        25120        25062
# 493        25080        25069
# 494        25060        25030
# 495        25040        25010
# 496        25040        24991
# 497        25040        24988
# 498        24930        24987
# 499        24980        24900
# 500        24995        24926
# 501        24980        24939
# 502        24930        24927
# 503        24930        24886
# 504        24930        24883
# 505        24940        24870
# 506        24950        24882
# 507        24850        24894
# 508        24870        24814
# 509        24890        24816
# 510        24890        24831
# 511        24890        24832
# 512        24820        24835
# 513        24740        24781
# 514        24760        24701
# 515        24780        24708
# 516        24810        24725
# 517        24810        24751
# 518        24810        24757
# 519        24710        24753
# 520        24660        24666
# 521        24680        24618
# 522        24690        24627
# 523        24690        24636
# 524        24690        24638
# 525        24690        24641
# 526        24690        24633
# 527        24690        24629
# 528        24675        24630
# 529        24580        24619
# 530        24430        24543
# 531        24430        24418
# 532        24430        24399
# 533        24500        24391
# 534        24490        24443
# 535        24385        24442
# 536        24410        24358
# 537        24390        24356
# 538        24390        24339
# 539        24390        24335
# 540        24380        24339
# 541        24430        24332
# 542        24470        24363
# 543        24410        24401
# 544        24400        24359
# 545        24400        24347
# 546        24400        24344
# 547        24460        24341
# 548        24430        24391
# 549        24410        24377
# 550        24460        24357
# 551        24420        24393
# 552        24420        24366
# 553        24420        24363
# 554        24400        24366
# 555        24430        24348
# 556        24480        24367
# 557        24580        24413
# 558        24580        24496
# 559        24580        24509
# 560        24580        24514
# 561        24670        24513
# 562        24665        24585
# 563        24665        24592
# 564        24670        24601
# 565        24640        24606
# 566        24640        24582
# 567        24640        24577
# 568        24660        24583
# 569        24765        24598
# 570        24810        24685
# 571        25010        24734
# 572        24980        24908
# 573        24980        24904
# 574        24980        24905
# 575        25070        24903
# 576        25092        24982
# 577        25220        25008
# 578        25233        25139
# 579        25197        25160
# 580        25197        25132
# 581        25197        25126
# 582        25194        25131
# 583        25164        25127
# 584        25118        25115
# 585        25090        25077
# 586        25114        25045
# 587        25114        25061
# 588        25114        25063
# 589        25125        25064
# 590        25160        25072
# 591        25170        25098
# 592        25197        25106
# 593        25130        25133
# 594        25130        25079
# 595        25130        25073
# 596        25116        25072
# 597        25160        25063
# 598        25180        25099
# 599        25184        25124
# 600        25190        25124
# 601        25190        25130
# 602        25190        25130
# 603        25200        25128
# 604        25205        25140
# 605        25200        25147
# 606        25200        25144
# 607        25200        25144
# 608        25200        25144
# 609        25200        25143
# 610        25197        25144
# 611        25200        25142
# 612        25200        25144
# 613        25175        25144
# 614        25160        25124
# 615        25160        25109
# 616        25160        25107
# 617        25149        25106
# 618        25170        25098
# 619        25172        25115
# 620        25176        25116
# 621        25164        25118
# 622        25164        25109
# 623        25164        25108
# 624        25157        25106
# 625        25170        25102
# 626        25165        25113
# 627        25171        25110
# 628        25177        25114
# 629        25177        25119
# 630        25177        25120
# 631        25185        25119
# 632        25183        25127
# 633        25191        25126
# 634        25219        25133
# 635        25240        25158
# 636        25240        25178
# 637        25240        25180
# 638        25230        25182
# 639        25223        25172
# 640        25236        25165
# 641        25225        25178
# 642        25238        25172
# 643        25238        25182
# 644        25238        25184
# 645        25243        25183
# 646        25251        25186
# 647        25251        25195
# 648        25259        25194
# 649        25250        25202
# 650        25250        25195
# 651        25250        25195
# 652        25253        25195
# 653        25208        25198
# 654        25186        25160
# 655        25194        25139
# 656        25198        25142
# 657        25198        25145
# 658        25198        25146
# 659        25200        25148
# 660        25203        25146
# 661        25194        25146
# 662        25189        25139
# 663        25150        25135
# 664        25150        25101
# 665        25150        25098
# 666        25150        25097
# 667        25090        25098
# 668        24960        25048
# 669        24960        24937
# 670        24800        24920
# 671        24800        24789
# 672        24800        24774
# 673        24800        24770
# 674        24800        24764
# 675        24800        24752
# 676        24800        24755
# 677        24800        24741
# 678        24800        24741
# 679        24800        24741
# 680        25140        24741
# 681        25000        25025
# 682        24980        24939
# 683        25090        24919
# 684        25110        25006
# 685        25110        25028
# 686        25110        25025
# 687        25200        25060
# 688        25340        25122
# 689        25380        25246
# 690        25300        25305
# 691        25220        25244
# 692        25220        25168
# 693        25220        25154
# 694        25280        25157
# 695        25340        25223
# 696        25340        25287
# 697        25350        25287
# 698        25320        25289
# 699        25320        25263
# 700        25320        25257
# 701        25310        25262
# 702        25330        25260
# 703        25360        25276
# 704        25380        25305
# 705        25370        25322
# 706        25370        25316
# 707        25370        25315
# 708        25420        25313
# 709        25390        25357
# 710        25320        25338
# 711        25300        25280
# 712        25300        25255
# 713        25330        25251
# 714        25330        25275
# 715        25340        25286
# 716        25290        25293
# 717        25280        25244
# 718        25320        25229
# 719        25350        25260
# 720        25350        25292
# 721        25350        25296
# 722        25360        25300
# 723        25350        25302
# 724        25370        25292
# 725        25380        25312
# 726        25400        25325
# 727        25400        25343
# 728        25400        25345
# 729        25450        25347
# 730        25450        25388
# 731        25390        25393
# 732        25390        25343
# 733        25400        25341
# 734        25400        25347
# 735        25400        25347
# 736        25380        25354
# 737        25460        25338
# 738        25460        25398
# 739        25620        25404
# 740        25600        25548
# 741        25600        25544
# 742        25600        25544
# 743        25600        25537
# 744        25780        25543
# 745        25822        25699
# 746        25610        25771
# 747        25560        25585
# 748        25560        25525
# 749        25560        25513
# 750        25640        25507
# 751        25650        25604
# 752        25650        25633
# 753        25700        25608
# 754        25760        25646
# 755        25760        25702
# 756        25760        25704
# 757        25700        25714
# 758        25755        25661
# 759        25781        25701
# 760        25814        25732
# 761        25835        25773
