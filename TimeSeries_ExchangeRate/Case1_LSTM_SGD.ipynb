# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler #chuẩn hóa dữ liệu
from keras.callbacks import ModelCheckpoint #lưu lại huấn luyện tốt nhất
from tensorflow.keras.models import load_model #tải mô hình
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

import random
import tensorflow as tf

#các lớp để xây dựng mô hình
from keras.models import Sequential #đầu vào
from keras.layers import LSTM #học phụ thuộc
from keras.layers import Dropout, BatchNormalization #tránh học tủ
from keras.layers import Dense #đầu ra

#kiểm tra độ chính xác của mô hình
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
random.seed(42)
np.random.seed(42)
tf.random.set_seed(42)

# %%
df_usd = pd.read_parquet("./minio/usd/part-00000-18b834c3-cd6d-42ae-82c3-638999ff6d84-c000.snappy.parquet", engine="pyarrow")
df_usd.head()
# Out:
#         ngay ma_ngoai_te ten_ngoai_te  mua_chuyen_khoan      ban
# 0 2020-02-01         USD    US DOLLAR           23165.0  23305.0
# 1 2020-02-02         USD    US DOLLAR           23165.0  23305.0
# 2 2020-02-03         USD    US DOLLAR           23200.0  23340.0
# 3 2020-02-04         USD    US DOLLAR           23170.0  23310.0
# 4 2020-02-05         USD    US DOLLAR           23160.0  23300.0

# %%
df_usd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1911 entries, 0 to 1910
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ngay              1911 non-null   datetime64[ns]
#  1   ma_ngoai_te       1911 non-null   object
#  2   ten_ngoai_te      1911 non-null   object
#  3   mua_chuyen_khoan  1911 non-null   float64
#  4   ban               1911 non-null   float64
# dtypes: datetime64[ns](1), float64(2), object(2)
# memory usage: 74.8+ KB

# %%
df_usd.describe()
# Out:
#                       ngay  mua_chuyen_khoan           ban
# count                 1911       1911.000000   1911.000000
# mean   2022-09-13 00:00:00      23666.414443  23934.197279
# min    2020-02-01 00:00:00      22480.000000  22745.000000
# 25%    2021-05-23 12:00:00      22985.000000  23170.000000
# 50%    2022-09-13 00:00:00      23300.000000  23620.000000
# 75%    2024-01-03 12:00:00      24390.000000  24730.000000
# max    2025-04-25 00:00:00      25835.000000  26195.000000
# std                    NaN        885.147984    926.810272

# %%
print(df_usd.dtypes)
# Out:
# ngay                datetime64[ns]
# ma_ngoai_te                 object
# ten_ngoai_te                object
# mua_chuyen_khoan           float64
# ban                        float64
# dtype: object

# %%
import matplotlib.pyplot as plt
from matplotlib.dates import YearLocator, DateFormatter, MonthLocator

# Vẽ biểu đồ
plt.figure(figsize=(10, 5))
plt.plot(df_usd['ngay'].values, df_usd['mua_chuyen_khoan'].values, label='Giá mua chuyển khoản', color='red')

plt.xlabel('Năm')
plt.ylabel('Giá mua chuyển khoản')
plt.title('Biểu đồ tỷ giá VND_USD mua chuyển khoảng qua các năm')
plt.legend(loc='best')

# Định dạng trục x
plt.gca().xaxis.set_major_locator(YearLocator())
plt.gca().xaxis.set_major_formatter(DateFormatter('%Y'))
plt.gca().xaxis.set_minor_locator(MonthLocator())

plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
df_usd_ML = pd.DataFrame(df_usd, columns=['ngay','mua_chuyen_khoan'])
df_usd_ML.index = df_usd_ML.ngay
df_usd_ML.drop('ngay', axis = 1, inplace=True)
df_usd_ML.head()
# Out:
#             mua_chuyen_khoan
# ngay
# 2020-02-01           23165.0
# 2020-02-02           23165.0
# 2020-02-03           23200.0
# 2020-02-04           23170.0
# 2020-02-05           23160.0

# %%
print(df_usd_ML.columns)
# Out:
# Index(['mua_chuyen_khoan'], dtype='object')

# %%
data = df_usd_ML.values

# %%
data
# Out:
# array([[23165.],
#        [23165.],
#        [23200.],
#        ...,
#        [25781.],
#        [25814.],
#        [25835.]])

# %%
#hàm hóa dữ liệu
sc = MinMaxScaler(feature_range=(0,1))

#chuẩn hóa dữ train
scale_data = sc.fit_transform(data)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))

plt.plot(scale_data, label="Dữ liệu sau chuẩn hóa", color="red")

plt.xlabel("Thời gian (Index)")
plt.ylabel("Giá trị sau chuẩn hóa")
plt.title("Biểu đồ dữ liệu sau khi chuẩn hóa bằng MinMaxScaler")
plt.legend()
plt.show()

# %%
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Bidirectional, LSTM, Dense, Dropout

# Chọn window
window_size = 7
X_train, Y_train = [], []

for i in range(len(scale_data) - window_size):
    X_train.append(scale_data[i:i + window_size])
    Y_train.append(scale_data[i + window_size])

X_train = np.array(X_train)
Y_train = np.array(Y_train)

# Phân chia tập dữ liệu thành tập train và test
split_index = int(0.8 * len(X_train))

X_train, X_test = X_train[:split_index], X_train[split_index:]
Y_train, Y_test = Y_train[:split_index], Y_train[split_index:]

# Đảm bảo dữ liệu có đúng shape cho mô hình BiLSTM
X_train = X_train.reshape((X_train.shape[0], window_size, -1))
X_test = X_test.reshape((X_test.shape[0], window_size, -1))

# %%
print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
print("y_train shape:", Y_train.shape)
print("y_test shape:", Y_test.shape)
# Out:
# X_train shape: (1523, 7, 1)
# X_test shape: (381, 7, 1)
# y_train shape: (1523, 1)
# y_test shape: (381, 1)

# %% [markdown]
# # MODEL

# %%
#xây dựng mô hình
model = Sequential() #tạo lớp mạng cho dữ liệu đầu vào
#2 lớp LSTM
model.add(LSTM(units=128,input_shape=(X_train.shape[1],1),return_sequences=True))
model.add(LSTM(units=64))
model.add(Dropout(0.5)) #loại bỏ 1 số đơn vị tránh học tủ (overfitting)
model.add(Dense(1)) #output đầu ra 1 chiều
#đo sai số tuyệt đối trung bình có sử dụng trình tối ưu hóa sgd
model.compile(loss='mean_absolute_error',optimizer='sgd')

# %% [markdown]
# # huấn luyện mô hình

# %%
#huấn luyện mô hình
save_model = "./Model/case_1/LSTM/model_SGD/save_model.hdf5"
best_model = ModelCheckpoint(save_model,monitor='loss',verbose=2,save_best_only=True,mode='auto')

import time
start_model = time.time()  # Bắt đầu đo thời gian
model.fit(X_train,Y_train,epochs=100,batch_size=50,validation_split=0.4,verbose=2,callbacks=[best_model])
end_model = time.time()  # Kết thúc đo thời gian
print(f"Thời gian thực thi mô hình: {end_model - start_model:.2f} giây")
# Out:
# Epoch 1/100
#
# Epoch 1: loss improved from inf to 0.06626, saving model to ./Model/case_1/LSTM/model_SGD\save_model.hdf5
# 19/19 - 3s - loss: 0.0663 - val_loss: 0.2246 - 3s/epoch - 144ms/step
# Epoch 2/100
#
# Epoch 2: loss improved from 0.06626 to 0.05298, saving model to ./Model/case_1/LSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0530 - val_loss: 0.2397 - 259ms/epoch - 14ms/step
# Epoch 3/100
#
# Epoch 3: loss improved from 0.05298 to 0.05297, saving model to ./Model/case_1/LSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0530 - val_loss: 0.2349 - 240ms/epoch - 13ms/step
# Epoch 4/100
#
# Epoch 4: loss improved from 0.05297 to 0.05240, saving model to ./Model/case_1/LSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0524 - val_loss: 0.2416 - 226ms/epoch - 12ms/step
# Epoch 5/100
#
# Epoch 5: loss improved from 0.05240 to 0.05170, saving model to ./Model/case_1/LSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0517 - val_loss: 0.2316 - 231ms/epoch - 12ms/step
# Epoch 6/100
#
# Epoch 6: loss improved from 0.05170 to 0.05039, saving model to ./Model/case_1/LSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0504 - val_loss: 0.2408 - 232ms/epoch - 12ms/step
# Epoch 7/100
#
# Epoch 7: loss did not improve from 0.05039
# 19/19 - 0s - loss: 0.0509 - val_loss: 0.2136 - 220ms/epoch - 12ms/step
# Epoch 8/100
#
# Epoch 8: loss improved from 0.05039 to 0.05004, saving model to ./Model/case_1/LSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0500 - val_loss: 0.2200 - 235ms/epoch - 12ms/step
# Epoch 9/100
#
# Epoch 9: loss improved from 0.05004 to 0.04849, saving model to ./Model/case_1/LSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0485 - val_loss: 0.2087 - 231ms/epoch - 12ms/step
# Epoch 10/100
#
# Epoch 10: loss did not improve from 0.04849
# 19/19 - 0s - loss: 0.0488 - val_loss: 0.2183 - 223ms/epoch - 12ms/step
# Epoch 11/100
#
# Epoch 11: loss improved from 0.04849 to 0.04821, saving model to ./Model/case_1/LSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0482 - val_loss: 0.2126 - 237ms/epoch - 12ms/step
# Epoch 12/100
#
# Epoch 12: loss improved from 0.04821 to 0.04704, saving model to ./Model/case_1/LSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0470 - val_loss: 0.2001 - 247ms/epoch - 13ms/step
# Epoch 13/100
#
# Epoch 13: loss did not improve from 0.04704
# 19/19 - 0s - loss: 0.0475 - val_loss: 0.2165 - 228ms/epoch - 12ms/step
# Epoch 14/100
#
# Epoch 14: loss improved from 0.04704 to 0.04634, saving model to ./Model/case_1/LSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0463 - val_loss: 0.2114 - 236ms/epoch - 12ms/step
# Epoch 15/100
#
# Epoch 15: loss did not improve from 0.04634
# 19/19 - 0s - loss: 0.0468 - val_loss: 0.1982 - 244ms/epoch - 13ms/step
# Epoch 16/100
#
# Epoch 16: loss improved from 0.04634 to 0.04483, saving model to ./Model/case_1/LSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0448 - val_loss: 0.1939 - 241ms/epoch - 13ms/step
# Epoch 17/100
#
# Epoch 17: loss did not improve from 0.04483
# 19/19 - 0s - loss: 0.0451 - val_loss: 0.2177 - 215ms/epoch - 11ms/step
# Epoch 18/100
#
# Epoch 18: loss improved from 0.04483 to 0.04479, saving model to ./Model/case_1/LSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0448 - val_loss: 0.2045 - 242ms/epoch - 13ms/step
# Epoch 19/100
#
# Epoch 19: loss improved from 0.04479 to 0.04401, saving model to ./Model/case_1/LSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0440 - val_loss: 0.2100 - 244ms/epoch - 13ms/step
# Epoch 20/100
#
# Epoch 20: loss improved from 0.04401 to 0.04370, saving model to ./Model/case_1/LSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0437 - val_loss: 0.1989 - 251ms/epoch - 13ms/step
# Epoch 21/100
#
# Epoch 21: loss improved from 0.04370 to 0.04255, saving model to ./Model/case_1/LSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0426 - val_loss: 0.2144 - 239ms/epoch - 13ms/step
# Epoch 22/100
#
# Epoch 22: loss improved from 0.04255 to 0.04233, saving model to ./Model/case_1/LSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0423 - val_loss: 0.1953 - 230ms/epoch - 12ms/step
# Epoch 23/100
#
# Epoch 23: loss improved from 0.04233 to 0.04164, saving model to ./Model/case_1/LSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0416 - val_loss: 0.1859 - 251ms/epoch - 13ms/step
# Epoch 24/100
#
# Epoch 24: loss improved from 0.04164 to 0.04046, saving model to ./Model/case_1/LSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0405 - val_loss: 0.1870 - 241ms/epoch - 13ms/step
# Epoch 25/100
#
# Epoch 25: loss did not improve from 0.04046
# 19/19 - 0s - loss: 0.0405 - val_loss: 0.1855 - 250ms/epoch - 13ms/step
# Epoch 26/100
#
# Epoch 26: loss improved from 0.04046 to 0.04005, saving model to ./Model/case_1/LSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0401 - val_loss: 0.1992 - 256ms/epoch - 13ms/step
# Epoch 27/100
#
# Epoch 27: loss improved from 0.04005 to 0.03920, saving model to ./Model/case_1/LSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0392 - val_loss: 0.1731 - 268ms/epoch - 14ms/step
# Epoch 28/100
#
# Epoch 28: loss improved from 0.03920 to 0.03797, saving model to ./Model/case_1/LSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0380 - val_loss: 0.1759 - 271ms/epoch - 14ms/step
# Epoch 29/100
#
# Epoch 29: loss improved from 0.03797 to 0.03781, saving model to ./Model/case_1/LSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0378 - val_loss: 0.1856 - 251ms/epoch - 13ms/step
# Epoch 30/100
#
# Epoch 30: loss improved from 0.03781 to 0.03719, saving model to ./Model/case_1/LSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0372 - val_loss: 0.1636 - 254ms/epoch - 13ms/step
# Epoch 31/100
#
# Epoch 31: loss improved from 0.03719 to 0.03683, saving model to ./Model/case_1/LSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0368 - val_loss: 0.1536 - 298ms/epoch - 16ms/step
# Epoch 32/100
#
# Epoch 32: loss improved from 0.03683 to 0.03548, saving model to ./Model/case_1/LSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0355 - val_loss: 0.1645 - 261ms/epoch - 14ms/step
# Epoch 33/100
#
# Epoch 33: loss improved from 0.03548 to 0.03471, saving model to ./Model/case_1/LSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0347 - val_loss: 0.1546 - 254ms/epoch - 13ms/step
# Epoch 34/100
#
# Epoch 34: loss improved from 0.03471 to 0.03400, saving model to ./Model/case_1/LSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0340 - val_loss: 0.1425 - 252ms/epoch - 13ms/step
# Epoch 35/100
#
# Epoch 35: loss improved from 0.03400 to 0.03372, saving model to ./Model/case_1/LSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0337 - val_loss: 0.1387 - 299ms/epoch - 16ms/step
# Epoch 36/100
#
# Epoch 36: loss improved from 0.03372 to 0.03226, saving model to ./Model/case_1/LSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0323 - val_loss: 0.1451 - 250ms/epoch - 13ms/step
# Epoch 37/100
#
# Epoch 37: loss did not improve from 0.03226
# 19/19 - 0s - loss: 0.0324 - val_loss: 0.1494 - 250ms/epoch - 13ms/step
# Epoch 38/100
#
# Epoch 38: loss improved from 0.03226 to 0.03103, saving model to ./Model/case_1/LSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0310 - val_loss: 0.1491 - 251ms/epoch - 13ms/step
# Epoch 39/100
#
# Epoch 39: loss improved from 0.03103 to 0.02987, saving model to ./Model/case_1/LSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0299 - val_loss: 0.1347 - 264ms/epoch - 14ms/step
# Epoch 40/100
#
# Epoch 40: loss improved from 0.02987 to 0.02975, saving model to ./Model/case_1/LSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0298 - val_loss: 0.1266 - 267ms/epoch - 14ms/step
# Epoch 41/100
#
# Epoch 41: loss improved from 0.02975 to 0.02813, saving model to ./Model/case_1/LSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0281 - val_loss: 0.1307 - 233ms/epoch - 12ms/step
# Epoch 42/100
#
# Epoch 42: loss improved from 0.02813 to 0.02693, saving model to ./Model/case_1/LSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0269 - val_loss: 0.1154 - 251ms/epoch - 13ms/step
# Epoch 43/100
#
# Epoch 43: loss improved from 0.02693 to 0.02682, saving model to ./Model/case_1/LSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0268 - val_loss: 0.1353 - 266ms/epoch - 14ms/step
# Epoch 44/100
#
# Epoch 44: loss improved from 0.02682 to 0.02610, saving model to ./Model/case_1/LSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0261 - val_loss: 0.1121 - 243ms/epoch - 13ms/step
# Epoch 45/100
#
# Epoch 45: loss improved from 0.02610 to 0.02471, saving model to ./Model/case_1/LSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0247 - val_loss: 0.1034 - 256ms/epoch - 13ms/step
# Epoch 46/100
#
# Epoch 46: loss improved from 0.02471 to 0.02417, saving model to ./Model/case_1/LSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0242 - val_loss: 0.1104 - 248ms/epoch - 13ms/step
# Epoch 47/100
#
# Epoch 47: loss improved from 0.02417 to 0.02270, saving model to ./Model/case_1/LSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0227 - val_loss: 0.1160 - 237ms/epoch - 12ms/step
# Epoch 48/100
#
# Epoch 48: loss improved from 0.02270 to 0.02244, saving model to ./Model/case_1/LSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0224 - val_loss: 0.1102 - 234ms/epoch - 12ms/step
# Epoch 49/100
#
# Epoch 49: loss improved from 0.02244 to 0.02139, saving model to ./Model/case_1/LSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0214 - val_loss: 0.0774 - 235ms/epoch - 12ms/step
# Epoch 50/100
#
# Epoch 50: loss improved from 0.02139 to 0.02049, saving model to ./Model/case_1/LSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0205 - val_loss: 0.0876 - 231ms/epoch - 12ms/step
# Epoch 51/100
#
# Epoch 51: loss improved from 0.02049 to 0.02012, saving model to ./Model/case_1/LSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0201 - val_loss: 0.0661 - 239ms/epoch - 13ms/step
# Epoch 52/100
#
# Epoch 52: loss improved from 0.02012 to 0.01999, saving model to ./Model/case_1/LSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.
# Epoch 93/100
#
# Epoch 93: loss did not improve from 0.01705
# 19/19 - 0s - loss: 0.0194 - val_loss: 0.0215 - 212ms/epoch - 11ms/step
# Epoch 94/100
#
# Epoch 94: loss did not improve from 0.01705
# 19/19 - 0s - loss: 0.0192 - val_loss: 0.0506 - 221ms/epoch - 12ms/step
# Epoch 95/100
#
# Epoch 95: loss did not improve from 0.01705
# 19/19 - 0s - loss: 0.0185 - val_loss: 0.0217 - 220ms/epoch - 12ms/step
# Epoch 96/100
#
# Epoch 96: loss did not improve from 0.01705
# 19/19 - 0s - loss: 0.0195 - val_loss: 0.0421 - 253ms/epoch - 13ms/step
# Epoch 97/100
#
# Epoch 97: loss did not improve from 0.01705
# 19/19 - 0s - loss: 0.0194 - val_loss: 0.0354 - 222ms/epoch - 12ms/step
# Epoch 98/100
#
# Epoch 98: loss did not improve from 0.01705
# 19/19 - 0s - loss: 0.0195 - val_loss: 0.0215 - 223ms/epoch - 12ms/step
# Epoch 99/100
#
# Epoch 99: loss did not improve from 0.01705
# 19/19 - 0s - loss: 0.0183 - val_loss: 0.0363 - 221ms/epoch - 12ms/step
# Epoch 100/100
#
# Epoch 100: loss did not improve from 0.01705
# 19/19 - 0s - loss: 0.0195 - val_loss: 0.0229 - 213ms/epoch - 11ms/step
# Thời gian thực thi mô hình: 26.32 giây

# %%
#Model
final_model = load_model("./Model/case_1/LSTM/model_SGD/save_model.hdf5")

# %%
#dữ liệu train
Y_train_predict = final_model.predict(X_train) #dự đoán trên tập đã train
Y_train_predict = sc.inverse_transform(Y_train_predict) #giá thực dự đoán
Y_train = sc.inverse_transform(Y_train) #giá thực train
# Out:
# 48/48 [==============================] - 1s 2ms/step

# %% [markdown]
# # DỰ ĐOÁN TRÊN TẬP TEST

# %%
#dữ liệu test
import time
start_model = time.time()  # Bắt đầu đo thời gian
Y_test_predict = final_model.predict(X_test)
end_model = time.time()  # Kết thúc đo thời gian
print(f"Thời gian thực thi mô hình: {end_model - start_model:.2f} giây")
Y_test_predict = sc.inverse_transform(Y_test_predict) #giá dự đoán
Y_test = sc.inverse_transform(Y_test) #giá thực
# Out:
# 12/12 [==============================] - 0s 3ms/step
# Thời gian thực thi mô hình: 0.08 giây

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import mean_absolute_error, mean_squared_error

# Tính toán các giá trị cho tập Train
mae_train = round(mean_absolute_error(Y_train, Y_train_predict), 3)
mse_train = round(mean_squared_error(Y_train, Y_train_predict), 3)
rmse_train = round(np.sqrt(mse_train), 3)

# Tính toán các giá trị cho tập Test
mae_test = round(mean_absolute_error(Y_test, Y_test_predict), 3)
mse_test = round(mean_squared_error(Y_test, Y_test_predict), 3)
rmse_test = round(np.sqrt(mse_test), 3)

# Tạo DataFrame để hiển thị kết quả
metrics = pd.DataFrame({
    "Tập dữ liệu": ["Train", "Test"],
    "MAE": [mae_train, mae_test],
    "MSE": [mse_train, mse_test],
    "RMSE": [rmse_train, rmse_test]
})

# In kết quả
print(metrics)
print(f"Thời gian thực thi mô hình: {end_model - start_model:.2f} giây")
# Out:
#   Tập dữ liệu      MAE         MSE     RMSE
# 0       Train  103.890   19181.271  138.496
# 1        Test  440.239  206303.308  454.206
# Thời gian thực thi mô hình: 0.08 giây

# %%
# Xác định 80% dữ liệu làm tập train
train_size = int(len(df_usd_ML) * 0.8)

# Cắt lại cho đúng chiều dài:
train_data1 = df_usd_ML[6:train_size+1].copy()
test_data1 = df_usd_ML[train_size+2:].copy()


print(len(train_data1), len(Y_train_predict))
print(len(test_data1), len(Y_test_predict))


plt.figure(figsize=(24,8))
plt.plot(df_usd_ML,label='Giá thực tế',color='red') #đường giá thực
train_data1['Dự đoán'] = Y_train_predict #thêm dữ liệu
plt.plot(train_data1['Dự đoán'],label='Giá dự đoán train',color='green') #đường giá dự báo train
test_data1['Dự đoán'] = Y_test_predict #thêm dữ liệu
plt.plot(test_data1['Dự đoán'],label='Giá dự đoán test',color='blue') #đường giá dự báo test
plt.title('So sánh giá dự báo và giá thực tế') #đặt tên biểu đồ
plt.xlabel('Thời gian') #đặt tên hàm x
plt.ylabel('Giá mua chuyển khoản (VNĐ)') #đặt tên hàm y
plt.legend() #chú thích
plt.show()
# Out:
# 1523 1523
# 381 381

# %%
from tensorflow.keras.models import load_model

# Gọi lại mô hình đã lưu
loaded_model = load_model("./Model/case_1/LSTM/model_SGD/save_model.hdf5")
# Dự đoán lại trên tập test
Y_test_predict = loaded_model.predict(X_test)
# Đảo chuẩn hóa (inverse transform)
Y_test_predict = sc.inverse_transform(Y_test_predict)

# Tạo bảng so sánh
compare_df = pd.DataFrame({
    "Giá thực tế": Y_test.flatten(),
    "Giá dự đoán": Y_test_predict.flatten()
})

# Làm tròn về số nguyên
compare_df = compare_df.astype(int)
pd.set_option('display.max_rows', None)
# Hiển thị toàn bộ bảng
display(compare_df)
compare_df.to_csv("./Model/case_1/LSTM/model_SGD/predict.csv", index=False)
# Out:
# 12/12 [==============================] - 0s 2ms/step
#      Giá thực tế  Giá dự đoán
# 0          24790        24441
# 1          24830        24441
# 2          24840        24446
# 3          24840        24451
# 4          24840        24458
# 5          24960        24465
# 6          25008        24478
# 7          25130        24497
# 8          25130        24528
# 9          25163        24559
# 10         25163        24595
# 11         25163        24632
# 12         25175        24670
# 13         25178        24695
# 14         25177        24714
# 15         25167        24719
# 16         25118        24724
# 17         25118        24722
# 18         25118        24718
# 19         25118        24713
# 20         25118        24706
# 21         25118        24699
# 22         25144        24692
# 23         25143        24688
# 24         25147        24691
# 25         25147        24693
# 26         25157        24697
# 27         25155        24701
# 28         25161        24705
# 29         25178        24710
# 30         25184        24712
# 31         25184        24716
# 32         25184        24720
# 33         25179        24724
# 34         25182        24727
# 35         25182        24731
# 36         25152        24733
# 37         25250        24732
# 38         25250        24734
# 39         25250        24739
# 40         25259        24746
# 41         25263        24755
# 42         25266        24764
# 43         25250        24774
# 44         25277        24786
# 45         25277        24788
# 46         25277        24790
# 47         25281        24793
# 48         25268        24795
# 49         25265        24797
# 50         25250        24797
# 51         25254        24798
# 52         25254        24796
# 53         25254        24793
# 54         25234        24790
# 55         25218        24786
# 56         25213        24782
# 57         25213        24777
# 58         25213        24773
# 59         25213        24768
# 60         25213        24763
# 61         25214        24758
# 62         25222        24756
# 63         25226        24756
# 64         25217        24757
# 65         25221        24758
# 66         25221        24759
# 67         25221        24760
# 68         25231        24760
# 69         25251        24762
# 70         25249        24764
# 71         25247        24766
# 72         25248        24769
# 73         25248        24772
# 74         25248        24776
# 75         25255        24779
# 76         25245        24781
# 77         25250        24781
# 78         25257        24781
# 79         25253        24782
# 80         25253        24782
# 81         25253        24783
# 82         25244        24783
# 83         25245        24783
# 84         25250        24783
# 85         25243        24783
# 86         25238        24781
# 87         25238        24780
# 88         25238        24778
