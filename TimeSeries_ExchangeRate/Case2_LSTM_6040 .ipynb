# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler #chuẩn hóa dữ liệu
from keras.callbacks import ModelCheckpoint #lưu lại huấn luyện tốt nhất
from tensorflow.keras.models import load_model #tải mô hình
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import ModelCheckpoint

import random
import tensorflow as tf

#các lớp để xây dựng mô hình
from keras.models import Sequential #đầu vào
from keras.layers import LSTM #học phụ thuộc
from keras.layers import Dropout, BatchNormalization #tránh học tủ
from keras.layers import Dense #đầu ra

#kiểm tra độ chính xác của mô hình
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
random.seed(42)
np.random.seed(42)
tf.random.set_seed(42)

# %%
df_usd = pd.read_parquet("./minio/usd/part-00000-18b834c3-cd6d-42ae-82c3-638999ff6d84-c000.snappy.parquet", engine="pyarrow")
df_usd.head()
# Out:
#         ngay ma_ngoai_te ten_ngoai_te  mua_chuyen_khoan      ban
# 0 2020-02-01         USD    US DOLLAR           23165.0  23305.0
# 1 2020-02-02         USD    US DOLLAR           23165.0  23305.0
# 2 2020-02-03         USD    US DOLLAR           23200.0  23340.0
# 3 2020-02-04         USD    US DOLLAR           23170.0  23310.0
# 4 2020-02-05         USD    US DOLLAR           23160.0  23300.0

# %%
df_usd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1911 entries, 0 to 1910
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ngay              1911 non-null   datetime64[ns]
#  1   ma_ngoai_te       1911 non-null   object
#  2   ten_ngoai_te      1911 non-null   object
#  3   mua_chuyen_khoan  1911 non-null   float64
#  4   ban               1911 non-null   float64
# dtypes: datetime64[ns](1), float64(2), object(2)
# memory usage: 74.8+ KB

# %%
df_usd.describe()
# Out:
#                       ngay  mua_chuyen_khoan           ban
# count                 1911       1911.000000   1911.000000
# mean   2022-09-13 00:00:00      23666.414443  23934.197279
# min    2020-02-01 00:00:00      22480.000000  22745.000000
# 25%    2021-05-23 12:00:00      22985.000000  23170.000000
# 50%    2022-09-13 00:00:00      23300.000000  23620.000000
# 75%    2024-01-03 12:00:00      24390.000000  24730.000000
# max    2025-04-25 00:00:00      25835.000000  26195.000000
# std                    NaN        885.147984    926.810272

# %%
print(df_usd.dtypes)
# Out:
# ngay                datetime64[ns]
# ma_ngoai_te                 object
# ten_ngoai_te                object
# mua_chuyen_khoan           float64
# ban                        float64
# dtype: object

# %%
import matplotlib.pyplot as plt
from matplotlib.dates import YearLocator, DateFormatter, MonthLocator

# Vẽ biểu đồ
plt.figure(figsize=(10, 5))
plt.plot(df_usd['ngay'].values, df_usd['mua_chuyen_khoan'].values, label='Giá mua chuyển khoản', color='red')

plt.xlabel('Năm')
plt.ylabel('Giá mua chuyển khoản')
plt.title('Biểu đồ tỷ giá VND_USD mua chuyển khoảng qua các năm')
plt.legend(loc='best')

# Định dạng trục x
plt.gca().xaxis.set_major_locator(YearLocator())
plt.gca().xaxis.set_major_formatter(DateFormatter('%Y'))
plt.gca().xaxis.set_minor_locator(MonthLocator())

plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
df_usd_ML = pd.DataFrame(df_usd, columns=['ngay','mua_chuyen_khoan'])
df_usd_ML.index = df_usd_ML.ngay
df_usd_ML.drop('ngay', axis = 1, inplace=True)
df_usd_ML.head()
# Out:
#             mua_chuyen_khoan
# ngay
# 2020-02-01           23165.0
# 2020-02-02           23165.0
# 2020-02-03           23200.0
# 2020-02-04           23170.0
# 2020-02-05           23160.0

# %%
print(df_usd_ML.columns)
# Out:
# Index(['mua_chuyen_khoan'], dtype='object')

# %%
data = df_usd_ML.values

# %%
data
# Out:
# array([[23165.],
#        [23165.],
#        [23200.],
#        ...,
#        [25781.],
#        [25814.],
#        [25835.]])

# %%
#hàm hóa dữ liệu
sc = MinMaxScaler(feature_range=(0,1))

#chuẩn hóa dữ train
scale_data = sc.fit_transform(data)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))

plt.plot(scale_data, label="Dữ liệu sau chuẩn hóa", color="red")

plt.xlabel("Thời gian (Index)")
plt.ylabel("Giá trị sau chuẩn hóa")
plt.title("Biểu đồ dữ liệu sau khi chuẩn hóa bằng MinMaxScaler")
plt.legend()
plt.show()

# %%
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Bidirectional, LSTM, Dense, Dropout

# Chọn window
window_size = 7
X_train, Y_train = [], []

for i in range(len(scale_data) - window_size):
    X_train.append(scale_data[i:i + window_size])
    Y_train.append(scale_data[i + window_size])

X_train = np.array(X_train)
Y_train = np.array(Y_train)

# Phân chia tập dữ liệu thành tập train và test 60 - 40
split_index = int(0.6 * len(X_train))

X_train, X_test = X_train[:split_index], X_train[split_index:]
Y_train, Y_test = Y_train[:split_index], Y_train[split_index:]

# Đảm bảo dữ liệu có đúng shape cho mô hình BiLSTM
X_train = X_train.reshape((X_train.shape[0], window_size, -1))
X_test = X_test.reshape((X_test.shape[0], window_size, -1))

# %%
print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
print("y_train shape:", Y_train.shape)
print("y_test shape:", Y_test.shape)
# Out:
# X_train shape: (1142, 7, 1)
# X_test shape: (762, 7, 1)
# y_train shape: (1142, 1)
# y_test shape: (762, 1)

# %% [markdown]
# # MODEL

# %%
#xây dựng mô hình
model = Sequential() #tạo lớp mạng cho dữ liệu đầu vào
#2 lớp LSTM
model.add(LSTM(units=128,input_shape=(X_train.shape[1],1),return_sequences=True))
model.add(LSTM(units=64))
model.add(Dropout(0.5)) #loại bỏ 1 số đơn vị tránh học tủ (overfitting)
model.add(Dense(1)) #output đầu ra 1 chiều
#đo sai số tuyệt đối trung bình có sử dụng trình tối ưu hóa rmsprop
model.compile(loss='mean_absolute_error',optimizer='rmsprop')

# %% [markdown]
# # huấn luyện mô hình

# %%
#huấn luyện mô hình
save_model = "./Model/case_2/LSTM/model_6040/save_model.hdf5"
best_model = ModelCheckpoint(save_model,monitor='loss',verbose=2,save_best_only=True,mode='auto')

import time
start_model = time.time()  # Bắt đầu đo thời gian
model.fit(X_train,Y_train,epochs=100,batch_size=50,validation_split=0.4,verbose=2,callbacks=[best_model])
end_model = time.time()  # Kết thúc đo thời gian
print(f"Thời gian thực thi mô hình: {end_model - start_model:.2f} giây")
# Out:
# Epoch 1/100
#
# Epoch 1: loss improved from inf to 0.05002, saving model to ./Model/case_2/LSTM/model_6040\save_model.hdf5
# 14/14 - 3s - loss: 0.0500 - val_loss: 0.0579 - 3s/epoch - 193ms/step
# Epoch 2/100
#
# Epoch 2: loss improved from 0.05002 to 0.03166, saving model to ./Model/case_2/LSTM/model_6040\save_model.hdf5
# 14/14 - 0s - loss: 0.0317 - val_loss: 0.0508 - 168ms/epoch - 12ms/step
# Epoch 3/100
#
# Epoch 3: loss improved from 0.03166 to 0.02687, saving model to ./Model/case_2/LSTM/model_6040\save_model.hdf5
# 14/14 - 0s - loss: 0.0269 - val_loss: 0.0251 - 176ms/epoch - 13ms/step
# Epoch 4/100
#
# Epoch 4: loss improved from 0.02687 to 0.02539, saving model to ./Model/case_2/LSTM/model_6040\save_model.hdf5
# 14/14 - 0s - loss: 0.0254 - val_loss: 0.0301 - 175ms/epoch - 12ms/step
# Epoch 5/100
#
# Epoch 5: loss improved from 0.02539 to 0.02442, saving model to ./Model/case_2/LSTM/model_6040\save_model.hdf5
# 14/14 - 0s - loss: 0.0244 - val_loss: 0.0190 - 181ms/epoch - 13ms/step
# Epoch 6/100
#
# Epoch 6: loss improved from 0.02442 to 0.02262, saving model to ./Model/case_2/LSTM/model_6040\save_model.hdf5
# 14/14 - 0s - loss: 0.0226 - val_loss: 0.0281 - 182ms/epoch - 13ms/step
# Epoch 7/100
#
# Epoch 7: loss did not improve from 0.02262
# 14/14 - 0s - loss: 0.0238 - val_loss: 0.0180 - 155ms/epoch - 11ms/step
# Epoch 8/100
#
# Epoch 8: loss did not improve from 0.02262
# 14/14 - 0s - loss: 0.0236 - val_loss: 0.0192 - 173ms/epoch - 12ms/step
# Epoch 9/100
#
# Epoch 9: loss improved from 0.02262 to 0.02131, saving model to ./Model/case_2/LSTM/model_6040\save_model.hdf5
# 14/14 - 0s - loss: 0.0213 - val_loss: 0.0187 - 216ms/epoch - 15ms/step
# Epoch 10/100
#
# Epoch 10: loss improved from 0.02131 to 0.02090, saving model to ./Model/case_2/LSTM/model_6040\save_model.hdf5
# 14/14 - 0s - loss: 0.0209 - val_loss: 0.0189 - 184ms/epoch - 13ms/step
# Epoch 11/100
#
# Epoch 11: loss did not improve from 0.02090
# 14/14 - 0s - loss: 0.0210 - val_loss: 0.0198 - 164ms/epoch - 12ms/step
# Epoch 12/100
#
# Epoch 12: loss improved from 0.02090 to 0.02003, saving model to ./Model/case_2/LSTM/model_6040\save_model.hdf5
# 14/14 - 0s - loss: 0.0200 - val_loss: 0.0417 - 187ms/epoch - 13ms/step
# Epoch 13/100
#
# Epoch 13: loss did not improve from 0.02003
# 14/14 - 0s - loss: 0.0214 - val_loss: 0.0224 - 161ms/epoch - 12ms/step
# Epoch 14/100
#
# Epoch 14: loss improved from 0.02003 to 0.01949, saving model to ./Model/case_2/LSTM/model_6040\save_model.hdf5
# 14/14 - 0s - loss: 0.0195 - val_loss: 0.0244 - 182ms/epoch - 13ms/step
# Epoch 15/100
#
# Epoch 15: loss did not improve from 0.01949
# 14/14 - 0s - loss: 0.0210 - val_loss: 0.0284 - 162ms/epoch - 12ms/step
# Epoch 16/100
#
# Epoch 16: loss improved from 0.01949 to 0.01767, saving model to ./Model/case_2/LSTM/model_6040\save_model.hdf5
# 14/14 - 0s - loss: 0.0177 - val_loss: 0.0273 - 191ms/epoch - 14ms/step
# Epoch 17/100
#
# Epoch 17: loss did not improve from 0.01767
# 14/14 - 0s - loss: 0.0209 - val_loss: 0.0162 - 194ms/epoch - 14ms/step
# Epoch 18/100
#
# Epoch 18: loss did not improve from 0.01767
# 14/14 - 0s - loss: 0.0196 - val_loss: 0.0188 - 189ms/epoch - 13ms/step
# Epoch 19/100
#
# Epoch 19: loss did not improve from 0.01767
# 14/14 - 0s - loss: 0.0184 - val_loss: 0.0225 - 181ms/epoch - 13ms/step
# Epoch 20/100
#
# Epoch 20: loss did not improve from 0.01767
# 14/14 - 0s - loss: 0.0177 - val_loss: 0.0283 - 173ms/epoch - 12ms/step
# Epoch 21/100
#
# Epoch 21: loss did not improve from 0.01767
# 14/14 - 0s - loss: 0.0185 - val_loss: 0.0157 - 200ms/epoch - 14ms/step
# Epoch 22/100
#
# Epoch 22: loss did not improve from 0.01767
# 14/14 - 0s - loss: 0.0180 - val_loss: 0.0206 - 198ms/epoch - 14ms/step
# Epoch 23/100
#
# Epoch 23: loss did not improve from 0.01767
# 14/14 - 0s - loss: 0.0181 - val_loss: 0.0175 - 174ms/epoch - 12ms/step
# Epoch 24/100
#
# Epoch 24: loss improved from 0.01767 to 0.01765, saving model to ./Model/case_2/LSTM/model_6040\save_model.hdf5
# 14/14 - 0s - loss: 0.0176 - val_loss: 0.0218 - 211ms/epoch - 15ms/step
# Epoch 25/100
#
# Epoch 25: loss improved from 0.01765 to 0.01685, saving model to ./Model/case_2/LSTM/model_6040\save_model.hdf5
# 14/14 - 0s - loss: 0.0169 - val_loss: 0.0319 - 189ms/epoch - 14ms/step
# Epoch 26/100
#
# Epoch 26: loss did not improve from 0.01685
# 14/14 - 0s - loss: 0.0176 - val_loss: 0.0154 - 178ms/epoch - 13ms/step
# Epoch 27/100
#
# Epoch 27: loss improved from 0.01685 to 0.01670, saving model to ./Model/case_2/LSTM/model_6040\save_model.hdf5
# 14/14 - 0s - loss: 0.0167 - val_loss: 0.0179 - 188ms/epoch - 13ms/step
# Epoch 28/100
#
# Epoch 28: loss did not improve from 0.01670
# 14/14 - 0s - loss: 0.0168 - val_loss: 0.0162 - 161ms/epoch - 11ms/step
# Epoch 29/100
#
# Epoch 29: loss did not improve from 0.01670
# 14/14 - 0s - loss: 0.0172 - val_loss: 0.0398 - 175ms/epoch - 13ms/step
# Epoch 30/100
#
# Epoch 30: loss improved from 0.01670 to 0.01667, saving model to ./Model/case_2/LSTM/model_6040\save_model.hdf5
# 14/14 - 0s - loss: 0.0167 - val_loss: 0.0239 - 182ms/epoch - 13ms/step
# Epoch 31/100
#
# Epoch 31: loss improved from 0.01667 to 0.01621, saving model to ./Model/case_2/LSTM/model_6040\save_model.hdf5
# 14/14 - 0s - loss: 0.0162 - val_loss: 0.0157 - 195ms/epoch - 14ms/step
# Epoch 32/100
#
# Epoch 32: loss improved from 0.01621 to 0.01549, saving model to ./Model/case_2/LSTM/model_6040\save_model.hdf5
# 14/14 - 0s - loss: 0.0155 - val_loss: 0.0156 - 175ms/epoch - 13ms/step
# Epoch 33/100
#
# Epoch 33: loss did not improve from 0.01549
# 14/14 - 0s - loss: 0.0156 - val_loss: 0.0179 - 191ms/epoch - 14ms/step
# Epoch 34/100
#
# Epoch 34: loss improved from 0.01549 to 0.01526, saving model to ./Model/case_2/LSTM/model_6040\save_model.hdf5
# 14/14 - 0s - loss: 0.0153 - val_loss: 0.0173 - 174ms/epoch - 12ms/step
# Epoch 35/100
#
# Epoch 35: loss improved from 0.01526 to 0.01436, saving model to ./Model/case_2/LSTM/model_6040\save_model.hdf5
# 14/14 - 0s - loss: 0.0144 - val_loss: 0.0149 - 186ms/epoch - 13ms/step
# Epoch 36/100
#
# Epoch 36: loss did not improve from 0.01436
# 14/14 - 0s - loss: 0.0156 - val_loss: 0.0303 - 160ms/epoch - 11ms/step
# Epoch 37/100
#
# Epoch 37: loss did not improve from 0.01436
# 14/14 - 0s - loss: 0.0161 - val_loss: 0.0206 - 179ms/epoch - 13ms/step
# Epoch 38/100
#
# Epoch 38: loss did not improve from 0.01436
# 14/14 - 0s - loss: 0.0145 - val_loss: 0.0167 - 158ms/epoch - 11ms/step
# Epoch 39/100
#
# Epoch 39: loss improved from 0.01436 to 0.01207, saving model to ./Model/case_2/LSTM/model_6040\save_model.hdf5
# 14/14 - 0s - loss: 0.0121 - val_loss: 0.0194 - 190ms/epoch - 14ms/step
# Epoch 40/100
#
# Epoch 40: loss did not improve from 0.01207
# 14/14 - 0s - loss: 0.0167 - val_loss: 0.0145 - 158ms/epoch - 11ms/step
# Epoch 41/100
#
# Epoch 41: loss did not improve from 0.01207
# 14/14 - 0s - loss: 0.0142 - val_loss: 0.0149 - 180ms/epoch - 13ms/step
# Epoch 42/100
#
# Epoch 42: loss did not improve from 0.01207
# 14/14 - 0s - loss: 0.0135 - val_loss: 0.0161 - 165ms/epoch - 12ms/step
# Epoch 43/100
#
# Epoch 43: loss did not improve from 0.01207
# 14/14 - 0s - loss: 0.0141 - val_loss: 0.0143 - 157ms/epoch - 11ms/step
# Epoch 44/100
#
# Epoch 44: loss did not improve from 0.01207
# 14/14 - 0s - loss: 0.0140 - val_loss: 0.0159 - 160ms/epoch - 11ms/step
# Epoch 45/100
#
# Epoch 45: loss did not improve from 0.01207
# 14/14 - 0s - loss: 0.0138 - val_loss: 0.0136 - 161ms/epoch - 12ms/step
# Epoch 46/100
#
# Epoch 46: loss did not improve from 0.01207
# 14/14 - 0s - loss: 0.0139 - val_loss: 0.0210 - 164ms/epoch - 12ms/step
# Epoch 47/100
#
# Epoch 47: loss did not improve from 0.01207
# 14/14 - 0s - loss: 0.0126 - val_loss: 0.0266 - 167ms/epoch - 12ms/step
# Epoch 48/100
#
# Epoch 48: loss did not improve from 0.01207
# 14/14 - 0s - loss: 0.0137 - val_loss: 0.0186 - 167ms/epoch - 12ms/step
# Epoch 49/100
#
# Epoch 49: loss did not improve from 0.01207
# 14/14 - 0s - loss: 0.0128 - val_loss: 0.0133 - 174ms/epoch - 12ms/step
# Epoch 50/100
#
# Epoch 50: loss did not improve from 0.01207
# 14/14 - 0s - loss: 0.0135 - val_loss: 0.0206 - 167ms/epoch - 12ms/step
# Epoch 51/100
#
# Epoch 51: loss did not improve from 0.01207
# 14/14 - 0s - loss: 0.0135 - val_loss: 0.0276 - 172ms/epoch - 12ms/step
# Epoch 52/100
#
# Epoch 52: loss did not improve from 0.01207
# 14/14 - 0s - loss: 0.0124 - val_loss: 0.0197 - 169ms/epoch - 12ms/step
# Epoch 53/100
#
# Epoch 53: loss did not improve from 0.01207
# 14/14 - 0s - loss: 0.0121 - val_loss: 0.0144 - 165ms/epoch - 12ms/step
# Epoch 54/100
#
# Epoch 54: loss did not improve from 0.01207
# 14/14 - 0s - loss: 0.0134 - val_loss: 0.0154 - 164ms/epoch - 12ms/step
# Epoch 55/100
#
# Epoch 55: loss did not improve from 0.01207
# 14/14 - 0s - loss: 0.0123 - val_loss: 0.0231 - 172ms/epoch - 12ms/step
# Epoch 56/100
#
# Epoch 56: loss did not improve from 0.01207
# 14/14 - 0s - loss: 0.0122 - val_loss: 0.0270 - 198ms/epoch - 14ms/step
# Epoch 57/100
#
# Epoch 57: loss did not improve from 0.01207
# 14/14 - 0s - loss: 0.0127 - val_loss: 0.0196 - 209ms/epoch - 15ms/step
# Epoch 58/100
#
# Epoch 58: loss improved from 0.01207 to 0.01166, saving model to ./Model/case_2/LSTM/model_6040\save_model.hdf5
# 14/14 - 0s - loss: 0.0117 - val_loss: 0.0241 - 221ms/epoch - 16ms/step
# Epoch 59/100
#
# Epoch 59: loss improved from 0.01166 to 0.01152, saving model to ./Model/case_2/LSTM/model_6040\save_model.hdf5
# 14/14 - 0s - loss: 0.0115 - val_loss: 0.0146 - 222ms/epoch - 16ms/step
# Epoch 60/100
#
# Epoch 60: loss did not improve from 0.01152
# 14/14 - 0s - loss: 0.0124 - val_loss: 0.0140 - 201ms/epoch - 14ms/step
# Epoch 61/100
#
# Epoch 61: loss did not improve from 0.01152
# 14/14 - 0s - loss: 0.0118 - val_loss: 0.0140 - 170ms/epoch - 12ms/step
# Epoch 62/100
#
# Epoch 62: loss did not improve from 0.01152
# 14/14 - 0s - loss: 0.0118 - val_loss: 0.0187 - 183ms/epoch - 13ms/step
# Epoch 63/100
#
# Epoch 63: loss did not improve from 0.01152
# 14/14 - 0s - loss: 0.0122 - val_loss: 0.0194 - 181ms/epoch - 13ms/step
# Epoch 64/100
#
# Epoch 64: loss improved from 0.01152 to 0.01125, saving model to ./Model/case_2/LSTM/model_6040\save_model.hdf5
# 14/14 - 0s - loss: 0.0113 - val_loss: 0.0206 - 191ms/epoch - 14ms/step
# Epoch 65/100
#
# Epoch 65: loss improved from 0.01125 to 0.01110, saving model to ./Model/case_2/LSTM/model_6040\save_model.hdf5
# 14/14 - 0s - loss: 0.0111 - val_loss: 0.0317 - 194ms/epoch - 14ms/step
# Epoch 66/100
#
# Epoch 66: loss did not improve from 0.01110
# 14/14 - 0s - loss: 0.0120 - val_loss: 0.0142 - 165ms/epoch - 12ms/step
# Epoch 67/100
#
# Epoch 67: loss did not improve from 0.01110
# 14/14 - 0s - loss: 0.0117 - val_loss: 0.0126 - 165ms/epoch - 12ms/step
# Epoch 68/100
#
# Epoch 68: loss improved from 0.01110 to 0.01068, saving model to ./Model/case_2/LSTM/model_6040\save_model.hdf5
# 14/14 - 0s - loss: 0.0107 - val_loss: 0.0145 - 183ms/epoch - 13ms/step
# Epoch 69/100
#
# Epoch 69: loss did not improve from 0.01068
# 14/14 - 0s - loss: 0.0120 - val_loss: 0.0174 - 167ms/epoch - 12ms/step
# Epoch 70/100
#
# Epoch 70: loss did not improve from 0.01068
# 14/14 - 0s - loss: 0.0113 - val_loss: 0.0148 - 169ms/epoch - 12ms/step
# Epoch 71/100
#
# Epoch 71: loss did not improve from 0.01068
# 14/14 - 0s - loss: 0.0109 - val_loss: 0.0253 - 159ms/epoch - 11ms/step
# Epoch 72/100
#
# Epoch 72: loss improved from 0.01068 to 0.01063, saving model to ./Model/case_2/LSTM/model_6040\save_model.hdf5
# 14/14 - 0s - loss: 0.0106 - val_loss: 0.0254 - 179ms/epoch - 13ms/step
# Epoch 73/100
#
# Epoch 73: loss did not improve from 0.01063
# 14/14 - 0s - loss: 0.0110 - val_loss: 0.0221 - 169ms/epoch - 12ms/step
# Epoch 74/100
#
# Epoch 74: loss did not improve from 0.01063
# 14/14 - 0s - loss: 0.0110 - val_loss: 0.0156 - 173ms/epoch - 12ms/step
# Epoch 75/100
#
# Epoch 75: loss did not improve from 0.01063
# 14/14 - 0s - loss: 0.0118 - val_loss: 0.0197 - 166ms/epoch - 12ms/step
# Epoch 76/100
#
# Epoch 76: loss improved from 0.01063 to 0.01061, saving model to ./Model/case_2/LSTM/model_6040\save_model.hdf5
# 14/14 - 0s - loss: 0.0106 - val_loss: 0.0251 - 185ms/epoch - 13ms/step
# Epoch 77/100
#
# Epoch 77: loss improved from 0.01061 to 0.01046, saving model to ./Model/case_2/LSTM/model_6040\save_model.hdf5
# 14/14 - 0s - loss: 0.0105 - val_loss: 0.0178 - 199ms/epoch - 14ms/step
# Epoch 78/100
#
# Epoch 78: loss did not improve from 0.01046
# 14/14 - 0s - loss: 0.0105 - val_loss: 0.0138 - 160ms/epoch - 11ms/step
# Epoch 79/100
#
# Epoch 79: loss improved from 0.01046 to 0.01045, saving model to ./Model/case_2/LSTM/model_6040\save_model.hdf5
# 14/14 - 0s - loss: 0.0104 - val_loss: 0.0152 - 193ms/epoch - 14ms/step
# Epoch 80/100
#
# Epoch 80: loss did not improve from 0.01045
# 14/14 - 0s - loss: 0.0106 - val_loss: 0.0151 - 164ms/epoch - 12ms/step
# Epoch 81/100
#
# Epoch 81: loss improved from 0.01045 to 0.01043, saving model to ./Model/case_2/LSTM/model_6040\save_model.hdf5
# 14/14 - 0s - loss: 0.0104 - val_loss: 0.0193 - 177ms/epoch - 13ms/step
# Epoch 82/100
#
# Epoch 82: loss improved from 0.01043 to 0.01043, saving model to ./Model/case_2/LSTM/model_6040\save_model.hdf5
# 14/14 - 0s - loss: 0.0104 - val_loss: 0.0133 - 206ms/epoch - 15ms/step
# Epoch 83/100
#
# Epoch 83: loss did not improve from 0.01043
# 14/14 - 0s - loss: 0.0104 - val_loss: 0.0132 - 166ms/epoch - 12ms/step
# Epoch 84/100
#
# Epoch 84: loss did not improve from 0.01043
# 14/14 - 0s - loss: 0.0112 - val_loss: 0.0133 - 170ms/epoch - 12ms/step
# Epoch 85/100
#
# Epoch 85: loss improved from 0.01043 to 0.00982, saving model to ./Model/case_2/LSTM/model_6040\save_model.hdf5
# 14/14 - 0s - loss: 0.0098 - val_loss: 0.0190 - 187ms/epoch - 13ms/step
# Epoch 86/100
#
# Epoch 86: loss did not improve from 0.00982
# 14/14 - 0s - loss: 0.0102 - val_loss: 0.0218 - 179ms/epoch - 13ms/step
# Epoch 87/100
#
# Epoch 87: loss did not improve from 0.00982
# 14/14 - 0s - loss: 0.0101 - val_loss: 0.0155 - 164ms/epoch - 12ms/step
# Epoch 88/100
#
# Epoch 88: loss did not improve from 0.00982
# 14/14 - 0s - loss: 0.0108 - val_loss: 0.0152 - 167ms/epoch - 12ms/step
# Epoch 89/100
#
# Epoch 89: loss did not improve from 0.00982
# 14/14 - 0s - loss: 0.0104 - val_loss: 0.0157 - 193ms/epoch - 14ms/step
# Epoch 90/100
#
# Epoch 90: loss did not improve from 0.00982
# 14/14 - 0s - loss: 0.0104 - val_loss: 0.0156 - 172ms/epoch - 12ms/step
# Epoch 91/100
#
# Epoch 91: loss did not improve from 0.00982
# 14/14 - 0s - loss: 0.0100 - val_loss: 0.0200 - 165ms/epoch - 12ms/step
# Epoch 92/100
#
# Epoch 92: loss improved from 0.00982 to 0.00977, saving model to ./Model/case_2/LSTM/model_6040\save_model.hdf5
# 14/14 - 0s - loss: 0.0098 - val_loss: 0.0117 - 207ms/epoch - 15ms/step
# Epoch 93/100
#
# Epoch 93: loss did not improve from 0.00977
# 14/14 - 0s - loss: 0.0102 - val_loss: 0.0155 - 172ms/epoch - 12ms/step
# Epoch 94/100
#
# Epoch 94: loss did not improve from 0.00977
# 14/14 - 0s - loss: 0.0099 - val_loss: 0.0251 - 171ms/epoch - 12ms/step
# Epoch 95/100
#
# Epoch 95: loss improved from 0.00977 to 0.00917, saving model to ./Model/case_2/LSTM/model_6040\save_model.hdf5
# 14/14 - 0s - loss: 0.0092 - val_loss: 0.0177 - 183ms/epoch - 13ms/step
# Epoch 96/100
#
# Epoch 96: loss did not improve from 0.00917
# 14/14 - 0s - loss: 0.0103 - val_loss: 0.0243 - 176ms/epoch - 13ms/step
# Epoch 97/100
#
# Epoch 97: loss did not improve from 0.00917
# 14/14 - 0s - loss: 0.0100 - val_loss: 0.0165 - 199ms/epoch - 14ms/step
# Epoch 98/100
#
# Epoch 98: loss did not improve from 0.00917
# 14/14 - 0s - loss: 0.0101 - val_loss: 0.0223 - 172ms/epoch - 12ms/step
# Epoch 99/100
#
# Epoch 99: loss did not improve from 0.00917
# 14/14 - 0s - loss: 0.0092 - val_loss: 0.0157 - 169ms/epoch - 12ms/step
# Epoch 100/100
#
# Epoch 100: loss improved from 0.00917 to 0.00894, saving model to ./Model/case_2/LSTM/model_6040\save_model.hdf5
# 14/14 - 0s - loss: 0.0089 - val_loss: 0.0137 - 191ms/epoch - 14ms/step
# Thời gian thực thi mô hình: 20.56 giây

# %%
#Model
final_model = load_model("./Model/case_2/LSTM/model_6040/save_model.hdf5")

# %%
#dữ liệu train
Y_train_predict = final_model.predict(X_train) #dự đoán trên tập đã train
Y_train_predict = sc.inverse_transform(Y_train_predict) #giá thực dự đoán
Y_train = sc.inverse_transform(Y_train) #giá thực train
# Out:
# 36/36 [==============================] - 1s 3ms/step

# %% [markdown]
# # DỰ ĐOÁN TRÊN TẬP TEST

# %%
#dữ liệu test
import time
start_model = time.time()  # Bắt đầu đo thời gian
Y_test_predict = final_model.predict(X_test)
end_model = time.time()  # Kết thúc đo thời gian
print(f"Thời gian thực thi mô hình: {end_model - start_model:.2f} giây")
Y_test_predict = sc.inverse_transform(Y_test_predict) #giá dự đoán
Y_test = sc.inverse_transform(Y_test) #giá thực
# Out:
# 24/24 [==============================] - 0s 3ms/step
# Thời gian thực thi mô hình: 0.14 giây

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import mean_absolute_error, mean_squared_error

# Tính toán các giá trị cho tập Train
mae_train = round(mean_absolute_error(Y_train, Y_train_predict), 3)
mse_train = round(mean_squared_error(Y_train, Y_train_predict), 3)
rmse_train = round(np.sqrt(mse_train), 3)

# Tính toán các giá trị cho tập Test
mae_test = round(mean_absolute_error(Y_test, Y_test_predict), 3)
mse_test = round(mean_squared_error(Y_test, Y_test_predict), 3)
rmse_test = round(np.sqrt(mse_test), 3)

# Tạo DataFrame để hiển thị kết quả
metrics = pd.DataFrame({
    "Tập dữ liệu": ["Train", "Test"],
    "MAE": [mae_train, mae_test],
    "MSE": [mse_train, mse_test],
    "RMSE": [rmse_train, rmse_test]
})

# In kết quả
print(metrics)
print(f"Thời gian thực thi mô hình: {end_model - start_model:.2f} giây")
# Out:
#   Tập dữ liệu     MAE       MSE    RMSE
# 0       Train  31.662  3111.712  55.783
# 1        Test  56.817  5819.968  76.289
# Thời gian thực thi mô hình: 0.14 giây

# %%
# Xác định 60% dữ liệu làm tập train
train_size = int(len(df_usd_ML) * 0.6)

# Cắt lại cho đúng chiều dài:
train_data1 = df_usd_ML[6:train_size+2].copy()
test_data1 = df_usd_ML[train_size+3:].copy()


print(len(train_data1), len(Y_train_predict))
print(len(test_data1), len(Y_test_predict))

# Cắt dữ liệu dự đoán để khớp với dữ liệu gốc
Y_train_predict = Y_train_predict[:len(train_data1)]
Y_test_predict = Y_test_predict[:len(test_data1)]

# Đảm bảo test_data1 có số lượng dòng khớp với Y_test_predict
test_data1 = test_data1.iloc[:len(Y_test_predict)]

plt.figure(figsize=(24,8))
plt.plot(df_usd_ML, label='Giá thực tế', color='red')  # đường giá thực

# Thêm dữ liệu dự đoán vào train_data1 và test_data1
train_data1["Dự đoán"] = Y_train_predict
plt.plot(train_data1["Dự đoán"], label='Giá dự đoán train', color='green')

test_data1["Dự đoán"] = Y_test_predict
plt.plot(test_data1["Dự đoán"], label='Giá dự đoán test', color='blue')

plt.title('So sánh giá dự báo và giá thực tế')
plt.xlabel('Thời gian')
plt.ylabel('Giá mua chuyển khoản (VNĐ)')
plt.legend()
plt.show()
# Out:
# 1142 1142
# 762 762

# %%
from tensorflow.keras.models import load_model

# Gọi lại mô hình đã lưu
loaded_model = load_model("./Model/case_2/LSTM/model_6040/save_model.hdf5")
# Dự đoán lại trên tập test
Y_test_predict = loaded_model.predict(X_test)
# Đảo chuẩn hóa (inverse transform)
Y_test_predict = sc.inverse_transform(Y_test_predict)

# Tạo bảng so sánh
compare_df = pd.DataFrame({
    "Giá thực tế": Y_test.flatten(),
    "Giá dự đoán": Y_test_predict.flatten()
})

# Làm tròn về số nguyên
compare_df = compare_df.astype(int)
pd.set_option('display.max_rows', None)
# Hiển thị toàn bộ bảng
display(compare_df)
compare_df.to_csv("./Model/case_2/LSTM/model_6040/predict.csv", index=False)
# Out:
# 24/24 [==============================] - 1s 2ms/step
#      Giá thực tế  Giá dự đoán
# 0          23340        23343
# 1          23340        23335
# 2          23320        23330
# 3          23310        23323
# 4          23300        23316
# 5          23290        23309
# 6          23290        23299
# 7          23290        23291
# 8          23310        23285
# 9          23295        23284
# 10         23280        23284
# 11         23280        23280
# 12         23280        23277
# 13         23280        23273
# 14         23280        23271
# 15         23280        23269
# 16         23290        23267
# 17         23290        23268
# 18         23270        23271
# 19         23280        23269
# 20         23280        23268
# 21         23280        23267
# 22         23320        23267
# 23         23360        23274
# 24         23305        23291
# 25         23320        23297
# 26         23320        23302
# 27         23320        23305
# 28         23320        23307
# 29         23310        23308
# 30         23310        23306
# 31         23310        23302
# 32         23290        23301
# 33         23290        23295
# 34         23290        23290
# 35         23290        23285
# 36         23290        23281
# 37         23290        23279
# 38         23290        23277
# 39         23280        23277
# 40         23280        23275
# 41         23280        23272
# 42         23280        23270
# 43         23290        23269
# 44         23290        23270
# 45         23300        23271
# 46         23300        23275
# 47         23300        23278
# 48         23300        23282
# 49         23300        23284
# 50         23280        23286
# 51         23280        23282
# 52         23285        23278
# 53         23280        23275
# 54         23320        23272
# 55         23320        23278
# 56         23320        23285
# 57         23275        23292
# 58         23290        23289
# 59         23320        23286
# 60         23300        23289
# 61         23320        23290
# 62         23320        23293
# 63         23320        23296
# 64         23310        23300
# 65         23315        23301
# 66         23325        23302
# 67         23310        23304
# 68         23310        23304
# 69         23310        23302
# 70         23310        23300
# 71         23330        23299
# 72         23320        23302
# 73         23320        23304
# 74         23320        23305
# 75         23310        23306
# 76         23310        23305
# 77         23310        23303
# 78         23300        23301
# 79         23320        23297
# 80         23330        23298
# 81         23360        23301
# 82         23360        23311
# 83         23360        23322
# 84         23360        23331
# 85         23350        23338
# 86         23350        23341
# 87         23340        23342
# 88         23340        23339
# 89         23350        23335
# 90         23350        23334
# 91         23350        23334
# 92         23360        23335
# 93         23370        23337
# 94         23380        23342
# 95         23390        23349
# 96         23410        23357
# 97         23410        23368
# 98         23410        23378
# 99         23480        23386
# 100        23520        23405
# 101        23580        23432
# 102        23560        23468
# 103        23470        23498
# 104        23470        23503
# 105        23470        23498
# 106        23480        23489
# 107        23520        23481
# 108        23510        23482
# 109        23475        23483
# 110        23470        23480
# 111        23470        23477
# 112        23470        23472
# 113        23460        23468
# 114        23470        23462
# 115        23465        23458
# 116        23470        23456
# 117        23480        23456
# 118        23480        23458
# 119        23480        23461
# 120        23485        23464
# 121        23490        23467
# 122        23495        23470
# 123        23500        23474
# 124        23520        23478
# 125        23520        23486
# 126        23520        23493
# 127        23515        23499
# 128        23520        23502
# 129        23555        23505
# 130        23580        23514
# 131        23550        23527
# 132        23550        23535
# 133        23550        23538
# 134        23550        23540
# 135        23555        23541
# 136        23570        23542
# 137        23570        23545
# 138        23570        23548
# 139        23570        23552
# 140        23570        23555
# 141        23650        23557
# 142        23800        23574
# 143        23785        23621
# 144        23700        23668
# 145        23630        23691
# 146        23630        23688
# 147        23630        23676
# 148        23630        23661
# 149        23730        23646
# 150        23800        23650
# 151        23810        23677
# 152        23810        23712
# 153        23810        23744
# 154        23810        23768
# 155        23920        23785
# 156        24010        23816
# 157        23975        23862
# 158        23900        23897
# 159        23900        23910
# 160        23900        23913
# 161        23900        23911
# 162        23900        23906
# 163        23900        23899
# 164        23880        23892
# 165        23880        23885
# 166        23920        23881
# 167        23920        23884
# 168        23920        23890
# 169        23885        23896
# 170        23920        23894
# 171        23980        23897
# 172        24045        23912
# 173        24085        23941
# 174        24085        23976
# 175        24085        24008
# 176        24190        24034
# 177        24205        24073
# 178        24140        24111
# 179        24120        24128
# 180        24190        24131
# 181        24190        24141
# 182        24190        24152
# 183        24195        24161
# 184        24200        24166
# 185        24200        24172
# 186        24220        24178
# 187        24120        24187
# 188        24120        24174
# 189        24120        24156
# 190        24150        24140
# 191        24210        24133
# 192        24240        24141
# 193        24220        24160
# 194        24210        24175
# 195        24210        24187
# 196        24210        24194
# 197        24210        24198
# 198        24245        24199
# 199        24265        24204
# 200        24270        24214
# 201        24275        24226
# 202        24275        24237
# 203        24275        24246
# 204        24290        24253
# 205        24328        24260
# 206        24350        24272
# 207        24370        24288
# 208        24360        24306
# 209        24360        24320
# 210        24360        24331
# 211        24420        24338
# 212        24390        24353
# 213        24380        24361
# 214        24420        24365
# 215        24390        24373
# 216        24390        24376
# 217        24390        24377
# 218        24385        24376
# 219        24390        24373
# 220        24410        24372
# 221        24410        24376
# 222        24350        24379
# 223        24350        24372
# 224        24350        24362
# 225        24160        24353
# 226        24150        24310
# 227        24190        24260
# 228        24190        24224
# 229        24130        24199
# 230        24130        24174
# 231        24130        24152
# 232        24200        24135
# 233        24190        24142
# 234        24100        24151
# 235        24115        24141
# 236        24075        24130
# 237        24075        24114
# 238        24075        24099
# 239        24005        24085
# 240        23950        24061
# 241        24015        24028
# 242        24050        24011
# 243        24080        24009
# 244        24080        24019
# 245        24080        24032
# 246        24075        24043
# 247        24080        24053
# 248        24045        24061
# 249        24090        24059
# 250        24110        24061
# 251        24110        24068
# 252        24110        24076
# 253        24065        24083
# 254        24090        24081
# 255        24095        24079
# 256        24090        24080
# 257        24050        24079
# 258        24050        24070
# 259        24050        24061
# 260        24060        24053
# 261        24090        24049
# 262        24080        24053
# 263        24080        24056
# 264        24070        24060
# 265        24070        24062
# 266        24070        24062
# 267        24140        24061
# 268        24175        24074
# 269        24170        24094
# 270        24160        24114
# 271        24060        24128
# 272        24060        24119
# 273        24060        24103
# 274        24060        24087
# 275        24130        24072
# 276        24140        24073
# 277        24060        24083
# 278        24080        24079
# 279        24080        24078
# 280        24080        24076
# 281        24080        24074
# 282        24155        24072
# 283        24180        24083
# 284        24190        24102
# 285        24190        24125
# 286        24190        24144
# 287        24190        24158
# 288        24175        24168
# 289        24185        24171
# 290        24215        24171
# 291        24295        24177
# 292        24290        24198
# 293        24290        24220
# 294        24290        24240
# 295        24295        24254
# 296        24370        24266
# 297        24360        24287
# 298        24385        24306
# 299        24375        24323
# 300        24375        24337
# 301        24375        24347
# 302        24365        24353
# 303        24390        24355
# 304        24430        24358
# 305        24430        24369
# 306        24425        24381
# 307        24425        24390
# 308        24425        24397
# 309        24375        24402
# 310        24235        24396
# 311        24255        24360
# 312        24240        24323
# 313        24160        24289
# 314        24160        24248
# 315        24160        24212
# 316        24200        24184
# 317        24190        24173
# 318        24230        24171
# 319        24230        24177
# 320        24230        24187
# 321        24230        24198
# 322        24230        24206
# 323        24230        24211
# 324        24230        24214
# 325        24230        24215
# 326        24270        24215
# 327        24340        24223
# 328        24340        24245
# 329        24340        24268
# 330        24360        24288
# 331        24360        24306
# 332        24340        24321
# 333        24420        24328
# 334        24450        24345
# 335        24450        24366
# 336        24450        24387
# 337        24500        24403
# 338        24460        24424
# 339        24450        24436
# 340        24480        24441
# 341        24470        24445
# 342        24470        24447
# 343        24470        24448
# 344        24500        24449
# 345        24510        24454
# 346        24520        24463
# 347        24530        24474
# 348        24500        24484
# 349        24500        24487
# 350        24500        24487
# 351        24450        24486
# 352        24460        24474
# 353        24480        24463
# 354        24530        24458
# 355        24550        24464
# 356        24550        24479
# 357        24550        24493
# 358        24560        24506
# 359        24590        24518
# 360        24610        24532
# 361        24610        24548
# 362        24610        24560
# 363        24610        24569
# 364        24610        24576
# 365        24590        24581
# 366        24610        24580
# 367        24610        24580
# 368        24610        24581
# 369        24630        24582
# 370        24630        24586
# 371        24630        24591
# 372        24630        24596
# 373        24710        24599
# 374        24790        24616
# 375        24770        24650
# 376        24780        24679
# 377        24780        24704
# 378        24780        24723
# 379        24790        24736
# 380        24790        24746
# 381        24790        24751
# 382        24830        24753
# 383        24840        24762
# 384        24840        24773
# 385        24840        24784
# 386        24960        24792
# 387        25008        24820
# 388        25130        24858
# 389        25130        24915
# 390        25163        24968
# 391        25163        25016
# 392        25163        25054
# 393        25175        25081
# 394        25178        25098
# 395        25177        25109
# 396        25167        25114
# 397        25118        25116
# 398        25118        25107
# 399        25118        25095
# 400        25118        25085
# 401        25118        25077
# 402        25118        25072
# 403        25144        25068
# 404        25143        25070
# 405        25147        25076
# 406        25147        25081
# 407        25157        25086
# 408        25155        25091
# 409        25161        25095
# 410        25178        25098
# 411        25184        25104
# 412        25184        25111
# 413        25184        25116
# 414        25179        25121
# 415        25182        25123
# 416        25182        25124
# 417        25152        25125
# 418        25250        25120
# 419        25250        25131
# 420        25250        25146
# 421        25259        25160
# 422        25263        25173
# 423        25266        25183
# 424        25250        25192
# 425        25277        25195
# 426        25277        25199
# 427        25277        25203
# 428        25281        25207
# 429        25268        25210
# 430        25265        25210
# 431        25250        25209
# 432        25254        25205
# 433        25254        25200
# 434        25254        25197
# 435        25234        25195
# 436        25218        25189
# 437        25213        25182
# 438        25213        25173
# 439        25213        25167
# 440        25213        25161
# 441        25213        25158
# 442        25214        25155
# 443        25222        25154
# 444        25226        25156
# 445        25217        25158
# 446        25221        25159
# 447        25221        25160
# 448        25221        25161
# 449        25231        25161
# 450        25251        25163
# 451        25249        25169
# 452        25247        25174
# 453        25248        25179
# 454        25248        25182
# 455        25248        25185
# 456        25255        25186
# 457        25245        25188
# 458        25250        25187
# 459        25257        25187
# 460        25253        25189
# 461        25253        25190
# 462        25253        25190
# 463        25244        25191
# 464        25245        25189
# 465        25250        25188
# 466        25243        25187
# 467        25238        25186
# 468        25238        25184
# 469        25238        25182
# 470        25235        25180
# 471        25234        25178
# 472        25239        25177
# 473        25245        25176
# 474        25240        25177
# 475        25240        25178
# 476        25240        25179
# 477        25237        25179
# 478        25237        25179
# 479        25168        25178
# 480        25150        25165
# 481        25158        25147
# 482        25158        25132
# 483        25158        25120
# 484        25154        25111
# 485        25157        25105
# 486        25177        25102
# 487        25120        25105
# 488        25121        25100
# 489        25121        25091
# 490        25121        25084
# 491        25115        25078
# 492        25120        25073
# 493        25080        25069
# 494        25060        25060
# 495        25040        25048
# 496        25040        25033
# 497        25040        25019
# 498        24930        25009
# 499        24980        24981
# 500        24995        24962
# 501        24980        24952
# 502        24930        24945
# 503        24930        24932
# 504        24930        24918
# 505        24940        24907
# 506        24950        24903
# 507        24850        24901
# 508        24870        24883
# 509        24890        24867
# 510        24890        24858
# 511        24890        24853
# 512        24820        24851
# 513        24740        24837
# 514        24760        24807
# 515        24780        24782
# 516        24810        24765
# 517        24810        24759
# 518        24810        24759
# 519        24710        24762
# 520        24660        24748
# 521        24680        24723
# 522        24690        24700
# 523        24690        24683
# 524        24690        24670
# 525        24690        24663
# 526        24690        24659
# 527        24690        24659
# 528        24675        24661
# 529        24580        24659
# 530        24430        24638
# 531        24430        24587
# 532        24430        24534
# 533        24500        24489
# 534        24490        24468
# 535        24385        24458
# 536        24410        24435
# 537        24390        24419
# 538        24390        24407
# 539        24390        24395
# 540        24380        24386
# 541        24430        24376
# 542        24470        24378
# 543        24410        24394
# 544        24400        24399
# 545        24400        24398
# 546        24400        24395
# 547        24460        24392
# 548        24430        24400
# 549        24410        24404
# 550        24460        24402
# 551        24420        24410
# 552        24420        24411
# 553        24420        24410
# 554        24400        24408
# 555        24430        24401
# 556        24480        24401
# 557        24580        24412
# 558        24580        24442
# 559        24580        24476
# 560        24580        24505
# 561        24670        24527
# 562        24665        24559
# 563        24665        24587
# 564        24670        24607
# 565        24640        24620
# 566        24640        24625
# 567        24640        24625
# 568        24660        24624
# 569        24765        24623
# 570        24810        24644
# 571        25010        24677
# 572        24980        24745
# 573        24980        24808
# 574        24980        24859
# 575        25070        24895
# 576        25092        24936
# 577        25220        24971
# 578        25233        25021
# 579        25197        25067
# 580        25197        25099
# 581        25197        25121
# 582        25194        25135
# 583        25164        25140
# 584        25118        25136
# 585        25090        25119
# 586        25114        25097
# 587        25114        25082
# 588        25114        25072
# 589        25125        25066
# 590        25160        25064
# 591        25170        25071
# 592        25197        25083
# 593        25130        25099
# 594        25130        25101
# 595        25130        25097
# 596        25116        25093
# 597        25160        25085
# 598        25180        25086
# 599        25184        25092
# 600        25190        25101
# 601        25190        25111
# 602        25190        25120
# 603        25200        25126
# 604        25205        25132
# 605        25200        25137
# 606        25200        25139
# 607        25200        25141
# 608        25200        25142
# 609        25200        25142
# 610        25197        25142
# 611        25200        25142
# 612        25200        25141
# 613        25175        25141
# 614        25160        25137
# 615        25160        25129
# 616        25160        25122
# 617        25149        25115
# 618        25170        25109
# 619        25172        25107
# 620        25176        25108
# 621        25164        25111
# 622        25164        25112
# 623        25164        25111
# 624        25157        25111
# 625        25170        25109
# 626        25165        25109
# 627        25171        25109
# 628        25177        25110
# 629        25177        25113
# 630        25177        25115
# 631        25185        25117
# 632        25183        25120
# 633        25191        25123
# 634        25219        25126
# 635        25240        25133
# 636        25240        25145
# 637        25240        25156
# 638        25230        25165
# 639        25223        25170
# 640        25236        25171
# 641        25225        25172
# 642        25238        25171
# 643        25238        25171
# 644        25238        25173
# 645        25243        25174
# 646        25251        25176
# 647        25251        25180
# 648        25259        25183
# 649        25250        25187
# 650        25250        25188
# 651        25250        25189
# 652        25253        25189
# 653        25208        25190
# 654        25186        25182
# 655        25194        25169
# 656        25198        25158
# 657        25198        25150
# 658        25198        25145
# 659        25200        25141
# 660        25203        25140
# 661        25194        25141
# 662        25189        25141
# 663        25150        25139
# 664        25150        25130
# 665        25150        25120
# 666        25150        25111
# 667        25090        25105
# 668        24960        25089
# 669        24960        25051
# 670        24800        25011
# 671        24800        24949
# 672        24800        24889
# 673        24800        24841
# 674        24800        24806
# 675        24800        24784
# 676        24800        24773
# 677        24800        24766
# 678        24800        24766
# 679        24800        24766
# 680        25140        24766
# 681        25000        24828
# 682        24980        24875
# 683        25090        24906
# 684        25110        24945
# 685        25110        24983
# 686        25110        25014
# 687        25200        25036
# 688        25340        25059
# 689        25380        25112
# 690        25300        25170
# 691        25220        25204
# 692        25220        25210
# 693        25220        25205
# 694        25280        25196
# 695        25340        25195
# 696        25340        25206
# 697        25350        25221
# 698        25320        25239
# 699        25320        25251
# 700        25320        25257
# 701        25310        25259
# 702        25330        25256
# 703        25360        25255
# 704        25380        25261
# 705        25370        25272
# 706        25370        25282
# 707        25370        25289
# 708        25420        25294
# 709        25390        25306
# 710        25320        25313
# 711        25300        25303
# 712        25300        25287
# 713        25330        25271
# 714        25330        25263
# 715        25340        25259
# 716        25290        25258
# 717        25280        25251
# 718        25320        25243
# 719        25350        25243
# 720        25350        25250
# 721        25350        25257
# 722        25360        25264
# 723        25350        25272
# 724        25370        25278
# 725        25380        25284
# 726        25400        25291
# 727        25400        25300
# 728        25400        25308
# 729        25450        25315
# 730        25450        25329
# 731        25390        25343
# 732        25390        25343
# 733        25400        25338
# 734        25400        25334
# 735        25400        25331
# 736        25380        25329
# 737        25460        25323
# 738        25460        25331
# 739        25620        25345
# 740        25600        25385
# 741        25600        25424
# 742        25600        25455
# 743        25600        25478
# 744        25780        25495
# 745        25822        25534
# 746        25610        25583
# 747        25560        25586
# 748        25560        25567
# 749        25560        25543
# 750        25640        25521
# 751        25650        25516
# 752        25650        25517
# 753        25700        25521
# 754        25760        25541
# 755        25760        25571
# 756        25760        25598
# 757        25700        25619
# 758        25755        25623
# 759        25781        25629
# 760        25814        25640
# 761        25835        25655
