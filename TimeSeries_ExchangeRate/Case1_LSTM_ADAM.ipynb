# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler #chuẩn hóa dữ liệu
from keras.callbacks import ModelCheckpoint #lưu lại huấn luyện tốt nhất
from tensorflow.keras.models import load_model #tải mô hình
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import ModelCheckpoint

import random
import tensorflow as tf

#các lớp để xây dựng mô hình
from keras.models import Sequential #đầu vào
from keras.layers import LSTM #học phụ thuộc
from keras.layers import Dropout, BatchNormalization #tránh học tủ
from keras.layers import Dense #đầu ra

#kiểm tra độ chính xác của mô hình
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
random.seed(42)
np.random.seed(42)
tf.random.set_seed(42)

# %%
df_usd = pd.read_parquet("./minio/usd/part-00000-18b834c3-cd6d-42ae-82c3-638999ff6d84-c000.snappy.parquet", engine="pyarrow")
df_usd.head()
# Out:
#         ngay ma_ngoai_te ten_ngoai_te  mua_chuyen_khoan      ban
# 0 2020-02-01         USD    US DOLLAR           23165.0  23305.0
# 1 2020-02-02         USD    US DOLLAR           23165.0  23305.0
# 2 2020-02-03         USD    US DOLLAR           23200.0  23340.0
# 3 2020-02-04         USD    US DOLLAR           23170.0  23310.0
# 4 2020-02-05         USD    US DOLLAR           23160.0  23300.0

# %%
df_usd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1911 entries, 0 to 1910
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ngay              1911 non-null   datetime64[ns]
#  1   ma_ngoai_te       1911 non-null   object
#  2   ten_ngoai_te      1911 non-null   object
#  3   mua_chuyen_khoan  1911 non-null   float64
#  4   ban               1911 non-null   float64
# dtypes: datetime64[ns](1), float64(2), object(2)
# memory usage: 74.8+ KB

# %%
df_usd.describe()
# Out:
#                       ngay  mua_chuyen_khoan           ban
# count                 1911       1911.000000   1911.000000
# mean   2022-09-13 00:00:00      23666.414443  23934.197279
# min    2020-02-01 00:00:00      22480.000000  22745.000000
# 25%    2021-05-23 12:00:00      22985.000000  23170.000000
# 50%    2022-09-13 00:00:00      23300.000000  23620.000000
# 75%    2024-01-03 12:00:00      24390.000000  24730.000000
# max    2025-04-25 00:00:00      25835.000000  26195.000000
# std                    NaN        885.147984    926.810272

# %%
print(df_usd.dtypes)
# Out:
# ngay                datetime64[ns]
# ma_ngoai_te                 object
# ten_ngoai_te                object
# mua_chuyen_khoan           float64
# ban                        float64
# dtype: object

# %%
import matplotlib.pyplot as plt
from matplotlib.dates import YearLocator, DateFormatter, MonthLocator

# Vẽ biểu đồ
plt.figure(figsize=(10, 5))
plt.plot(df_usd['ngay'].values, df_usd['mua_chuyen_khoan'].values, label='Giá mua chuyển khoản', color='red')

plt.xlabel('Năm')
plt.ylabel('Giá mua chuyển khoản')
plt.title('Biểu đồ tỷ giá VND_USD mua chuyển khoảng qua các năm')
plt.legend(loc='best')

# Định dạng trục x
plt.gca().xaxis.set_major_locator(YearLocator())
plt.gca().xaxis.set_major_formatter(DateFormatter('%Y'))
plt.gca().xaxis.set_minor_locator(MonthLocator())

plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
df_usd_ML = pd.DataFrame(df_usd, columns=['ngay','mua_chuyen_khoan'])
df_usd_ML.index = df_usd_ML.ngay
df_usd_ML.drop('ngay', axis = 1, inplace=True)
df_usd_ML.head()
# Out:
#             mua_chuyen_khoan
# ngay
# 2020-02-01           23165.0
# 2020-02-02           23165.0
# 2020-02-03           23200.0
# 2020-02-04           23170.0
# 2020-02-05           23160.0

# %%
print(df_usd_ML.columns)
# Out:
# Index(['mua_chuyen_khoan'], dtype='object')

# %%
data = df_usd_ML.values

# %%
data
# Out:
# array([[23165.],
#        [23165.],
#        [23200.],
#        ...,
#        [25781.],
#        [25814.],
#        [25835.]])

# %%
#hàm hóa dữ liệu
sc = MinMaxScaler(feature_range=(0,1))

#chuẩn hóa dữ train
scale_data = sc.fit_transform(data)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))

plt.plot(scale_data, label="Dữ liệu sau chuẩn hóa", color="red")

plt.xlabel("Thời gian (Index)")
plt.ylabel("Giá trị sau chuẩn hóa")
plt.title("Biểu đồ dữ liệu sau khi chuẩn hóa bằng MinMaxScaler")
plt.legend()
plt.show()

# %%
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Bidirectional, LSTM, Dense, Dropout

# Chọn window
window_size = 7
X_train, Y_train = [], []

for i in range(len(scale_data) - window_size):
    X_train.append(scale_data[i:i + window_size])
    Y_train.append(scale_data[i + window_size])

X_train = np.array(X_train)
Y_train = np.array(Y_train)

# Phân chia tập dữ liệu thành tập train và test
split_index = int(0.8 * len(X_train))

X_train, X_test = X_train[:split_index], X_train[split_index:]
Y_train, Y_test = Y_train[:split_index], Y_train[split_index:]

# Đảm bảo dữ liệu có đúng shape cho mô hình BiLSTM
X_train = X_train.reshape((X_train.shape[0], window_size, -1))
X_test = X_test.reshape((X_test.shape[0], window_size, -1))

# %%
print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
print("y_train shape:", Y_train.shape)
print("y_test shape:", Y_test.shape)
# Out:
# X_train shape: (1523, 7, 1)
# X_test shape: (381, 7, 1)
# y_train shape: (1523, 1)
# y_test shape: (381, 1)

# %% [markdown]
# # MODEL

# %%
#xây dựng mô hình
model = Sequential() #tạo lớp mạng cho dữ liệu đầu vào
#2 lớp LSTM
model.add(LSTM(units=128,input_shape=(X_train.shape[1],1),return_sequences=True))
model.add(LSTM(units=64))
model.add(Dropout(0.5)) #loại bỏ 1 số đơn vị tránh học tủ (overfitting)
model.add(Dense(1)) #output đầu ra 1 chiều
#đo sai số tuyệt đối trung bình có sử dụng trình tối ưu hóa adam
model.compile(loss='mean_absolute_error',optimizer='adam')

# %% [markdown]
# # huấn luyện mô hình

# %%
#huấn luyện mô hình
save_model = "./Model/case_1/LSTM/model_SGD/save_model.hdf5"
best_model = ModelCheckpoint(save_model,monitor='loss',verbose=2,save_best_only=True,mode='auto')

import time
start_model = time.time()  # Bắt đầu đo thời gian
model.fit(X_train,Y_train,epochs=100,batch_size=50,validation_split=0.4,verbose=2,callbacks=[best_model])
end_model = time.time()  # Kết thúc đo thời gian
print(f"Thời gian thực thi mô hình: {end_model - start_model:.2f} giây")
# Out:
# Epoch 1/100
#
# Epoch 1: loss improved from inf to 0.05478, saving model to ./Model/case_1/LSTM/model_SGD\save_model.hdf5
# 19/19 - 3s - loss: 0.0548 - val_loss: 0.0949 - 3s/epoch - 158ms/step
# Epoch 2/100
#
# Epoch 2: loss improved from 0.05478 to 0.02592, saving model to ./Model/case_1/LSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0259 - val_loss: 0.0224 - 243ms/epoch - 13ms/step
# Epoch 3/100
#
# Epoch 3: loss improved from 0.02592 to 0.02060, saving model to ./Model/case_1/LSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0206 - val_loss: 0.0172 - 234ms/epoch - 12ms/step
# Epoch 4/100
#
# Epoch 4: loss improved from 0.02060 to 0.01854, saving model to ./Model/case_1/LSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0185 - val_loss: 0.0201 - 246ms/epoch - 13ms/step
# Epoch 5/100
#
# Epoch 5: loss improved from 0.01854 to 0.01679, saving model to ./Model/case_1/LSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0168 - val_loss: 0.0178 - 232ms/epoch - 12ms/step
# Epoch 6/100
#
# Epoch 6: loss improved from 0.01679 to 0.01678, saving model to ./Model/case_1/LSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0168 - val_loss: 0.0219 - 255ms/epoch - 13ms/step
# Epoch 7/100
#
# Epoch 7: loss improved from 0.01678 to 0.01650, saving model to ./Model/case_1/LSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0165 - val_loss: 0.0201 - 246ms/epoch - 13ms/step
# Epoch 8/100
#
# Epoch 8: loss improved from 0.01650 to 0.01612, saving model to ./Model/case_1/LSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0161 - val_loss: 0.0195 - 246ms/epoch - 13ms/step
# Epoch 9/100
#
# Epoch 9: loss improved from 0.01612 to 0.01579, saving model to ./Model/case_1/LSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0158 - val_loss: 0.0196 - 257ms/epoch - 14ms/step
# Epoch 10/100
#
# Epoch 10: loss improved from 0.01579 to 0.01462, saving model to ./Model/case_1/LSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0146 - val_loss: 0.0360 - 277ms/epoch - 15ms/step
# Epoch 11/100
#
# Epoch 11: loss did not improve from 0.01462
# 19/19 - 0s - loss: 0.0154 - val_loss: 0.0184 - 234ms/epoch - 12ms/step
# Epoch 12/100
#
# Epoch 12: loss improved from 0.01462 to 0.01438, saving model to ./Model/case_1/LSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0144 - val_loss: 0.0189 - 225ms/epoch - 12ms/step
# Epoch 13/100
#
# Epoch 13: loss improved from 0.01438 to 0.01398, saving model to ./Model/case_1/LSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0140 - val_loss: 0.0189 - 222ms/epoch - 12ms/step
# Epoch 14/100
#
# Epoch 14: loss improved from 0.01398 to 0.01379, saving model to ./Model/case_1/LSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0138 - val_loss: 0.0147 - 217ms/epoch - 11ms/step
# Epoch 15/100
#
# Epoch 15: loss improved from 0.01379 to 0.01284, saving model to ./Model/case_1/LSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0128 - val_loss: 0.0156 - 227ms/epoch - 12ms/step
# Epoch 16/100
#
# Epoch 16: loss did not improve from 0.01284
# 19/19 - 0s - loss: 0.0133 - val_loss: 0.0192 - 269ms/epoch - 14ms/step
# Epoch 17/100
#
# Epoch 17: loss improved from 0.01284 to 0.01278, saving model to ./Model/case_1/LSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0128 - val_loss: 0.0146 - 268ms/epoch - 14ms/step
# Epoch 18/100
#
# Epoch 18: loss did not improve from 0.01278
# 19/19 - 0s - loss: 0.0130 - val_loss: 0.0171 - 252ms/epoch - 13ms/step
# Epoch 19/100
#
# Epoch 19: loss improved from 0.01278 to 0.01210, saving model to ./Model/case_1/LSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0121 - val_loss: 0.0173 - 240ms/epoch - 13ms/step
# Epoch 20/100
#
# Epoch 20: loss did not improve from 0.01210
# 19/19 - 0s - loss: 0.0123 - val_loss: 0.0212 - 236ms/epoch - 12ms/step
# Epoch 21/100
#
# Epoch 21: loss did not improve from 0.01210
# 19/19 - 0s - loss: 0.0134 - val_loss: 0.0179 - 242ms/epoch - 13ms/step
# Epoch 22/100
#
# Epoch 22: loss improved from 0.01210 to 0.01145, saving model to ./Model/case_1/LSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0114 - val_loss: 0.0207 - 229ms/epoch - 12ms/step
# Epoch 23/100
#
# Epoch 23: loss improved from 0.01145 to 0.01126, saving model to ./Model/case_1/LSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0113 - val_loss: 0.0156 - 248ms/epoch - 13ms/step
# Epoch 24/100
#
# Epoch 24: loss improved from 0.01126 to 0.01115, saving model to ./Model/case_1/LSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0112 - val_loss: 0.0269 - 233ms/epoch - 12ms/step
# Epoch 25/100
#
# Epoch 25: loss did not improve from 0.01115
# 19/19 - 0s - loss: 0.0113 - val_loss: 0.0223 - 207ms/epoch - 11ms/step
# Epoch 26/100
#
# Epoch 26: loss improved from 0.01115 to 0.01097, saving model to ./Model/case_1/LSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0110 - val_loss: 0.0369 - 246ms/epoch - 13ms/step
# Epoch 27/100
#
# Epoch 27: loss did not improve from 0.01097
# 19/19 - 0s - loss: 0.0110 - val_loss: 0.0197 - 233ms/epoch - 12ms/step
# Epoch 28/100
#
# Epoch 28: loss improved from 0.01097 to 0.01086, saving model to ./Model/case_1/LSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0109 - val_loss: 0.0232 - 235ms/epoch - 12ms/step
# Epoch 29/100
#
# Epoch 29: loss improved from 0.01086 to 0.01064, saving model to ./Model/case_1/LSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0106 - val_loss: 0.0146 - 224ms/epoch - 12ms/step
# Epoch 30/100
#
# Epoch 30: loss improved from 0.01064 to 0.01029, saving model to ./Model/case_1/LSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0103 - val_loss: 0.0302 - 225ms/epoch - 12ms/step
# Epoch 31/100
#
# Epoch 31: loss did not improve from 0.01029
# 19/19 - 0s - loss: 0.0103 - val_loss: 0.0212 - 225ms/epoch - 12ms/step
# Epoch 32/100
#
# Epoch 32: loss improved from 0.01029 to 0.01023, saving model to ./Model/case_1/LSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0102 - val_loss: 0.0203 - 235ms/epoch - 12ms/step
# Epoch 33/100
#
# Epoch 33: loss improved from 0.01023 to 0.00991, saving model to ./Model/case_1/LSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0099 - val_loss: 0.0158 - 243ms/epoch - 13ms/step
# Epoch 34/100
#
# Epoch 34: loss did not improve from 0.00991
# 19/19 - 0s - loss: 0.0103 - val_loss: 0.0207 - 217ms/epoch - 11ms/step
# Epoch 35/100
#
# Epoch 35: loss improved from 0.00991 to 0.00979, saving model to ./Model/case_1/LSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0098 - val_loss: 0.0173 - 230ms/epoch - 12ms/step
# Epoch 36/100
#
# Epoch 36: loss improved from 0.00979 to 0.00935, saving model to ./Model/case_1/LSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0093 - val_loss: 0.0292 - 231ms/epoch - 12ms/step
# Epoch 37/100
#
# Epoch 37: loss did not improve from 0.00935
# 19/19 - 0s - loss: 0.0096 - val_loss: 0.0148 - 210ms/epoch - 11ms/step
# Epoch 38/100
#
# Epoch 38: loss did not improve from 0.00935
# 19/19 - 0s - loss: 0.0094 - val_loss: 0.0201 - 242ms/epoch - 13ms/step
# Epoch 39/100
#
# Epoch 39: loss did not improve from 0.00935
# 19/19 - 0s - loss: 0.0094 - val_loss: 0.0156 - 220ms/epoch - 12ms/step
# Epoch 40/100
#
# Epoch 40: loss did not improve from 0.00935
# 19/19 - 0s - loss: 0.0094 - val_loss: 0.0150 - 223ms/epoch - 12ms/step
# Epoch 41/100
#
# Epoch 41: loss did not improve from 0.00935
# 19/19 - 0s - loss: 0.0095 - val_loss: 0.0151 - 211ms/epoch - 11ms/step
# Epoch 42/100
#
# Epoch 42: loss improved from 0.00935 to 0.00889, saving model to ./Model/case_1/LSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0089 - val_loss: 0.0240 - 241ms/epoch - 13ms/step
# Epoch 43/100
#
# Epoch 43: loss did not improve from 0.00889
# 19/19 - 0s - loss: 0.0097 - val_loss: 0.0236 - 227ms/epoch - 12ms/step
# Epoch 44/100
#
# Epoch 44: loss did not improve from 0.00889
# 19/19 - 0s - loss: 0.0099 - val_loss: 0.0196 - 222ms/epoch - 12ms/step
# Epoch 45/100
#
# Epoch 45: loss did not improve from 0.00889
# 19/19 - 0s - loss: 0.0092 - val_loss: 0.0149 - 222ms/epoch - 12ms/step
# Epoch 46/100
#
# Epoch 46: loss did not improve from 0.00889
# 19/19 - 0s - loss: 0.0092 - val_loss: 0.0147 - 220ms/epoch - 12ms/step
# Epoch 47/100
#
# Epoch 47: loss improved from 0.00889 to 0.00883, saving model to ./Model/case_1/LSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0088 - val_loss: 0.0149 - 243ms/epoch - 13ms/step
# Epoch 48/100
#
# Epoch 48: loss improved from 0.00883 to 0.00875, saving model to ./Model/case_1/LSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0088 - val_loss: 0.0179 - 233ms/epoch - 12ms/step
# Epoch 49/100
#
# Epoch 49: loss did not improve from 0.00875
# 19/19 - 0s - loss: 0.0089 - val_loss: 0.0133 - 214ms/epoch - 11ms/step
# Epoch 50/100
#
# Epoch 50: loss did not improve from 0.00875
# 19/19 - 0s - loss: 0.0089 - val_loss: 0.0193 - 232ms/epoch - 12ms/step
# Epoch 51/100
#
# Epoch 51: loss improved from 0.00875 to 0.00872, saving model to ./Model/case_1/LSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0087 - val_loss: 0.0321 - 297ms/epoch - 16ms/step
# Epoch 52/100
#
# Epoch 52: loss did not improve from 0.00872
# 19/19 - 0s - loss: 0.0092 - val_loss: 0.0357 - 256ms/epoch - 13ms/step
# Epoch 53/100
#
# Epoch 53: loss improved from 0.00872 to 0.00860, saving model to ./Model/case_1/LSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0086 - val_loss: 0.0277 - 235ms/epoch - 12ms/step
# Epoch 54/100
#
# Epoch 54: loss did not improve from 0.00860
# 19/19 - 0s - loss: 0.0090 - val_loss: 0.0178 - 243ms/epoch - 13ms/step
# Epoch 55/100
#
# Epoch 55: loss improved from 0.00860 to 0.00857, saving model to ./Model/case_1/LSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0086 - val_loss: 0.0286 - 278ms/epoch - 15ms/step
# Epoch 56/100
#
# Epoch 56: loss did not improve from 0.00857
# 19/19 - 0s - loss: 0.0087 - val_loss: 0.0228 - 246ms/epoch - 13ms/step
# Epoch 57/100
#
# Epoch 57: loss did not improve from 0.00857
# 19/19 - 0s - loss: 0.0090 - val_loss: 0.0137 - 221ms/epoch - 12ms/step
# Epoch 58/100
#
# Epoch 58: loss did not improve from 0.00857
# 19/19 - 0s - loss: 0.0087 - val_loss: 0.0175 - 231ms/epoch - 12ms/step
# Epoch 59/100
#
# Epoch 59: loss improved from 0.00857 to 0.00850, saving model to ./Model/case_1/LSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0085 - val_loss: 0.0182 - 238ms/epoch - 13ms/step
# Epoch 60/100
#
# Epoch 60: loss did not improve from 0.00850
# 19/19 - 0s - loss: 0.0088 - val_loss: 0.0178 - 240ms/epoch - 13ms/step
# Epoch 61/100
#
# Epoch 61: loss improved from 0.00850 to 0.00831, saving model to ./Model/case_1/LSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0083 - val_loss: 0.0217 - 268ms/epoch - 14ms/step
# Epoch 62/100
#
# Epoch 62: loss did not improve from 0.00831
# 19/19 - 0s - loss: 0.0086 - val_loss: 0.0246 - 228ms/epoch - 12ms/step
# Epoch 63/100
#
# Epoch 63: loss improved from 0.00831 to 0.00809, saving model to ./Model/case_1/LSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0081 - val_loss: 0.0174 - 244ms/epoch - 13ms/step
# Epoch 64/100
#
# Epoch 64: loss did not improve from 0.00809
# 19/19 - 0s - loss: 0.0083 - val_loss: 0.0229 - 215ms/epoch - 11ms/step
# Epoch 65/100
#
# Epoch 65: loss did not improve from 0.00809
# 19/19 - 0s - loss: 0.0086 - val_loss: 0.0359 - 219ms/epoch - 12ms/step
# Epoch 66/100
#
# Epoch 66: loss did not improve from 0.00809
# 19/19 - 0s - loss: 0.0083 - val_loss: 0.0156 - 228ms/epoch - 12ms/step
# Epoch 67/100
#
# Epoch 67: loss improved from 0.00809 to 0.00797, saving model to ./Model/case_1/LSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0080 - val_loss: 0.0113 - 250ms/epoch - 13ms/step
# Epoch 68/100
#
# Epoch 68: loss did not improve from 0.00797
# 19/19 - 0s - loss: 0.0082 - val_loss: 0.0162 - 215ms/epoch - 11ms/step
# Epoch 69/100
#
# Epoch 69: loss did not improve from 0.00797
# 19/19 - 0s - loss: 0.0083 - val_loss: 0.0146 - 224ms/epoch - 12ms/step
# Epoch 70/100
#
# Epoch 70: loss did not improve from 0.00797
# 19/19 - 0s - loss: 0.0087 - val_loss: 0.0258 - 246ms/epoch - 13ms/step
# Epoch 71/100
#
# Epoch 71: loss did not improve from 0.00797
# 19/19 - 0s - loss: 0.0089 - val_loss: 0.0206 - 241ms/epoch - 13ms/step
# Epoch 72/100
#
# Epoch 72: loss did not improve from 0.00797
# 19/19 - 0s - loss: 0.0083 - val_loss: 0.0246 - 255ms/epoch - 13ms/step
# Epoch 73/100
#
# Epoch 73: loss did not improve from 0.00797
# 19/19 - 0s - loss: 0.0082 - val_loss: 0.0187 - 244ms/epoch - 13ms/step
# Epoch 74/100
#
# Epoch 74: loss did not improve from 0.00797
# 19/19 - 0s - loss: 0.0080 - val_loss: 0.0256 - 231ms/epoch - 12ms/step
# Epoch 75/100
#
# Epoch 75: loss did not improve from 0.00797
# 19/19 - 0s - loss: 0.0081 - val_loss: 0.0212 - 254ms/epoch - 13ms/step
# Epoch 76/100
#
# Epoch 76: loss did not improve from 0.00797
# 19/19 - 0s - loss: 0.0089 - val_loss: 0.0112 - 243ms/epoch - 13ms/step
# Epoch 77/100
#
# Epoch 77: loss did not improve from 0.00797
# 19/19 - 0s - loss: 0.0081 - val_loss: 0.0120 - 237ms/epoch - 12ms/step
# Epoch 78/100
#
# Epoch 78: loss improved from 0.00797 to 0.00794, saving model to ./Model/case_1/LSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0079 - val_loss: 0.0136 - 284ms/epoch - 15ms/step
# Epoch 79/100
#
# Epoch 79: loss did not improve from 0.00794
# 19/19 - 0s - loss: 0.0083 - val_loss: 0.0105 - 217ms/epoch - 11ms/step
# Epoch 80/100
#
# Epoch 80: loss improved from 0.00794 to 0.00780, saving model to ./Model/case_1/LSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0078 - val_loss: 0.0154 - 261ms/epoch - 14ms/step
# Epoch 81/100
#
# Epoch 81: loss did not improve from 0.00780
# 19/19 - 0s - loss: 0.0079 - val_loss: 0.0106 - 236ms/epoch - 12ms/step
# Epoch 82/100
#
# Epoch 82: loss did not improve from 0.00780
# 19/19 - 0s - loss: 0.0084 - val_loss: 0.0104 - 235ms/epoch - 12ms/step
# Epoch 83/100
#
# Epoch 83: loss did not improve from 0.00780
# 19/19 - 0s - loss: 0.0079 - val_loss: 0.0181 - 270ms/epoch - 14ms/step
# Epoch 84/100
#
# Epoch 84: loss did not improve from 0.00780
# 19/19 - 0s - loss: 0.0081 - val_loss: 0.0215 - 261ms/epoch - 14ms/step
# Epoch 85/100
#
# Epoch 85: loss did not improve from 0.00780
# 19/19 - 0s - loss: 0.0080 - val_loss: 0.0234 - 271ms/epoch - 14ms/step
# Epoch 86/100
#
# Epoch 86: loss did not improve from 0.00780
# 19/19 - 0s - loss: 0.0086 - val_loss: 0.0185 - 244ms/epoch - 13ms/step
# Epoch 87/100
#
# Epoch 87: loss did not improve from 0.00780
# 19/19 - 0s - loss: 0.0082 - val_loss: 0.0252 - 259ms/epoch - 14ms/step
# Epoch 88/100
#
# Epoch 88: loss did not improve from 0.00780
# 19/19 - 0s - loss: 0.0079 - val_loss: 0.0228 - 253ms/epoch - 13ms/step
# Epoch 89/100
#
# Epoch 89: loss did not improve from 0.00780
# 19/19 - 0s - loss: 0.0082 - val_loss: 0.0151 - 234ms/epoch - 12ms/step
# Epoch 90/100
#
# Epoch 90: loss did not improve from 0.00780
# 19/19 - 0s - loss: 0.0090 - val_loss: 0.0167 - 233ms/epoch - 12ms/step
# Epoch 91/100
#
# Epoch 91: loss did not improve from 0.00780
# 19/19 - 0s - loss: 0.0078 - val_loss: 0.0165 - 226ms/epoch - 12ms/step
# Epoch 92/100
#
# Epoch 92: loss did not improve from 0.00780
# 19/19 - 0s - loss: 0.0082 - val_loss: 0.0133 - 210ms/epoch - 11ms/step
# Epoch 93/100
#
# Epoch 93: loss improved from 0.00780 to 0.00775, saving model to ./Model/case_1/LSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0078 - val_loss: 0.0137 - 246ms/epoch - 13ms/step
# Epoch 94/100
#
# Epoch 94: loss improved from 0.00775 to 0.00773, saving model to ./Model/case_1/LSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0077 - val_loss: 0.0380 - 241ms/epoch - 13ms/step
# Epoch 95/100
#
# Epoch 95: loss did not improve from 0.00773
# 19/19 - 0s - loss: 0.0082 - val_loss: 0.0202 - 231ms/epoch - 12ms/step
# Epoch 96/100
#
# Epoch 96: loss did not improve from 0.00773
# 19/19 - 0s - loss: 0.0086 - val_loss: 0.0113 - 210ms/epoch - 11ms/step
# Epoch 97/100
#
# Epoch 97: loss did not improve from 0.00773
# 19/19 - 0s - loss: 0.0080 - val_loss: 0.0123 - 224ms/epoch - 12ms/step
# Epoch 98/100
#
# Epoch 98: loss did not improve from 0.00773
# 19/19 - 0s - loss: 0.0079 - val_loss: 0.0096 - 211ms/epoch - 11ms/step
# Epoch 99/100
#
# Epoch 99: loss did not improve from 0.00773
# 19/19 - 0s - loss: 0.0082 - val_loss: 0.0186 - 207ms/epoch - 11ms/step
# Epoch 100/100
#
# Epoch 100: loss did not improve from 0.00773
# 19/19 - 0s - loss: 0.0085 - val_loss: 0.0101 - 220ms/epoch - 12ms/step
# Thời gian thực thi mô hình: 26.71 giây

# %%
#Model
final_model = load_model("./Model/case_1/LSTM/model_SGD/save_model.hdf5")

# %%
#dữ liệu train
Y_train_predict = final_model.predict(X_train) #dự đoán trên tập đã train
Y_train_predict = sc.inverse_transform(Y_train_predict) #giá thực dự đoán
Y_train = sc.inverse_transform(Y_train) #giá thực train
# Out:
# 48/48 [==============================] - 0s 2ms/step

# %% [markdown]
# # DỰ ĐOÁN TRÊN TẬP TEST

# %%
#dữ liệu test
import time
start_model = time.time()  # Bắt đầu đo thời gian
Y_test_predict = final_model.predict(X_test)
end_model = time.time()  # Kết thúc đo thời gian
print(f"Thời gian thực thi mô hình: {end_model - start_model:.2f} giây")
Y_test_predict = sc.inverse_transform(Y_test_predict) #giá dự đoán
Y_test = sc.inverse_transform(Y_test) #giá thực
# Out:
# 12/12 [==============================] - 0s 2ms/step
# Thời gian thực thi mô hình: 0.07 giây

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import mean_absolute_error, mean_squared_error

# Tính toán các giá trị cho tập Train
mae_train = round(mean_absolute_error(Y_train, Y_train_predict), 3)
mse_train = round(mean_squared_error(Y_train, Y_train_predict), 3)
rmse_train = round(np.sqrt(mse_train), 3)

# Tính toán các giá trị cho tập Test
mae_test = round(mean_absolute_error(Y_test, Y_test_predict), 3)
mse_test = round(mean_squared_error(Y_test, Y_test_predict), 3)
rmse_test = round(np.sqrt(mse_test), 3)

# Tạo DataFrame để hiển thị kết quả
metrics = pd.DataFrame({
    "Tập dữ liệu": ["Train", "Test"],
    "MAE": [mae_train, mae_test],
    "MSE": [mse_train, mse_test],
    "RMSE": [rmse_train, rmse_test]
})

# In kết quả
print(metrics)
print(f"Thời gian thực thi mô hình: {end_model - start_model:.2f} giây")
# Out:
#   Tập dữ liệu      MAE         MSE     RMSE
# 0       Train   66.727    9872.773   99.362
# 1        Test  329.267  113652.324  337.124
# Thời gian thực thi mô hình: 0.07 giây

# %%
# Xác định 80% dữ liệu làm tập train
train_size = int(len(df_usd_ML) * 0.8)

# Cắt lại cho đúng chiều dài:
train_data1 = df_usd_ML[6:train_size+1].copy()
test_data1 = df_usd_ML[train_size+2:].copy()


print(len(train_data1), len(Y_train_predict))
print(len(test_data1), len(Y_test_predict))

plt.figure(figsize=(24,8))
plt.plot(df_usd_ML,label='Giá thực tế',color='red') #đường giá thực
train_data1['Dự đoán'] = Y_train_predict #thêm dữ liệu
plt.plot(train_data1['Dự đoán'],label='Giá dự đoán train',color='green') #đường giá dự báo train
test_data1['Dự đoán'] = Y_test_predict #thêm dữ liệu
plt.plot(test_data1['Dự đoán'],label='Giá dự đoán test',color='blue') #đường giá dự báo test
plt.title('So sánh giá dự báo và giá thực tế') #đặt tên biểu đồ
plt.xlabel('Thời gian') #đặt tên hàm x
plt.ylabel('Giá mua chuyển khoản (VNĐ)') #đặt tên hàm y
plt.legend() #chú thích
plt.show()
# Out:
# 1523 1523
# 381 381

# %%
from tensorflow.keras.models import load_model

# Gọi lại mô hình đã lưu
loaded_model = load_model("./Model/case_1/LSTM/model_ADAM/save_model.hdf5")
# Dự đoán lại trên tập test
Y_test_predict = loaded_model.predict(X_test)
# Đảo chuẩn hóa (inverse transform)
Y_test_predict = sc.inverse_transform(Y_test_predict)

# Tạo bảng so sánh
compare_df = pd.DataFrame({
    "Giá thực tế": Y_test.flatten(),
    "Giá dự đoán": Y_test_predict.flatten()
})

# Làm tròn về số nguyên
compare_df = compare_df.astype(int)
pd.set_option('display.max_rows', None)
# Hiển thị toàn bộ bảng
display(compare_df)
compare_df.to_csv("./Model/case_1/LSTM/model_ADAM/predict.csv", index=False)
# Out:
# 12/12 [==============================] - 0s 2ms/step
#      Giá thực tế  Giá dự đoán
# 0          24790        24684
# 1          24830        24684
# 2          24840        24689
# 3          24840        24696
# 4          24840        24704
# 5          24960        24712
# 6          25008        24728
# 7          25130        24751
# 8          25130        24787
# 9          25163        24826
# 10         25163        24868
# 11         25163        24913
# 12         25175        24958
# 13         25178        24987
# 14         25177        25009
# 15         25167        25015
# 16         25118        25021
# 17         25118        25019
# 18         25118        25014
# 19         25118        25008
# 20         25118        25000
# 21         25118        24992
# 22         25144        24983
# 23         25143        24979
# 24         25147        24981
# 25         25147        24985
# 26         25157        24989
# 27         25155        24994
# 28         25161        24999
# 29         25178        25004
# 30         25184        25007
# 31         25184        25012
# 32         25184        25017
# 33         25179        25022
# 34         25182        25026
# 35         25182        25029
# 36         25152        25032
# 37         25250        25030
# 38         25250        25033
# 39         25250        25040
# 40         25259        25048
# 41         25263        25058
# 42         25266        25069
# 43         25250        25081
# 44         25277        25095
# 45         25277        25097
# 46         25277        25100
# 47         25281        25103
# 48         25268        25106
# 49         25265        25108
# 50         25250        25108
# 51         25254        25109
# 52         25254        25107
# 53         25254        25103
# 54         25234        25100
# 55         25218        25095
# 56         25213        25090
# 57         25213        25084
# 58         25213        25079
# 59         25213        25073
# 60         25213        25068
# 61         25214        25062
# 62         25222        25059
# 63         25226        25059
# 64         25217        25060
# 65         25221        25061
# 66         25221        25063
# 67         25221        25064
# 68         25231        25065
# 69         25251        25066
# 70         25249        25068
# 71         25247        25071
# 72         25248        25075
# 73         25248        25079
# 74         25248        25083
# 75         25255        25087
# 76         25245        25089
# 77         25250        25089
# 78         25257        25089
# 79         25253        25090
# 80         25253        25091
# 81         25253        25091
# 82         25244        25092
