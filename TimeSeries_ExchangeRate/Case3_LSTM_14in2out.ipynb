# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler #chuẩn hóa dữ liệu
from keras.callbacks import ModelCheckpoint #lưu lại huấn luyện tốt nhất
from tensorflow.keras.models import load_model #tải mô hình
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import ModelCheckpoint

import random
import tensorflow as tf

#các lớp để xây dựng mô hình
from keras.models import Sequential #đầu vào
from keras.layers import LSTM #học phụ thuộc
from keras.layers import Dropout, BatchNormalization #tránh học tủ
from keras.layers import Dense #đầu ra

#kiểm tra độ chính xác của mô hình
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %% [markdown]
# random.seed(42)
# np.random.seed(42)
# tf.random.set_seed(42)

# %%
df_usd = pd.read_parquet("./minio/usd/part-00000-18b834c3-cd6d-42ae-82c3-638999ff6d84-c000.snappy.parquet", engine="pyarrow")
df_usd.head()
# Out:
#         ngay ma_ngoai_te ten_ngoai_te  mua_chuyen_khoan      ban
# 0 2020-02-01         USD    US DOLLAR           23165.0  23305.0
# 1 2020-02-02         USD    US DOLLAR           23165.0  23305.0
# 2 2020-02-03         USD    US DOLLAR           23200.0  23340.0
# 3 2020-02-04         USD    US DOLLAR           23170.0  23310.0
# 4 2020-02-05         USD    US DOLLAR           23160.0  23300.0

# %%
df_usd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1911 entries, 0 to 1910
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ngay              1911 non-null   datetime64[ns]
#  1   ma_ngoai_te       1911 non-null   object
#  2   ten_ngoai_te      1911 non-null   object
#  3   mua_chuyen_khoan  1911 non-null   float64
#  4   ban               1911 non-null   float64
# dtypes: datetime64[ns](1), float64(2), object(2)
# memory usage: 74.8+ KB

# %%
df_usd.describe()
# Out:
#                       ngay  mua_chuyen_khoan           ban
# count                 1911       1911.000000   1911.000000
# mean   2022-09-13 00:00:00      23666.414443  23934.197279
# min    2020-02-01 00:00:00      22480.000000  22745.000000
# 25%    2021-05-23 12:00:00      22985.000000  23170.000000
# 50%    2022-09-13 00:00:00      23300.000000  23620.000000
# 75%    2024-01-03 12:00:00      24390.000000  24730.000000
# max    2025-04-25 00:00:00      25835.000000  26195.000000
# std                    NaN        885.147984    926.810272

# %%
print(df_usd.dtypes)
# Out:
# ngay                datetime64[ns]
# ma_ngoai_te                 object
# ten_ngoai_te                object
# mua_chuyen_khoan           float64
# ban                        float64
# dtype: object

# %%
import matplotlib.pyplot as plt
from matplotlib.dates import YearLocator, DateFormatter, MonthLocator

# Vẽ biểu đồ
plt.figure(figsize=(10, 5))
plt.plot(df_usd['ngay'].values, df_usd['mua_chuyen_khoan'].values, label='Giá mua chuyển khoản', color='red')

plt.xlabel('Năm')
plt.ylabel('Giá mua chuyển khoản')
plt.title('Biểu đồ tỷ giá VND_USD mua chuyển khoảng qua các năm')
plt.legend(loc='best')

# Định dạng trục x
plt.gca().xaxis.set_major_locator(YearLocator())
plt.gca().xaxis.set_major_formatter(DateFormatter('%Y'))
plt.gca().xaxis.set_minor_locator(MonthLocator())

plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
df_usd_ML = pd.DataFrame(df_usd, columns=['ngay','mua_chuyen_khoan'])
df_usd_ML.index = df_usd_ML.ngay
df_usd_ML.drop('ngay', axis = 1, inplace=True)
df_usd_ML.head()
# Out:
#             mua_chuyen_khoan
# ngay
# 2020-02-01           23165.0
# 2020-02-02           23165.0
# 2020-02-03           23200.0
# 2020-02-04           23170.0
# 2020-02-05           23160.0

# %%
print(df_usd_ML.columns)
# Out:
# Index(['mua_chuyen_khoan'], dtype='object')

# %%
data = df_usd_ML.values

# %%
data
# Out:
# array([[23165.],
#        [23165.],
#        [23200.],
#        ...,
#        [25781.],
#        [25814.],
#        [25835.]])

# %%
#hàm hóa dữ liệu
sc = MinMaxScaler(feature_range=(0,1))

#chuẩn hóa dữ train
scale_data = sc.fit_transform(data)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))

plt.plot(scale_data, label="Dữ liệu sau chuẩn hóa", color="red")

plt.xlabel("Thời gian (Index)")
plt.ylabel("Giá trị sau chuẩn hóa")
plt.title("Biểu đồ dữ liệu sau khi chuẩn hóa bằng MinMaxScaler")
plt.legend()
plt.show()

# %%
window_size = 14
X_train, Y_train = [], []

for i in range(len(scale_data) - window_size - 1):  # trừ 1 vì lấy 2 output
    X_train.append(scale_data[i:i + window_size])  # 14 giá trị làm input
    Y_train.append(scale_data[i + window_size : i + window_size + 2])  # 2 giá trị output kế tiếp

X_train = np.array(X_train)
Y_train = np.array(Y_train)

# Kiểm tra shape dữ liệu
print('X_train shape:', X_train.shape)  # (số mẫu, 14)
print('Y_train shape:', Y_train.shape)  # (số mẫu, 2)

# Phân chia tập train-test
split_index = int(0.9 * len(X_train))
X_train, X_test = X_train[:split_index], X_train[split_index:]
Y_train, Y_test = Y_train[:split_index], Y_train[split_index:]

#Reshape cho model LSTM
X_train = X_train.reshape((X_train.shape[0], window_size, 1))
X_test = X_test.reshape((X_test.shape[0], window_size, 1))
# Out:
# X_train shape: (1896, 14, 1)
# Y_train shape: (1896, 2, 1)

# %%
print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
print("y_train shape:", Y_train.shape)
print("y_test shape:", Y_test.shape)
# Out:
# X_train shape: (1706, 14, 1)
# X_test shape: (190, 14, 1)
# y_train shape: (1706, 2, 1)
# y_test shape: (190, 2, 1)

# %% [markdown]
# # MODEL

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Bidirectional, BatchNormalization

# Xây dựng mô hình BiLSTM
model = Sequential()
# Lớp LSTM đầu tiên (return_sequences=True để kết nối lớp tiếp theo)
model.add(LSTM(units=64, return_sequences=True, input_shape=(14, 1)))
model.add(BatchNormalization())  # Ổn định dữ liệu đầu ra
# Lớp BiLSTM thứ hai
model.add(Bidirectional(LSTM(units=64)))
model.add(BatchNormalization())
# Dropout để giảm overfitting
model.add(Dropout(0.5))
# Lớp Dense đầu ra với 2 neuron (dự báo 2 giá trị)
model.add(Dense(2))
#đo sai số tuyệt đối trung bình có sử dụng trình tối ưu hóa rmsprop
model.compile(loss='mean_absolute_error', optimizer='rmsprop')

# %% [markdown]
# # huấn luyện mô hình

# %%
save_model = "./Model/case_3/LSTM/model_14in2out/save_model.hdf5"
best_model = ModelCheckpoint(save_model,monitor='loss',verbose=2,save_best_only=True,mode='auto')

import time
start_model = time.time()  # Bắt đầu đo thời gian
model.fit(X_train,Y_train,epochs=100,batch_size=50,validation_split=0.4,verbose=2,callbacks=[best_model])
end_model = time.time()  # Kết thúc đo thời gian
print(f"Thời gian thực thi mô hình: {end_model - start_model:.2f} giây")
# Out:
# Epoch 1/100
#
# Epoch 1: loss improved from inf to 0.89696, saving model to ./Model/case_3/LSTM/model_14in2out\save_model.hdf5
# 21/21 - 4s - loss: 0.8970 - val_loss: 0.3662 - 4s/epoch - 209ms/step
# Epoch 2/100
#
# Epoch 2: loss improved from 0.89696 to 0.70800, saving model to ./Model/case_3/LSTM/model_14in2out\save_model.hdf5
# 21/21 - 0s - loss: 0.7080 - val_loss: 0.3723 - 450ms/epoch - 21ms/step
# Epoch 3/100
#
# Epoch 3: loss improved from 0.70800 to 0.64541, saving model to ./Model/case_3/LSTM/model_14in2out\save_model.hdf5
# 21/21 - 0s - loss: 0.6454 - val_loss: 0.3508 - 468ms/epoch - 22ms/step
# Epoch 4/100
#
# Epoch 4: loss improved from 0.64541 to 0.55148, saving model to ./Model/case_3/LSTM/model_14in2out\save_model.hdf5
# 21/21 - 0s - loss: 0.5515 - val_loss: 0.3978 - 470ms/epoch - 22ms/step
# Epoch 5/100
#
# Epoch 5: loss improved from 0.55148 to 0.43456, saving model to ./Model/case_3/LSTM/model_14in2out\save_model.hdf5
# 21/21 - 0s - loss: 0.4346 - val_loss: 0.3236 - 459ms/epoch - 22ms/step
# Epoch 6/100
#
# Epoch 6: loss improved from 0.43456 to 0.32729, saving model to ./Model/case_3/LSTM/model_14in2out\save_model.hdf5
# 21/21 - 0s - loss: 0.3273 - val_loss: 0.3611 - 472ms/epoch - 22ms/step
# Epoch 7/100
#
# Epoch 7: loss improved from 0.32729 to 0.16942, saving model to ./Model/case_3/LSTM/model_14in2out\save_model.hdf5
# 21/21 - 0s - loss: 0.1694 - val_loss: 0.3716 - 459ms/epoch - 22ms/step
# Epoch 8/100
#
# Epoch 8: loss improved from 0.16942 to 0.06363, saving model to ./Model/case_3/LSTM/model_14in2out\save_model.hdf5
# 21/21 - 0s - loss: 0.0636 - val_loss: 0.3496 - 465ms/epoch - 22ms/step
# Epoch 9/100
#
# Epoch 9: loss improved from 0.06363 to 0.04216, saving model to ./Model/case_3/LSTM/model_14in2out\save_model.hdf5
# 21/21 - 0s - loss: 0.0422 - val_loss: 0.3224 - 500ms/epoch - 24ms/step
# Epoch 10/100
#
# Epoch 10: loss improved from 0.04216 to 0.03550, saving model to ./Model/case_3/LSTM/model_14in2out\save_model.hdf5
# 21/21 - 0s - loss: 0.0355 - val_loss: 0.2394 - 497ms/epoch - 24ms/step
# Epoch 11/100
#
# Epoch 11: loss improved from 0.03550 to 0.03105, saving model to ./Model/case_3/LSTM/model_14in2out\save_model.hdf5
# 21/21 - 1s - loss: 0.0310 - val_loss: 0.2203 - 502ms/epoch - 24ms/step
# Epoch 12/100
#
# Epoch 12: loss improved from 0.03105 to 0.03020, saving model to ./Model/case_3/LSTM/model_14in2out\save_model.hdf5
# 21/21 - 0s - loss: 0.0302 - val_loss: 0.1642 - 498ms/epoch - 24ms/step
# Epoch 13/100
#
# Epoch 13: loss improved from 0.03020 to 0.02920, saving model to ./Model/case_3/LSTM/model_14in2out\save_model.hdf5
# 21/21 - 0s - loss: 0.0292 - val_loss: 0.1785 - 489ms/epoch - 23ms/step
# Epoch 14/100
#
# Epoch 14: loss improved from 0.02920 to 0.02849, saving model to ./Model/case_3/LSTM/model_14in2out\save_model.hdf5
# 21/21 - 1s - loss: 0.0285 - val_loss: 0.1661 - 519ms/epoch - 25ms/step
# Epoch 15/100
#
# Epoch 15: loss improved from 0.02849 to 0.02729, saving model to ./Model/case_3/LSTM/model_14in2out\save_model.hdf5
# 21/21 - 0s - loss: 0.0273 - val_loss: 0.1473 - 500ms/epoch - 24ms/step
# Epoch 16/100
#
# Epoch 16: loss did not improve from 0.02729
# 21/21 - 0s - loss: 0.0303 - val_loss: 0.1470 - 470ms/epoch - 22ms/step
# Epoch 17/100
#
# Epoch 17: loss improved from 0.02729 to 0.02578, saving model to ./Model/case_3/LSTM/model_14in2out\save_model.hdf5
# 21/21 - 1s - loss: 0.0258 - val_loss: 0.1458 - 515ms/epoch - 25ms/step
# Epoch 18/100
#
# Epoch 18: loss did not improve from 0.02578
# 21/21 - 1s - loss: 0.0299 - val_loss: 0.1691 - 508ms/epoch - 24ms/step
# Epoch 19/100
#
# Epoch 19: loss did not improve from 0.02578
# 21/21 - 0s - loss: 0.0287 - val_loss: 0.1760 - 496ms/epoch - 24ms/step
# Epoch 20/100
#
# Epoch 20: loss improved from 0.02578 to 0.02445, saving model to ./Model/case_3/LSTM/model_14in2out\save_model.hdf5
# 21/21 - 0s - loss: 0.0244 - val_loss: 0.2043 - 477ms/epoch - 23ms/step
# Epoch 21/100
#
# Epoch 21: loss did not improve from 0.02445
# 21/21 - 0s - loss: 0.0268 - val_loss: 0.1730 - 498ms/epoch - 24ms/step
# Epoch 22/100
#
# Epoch 22: loss did not improve from 0.02445
# 21/21 - 0s - loss: 0.0254 - val_loss: 0.1383 - 465ms/epoch - 22ms/step
# Epoch 23/100
#
# Epoch 23: loss did not improve from 0.02445
# 21/21 - 0s - loss: 0.0269 - val_loss: 0.1224 - 460ms/epoch - 22ms/step
# Epoch 24/100
#
# Epoch 24: loss did not improve from 0.02445
# 21/21 - 0s - loss: 0.0273 - val_loss: 0.1968 - 443ms/epoch - 21ms/step
# Epoch 25/100
#
# Epoch 25: loss did not improve from 0.02445
# 21/21 - 0s - loss: 0.0273 - val_loss: 0.1092 - 445ms/epoch - 21ms/step
# Epoch 26/100
#
# Epoch 26: loss improved from 0.02445 to 0.02435, saving model to ./Model/case_3/LSTM/model_14in2out\save_model.hdf5
# 21/21 - 0s - loss: 0.0243 - val_loss: 0.1506 - 490ms/epoch - 23ms/step
# Epoch 27/100
#
# Epoch 27: loss improved from 0.02435 to 0.02223, saving model to ./Model/case_3/LSTM/model_14in2out\save_model.hdf5
# 21/21 - 0s - loss: 0.0222 - val_loss: 0.1125 - 495ms/epoch - 24ms/step
# Epoch 28/100
#
# Epoch 28: loss did not improve from 0.02223
# 21/21 - 0s - loss: 0.0235 - val_loss: 0.0967 - 452ms/epoch - 22ms/step
# Epoch 29/100
#
# Epoch 29: loss did not improve from 0.02223
# 21/21 - 0s - loss: 0.0265 - val_loss: 0.0900 - 468ms/epoch - 22ms/step
# Epoch 30/100
#
# Epoch 30: loss did not improve from 0.02223
# 21/21 - 0s - loss: 0.0246 - val_loss: 0.0783 - 496ms/epoch - 24ms/step
# Epoch 31/100
#
# Epoch 31: loss improved from 0.02223 to 0.01976, saving model to ./Model/case_3/LSTM/model_14in2out\save_model.hdf5
# 21/21 - 1s - loss: 0.0198 - val_loss: 0.1009 - 510ms/epoch - 24ms/step
# Epoch 32/100
#
# Epoch 32: loss did not improve from 0.01976
# 21/21 - 0s - loss: 0.0233 - val_loss: 0.0767 - 464ms/epoch - 22ms/step
# Epoch 33/100
#
# Epoch 33: loss did not improve from 0.01976
# 21/21 - 0s - loss: 0.0266 - val_loss: 0.0720 - 477ms/epoch - 23ms/step
# Epoch 34/100
#
# Epoch 34: loss did not improve from 0.01976
# 21/21 - 0s - loss: 0.0243 - val_loss: 0.0492 - 450ms/epoch - 21ms/step
# Epoch 35/100
#
# Epoch 35: loss did not improve from 0.01976
# 21/21 - 0s - loss: 0.0241 - val_loss: 0.1602 - 437ms/epoch - 21ms/step
# Epoch 36/100
#
# Epoch 36: loss did not improve from 0.01976
# 21/21 - 0s - loss: 0.0259 - val_loss: 0.3994 - 415ms/epoch - 20ms/step
# Epoch 37/100
#
# Epoch 37: loss did not improve from 0.01976
# 21/21 - 0s - loss: 0.0235 - val_loss: 0.1428 - 417ms/epoch - 20ms/step
# Epoch 38/100
#
# Epoch 38: loss did not improve from 0.01976
# 21/21 - 0s - loss: 0.0245 - val_loss: 0.2315 - 462ms/epoch - 22ms/step
# Epoch 39/100
#
# Epoch 39: loss did not improve from 0.01976
# 21/21 - 0s - loss: 0.0236 - val_loss: 0.2773 - 437ms/epoch - 21ms/step
# Epoch 40/100
#
# Epoch 40: loss did not improve from 0.01976
# 21/21 - 0s - loss: 0.0247 - val_loss: 0.3871 - 462ms/epoch - 22ms/step
# Epoch 41/100
#
# Epoch 41: loss did not improve from 0.01976
# 21/21 - 0s - loss: 0.0258 - val_loss: 0.0597 - 447ms/epoch - 21ms/step
# Epoch 42/100
#
# Epoch 42: loss did not improve from 0.01976
# 21/21 - 0s - loss: 0.0242 - val_loss: 0.0940 - 440ms/epoch - 21ms/step
# Epoch 43/100
#
# Epoch 43: loss did not improve from 0.01976
# 21/21 - 0s - loss: 0.0218 - val_loss: 0.1840 - 467ms/epoch - 22ms/step
# Epoch 44/100
#
# Epoch 44: loss did not improve from 0.01976
# 21/21 - 0s - loss: 0.0247 - val_loss: 0.0457 - 430ms/epoch - 20ms/step
# Epoch 45/100
#
# Epoch 45: loss did not improve from 0.01976
# 21/21 - 0s - loss: 0.0218 - val_loss: 0.0710 - 430ms/epoch - 20ms/step
# Epoch 46/100
#
# Epoch 46: loss did not improve from 0.01976
# 21/21 - 0s - loss: 0.0252 - val_loss: 0.0473 - 460ms/epoch - 22ms/step
# Epoch 47/100
#
# Epoch 47: loss did not improve from 0.01976
# 21/21 - 0s - loss: 0.0220 - val_loss: 0.0739 - 476ms/epoch - 23ms/step
# Epoch 48/100
#
# Epoch 48: loss did not improve from 0.01976
# 21/21 - 0s - loss: 0.0247 - val_loss: 0.1041 - 467ms/epoch - 22ms/step
# Epoch 49/100
#
# Epoch 49: loss did not improve from 0.01976
# 21/21 - 0s - loss: 0.0233 - val_loss: 0.2615 - 482ms/epoch - 23ms/step
# Epoch 50/100
#
# Epoch 50: loss did not improve from 0.01976
# 21/21 - 0s - loss: 0.0245 - val_loss: 0.0359 - 454ms/epoch - 22ms/step
# Epoch 51/100
#
# Epoch 51: loss did not improve from 0.01976
# 21/21 - 0s - loss: 0.0234 - val_loss: 0.2437 - 465ms/epoch - 22ms/step
# Epoch 52/100
#
# Epoch 52: loss did not improve from 0.01976
# 21/21 - 0s - loss: 0.0254 - val_loss: 0.1015 - 466ms/epoch - 22ms/step
# Epoch 53/100
#
# Epoch 53: loss did not improve from 0.01976
# 21/21 - 0s - loss: 0.0227 - val_loss: 0.1439 - 446ms/epoch - 21ms/step
# Epoch 54/100
#
# Epoch 54: loss did not improve from 0.01976
# 21/21 - 0s - loss: 0.0240 - val_loss: 0.0294 - 430ms/epoch - 20ms/step
# Epoch 55/100
#
# Epoch 55: loss did not improve from 0.01976
# 21/21 - 0s - loss: 0.0223 - val_loss: 0.0650 - 462ms/epoch - 22ms/step
# Epoch 56/100
#
# Epoch 56: loss did not improve from 0.01976
# 21/21 - 0s - loss: 0.0226 - val_loss: 0.0829 - 436ms/epoch - 21ms/step
# Epoch 57/100
#
# Epoch 57: loss improved from 0.01976 to 0.01931, saving model to ./Model/case_3/LSTM/model_14in2out\save_model.hdf5
# 21/21 - 0s - loss: 0.0193 - val_loss: 0.2092 - 492ms/epoch - 23ms/step
# Epoch 58/100
#
# Epoch 58: loss did not improve from 0.01931
# 21/21 - 0s - loss: 0.0240 - val_loss: 0.0266 - 467ms/epoch - 22ms/step
# Epoch 59/100
#
# Epoch 59: loss did not improve from 0.01931
# 21/21 - 0s - loss: 0.0215 - val_loss: 0.0479 - 460ms/epoch - 22ms/step
# Epoch 60/100
#
# Epoch 60: loss did not improve from 0.01931
# 21/21 - 0s - loss: 0.0253 - val_loss: 0.2446 - 452ms/epoch - 22ms/step
# Epoch 61/100
#
# Epoch 61: loss did not improve from 0.01931
# 21/21 - 0s - loss: 0.0228 - val_loss: 0.2704 - 465ms/epoch - 22ms/step
# Epoch 62/100
#
# Epoch 62: loss did not improve from 0.01931
# 21/21 - 0s - loss: 0.0250 - val_loss: 0.1051 - 440ms/epoch - 21ms/step
# Epoch 63/100
#
# Epoch 63: loss did not improve from 0.01931
# 21/21 - 0s - loss: 0.0202 - val_loss: 0.0644 - 459ms/epoch - 22ms/step
# Epoch 64/100
#
# Epoch 64: loss did not improve from 0.01931
# 21/21 - 0s - loss: 0.0196 - val_loss: 0.0298 - 451ms/epoch - 21ms/step
# Epoch 65/100
#
# Epoch 65: loss did not improve from 0.01931
# 21/21 - 0s - loss: 0.0217 - val_loss: 0.1729 - 448ms/epoch - 21ms/step
# Epoch 66/100
#
# Epoch 66: loss did not improve from 0.01931
# 21/21 - 0s - loss: 0.0239 - val_loss: 0.1402 - 456ms/epoch - 22ms/step
# Epoch 67/100
#
# Epoch 67: loss did not improve from 0.01931
# 21/21 - 0s - loss: 0.0207 - val_loss: 0.2041 - 450ms/epoch - 21ms/step
# Epoch 68/100
#
# Epoch 68: loss did not improve from 0.01931
# 21/21 - 0s - loss: 0.0216 - val_loss: 0.0841 - 462ms/epoch - 22ms/step
# Epoch 69/100
#
# Epoch 69: loss did not improve from 0.01931
# 21/21 - 0s - loss: 0.0200 - val_loss: 0.1810 - 460ms/epoch - 22ms/step
# Epoch 70/100
#
# Epoch 70: loss did not improve from 0.01931
# 21/21 - 0s - loss: 0.0219 - val_loss: 0.3269 - 450ms/epoch - 21ms/step
# Epoch 71/100
#
# Epoch 71: loss improved from 0.01931 to 0.01862, saving model to ./Model/case_3/LSTM/model_14in2out\save_model.hdf5
# 21/21 - 0s - loss: 0.0186 - val_loss: 0.1711 - 485ms/epoch - 23ms/step
# Epoch 72/100
#
# Epoch 72: loss did not improve from 0.01862
# 21/21 - 0s - loss: 0.0201 - val_loss: 0.0473 - 440ms/epoch - 21ms/step
# Epoch 73/100
#
# Epoch 73: loss did not improve from 0.01862
# 21/21 - 0s - loss: 0.0219 - val_loss: 0.2868 - 459ms/epoch - 22ms/step
# Epoch 74/100
#
# Epoch 74: loss did not improve from 0.01862
# 21/21 - 0s - loss: 0.0226 - val_loss: 0.3957 - 450ms/epoch - 21ms/step
# Epoch 75/100
#
# Epoch 75: loss did not improve from 0.01862
# 21/21 - 0s - loss: 0.0253 - val_loss: 0.0279 - 427ms/epoch - 20ms/step
# Epoch 76/100
#
# Epoch 76: loss did not improve from 0.01862
# 21/21 - 0s - loss: 0.0199 - val_loss: 0.0813 - 442ms/epoch - 21ms/step
# Epoch 77/100
#
# Epoch 77: loss did not improve from 0.01862
# 21/21 - 0s - loss: 0.0255 - val_loss: 0.0407 - 440ms/epoch - 21ms/step
# Epoch 78/100
#
# Epoch 78: loss did not improve from 0.01862
# 21/21 - 0s - loss: 0.0229 - val_loss: 0.2836 - 416ms/epoch - 20ms/step
# Epoch 79/100
#
# Epoch 79: loss did not improve from 0.01862
# 21/21 - 0s - loss: 0.0195 - val_loss: 0.2250 - 450ms/epoch - 21ms/step
# Epoch 80/100
#
# Epoch 80: loss did not improve from 0.01862
# 21/21 - 0s - loss: 0.0200 - val_loss: 0.0813 - 408ms/epoch - 19ms/step
# Epoch 81/100
#
# Epoch 81: loss did not improve from 0.01862
# 21/21 - 0s - loss: 0.0210 - val_loss: 0.3671 - 410ms/epoch - 20ms/step
# Epoch 82/100
#
# Epoch 82: loss did not improve from 0.01862
# 21/21 - 0s - loss: 0.0225 - val_loss: 0.0431 - 410ms/epoch - 20ms/step
# Epoch 83/100
#
# Epoch 83: loss did not improve from 0.01862
# 21/21 - 0s - loss: 0.0231 - val_loss: 0.1043 - 400ms/epoch - 19ms/step
# Epoch 84/100
#
# Epoch 84: loss did not improve from 0.01862
# 21/21 - 0s - loss: 0.0189 - val_loss: 0.1996 - 410ms/epoch - 20ms/step
# Epoch 85/100
#
# Epoch 85: loss did not improve from 0.01862
# 21/21 - 0s - loss: 0.0227 - val_loss: 0.0381 - 422ms/epoch - 20ms/step
# Epoch 86/100
#
# Epoch 86: loss did not improve from 0.01862
# 21/21 - 0s - loss: 0.0220 - val_loss: 0.0676 - 409ms/epoch - 19ms/step
# Epoch 87/100
#
# Epoch 87: loss did not improve from 0.01862
# 21/21 - 0s - loss: 0.0189 - val_loss: 0.1344 - 450ms/epoch - 21ms/step
# Epoch 88/100
#
# Epoch 88: loss did not improve from 0.01862
# 21/21 - 0s - loss: 0.0223 - val_loss: 0.0615 - 451ms/epoch - 21ms/step
# Epoch 89/100
#
# Epoch 89: loss did not improve from 0.01862
# 21/21 - 0s - loss: 0.0208 - val_loss: 0.0374 - 440ms/epoch - 21ms/step
# Epoch 90/100
#
# Epoch 90: loss did not improve from 0.01862
# 21/21 - 0s - loss: 0.0226 - val_loss: 0.0458 - 459ms/epoch - 22ms/step
# Epoch 91/100
#
# Epoch 91: loss did not improve from 0.01862
# 21/21 - 0s - loss: 0.0200 - val_loss: 0.1714 - 434ms/epoch - 21ms/step
# Epoch 92/100
#
# Epoch 92: loss did not improve from 0.01862
# 21/21 - 0s - loss: 0.0197 - val_loss: 0.1477 - 440ms/epoch - 21ms/step
# Epoch 93/100
#
# Epoch 93: loss did not improve from 0.01862
# 21/21 - 0s - loss: 0.0219 - val_loss: 0.0429 - 416ms/epoch - 20ms/step
# Epoch 94/100
#
# Epoch 94: loss did not improve from 0.01862
# 21/21 - 0s - loss: 0.0219 - val_loss: 0.0498 - 410ms/epoch - 20ms/step
# Epoch 95/100
#
# Epoch 95: loss did not improve from 0.01862
# 21/21 - 0s - loss: 0.0207 - val_loss: 0.0855 - 400ms/epoch - 19ms/step
# Epoch 96/100
#
# Epoch 96: loss did not improve from 0.01862
# 21/21 - 0s - loss: 0.0212 - val_loss: 0.1569 - 425ms/epoch - 20ms/step
# Epoch 97/100
#
# Epoch 97: loss did not improve from 0.01862
# 21/21 - 0s - loss: 0.0208 - val_loss: 0.2661 - 470ms/epoch - 22ms/step
# Epoch 98/100
#
# Epoch 98: loss did not improve from 0.01862
# 21/21 - 0s - loss: 0.0225 - val_loss: 0.2375 - 420ms/epoch - 20ms/step
# Epoch 99/100
#
# Epoch 99: loss did not improve from 0.01862
# 21/21 - 0s - loss: 0.0195 - val_loss: 0.0920 - 409ms/epoch - 19ms/step
# Epoch 100/100
#
# Epoch 100: loss did not improve from 0.01862
# 21/21 - 0s - loss: 0.0198 - val_loss: 0.1085 - 424ms/epoch - 20ms/step
# Thời gian thực thi mô hình: 49.65 giây

# %%
#Model
final_model = load_model("./Model/case_3/LSTM/model_14in2out/save_model.hdf5")

# %%
#dữ liệu train
Y_train_predict = final_model.predict(X_train) 
# Nếu Y_train_predict là 3 chiều (samples, 2, 1) -> chuyển thành 2 chiều (samples, 2)
Y_train_predict = Y_train_predict.reshape(Y_train_predict.shape[0], Y_train_predict.shape[1])
Y_train_predict = sc.inverse_transform(Y_train_predict) #giá thực dự đoán

# Nếu Y_train là 3 chiều (samples, 2, 1) -> chuyển thành 2 chiều (samples, 2)
Y_train = Y_train.reshape(Y_train.shape[0], Y_train.shape[1])
Y_train = sc.inverse_transform(Y_train) #giá thực train
# Out:
# 54/54 [==============================] - 1s 3ms/step

# %%
print('Y_train_predict shape:', Y_train_predict.shape)
print('Y_train shape:', Y_train.shape)
# Out:
# Y_train_predict shape: (1706, 2)
# Y_train shape: (1706, 2)

# %% [markdown]
# # DỰ ĐOÁN TRÊN TẬP TEST

# %%
#dữ liệu test
import time
start_model = time.time()  # Bắt đầu đo thời gian
Y_test_predict = final_model.predict(X_test) 
end_model = time.time()  # Kết thúc đo thời gian
print(f"Thời gian thực thi mô hình: {end_model - start_model:.2f} giây")
# Nếu Y_test_predict là 3 chiều (samples, 2, 1) -> chuyển thành 2 chiều (samples, 2)
Y_test_predict = Y_test_predict.reshape(Y_test_predict.shape[0], Y_test_predict.shape[1])
Y_test_predict = sc.inverse_transform(Y_test_predict) #giá thực dự đoán

# Nếu Y_test là 3 chiều (samples, 2, 1) -> chuyển thành 2 chiều (samples, 2)
Y_test = Y_test.reshape(Y_test.shape[0], Y_test.shape[1])
Y_test = sc.inverse_transform(Y_test) #giá thực train
# Out:
# 6/6 [==============================] - 0s 3ms/step
# Thời gian thực thi mô hình: 0.07 giây

# %%
print('Y_test_predict shape:', Y_test_predict.shape)
print('Y_test shape:', Y_test.shape)
# Out:
# Y_test_predict shape: (190, 2)
# Y_test shape: (190, 2)

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import mean_absolute_error, mean_squared_error

# Tính toán các giá trị cho tập Train
mae_train = round(mean_absolute_error(Y_train, Y_train_predict), 3)
mse_train = round(mean_squared_error(Y_train, Y_train_predict), 3)
rmse_train = round(np.sqrt(mse_train), 3)

# Tính toán các giá trị cho tập Test
mae_test = round(mean_absolute_error(Y_test, Y_test_predict), 3)
mse_test = round(mean_squared_error(Y_test, Y_test_predict), 3)
rmse_test = round(np.sqrt(mse_test), 3)

# Tạo DataFrame để hiển thị kết quả
metrics = pd.DataFrame({
    "Tập dữ liệu": ["Train", "Test"],
    "MAE": [mae_train, mae_test],
    "MSE": [mse_train, mse_test],
    "RMSE": [rmse_train, rmse_test]
})
# In kết quả
print(metrics)
print(f"Thời gian thực thi mô hình: {end_model - start_model:.2f} giây")
# Out:
#   Tập dữ liệu      MAE         MSE     RMSE
# 0       Train  538.611  309154.063  556.016
# 1        Test  629.805  408010.193  638.757
# Thời gian thực thi mô hình: 0.07 giây

# %%
from tensorflow.keras.models import load_model

# Gọi lại mô hình đã lưu
loaded_model = load_model("./Model/case_3/LSTM/model_14in2out/save_model.hdf5")
# Dự đoán lại trên tập test
Y_test_predict = loaded_model.predict(X_test)
# Đảo chuẩn hóa (inverse transform)
Y_test_predict = sc.inverse_transform(Y_test_predict)

# Tạo bảng so sánh
compare_df = pd.DataFrame({
    "Giá thực tế": Y_test.flatten(),
    "Giá dự đoán": Y_test_predict.flatten()
})

# Làm tròn về số nguyên
compare_df = compare_df.astype(int)
pd.set_option('display.max_rows', None)
# Hiển thị toàn bộ bảng
display(compare_df)
compare_df.to_csv("./Model/case_3/LSTM/model_14in2out/predict.csv", index=False)
# Out:
# 6/6 [==============================] - 1s 3ms/step
#      Giá thực tế  Giá dự đoán
# 0          25010        25491
# 1          24980        25310
# 2          24980        25687
# 3          24980        25520
# 4          24980        25643
# 5          24980        25472
# 6          24980        25654
# 7          25070        25483
# 8          25070        25668
# 9          25092        25495
# 10         25092        25757
# 11         25220        25591
# 12         25220        25771
# 13         25233        25605
# 14         25233        25896
# 15         25197        25739
# 16         25197        25893
# 17         25197        25736
# 18         25197        25858
# 19         25197        25698
# 20         25197        25860
# 21         25194        25700
# 22         25194        25861
# 23         25164        25700
# 24         25164        25870
# 25         25118        25707
# 26         25118        25847
# 27         25090        25681
# 28         25090        25827
# 29         25114        25656
# 30         25114        25796
# 31         25114        25623
# 32         25114        25818
# 33         25114        25647
# 34         25114        25813
# 35         25125        25642
# 36         25125        25825
# 37         25160        25652
# 38         25160        25840
# 39         25170        25667
# 40         25170        25891
# 41         25197        25719
# 42         25197        25900
# 43         25130        25729
# 44         25130        25923
# 45         25130        25755
# 46         25130        25857
# 47         25130        25683
# 48         25130        25865
# 49         25116        25692
# 50         25116        25862
# 51         25160        25690
# 52         25160        25844
# 53         25180        25670
# 54         25180        25881
# 55         25184        25712
# 56         25184        25893
# 57         25190        25724
# 58         25190        25899
# 59         25190        25730
# 60         25190        25905
# 61         25190        25737
# 62         25190        25905
# 63         25200        25737
# 64         25200        25908
# 65         25205        25739
# 66         25205        25923
# 67         25200        25755
# 68         25200        25929
# 69         25200        25761
# 70         25200        25926
# 71         25200        25758
# 72         25200        25918
# 73         25200        25750
# 74         25200        25917
# 75         25200        25749
# 76         25200        25916
# 77         25197        25748
# 78         25197        25914
# 79         25200        25746
# 80         25200        25917
# 81         25200        25748
# 82         25200        25923
# 83         25175        25754
# 84         25175        25923
# 85         25160        25754
# 86         25160        25899
# 87         25160        25728
# 88         25160        25886
# 89         25160        25715
# 90         25160        25887
# 91         25149        25715
# 92         25149        25887
# 93         25170        25716
# 94         25170        25877
# 95         25172        25704
# 96         25172        25898
# 97         25176        25727
# 98         25176        25898
# 99         25164        25727
# 100        25164        25902
# 101        25164        25732
# 102        25164        25890
# 103        25164        25719
# 104        25164        25892
# 105        25157        25721
# 106        25157        25892
# 107        25170        25721
# 108        25170        25886
# 109        25165        25714
# 110        25165        25899
# 111        25171        25728
# 112        25171        25889
# 113        25177        25718
# 114        25177        25894
# 115        25177        25724
# 116        25177        25899
# 117        25177        25729
# 118        25177        25899
# 119        25185        25729
# 120        25185        25898
# 121        25183        25728
# 122        25183        25908
# 123        25191        25739
# 124        25191        25906
# 125        25219        25737
# 126        25219        25915
# 127        25240        25746
# 128        25240        25940
# 129        25240        25773
# 130        25240        25959
# 131        25240        25793
# 132        25240        25958
# 133        25230        25792
# 134        25230        25958
# 135        25223        25792
# 136        25223        25950
# 137        25236        25783
# 138        25236        25943
# 139        25225        25776
# 140        25225        25957
# 141        25238        25791
# 142        25238        25945
# 143        25238        25778
# 144        25238        25959
# 145        25238        25792
# 146        25238        25957
# 147        25243        25790
# 148        25243        25958
# 149        25251        25791
# 150        25251        25962
# 151        25251        25796
# 152        25251        25971
# 153        25259        25805
# 154        25259        25974
# 155        25250        25808
# 156        25250        25985
# 157        25250        25819
# 158        25250        25976
# 159        25250        25809
# 160        25250        25977
# 161        25253        25810
# 162        25253        25975
# 163        25208        25809
# 164        25208        25977
# 165        25186        25811
# 166        25186        25934
# 167        25194        25764
# 168        25194        25915
# 169        25198        25744
# 170        25198        25924
# 171        25198        25754
# 172        25198        25926
# 173        25198        25756
# 174        25198        25926
# 175        25200        25756
# 176        25200        25926
# 177        25203        25756
# 178        25203        25930
# 179        25194        25760
# 180        25194        25933
# 181        25189        25763
# 182        25189        25925
# 183        25150        25755
# 184        25150        25921
# 185        25150        25750
# 186        25150        25883
# 187        25150        25710
# 188        25150        25886
# 189        25150        25714
# 190        25150        25885
# 191        25090        25712
# 192        25090        25879
# 193        24960        25706
# 194        24960        25816
# 195        24960        25640
# 196        24960        25694
# 197        24800        25509
# 198        24800        25704
# 199        24800        25520
# 200        24800        25542
# 201        24800        25346
# 202        24800        25554
# 203        24800        25360
# 204        24800        25549
# 205        24800        25355
# 206        24800        25548
# 207        24800        25354
# 208        24800        25546
# 209        24800        25353
# 210        24800        25546
# 211        24800        25353
# 212        24800        25544
# 213        24800        25351
# 214        24800        25547
# 215        24800        25355
# 216        24800        25550
# 217        25140        25358
# 218        25140        25553
# 219        25000        25361
# 220        25000        25881
# 221        24980        25715
# 222        24980        25698
# 223        25090        25521
# 224        25090        25701
# 225        25110        25524
# 226        25110        25789
# 227        25110        25622
# 228        25110        25799
# 229        25110        25632
# 230        25110        25801
# 231        25200        25634
# 232        25200        25802
# 233        25340        25635
# 234        25340        25890
# 235        25380        25728
# 236        25380        26018
# 237        25300        25865
# 238        25300        26046
# 239        25220        25895
# 240        25220        25967
# 241        25220        25809
# 242        25220        25896
# 243        25220        25734
# 244        25220        25903
# 245        25280        25741
# 246        25280        25942
# 247        25340        25776
# 248        25340        25980
# 249        25340        25820
# 250        25340        26030
# 251        25350        25873
# 252        25350        26038
# 253        25320        25879
# 254        25320        26051
# 255        25320        25892
# 256        25320        26020
# 257        25320        25859
# 258        25320        26025
# 259        25310        25864
# 260        25310        26038
# 261        25330        25875
# 262        25330        26047
# 263        25360        25882
# 264        25360        26072
# 265        25380        25908
# 266        25380        26087
# 267        25370        25926
# 268        25370        26093
# 269        25370        25934
# 270        25370        26082
# 271        25370        25922
# 272        25370        26084
# 273        25420        25924
# 274        25420        26092
# 275        25390        25932
# 276        25390        26150
# 277        25320        25992
# 278        25320        26116
# 279        25300        25956
# 280        25300        26052
# 281        25300        25887
# 282        25300        26033
# 283        25330        25868
# 284        25330        26032
# 285        25330        25867
# 286        25330        26059
# 287        25340        25896
# 288        25340        26055
# 289        25290        25891
# 290        25290        26068
# 291        25280        25905
# 292        25280        26022
# 293        25320        25855
# 294        25320        26019
# 295        25350        25852
# 296        25350        26057
# 297        25350        25893
# 298        25350        26084
# 299        25350        25921
# 300        25350        26084
# 301        25360        25921
# 302        25360        26091
# 303        25350        25928
# 304        25350        26097
# 305        25370        25935
# 306        25370        26078
# 307        25380        25915
# 308        25380        26096
# 309        25400        25936
# 310        25400        26105
# 311        25400        25945
# 312        25400        26128
# 313        25400        25969
# 314        25400        26127
# 315        25450        25967
# 316        25450        26128
# 317        25450        25968
# 318        25450        26170
# 319        25390        26015
# 320        25390        26165
# 321        25390        26009
# 322        25390        26113
# 323        25400        25952
# 324        25400        26122
# 325        25400        25961
# 326        25400        26129
# 327        25400        25970
# 328        25400        26128
# 329        25380        25968
# 330        25380        26128
# 331        25460        25968
# 332        25460        26107
# 333        25460        25945
# 334        25460        26190
# 335        25620        26034
# 336        25620        26183
# 337        25600        26027
# 338        25600        26346
# 339        25600        26201
# 340        25600        26314
# 341        25600        26166
# 342        25600        26323
# 343        25600        26174
# 344        25600        26331
# 345        25780        26181
# 346        25780        26331
# 347        25822        26182
# 348        25822        26501
# 349        25610        26365
# 350        25610        26526
# 351        25560        26391
# 352        25560        26319
# 353        25560        26169
# 354        25560        26289
# 355        25560        26137
# 356        25560        26285
# 357        25640        26133
# 358        25640        26278
# 359        25650        26126
# 360        25650        26365
# 361        25650        26217
# 362        25650        26367
# 363        25700        26219
# 364        25700        26387
# 365        25760        26238
# 366        25760        26434
# 367        25760        26288
# 368        25760        26490
# 369        25760        26348
# 370        25760        26488
# 371        25700        26345
# 372        25700        26494
# 373        25755        26351
# 374        25755        26461
# 375        25781        26311
# 376        25781        26524
# 377        25814        26379
# 378        25814        26515
# 379        25835        26373
