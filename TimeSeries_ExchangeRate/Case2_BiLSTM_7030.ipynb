# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler #chuẩn hóa dữ liệu
from keras.callbacks import ModelCheckpoint #lưu lại huấn luyện tốt nhất
from tensorflow.keras.models import load_model #tải mô hình
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import ModelCheckpoint

import random
import tensorflow as tf

#các lớp để xây dựng mô hình
from keras.models import Sequential #đầu vào
from keras.layers import LSTM #học phụ thuộc
from keras.layers import Dropout, BatchNormalization #tránh học tủ
from keras.layers import Dense #đầu ra

#kiểm tra độ chính xác của mô hình
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
random.seed(42)
np.random.seed(42)
tf.random.set_seed(42)

# %%
df_usd = pd.read_parquet("./minio/usd/part-00000-18b834c3-cd6d-42ae-82c3-638999ff6d84-c000.snappy.parquet", engine="pyarrow")
df_usd.head()
# Out:
#         ngay ma_ngoai_te ten_ngoai_te  mua_chuyen_khoan      ban
# 0 2020-02-01         USD    US DOLLAR           23165.0  23305.0
# 1 2020-02-02         USD    US DOLLAR           23165.0  23305.0
# 2 2020-02-03         USD    US DOLLAR           23200.0  23340.0
# 3 2020-02-04         USD    US DOLLAR           23170.0  23310.0
# 4 2020-02-05         USD    US DOLLAR           23160.0  23300.0

# %%
df_usd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1911 entries, 0 to 1910
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ngay              1911 non-null   datetime64[ns]
#  1   ma_ngoai_te       1911 non-null   object
#  2   ten_ngoai_te      1911 non-null   object
#  3   mua_chuyen_khoan  1911 non-null   float64
#  4   ban               1911 non-null   float64
# dtypes: datetime64[ns](1), float64(2), object(2)
# memory usage: 74.8+ KB

# %%
df_usd.describe()
# Out:
#                       ngay  mua_chuyen_khoan           ban
# count                 1911       1911.000000   1911.000000
# mean   2022-09-13 00:00:00      23666.414443  23934.197279
# min    2020-02-01 00:00:00      22480.000000  22745.000000
# 25%    2021-05-23 12:00:00      22985.000000  23170.000000
# 50%    2022-09-13 00:00:00      23300.000000  23620.000000
# 75%    2024-01-03 12:00:00      24390.000000  24730.000000
# max    2025-04-25 00:00:00      25835.000000  26195.000000
# std                    NaN        885.147984    926.810272

# %%
print(df_usd.dtypes)
# Out:
# ngay                datetime64[ns]
# ma_ngoai_te                 object
# ten_ngoai_te                object
# mua_chuyen_khoan           float64
# ban                        float64
# dtype: object

# %%
import matplotlib.pyplot as plt
from matplotlib.dates import YearLocator, DateFormatter, MonthLocator

# Vẽ biểu đồ
plt.figure(figsize=(10, 5))
plt.plot(df_usd['ngay'].values, df_usd['mua_chuyen_khoan'].values, label='Giá mua chuyển khoản', color='red')

plt.xlabel('Năm')
plt.ylabel('Giá mua chuyển khoản')
plt.title('Biểu đồ tỷ giá VND_USD mua chuyển khoảng qua các năm')
plt.legend(loc='best')

# Định dạng trục x
plt.gca().xaxis.set_major_locator(YearLocator())
plt.gca().xaxis.set_major_formatter(DateFormatter('%Y'))
plt.gca().xaxis.set_minor_locator(MonthLocator())

plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
df_usd_ML = pd.DataFrame(df_usd, columns=['ngay','mua_chuyen_khoan'])
df_usd_ML.index = df_usd_ML.ngay
df_usd_ML.drop('ngay', axis = 1, inplace=True)
df_usd_ML.head()
# Out:
#             mua_chuyen_khoan
# ngay
# 2020-02-01           23165.0
# 2020-02-02           23165.0
# 2020-02-03           23200.0
# 2020-02-04           23170.0
# 2020-02-05           23160.0

# %%
print(df_usd_ML.columns)
# Out:
# Index(['mua_chuyen_khoan'], dtype='object')

# %%
data = df_usd_ML.values

# %%
data
# Out:
# array([[23165.],
#        [23165.],
#        [23200.],
#        ...,
#        [25781.],
#        [25814.],
#        [25835.]])

# %%
#hàm hóa dữ liệu
sc = MinMaxScaler(feature_range=(0,1))

#chuẩn hóa dữ train
scale_data = sc.fit_transform(data)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))

plt.plot(scale_data, label="Dữ liệu sau chuẩn hóa", color="red")

plt.xlabel("Thời gian (Index)")
plt.ylabel("Giá trị sau chuẩn hóa")
plt.title("Biểu đồ dữ liệu sau khi chuẩn hóa bằng MinMaxScaler")
plt.legend()
plt.show()

# %%
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Bidirectional, LSTM, Dense, Dropout

# Chọn window
window_size = 7
X_train, Y_train = [], []

for i in range(len(scale_data) - window_size):
    X_train.append(scale_data[i:i + window_size])
    Y_train.append(scale_data[i + window_size])

X_train = np.array(X_train)
Y_train = np.array(Y_train)

# Phân chia tập dữ liệu thành tập train và test 70 - 30
split_index = int(0.7 * len(X_train))

X_train, X_test = X_train[:split_index], X_train[split_index:]
Y_train, Y_test = Y_train[:split_index], Y_train[split_index:]

# Đảm bảo dữ liệu có đúng shape cho mô hình BiLSTM
X_train = X_train.reshape((X_train.shape[0], window_size, -1))
X_test = X_test.reshape((X_test.shape[0], window_size, -1))

# %%
print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
print("y_train shape:", Y_train.shape)
print("y_test shape:", Y_test.shape)
# Out:
# X_train shape: (1332, 7, 1)
# X_test shape: (572, 7, 1)
# y_train shape: (1332, 1)
# y_test shape: (572, 1)

# %%
print("Shape of X_train:", X_train.shape)
# Out:
# Shape of X_train: (1332, 7, 1)

# %% [markdown]
# # MODEL

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Bidirectional, BatchNormalization

# Xây dựng mô hình BiLSTM
model = Sequential()

# Lớp BiLSTM đầu tiên (return_sequences=True để kết nối lớp tiếp theo)
model.add(Bidirectional(LSTM(units=64, return_sequences=True, input_shape=(X_train.shape[1], 1))))
model.add(BatchNormalization())  # Ổn định dữ liệu đầu ra

# Lớp BiLSTM thứ hai
model.add(Bidirectional(LSTM(units=64)))
model.add(BatchNormalization())

# Dropout để giảm overfitting
model.add(Dropout(0.5))

# Lớp Dense đầu ra
model.add(Dense(1))

# Compile mô hình
model.compile(loss='mean_absolute_error', optimizer='adam')

# %% [markdown]
# # huấn luyện mô hình

# %%
save_model = "./Model/case_2/BiLSTM/model_7030/save_model.hdf5"
best_model = ModelCheckpoint(save_model,monitor='loss',verbose=2,save_best_only=True,mode='auto')

import time
start_model = time.time()  # Bắt đầu đo thời gian
model.fit(X_train,Y_train,epochs=100,batch_size=50,validation_split=0.4,verbose=2,callbacks=[best_model])
end_model = time.time()  # Kết thúc đo thời gian
print(f"Thời gian thực thi mô hình: {end_model - start_model:.2f} giây")
# Out:
# Epoch 1/100
#
# Epoch 1: loss improved from inf to 0.95113, saving model to ./Model/case_2/BiLSTM/model_7030\save_model.hdf5
# 16/16 - 6s - loss: 0.9511 - val_loss: 0.2442 - 6s/epoch - 376ms/step
# Epoch 2/100
#
# Epoch 2: loss improved from 0.95113 to 0.80379, saving model to ./Model/case_2/BiLSTM/model_7030\save_model.hdf5
# 16/16 - 0s - loss: 0.8038 - val_loss: 0.1986 - 239ms/epoch - 15ms/step
# Epoch 3/100
#
# Epoch 3: loss improved from 0.80379 to 0.66133, saving model to ./Model/case_2/BiLSTM/model_7030\save_model.hdf5
# 16/16 - 0s - loss: 0.6613 - val_loss: 0.1947 - 226ms/epoch - 14ms/step
# Epoch 4/100
#
# Epoch 4: loss improved from 0.66133 to 0.63147, saving model to ./Model/case_2/BiLSTM/model_7030\save_model.hdf5
# 16/16 - 0s - loss: 0.6315 - val_loss: 0.1968 - 271ms/epoch - 17ms/step
# Epoch 5/100
#
# Epoch 5: loss improved from 0.63147 to 0.52084, saving model to ./Model/case_2/BiLSTM/model_7030\save_model.hdf5
# 16/16 - 0s - loss: 0.5208 - val_loss: 0.1858 - 242ms/epoch - 15ms/step
# Epoch 6/100
#
# Epoch 6: loss improved from 0.52084 to 0.39936, saving model to ./Model/case_2/BiLSTM/model_7030\save_model.hdf5
# 16/16 - 0s - loss: 0.3994 - val_loss: 0.1901 - 261ms/epoch - 16ms/step
# Epoch 7/100
#
# Epoch 7: loss improved from 0.39936 to 0.25153, saving model to ./Model/case_2/BiLSTM/model_7030\save_model.hdf5
# 16/16 - 0s - loss: 0.2515 - val_loss: 0.1952 - 269ms/epoch - 17ms/step
# Epoch 8/100
#
# Epoch 8: loss improved from 0.25153 to 0.14908, saving model to ./Model/case_2/BiLSTM/model_7030\save_model.hdf5
# 16/16 - 0s - loss: 0.1491 - val_loss: 0.2307 - 246ms/epoch - 15ms/step
# Epoch 9/100
#
# Epoch 9: loss improved from 0.14908 to 0.07725, saving model to ./Model/case_2/BiLSTM/model_7030\save_model.hdf5
# 16/16 - 0s - loss: 0.0772 - val_loss: 0.2096 - 253ms/epoch - 16ms/step
# Epoch 10/100
#
# Epoch 10: loss improved from 0.07725 to 0.04531, saving model to ./Model/case_2/BiLSTM/model_7030\save_model.hdf5
# 16/16 - 0s - loss: 0.0453 - val_loss: 0.1969 - 270ms/epoch - 17ms/step
# Epoch 11/100
#
# Epoch 11: loss improved from 0.04531 to 0.02726, saving model to ./Model/case_2/BiLSTM/model_7030\save_model.hdf5
# 16/16 - 0s - loss: 0.0273 - val_loss: 0.1781 - 238ms/epoch - 15ms/step
# Epoch 12/100
#
# Epoch 12: loss improved from 0.02726 to 0.02184, saving model to ./Model/case_2/BiLSTM/model_7030\save_model.hdf5
# 16/16 - 0s - loss: 0.0218 - val_loss: 0.1456 - 241ms/epoch - 15ms/step
# Epoch 13/100
#
# Epoch 13: loss improved from 0.02184 to 0.02075, saving model to ./Model/case_2/BiLSTM/model_7030\save_model.hdf5
# 16/16 - 0s - loss: 0.0207 - val_loss: 0.1251 - 238ms/epoch - 15ms/step
# Epoch 14/100
#
# Epoch 14: loss improved from 0.02075 to 0.01816, saving model to ./Model/case_2/BiLSTM/model_7030\save_model.hdf5
# 16/16 - 0s - loss: 0.0182 - val_loss: 0.1150 - 266ms/epoch - 17ms/step
# Epoch 15/100
#
# Epoch 15: loss improved from 0.01816 to 0.01755, saving model to ./Model/case_2/BiLSTM/model_7030\save_model.hdf5
# 16/16 - 0s - loss: 0.0175 - val_loss: 0.1034 - 245ms/epoch - 15ms/step
# Epoch 16/100
#
# Epoch 16: loss improved from 0.01755 to 0.01695, saving model to ./Model/case_2/BiLSTM/model_7030\save_model.hdf5
# 16/16 - 0s - loss: 0.0169 - val_loss: 0.0815 - 234ms/epoch - 15ms/step
# Epoch 17/100
#
# Epoch 17: loss improved from 0.01695 to 0.01591, saving model to ./Model/case_2/BiLSTM/model_7030\save_model.hdf5
# 16/16 - 0s - loss: 0.0159 - val_loss: 0.0765 - 245ms/epoch - 15ms/step
# Epoch 18/100
#
# Epoch 18: loss did not improve from 0.01591
# 16/16 - 0s - loss: 0.0189 - val_loss: 0.0922 - 214ms/epoch - 13ms/step
# Epoch 19/100
#
# Epoch 19: loss improved from 0.01591 to 0.01496, saving model to ./Model/case_2/BiLSTM/model_7030\save_model.hdf5
# 16/16 - 0s - loss: 0.0150 - val_loss: 0.1167 - 238ms/epoch - 15ms/step
# Epoch 20/100
#
# Epoch 20: loss did not improve from 0.01496
# 16/16 - 0s - loss: 0.0152 - val_loss: 0.1353 - 203ms/epoch - 13ms/step
# Epoch 21/100
#
# Epoch 21: loss improved from 0.01496 to 0.01291, saving model to ./Model/case_2/BiLSTM/model_7030\save_model.hdf5
# 16/16 - 0s - loss: 0.0129 - val_loss: 0.1565 - 247ms/epoch - 15ms/step
# Epoch 22/100
#
# Epoch 22: loss did not improve from 0.01291
# 16/16 - 0s - loss: 0.0167 - val_loss: 0.1892 - 212ms/epoch - 13ms/step
# Epoch 23/100
#
# Epoch 23: loss did not improve from 0.01291
# 16/16 - 0s - loss: 0.0162 - val_loss: 0.2337 - 213ms/epoch - 13ms/step
# Epoch 24/100
#
# Epoch 24: loss did not improve from 0.01291
# 16/16 - 0s - loss: 0.0137 - val_loss: 0.2879 - 211ms/epoch - 13ms/step
# Epoch 25/100
#
# Epoch 25: loss did not improve from 0.01291
# 16/16 - 0s - loss: 0.0141 - val_loss: 0.3191 - 218ms/epoch - 14ms/step
# Epoch 26/100
#
# Epoch 26: loss did not improve from 0.01291
# 16/16 - 0s - loss: 0.0132 - val_loss: 0.3442 - 207ms/epoch - 13ms/step
# Epoch 27/100
#
# Epoch 27: loss did not improve from 0.01291
# 16/16 - 0s - loss: 0.0156 - val_loss: 0.3305 - 200ms/epoch - 13ms/step
# Epoch 28/100
#
# Epoch 28: loss did not improve from 0.01291
# 16/16 - 0s - loss: 0.0157 - val_loss: 0.3809 - 207ms/epoch - 13ms/step
# Epoch 29/100
#
# Epoch 29: loss did not improve from 0.01291
# 16/16 - 0s - loss: 0.0135 - val_loss: 0.4160 - 204ms/epoch - 13ms/step
# Epoch 30/100
#
# Epoch 30: loss did not improve from 0.01291
# 16/16 - 0s - loss: 0.0135 - val_loss: 0.4691 - 209ms/epoch - 13ms/step
# Epoch 31/100
#
# Epoch 31: loss did not improve from 0.01291
# 16/16 - 0s - loss: 0.0178 - val_loss: 0.4442 - 205ms/epoch - 13ms/step
# Epoch 32/100
#
# Epoch 32: loss did not improve from 0.01291
# 16/16 - 0s - loss: 0.0146 - val_loss: 0.4497 - 210ms/epoch - 13ms/step
# Epoch 33/100
#
# Epoch 33: loss did not improve from 0.01291
# 16/16 - 0s - loss: 0.0138 - val_loss: 0.4489 - 210ms/epoch - 13ms/step
# Epoch 34/100
#
# Epoch 34: loss did not improve from 0.01291
# 16/16 - 0s - loss: 0.0140 - val_loss: 0.3877 - 215ms/epoch - 13ms/step
# Epoch 35/100
#
# Epoch 35: loss did not improve from 0.01291
# 16/16 - 0s - loss: 0.0132 - val_loss: 0.3891 - 207ms/epoch - 13ms/step
# Epoch 36/100
#
# Epoch 36: loss did not improve from 0.01291
# 16/16 - 0s - loss: 0.0164 - val_loss: 0.3649 - 204ms/epoch - 13ms/step
# Epoch 37/100
#
# Epoch 37: loss improved from 0.01291 to 0.01164, saving model to ./Model/case_2/BiLSTM/model_7030\save_model.hdf5
# 16/16 - 0s - loss: 0.0116 - val_loss: 0.3870 - 238ms/epoch - 15ms/step
# Epoch 38/100
#
# Epoch 38: loss did not improve from 0.01164
# 16/16 - 0s - loss: 0.0125 - val_loss: 0.3503 - 206ms/epoch - 13ms/step
# Epoch 39/100
#
# Epoch 39: loss did not improve from 0.01164
# 16/16 - 0s - loss: 0.0148 - val_loss: 0.3115 - 205ms/epoch - 13ms/step
# Epoch 40/100
#
# Epoch 40: loss did not improve from 0.01164
# 16/16 - 0s - loss: 0.0162 - val_loss: 0.3091 - 202ms/epoch - 13ms/step
# Epoch 41/100
#
# Epoch 41: loss did not improve from 0.01164
# 16/16 - 0s - loss: 0.0144 - val_loss: 0.2393 - 203ms/epoch - 13ms/step
# Epoch 42/100
#
# Epoch 42: loss did not improve from 0.01164
# 16/16 - 0s - loss: 0.0133 - val_loss: 0.2227 - 199ms/epoch - 12ms/step
# Epoch 43/100
#
# Epoch 43: loss did not improve from 0.01164
# 16/16 - 0s - loss: 0.0126 - val_loss: 0.1839 - 211ms/epoch - 13ms/step
# Epoch 44/100
#
# Epoch 44: loss did not improve from 0.01164
# 16/16 - 0s - loss: 0.0150 - val_loss: 0.1323 - 207ms/epoch - 13ms/step
# Epoch 45/100
#
# Epoch 45: loss improved from 0.01164 to 0.01152, saving model to ./Model/case_2/BiLSTM/model_7030\save_model.hdf5
# 16/16 - 0s - loss: 0.0115 - val_loss: 0.1571 - 236ms/epoch - 15ms/step
# Epoch 46/100
#
# Epoch 46: loss did not improve from 0.01152
# 16/16 - 0s - loss: 0.0122 - val_loss: 0.1351 - 211ms/epoch - 13ms/step
# Epoch 47/100
#
# Epoch 47: loss did not improve from 0.01152
# 16/16 - 0s - loss: 0.0141 - val_loss: 0.0420 - 204ms/epoch - 13ms/step
# Epoch 48/100
#
# Epoch 48: loss did not improve from 0.01152
# 16/16 - 0s - loss: 0.0142 - val_loss: 0.0496 - 200ms/epoch - 13ms/step
# Epoch 49/100
#
# Epoch 49: loss did not improve from 0.01152
# 16/16 - 0s - loss: 0.0173 - val_loss: 0.0383 - 212ms/epoch - 13ms/step
# Epoch 50/100
#
# Epoch 50: loss did not improve from 0.01152
# 16/16 - 0s - loss: 0.0170 - val_loss: 0.0938 - 192ms/epoch - 12ms/step
# Epoch 51/100
#
# Epoch 51: loss did not improve from 0.01152
# 16/16 - 0s - loss: 0.0139 - val_loss: 0.0618 - 186ms/epoch - 12ms/step
# Epoch 52/100
#
# Epoch 52: loss did not improve from 0.01152
# 16/16 - 0s - loss: 0.0149 - val_loss: 0.0378 - 193ms/epoch - 12ms/step
# Epoch 53/100
#
# Epoch 53: loss did not improve from 0.01152
# 16/16 - 0s - loss: 0.0119 - val_loss: 0.0181 - 198ms/epoch - 12ms/step
# Epoch 54/100
#
# Epoch 54: loss did not improve from 0.01152
# 16/16 - 0s - loss: 0.0127 - val_loss: 0.0406 - 199ms/epoch - 12ms/step
# Epoch 55/100
#
# Epoch 55: loss did not improve from 0.01152
# 16/16 - 0s - loss: 0.0119 - val_loss: 0.0628 - 194ms/epoch - 12ms/step
# Epoch 56/100
#
# Epoch 56: loss did not improve from 0.01152
# 16/16 - 0s - loss: 0.0125 - val_loss: 0.0318 - 193ms/epoch - 12ms/step
# Epoch 57/100
#
# Epoch 57: loss did not improve from 0.01152
# 16/16 - 0s - loss: 0.0126 - val_loss: 0.0576 - 190ms/epoch - 12ms/step
# Epoch 58/100
#
# Epoch 58: loss improved from 0.01152 to 0.01119, saving model to ./Model/case_2/BiLSTM/model_7030\save_model.hdf5
# 16/16 - 0s - loss: 0.0112 - val_loss: 0.0172 - 251ms/epoch - 16ms/step
# Epoch 59/100
#
# Epoch 59: loss did not improve from 0.01119
# 16/16 - 0s - loss: 0.0126 - val_loss: 0.0105 - 194ms/epoch - 12ms/step
# Epoch 60/100
#
# Epoch 60: loss did not improve from 0.01119
# 16/16 - 0s - loss: 0.0144 - val_loss: 0.0195 - 192ms/epoch - 12ms/step
# Epoch 61/100
#
# Epoch 61: loss did not improve from 0.01119
# 16/16 - 0s - loss: 0.0140 - val_loss: 0.0118 - 195ms/epoch - 12ms/step
# Epoch 62/100
#
# Epoch 62: loss improved from 0.01119 to 0.01108, saving model to ./Model/case_2/BiLSTM/model_7030\save_model.hdf5
# 16/16 - 0s - loss: 0.0111 - val_loss: 0.0278 - 223ms/epoch - 14ms/step
# Epoch 63/100
#
# Epoch 63: loss improved from 0.01108 to 0.01003, saving model to ./Model/case_2/BiLSTM/model_7030\save_model.hdf5
# 16/16 - 0s - loss: 0.0100 - val_loss: 0.0299 - 221ms/epoch - 14ms/step
# Epoch 64/100
#
# Epoch 64: loss did not improve from 0.01003
# 16/16 - 0s - loss: 0.0168 - val_loss: 0.0445 - 188ms/epoch - 12ms/step
# Epoch 65/100
#
# Epoch 65: loss improved from 0.01003 to 0.00986, saving model to ./Model/case_2/BiLSTM/model_7030\save_model.hdf5
# 16/16 - 0s - loss: 0.0099 - val_loss: 0.0166 - 228ms/epoch - 14ms/step
# Epoch 66/100
#
# Epoch 66: loss did not improve from 0.00986
# 16/16 - 0s - loss: 0.0139 - val_loss: 0.0170 - 197ms/epoch - 12ms/step
# Epoch 67/100
#
# Epoch 67: loss did not improve from 0.00986
# 16/16 - 0s - loss: 0.0151 - val_loss: 0.0102 - 191ms/epoch - 12ms/step
# Epoch 68/100
#
# Epoch 68: loss did not improve from 0.00986
# 16/16 - 0s - loss: 0.0124 - val_loss: 0.0250 - 193ms/epoch - 12ms/step
# Epoch 69/100
#
# Epoch 69: loss did not improve from 0.00986
# 16/16 - 0s - loss: 0.0133 - val_loss: 0.0196 - 193ms/epoch - 12ms/step
# Epoch 70/100
#
# Epoch 70: loss did not improve from 0.00986
# 16/16 - 0s - loss: 0.0167 - val_loss: 0.0183 - 199ms/epoch - 12ms/step
# Epoch 71/100
#
# Epoch 71: loss did not improve from 0.00986
# 16/16 - 0s - loss: 0.0171 - val_loss: 0.0369 - 225ms/epoch - 14ms/step
# Epoch 72/100
#
# Epoch 72: loss did not improve from 0.00986
# 16/16 - 0s - loss: 0.0123 - val_loss: 0.0346 - 199ms/epoch - 12ms/step
# Epoch 73/100
#
# Epoch 73: loss did not improve from 0.00986
# 16/16 - 0s - loss: 0.0124 - val_loss: 0.0428 - 195ms/epoch - 12ms/step
# Epoch 74/100
#
# Epoch 74: loss did not improve from 0.00986
# 16/16 - 0s - loss: 0.0135 - val_loss: 0.0772 - 208ms/epoch - 13ms/step
# Epoch 75/100
#
# Epoch 75: loss did not improve from 0.00986
# 16/16 - 0s - loss: 0.0127 - val_loss: 0.0243 - 197ms/epoch - 12ms/step
# Epoch 76/100
#
# Epoch 76: loss did not improve from 0.00986
# 16/16 - 0s - loss: 0.0131 - val_loss: 0.0155 - 197ms/epoch - 12ms/step
# Epoch 77/100
#
# Epoch 77: loss did not improve from 0.00986
# 16/16 - 0s - loss: 0.0131 - val_loss: 0.0765 - 211ms/epoch - 13ms/step
# Epoch 78/100
#
# Epoch 78: loss did not improve from 0.00986
# 16/16 - 0s - loss: 0.0130 - val_loss: 0.0726 - 194ms/epoch - 12ms/step
# Epoch 79/100
#
# Epoch 79: loss did not improve from 0.00986
# 16/16 - 0s - loss: 0.0135 - val_loss: 0.0399 - 192ms/epoch - 12ms/step
# Epoch 80/100
#
# Epoch 80: loss did not improve from 0.00986
# 16/16 - 0s - loss: 0.0140 - val_loss: 0.0428 - 192ms/epoch - 12ms/step
# Epoch 81/100
#
# Epoch 81: loss did not improve from 0.00986
# 16/16 - 0s - loss: 0.0148 - val_loss: 0.0233 - 196ms/epoch - 12ms/step
# Epoch 82/100
#
# Epoch 82: loss did not improve from 0.00986
# 16/16 - 0s - loss: 0.0118 - val_loss: 0.0546 - 201ms/epoch - 13ms/step
# Epoch 83/100
#
# Epoch 83: loss did not improve from 0.00986
# 16/16 - 0s - loss: 0.0160 - val_loss: 0.0398 - 192ms/epoch - 12ms/step
# Epoch 84/100
#
# Epoch 84: loss did not improve from 0.00986
# 16/16 - 0s - loss: 0.0137 - val_loss: 0.0073 - 193ms/epoch - 12ms/step
# Epoch 85/100
#
# Epoch 85: loss did not improve from 0.00986
# 16/16 - 0s - loss: 0.0104 - val_loss: 0.0123 - 196ms/epoch - 12ms/step
# Epoch 86/100
#
# Epoch 86: loss did not improve from 0.00986
# 16/16 - 0s - loss: 0.0111 - val_loss: 0.0087 - 210ms/epoch - 13ms/step
# Epoch 87/100
#
# Epoch 87: loss did not improve from 0.00986
# 16/16 - 0s - loss: 0.0122 - val_loss: 0.0299 - 203ms/epoch - 13ms/step
# Epoch 88/100
#
# Epoch 88: loss improved from 0.00986 to 0.00931, saving model to ./Model/case_2/BiLSTM/model_7030\save_model.hdf5
# 16/16 - 0s - loss: 0.0093 - val_loss: 0.0399 - 222ms/epoch - 14ms/step
# Epoch 89/100
#
# Epoch 89: loss did not improve from 0.00931
# 16/16 - 0s - loss: 0.0115 - val_loss: 0.0201 - 194ms/epoch - 12ms/step
# Epoch 90/100
#
# Epoch 90: loss did not improve from 0.00931
# 16/16 - 0s - loss: 0.0125 - val_loss: 0.0171 - 187ms/epoch - 12ms/step
# Epoch 91/100
#
# Epoch 91: loss did not improve from 0.00931
# 16/16 - 0s - loss: 0.0109 - val_loss: 0.0287 - 193ms/epoch - 12ms/step
# Epoch 92/100
#
# Epoch 92: loss did not improve from 0.00931
# 16/16 - 0s - loss: 0.0126 - val_loss: 0.0238 - 188ms/epoch - 12ms/step
# Epoch 93/100
#
# Epoch 93: loss did not improve from 0.00931
# 16/16 - 0s - loss: 0.0122 - val_loss: 0.0482 - 186ms/epoch - 12ms/step
# Epoch 94/100
#
# Epoch 94: loss did not improve from 0.00931
# 16/16 - 0s - loss: 0.0135 - val_loss: 0.0172 - 197ms/epoch - 12ms/step
# Epoch 95/100
#
# Epoch 95: loss did not improve from 0.00931
# 16/16 - 0s - loss: 0.0120 - val_loss: 0.0323 - 191ms/epoch - 12ms/step
# Epoch 96/100
#
# Epoch 96: loss did not improve from 0.00931
# 16/16 - 0s - loss: 0.0100 - val_loss: 0.0249 - 188ms/epoch - 12ms/step
# Epoch 97/100
#
# Epoch 97: loss did not improve from 0.00931
# 16/16 - 0s - loss: 0.0176 - val_loss: 0.0523 - 194ms/epoch - 12ms/step
# Epoch 98/100
#
# Epoch 98: loss did not improve from 0.00931
# 16/16 - 0s - loss: 0.0134 - val_loss: 0.0120 - 198ms/epoch - 12ms/step
# Epoch 99/100
#
# Epoch 99: loss did not improve from 0.00931
# 16/16 - 0s - loss: 0.0141 - val_loss: 0.0108 - 201ms/epoch - 13ms/step
# Epoch 100/100
#
# Epoch 100: loss did not improve from 0.00931
# 16/16 - 0s - loss: 0.0105 - val_loss: 0.0129 - 199ms/epoch - 12ms/step
# Thời gian thực thi mô hình: 27.13 giây

# %%
#Model
final_model = load_model("./Model/case_2/BiLSTM/model_7030/save_model.hdf5")

# %%
#dữ liệu train
Y_train_predict = final_model.predict(X_train) #dự đoán trên tập đã train
Y_train_predict = sc.inverse_transform(Y_train_predict) #giá thực dự đoán
Y_train = sc.inverse_transform(Y_train) #giá thực train
# Out:
# 42/42 [==============================] - 1s 2ms/step

# %% [markdown]
# # DỰ ĐOÁN TRÊN TẬP TEST

# %%
#dữ liệu test
import time
start_model = time.time()  # Bắt đầu đo thời gian
Y_test_predict = final_model.predict(X_test)
end_model = time.time()  # Kết thúc đo thời gian
print(f"Thời gian thực thi mô hình: {end_model - start_model:.2f} giây")
Y_test_predict = sc.inverse_transform(Y_test_predict) #giá dự đoán
Y_test = sc.inverse_transform(Y_test) #giá thực
# Out:
# 18/18 [==============================] - 0s 2ms/step
# Thời gian thực thi mô hình: 0.10 giây

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import mean_absolute_error, mean_squared_error

# Tính toán các giá trị cho tập Train
mae_train = round(mean_absolute_error(Y_train, Y_train_predict), 3)
mse_train = round(mean_squared_error(Y_train, Y_train_predict), 3)
rmse_train = round(np.sqrt(mse_train), 3)

# Tính toán các giá trị cho tập Test
mae_test = round(mean_absolute_error(Y_test, Y_test_predict), 3)
mse_test = round(mean_squared_error(Y_test, Y_test_predict), 3)
rmse_test = round(np.sqrt(mse_test), 3)

# Tạo DataFrame để hiển thị kết quả
metrics = pd.DataFrame({
    "Tập dữ liệu": ["Train", "Test"],
    "MAE": [mae_train, mae_test],
    "MSE": [mse_train, mse_test],
    "RMSE": [rmse_train, rmse_test]
})

# In kết quả
print(metrics)
print(f"Thời gian thực thi mô hình: {end_model - start_model:.2f} giây")
# Out:
#   Tập dữ liệu      MAE        MSE     RMSE
# 0       Train  100.916  12741.441  112.878
# 1        Test  294.485  92230.944  303.695
# Thời gian thực thi mô hình: 0.10 giây

# %%
# Xác định 70% dữ liệu làm tập train
train_size = int(len(df_usd_ML) * 0.7)

# Cắt lại cho đúng chiều dài:
train_data1 = df_usd_ML[6:train_size-1].copy()
test_data1 = df_usd_ML[train_size+3:].copy()


print(len(train_data1), len(Y_train_predict))
print(len(test_data1), len(Y_test_predict))

# Cắt dữ liệu dự đoán để khớp với dữ liệu gốc
Y_train_predict = Y_train_predict[:len(train_data1)]
Y_test_predict = Y_test_predict[:len(test_data1)]

# Đảm bảo test_data1 có số lượng dòng khớp với Y_test_predict
test_data1 = test_data1.iloc[:len(Y_test_predict)]

plt.figure(figsize=(24,8))
plt.plot(df_usd_ML, label='Giá thực tế', color='red')  # đường giá thực

# Thêm dữ liệu dự đoán vào train_data1 và test_data1
train_data1["Dự đoán"] = Y_train_predict
plt.plot(train_data1["Dự đoán"], label='Giá dự đoán train', color='green')

test_data1["Dự đoán"] = Y_test_predict
plt.plot(test_data1["Dự đoán"], label='Giá dự đoán test', color='blue')

plt.title('So sánh giá dự báo và giá thực tế')
plt.xlabel('Thời gian')
plt.ylabel('Giá mua chuyển khoản (VNĐ)')
plt.legend()
plt.show()
# Out:
# 1330 1332
# 571 572

# %%
from tensorflow.keras.models import load_model

# Gọi lại mô hình đã lưu
loaded_model = load_model("./Model/case_2/BiLSTM/model_7030/save_model.hdf5")
# Dự đoán lại trên tập test
Y_test_predict = loaded_model.predict(X_test)
# Đảo chuẩn hóa (inverse transform)
Y_test_predict = sc.inverse_transform(Y_test_predict)

# Tạo bảng so sánh
compare_df = pd.DataFrame({
    "Giá thực tế": Y_test.flatten(),
    "Giá dự đoán": Y_test_predict.flatten()
})

# Làm tròn về số nguyên
compare_df = compare_df.astype(int)
pd.set_option('display.max_rows', None)
# Hiển thị toàn bộ bảng
display(compare_df)
compare_df.to_csv("./Model/case_2/BiLSTM/model_7030/predict.csv", index=False)
# Out:
# 18/18 [==============================] - 1s 3ms/step
#      Giá thực tế  Giá dự đoán
# 0          24150        23924
# 1          24210        23942
# 2          24240        23988
# 3          24220        24021
# 4          24210        24014
# 5          24210        24006
# 6          24210        24004
# 7          24210        24002
# 8          24245        24001
# 9          24265        24027
# 10         24270        24045
# 11         24275        24053
# 12         24275        24059
# 13         24275        24060
# 14         24290        24059
# 15         24328        24069
# 16         24350        24099
# 17         24370        24120
# 18         24360        24139
# 19         24360        24135
# 20         24360        24135
# 21         24420        24133
# 22         24390        24176
# 23         24380        24161
# 24         24420        24154
# 25         24390        24181
# 26         24390        24162
# 27         24390        24159
# 28         24385        24160
# 29         24390        24156
# 30         24410        24158
# 31         24410        24174
# 32         24350        24176
# 33         24350        24134
# 34         24350        24127
# 35         24160        24124
# 36         24150        23990
# 37         24190        23963
# 38         24190        23980
# 39         24130        23980
# 40         24130        23940
# 41         24130        23937
# 42         24200        23932
# 43         24190        23980
# 44         24100        23981
# 45         24115        23922
# 46         24075        23922
# 47         24075        23891
# 48         24075        23884
# 49         24005        23883
# 50         23950        23835
# 51         24015        23788
# 52         24050        23822
# 53         24080        23850
# 54         24080        23877
# 55         24080        23886
# 56         24075        23890
# 57         24080        23886
# 58         24045        23888
# 59         24090        23863
# 60         24110        23890
# 61         24110        23908
# 62         24110        23912
# 63         24065        23914
# 64         24090        23884
# 65         24095        23895
# 66         24090        23899
# 67         24050        23896
# 68         24050        23869
# 69         24050        23864
# 70         24060        23861
# 71         24090        23867
# 72         24080        23890
# 73         24080        23888
# 74         24070        23888
# 75         24070        23881
# 76         24070        23880
# 77         24140        23879
# 78         24175        23928
# 79         24170        23961
# 80         24160        23966
# 81         24060        23962
# 82         24060        23891
# 83         24060        23877
# 84         24060        23871
# 85         24130        23869
# 86         24140        23917
# 87         24060        23935
# 88         24080        23884
# 89         24080        23890
# 90         24080        23888
# 91         24080        23886
# 92         24155        23887
# 93         24180        23941
# 94         24190        23968
# 95         24190        23982
# 96         24190        23986
# 97         24190        23986
# 98         24175        23985
# 99         24185        23974
# 100        24215        23979
# 101        24295        24001
# 102        24290        24062
# 103        24290        24070
# 104        24290        24074
# 105        24295        24074
# 106        24370        24076
# 107        24360        24130
# 108        24385        24132
# 109        24375        24152
# 110        24375        24149
# 111        24375        24148
# 112        24365        24145
# 113        24390        24139
# 114        24430        24155
# 115        24430        24187
# 116        24425        24193
# 117        24425        24191
# 118        24425        24191
# 119        24375        24190
# 120        24235        24153
# 121        24255        24050
# 122        24240        24046
# 123        24160        24030
# 124        24160        23972
# 125        24160        23963
# 126        24200        23960
# 127        24190        23984
# 128        24230        23983
# 129        24230        24014
# 130        24230        24018
# 131        24230        24020
# 132        24230        24020
# 133        24230        24020
# 134        24230        24019
# 135        24230        24019
# 136        24270        24019
# 137        24340        24048
# 138        24340        24103
# 139        24340        24113
# 140        24360        24117
# 141        24360        24133
# 142        24340        24133
# 143        24420        24118
# 144        24450        24175
# 145        24450        24205
# 146        24450        24211
# 147        24500        24214
# 148        24460        24251
# 149        24450        24224
# 150        24480        24214
# 151        24470        24234
# 152        24470        24229
# 153        24470        24228
# 154        24500        24230
# 155        24510        24251
# 156        24520        24261
# 157        24530        24271
# 158        24500        24280
# 159        24500        24260
# 160        24500        24256
# 161        24450        24255
# 162        24460        24218
# 163        24480        24220
# 164        24530        24235
# 165        24550        24273
# 166        24550        24295
# 167        24550        24300
# 168        24560        24300
# 169        24590        24307
# 170        24610        24328
# 171        24610        24347
# 172        24610        24351
# 173        24610        24352
# 174        24610        24351
# 175        24590        24350
# 176        24610        24335
# 177        24610        24348
# 178        24610        24350
# 179        24630        24351
# 180        24630        24366
# 181        24630        24368
# 182        24630        24368
# 183        24710        24368
# 184        24790        24428
# 185        24770        24497
# 186        24780        24494
# 187        24780        24502
# 188        24780        24500
# 189        24790        24496
# 190        24790        24503
# 191        24790        24507
# 192        24830        24506
# 193        24840        24537
# 194        24840        24549
# 195        24840        24551
# 196        24960        24551
# 197        25008        24643
# 198        25130        24691
# 199        25130        24798
# 200        25163        24810
# 201        25163        24836
# 202        25163        24829
# 203        25175        24828
# 204        25178        24833
# 205        25177        24841
# 206        25167        24839
# 207        25118        24833
# 208        25118        24793
# 209        25118        24788
# 210        25118        24788
# 211        25118        24789
# 212        25118        24791
# 213        25144        24792
# 214        25143        24810
# 215        25147        24811
# 216        25147        24815
# 217        25157        24815
# 218        25155        24822
# 219        25161        24820
# 220        25178        24826
# 221        25184        24840
# 222        25184        24846
# 223        25184        24847
# 224        25179        24847
# 225        25182        24842
# 226        25182        24843
# 227        25152        24844
# 228        25250        24821
# 229        25250        24896
# 230        25250        24904
# 231        25259        24906
# 232        25263        24913
# 233        25266        24915
# 234        25250        24912
# 235        25277        24904
# 236        25277        24924
# 237        25277        24926
# 238        25281        24926
# 239        25268        24930
# 240        25265        24920
# 241        25250        24914
# 242        25254        24903
# 243        25254        24905
# 244        25254        24906
# 245        25234        24907
# 246        25218        24891
# 247        25213        24877
# 248        25213        24870
# 249        25213        24870
# 250        25213        24871
# 251        25213        24872
# 252        25214        24872
# 253        25222        24872
# 254        25226        24878
# 255        25217        24882
# 256        25221        24876
# 257        25221        24878
# 258        25221        24878
# 259        25231        24877
# 260        25251        24886
# 261        25249        24903
# 262        25247        24903
# 263        25248        24901
# 264        25248        24901
# 265        25248        24900
# 266        25255        24900
# 267        25245        24907
# 268        25250        24899
# 269        25257        24903
# 270        25253        24908
# 271        25253        24906
# 272        25253        24905
# 273        25244        24906
# 274        25245        24898
# 275        25250        24898
# 276        25243        24902
# 277        25238        24897
# 278        25238        24893
# 279        25238        24893
# 280        25235        24892
# 281        25234        24890
# 282        25239        24890
# 283        25245        24893
# 284        25240        24898
# 285        25240        24895
# 286        25240        24895
# 287        25237        24894
# 288        25237        24891
# 289        25168        24891
# 290        25150        24838
# 291        25158        24818
# 292        25158        24821
# 293        25158        24822
# 294        25154        24825
# 295        25157        24825
# 296        25177        24824
# 297        25120        24838
# 298        25121        24796
# 299        25121        24792
# 300        25121        24791
# 301        25115        24791
# 302        25120        24787
# 303        25080        24794
# 304        25060        24760
# 305        25040        24741
# 306        25040        24723
# 307        25040        24721
# 308        24930        24722
# 309        24980        24641
# 310        24995        24667
# 311        24980        24680
# 312        24930        24671
# 313        24930        24635
# 314        24930        24632
# 315        24940        24624
# 316        24950        24634
# 317        24850        24645
# 318        24870        24571
# 319        24890        24575
# 320        24890        24589
# 321        24890        24591
# 322        24820        24594
# 323        24740        24545
# 324        24760        24473
# 325        24780        24478
# 326        24810        24493
# 327        24810        24519
# 328        24810        24527
# 329        24710        24528
# 330        24660        24449
# 331        24680        24402
# 332        24690        24408
# 333        24690        24416
# 334        24690        24419
# 335        24690        24424
# 336        24690        24422
# 337        24690        24419
# 338        24675        24420
# 339        24580        24409
# 340        24430        24337
# 341        24430        24220
# 342        24430        24201
# 343        24500        24194
# 344        24490        24243
# 345        24385        24247
# 346        24410        24175
# 347        24390        24178
# 348        24390        24161
# 349        24390        24157
# 350        24380        24159
# 351        24430        24154
# 352        24470        24186
# 353        24410        24222
# 354        24400        24184
# 355        24400        24173
# 356        24400        24169
# 357        24460        24166
# 358        24430        24210
# 359        24410        24197
# 360        24460        24181
# 361        24420        24215
# 362        24420        24189
# 363        24420        24185
# 364        24400        24186
# 365        24430        24171
# 366        24480        24189
# 367        24580        24230
# 368        24580        24311
# 369        24580        24325
# 370        24580        24329
# 371        24670        24328
# 372        24665        24393
# 373        24665        24396
# 374        24670        24400
# 375        24640        24404
# 376        24640        24381
# 377        24640        24375
# 378        24660        24376
# 379        24765        24391
# 380        24810        24473
# 381        25010        24520
# 382        24980        24687
# 383        24980        24684
# 384        24980        24682
# 385        25070        24674
# 386        25092        24741
# 387        25220        24760
# 388        25233        24875
# 389        25197        24896
# 390        25197        24867
# 391        25197        24857
# 392        25194        24855
# 393        25164        24847
# 394        25118        24831
# 395        25090        24795
# 396        25114        24767
# 397        25114        24782
# 398        25114        24785
# 399        25125        24788
# 400        25160        24798
# 401        25170        24824
# 402        25197        24833
# 403        25130        24857
# 404        25130        24806
# 405        25130        24799
# 406        25116        24796
# 407        25160        24787
# 408        25180        24821
# 409        25184        24845
# 410        25190        24848
# 411        25190        24853
# 412        25190        24853
# 413        25200        24849
# 414        25205        24858
# 415        25200        24864
# 416        25200        24860
# 417        25200        24860
# 418        25200        24860
# 419        25200        24859
# 420        25197        24860
# 421        25200        24858
# 422        25200        24860
# 423        25175        24860
# 424        25160        24840
# 425        25160        24826
# 426        25160        24825
# 427        25149        24824
# 428        25170        24817
# 429        25172        24834
# 430        25176        24837
# 431        25164        24840
# 432        25164        24831
# 433        25164        24829
# 434        25157        24828
# 435        25170        24823
# 436        25165        24833
# 437        25171        24831
# 438        25177        24835
# 439        25177        24840
# 440        25177        24841
# 441        25185        24840
# 442        25183        24847
# 443        25191        24845
# 444        25219        24852
# 445        25240        24875
# 446        25240        24894
# 447        25240        24896
# 448        25230        24896
# 449        25223        24886
# 450        25236        24878
# 451        25225        24888
# 452        25238        24882
# 453        25238        24892
# 454        25238        24893
# 455        25243        24893
# 456        25251        24896
# 457        25251        24904
# 458        25259        24903
# 459        25250        24911
# 460        25250        24904
# 461        25250        24903
# 462        25253        24902
# 463        25208        24905
# 464        25186        24870
# 465        25194        24850
# 466        25198        24852
# 467        25198        24856
# 468        25198        24859
# 469        25200        24861
# 470        25203        24861
# 471        25194        24862
# 472        25189        24855
# 473        25150        24851
# 474        25150        24820
# 475        25150        24816
# 476        25150        24816
# 477        25090        24817
# 478        24960        24771
# 479        24960        24669
# 480        24800        24653
# 481        24800        24533
# 482        24800        24520
# 483        24800        24520
# 484        24800        24520
# 485        24800        24516
# 486        24800        24522
# 487        24800        24515
# 488        24800        24515
# 489        24800        24515
# 490        25140        24515
# 491        25000        24784
# 492        24980        24705
# 493        25090        24684
# 494        25110        24763
# 495        25110        24780
# 496        25110        24773
# 497        25200        24793
# 498        25340        24856
# 499        25380        24972
# 500        25300        25023
# 501        25220        24962
# 502        25220        24885
# 503        25220        24867
# 504        25280        24864
# 505        25340        24922
# 506        25340        24984
# 507        25350        24989
# 508        25320        24993
# 509        25320        24966
# 510        25320        24958
# 511        25310        24958
# 512        25330        24954
# 513        25360        24970
# 514        25380        24998
# 515        25370        25015
# 516        25370        25009
# 517        25370        25007
# 518        25420        25004
# 519        25390        25044
# 520        25320        25025
# 521        25300        24969
# 522        25300        24945
# 523        25330        24941
# 524        25330        24965
# 525        25340        24975
# 526        25290        24985
# 527        25280        24942
# 528        25320        24928
# 529        25350        24957
# 530        25350        24986
# 531        25350        24991
# 532        25360        24994
# 533        25350        24998
# 534        25370        24987
# 535        25380        25003
# 536        25400        25014
# 537        25400        25031
# 538        25400        25033
# 539        25450        25033
# 540        25450        25071
# 541        25390        25075
# 542        25390        25027
# 543        25400        25022
# 544        25400        25028
# 545        25400        25027
# 546        25380        25033
# 547        25460        25020
# 548        25460        25078
# 549        25620        25084
# 550        25600        25219
# 551        25600        25214
# 552        25600        25211
# 553        25600        25201
# 554        25780        25199
# 555        25822        25343
# 556        25610        25405
# 557        25560        25227
# 558        25560        25166
# 559        25560        25153
# 560        25640        25147
# 561        25650        25236
# 562        25650        25267
# 563        25700        25253
# 564        25760        25290
# 565        25760        25340
# 566        25760        25339
# 567        25700        25343
# 568        25755        25289
# 569        25781        25325
# 570        25814        25351
# 571        25835        25387
