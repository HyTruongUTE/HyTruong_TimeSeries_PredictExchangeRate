# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler #chuẩn hóa dữ liệu
from keras.callbacks import ModelCheckpoint #lưu lại huấn luyện tốt nhất
from tensorflow.keras.models import load_model #tải mô hình
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import ModelCheckpoint

import random
import tensorflow as tf

#các lớp để xây dựng mô hình
from keras.models import Sequential #đầu vào
from keras.layers import LSTM #học phụ thuộc
from keras.layers import Dropout, BatchNormalization #tránh học tủ
from keras.layers import Dense #đầu ra

#kiểm tra độ chính xác của mô hình
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
random.seed(42)
np.random.seed(42)
tf.random.set_seed(42)

# %%
df_usd = pd.read_parquet("./minio/usd/part-00000-18b834c3-cd6d-42ae-82c3-638999ff6d84-c000.snappy.parquet", engine="pyarrow")
df_usd.head()
# Out:
#         ngay ma_ngoai_te ten_ngoai_te  mua_chuyen_khoan      ban
# 0 2020-02-01         USD    US DOLLAR           23165.0  23305.0
# 1 2020-02-02         USD    US DOLLAR           23165.0  23305.0
# 2 2020-02-03         USD    US DOLLAR           23200.0  23340.0
# 3 2020-02-04         USD    US DOLLAR           23170.0  23310.0
# 4 2020-02-05         USD    US DOLLAR           23160.0  23300.0

# %%
df_usd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1911 entries, 0 to 1910
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ngay              1911 non-null   datetime64[ns]
#  1   ma_ngoai_te       1911 non-null   object
#  2   ten_ngoai_te      1911 non-null   object
#  3   mua_chuyen_khoan  1911 non-null   float64
#  4   ban               1911 non-null   float64
# dtypes: datetime64[ns](1), float64(2), object(2)
# memory usage: 74.8+ KB

# %%
df_usd.describe()
# Out:
#                       ngay  mua_chuyen_khoan           ban
# count                 1911       1911.000000   1911.000000
# mean   2022-09-13 00:00:00      23666.414443  23934.197279
# min    2020-02-01 00:00:00      22480.000000  22745.000000
# 25%    2021-05-23 12:00:00      22985.000000  23170.000000
# 50%    2022-09-13 00:00:00      23300.000000  23620.000000
# 75%    2024-01-03 12:00:00      24390.000000  24730.000000
# max    2025-04-25 00:00:00      25835.000000  26195.000000
# std                    NaN        885.147984    926.810272

# %%
print(df_usd.dtypes)
# Out:
# ngay                datetime64[ns]
# ma_ngoai_te                 object
# ten_ngoai_te                object
# mua_chuyen_khoan           float64
# ban                        float64
# dtype: object

# %%
import matplotlib.pyplot as plt
from matplotlib.dates import YearLocator, DateFormatter, MonthLocator

# Vẽ biểu đồ
plt.figure(figsize=(10, 5))
plt.plot(df_usd['ngay'].values, df_usd['mua_chuyen_khoan'].values, label='Giá mua chuyển khoản', color='red')

plt.xlabel('Năm')
plt.ylabel('Giá mua chuyển khoản')
plt.title('Biểu đồ tỷ giá VND_USD mua chuyển khoảng qua các năm')
plt.legend(loc='best')

# Định dạng trục x
plt.gca().xaxis.set_major_locator(YearLocator())
plt.gca().xaxis.set_major_formatter(DateFormatter('%Y'))
plt.gca().xaxis.set_minor_locator(MonthLocator())

plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
df_usd_ML = pd.DataFrame(df_usd, columns=['ngay','mua_chuyen_khoan'])
df_usd_ML.index = df_usd_ML.ngay
df_usd_ML.drop('ngay', axis = 1, inplace=True)
df_usd_ML.head()
# Out:
#             mua_chuyen_khoan
# ngay
# 2020-02-01           23165.0
# 2020-02-02           23165.0
# 2020-02-03           23200.0
# 2020-02-04           23170.0
# 2020-02-05           23160.0

# %%
print(df_usd_ML.columns)
# Out:
# Index(['mua_chuyen_khoan'], dtype='object')

# %%
data = df_usd_ML.values

# %%
data
# Out:
# array([[23165.],
#        [23165.],
#        [23200.],
#        ...,
#        [25781.],
#        [25814.],
#        [25835.]])

# %%
#hàm hóa dữ liệu
sc = MinMaxScaler(feature_range=(0,1))

#chuẩn hóa dữ train
scale_data = sc.fit_transform(data)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))

plt.plot(scale_data, label="Dữ liệu sau chuẩn hóa", color="red")

plt.xlabel("Thời gian (Index)")
plt.ylabel("Giá trị sau chuẩn hóa")
plt.title("Biểu đồ dữ liệu sau khi chuẩn hóa bằng MinMaxScaler")
plt.legend()
plt.show()

# %%
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Bidirectional, LSTM, Dense, Dropout

# Chọn window
window_size = 7
X_train, Y_train = [], []

for i in range(len(scale_data) - window_size):
    X_train.append(scale_data[i:i + window_size])
    Y_train.append(scale_data[i + window_size])

X_train = np.array(X_train)
Y_train = np.array(Y_train)

# Phân chia tập dữ liệu thành tập train và test 70 - 30
split_index = int(0.7 * len(X_train))

X_train, X_test = X_train[:split_index], X_train[split_index:]
Y_train, Y_test = Y_train[:split_index], Y_train[split_index:]

# Đảm bảo dữ liệu có đúng shape cho mô hình BiLSTM
X_train = X_train.reshape((X_train.shape[0], window_size, -1))
X_test = X_test.reshape((X_test.shape[0], window_size, -1))

# %%
print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
print("y_train shape:", Y_train.shape)
print("y_test shape:", Y_test.shape)
# Out:
# X_train shape: (1332, 7, 1)
# X_test shape: (572, 7, 1)
# y_train shape: (1332, 1)
# y_test shape: (572, 1)

# %% [markdown]
# # MODEL

# %%
#xây dựng mô hình
model = Sequential() #tạo lớp mạng cho dữ liệu đầu vào
#2 lớp LSTM
model.add(LSTM(units=128,input_shape=(X_train.shape[1],1),return_sequences=True))
model.add(LSTM(units=64))
model.add(Dropout(0.5)) #loại bỏ 1 số đơn vị tránh học tủ (overfitting)
model.add(Dense(1)) #output đầu ra 1 chiều
#đo sai số tuyệt đối trung bình có sử dụng trình tối ưu hóa rmsprop
model.compile(loss='mean_absolute_error',optimizer='rmsprop')

# %% [markdown]
# # huấn luyện mô hình

# %%
#huấn luyện mô hình
save_model = "./Model/case_2/LSTM/model_7030/save_model.hdf5"
best_model = ModelCheckpoint(save_model,monitor='loss',verbose=2,save_best_only=True,mode='auto')

import time
start_model = time.time()  # Bắt đầu đo thời gian
model.fit(X_train,Y_train,epochs=100,batch_size=50,validation_split=0.4,verbose=2,callbacks=[best_model])
end_model = time.time()  # Kết thúc đo thời gian
print(f"Thời gian thực thi mô hình: {end_model - start_model:.2f} giây")
# Out:
# Epoch 1/100
#
# Epoch 1: loss improved from inf to 0.04478, saving model to ./Model/case_2/LSTM/model_7030\save_model.hdf5
# 16/16 - 3s - loss: 0.0448 - val_loss: 0.0280 - 3s/epoch - 169ms/step
# Epoch 2/100
#
# Epoch 2: loss improved from 0.04478 to 0.02909, saving model to ./Model/case_2/LSTM/model_7030\save_model.hdf5
# 16/16 - 0s - loss: 0.0291 - val_loss: 0.0191 - 235ms/epoch - 15ms/step
# Epoch 3/100
#
# Epoch 3: loss improved from 0.02909 to 0.02538, saving model to ./Model/case_2/LSTM/model_7030\save_model.hdf5
# 16/16 - 0s - loss: 0.0254 - val_loss: 0.0161 - 245ms/epoch - 15ms/step
# Epoch 4/100
#
# Epoch 4: loss improved from 0.02538 to 0.02351, saving model to ./Model/case_2/LSTM/model_7030\save_model.hdf5
# 16/16 - 0s - loss: 0.0235 - val_loss: 0.0164 - 247ms/epoch - 15ms/step
# Epoch 5/100
#
# Epoch 5: loss improved from 0.02351 to 0.02268, saving model to ./Model/case_2/LSTM/model_7030\save_model.hdf5
# 16/16 - 0s - loss: 0.0227 - val_loss: 0.0157 - 276ms/epoch - 17ms/step
# Epoch 6/100
#
# Epoch 6: loss improved from 0.02268 to 0.02095, saving model to ./Model/case_2/LSTM/model_7030\save_model.hdf5
# 16/16 - 0s - loss: 0.0209 - val_loss: 0.0163 - 263ms/epoch - 16ms/step
# Epoch 7/100
#
# Epoch 7: loss did not improve from 0.02095
# 16/16 - 0s - loss: 0.0216 - val_loss: 0.0260 - 228ms/epoch - 14ms/step
# Epoch 8/100
#
# Epoch 8: loss improved from 0.02095 to 0.02033, saving model to ./Model/case_2/LSTM/model_7030\save_model.hdf5
# 16/16 - 0s - loss: 0.0203 - val_loss: 0.0195 - 246ms/epoch - 15ms/step
# Epoch 9/100
#
# Epoch 9: loss did not improve from 0.02033
# 16/16 - 0s - loss: 0.0220 - val_loss: 0.0174 - 230ms/epoch - 14ms/step
# Epoch 10/100
#
# Epoch 10: loss improved from 0.02033 to 0.01957, saving model to ./Model/case_2/LSTM/model_7030\save_model.hdf5
# 16/16 - 0s - loss: 0.0196 - val_loss: 0.0187 - 234ms/epoch - 15ms/step
# Epoch 11/100
#
# Epoch 11: loss improved from 0.01957 to 0.01932, saving model to ./Model/case_2/LSTM/model_7030\save_model.hdf5
# 16/16 - 0s - loss: 0.0193 - val_loss: 0.0149 - 250ms/epoch - 16ms/step
# Epoch 12/100
#
# Epoch 12: loss did not improve from 0.01932
# 16/16 - 0s - loss: 0.0199 - val_loss: 0.0156 - 230ms/epoch - 14ms/step
# Epoch 13/100
#
# Epoch 13: loss did not improve from 0.01932
# 16/16 - 0s - loss: 0.0201 - val_loss: 0.0365 - 235ms/epoch - 15ms/step
# Epoch 14/100
#
# Epoch 14: loss improved from 0.01932 to 0.01838, saving model to ./Model/case_2/LSTM/model_7030\save_model.hdf5
# 16/16 - 0s - loss: 0.0184 - val_loss: 0.0599 - 270ms/epoch - 17ms/step
# Epoch 15/100
#
# Epoch 15: loss improved from 0.01838 to 0.01838, saving model to ./Model/case_2/LSTM/model_7030\save_model.hdf5
# 16/16 - 0s - loss: 0.0184 - val_loss: 0.0351 - 256ms/epoch - 16ms/step
# Epoch 16/100
#
# Epoch 16: loss did not improve from 0.01838
# 16/16 - 0s - loss: 0.0186 - val_loss: 0.0210 - 235ms/epoch - 15ms/step
# Epoch 17/100
#
# Epoch 17: loss did not improve from 0.01838
# 16/16 - 0s - loss: 0.0190 - val_loss: 0.0355 - 235ms/epoch - 15ms/step
# Epoch 18/100
#
# Epoch 18: loss improved from 0.01838 to 0.01690, saving model to ./Model/case_2/LSTM/model_7030\save_model.hdf5
# 16/16 - 0s - loss: 0.0169 - val_loss: 0.0148 - 252ms/epoch - 16ms/step
# Epoch 19/100
#
# Epoch 19: loss did not improve from 0.01690
# 16/16 - 0s - loss: 0.0178 - val_loss: 0.0186 - 223ms/epoch - 14ms/step
# Epoch 20/100
#
# Epoch 20: loss did not improve from 0.01690
# 16/16 - 0s - loss: 0.0174 - val_loss: 0.0158 - 256ms/epoch - 16ms/step
# Epoch 21/100
#
# Epoch 21: loss improved from 0.01690 to 0.01589, saving model to ./Model/case_2/LSTM/model_7030\save_model.hdf5
# 16/16 - 0s - loss: 0.0159 - val_loss: 0.0144 - 257ms/epoch - 16ms/step
# Epoch 22/100
#
# Epoch 22: loss did not improve from 0.01589
# 16/16 - 0s - loss: 0.0179 - val_loss: 0.0150 - 221ms/epoch - 14ms/step
# Epoch 23/100
#
# Epoch 23: loss did not improve from 0.01589
# 16/16 - 0s - loss: 0.0160 - val_loss: 0.0141 - 219ms/epoch - 14ms/step
# Epoch 24/100
#
# Epoch 24: loss did not improve from 0.01589
# 16/16 - 0s - loss: 0.0166 - val_loss: 0.0174 - 233ms/epoch - 15ms/step
# Epoch 25/100
#
# Epoch 25: loss improved from 0.01589 to 0.01548, saving model to ./Model/case_2/LSTM/model_7030\save_model.hdf5
# 16/16 - 0s - loss: 0.0155 - val_loss: 0.0150 - 253ms/epoch - 16ms/step
# Epoch 26/100
#
# Epoch 26: loss did not improve from 0.01548
# 16/16 - 0s - loss: 0.0161 - val_loss: 0.0144 - 221ms/epoch - 14ms/step
# Epoch 27/100
#
# Epoch 27: loss improved from 0.01548 to 0.01540, saving model to ./Model/case_2/LSTM/model_7030\save_model.hdf5
# 16/16 - 0s - loss: 0.0154 - val_loss: 0.0210 - 250ms/epoch - 16ms/step
# Epoch 28/100
#
# Epoch 28: loss did not improve from 0.01540
# 16/16 - 0s - loss: 0.0162 - val_loss: 0.0153 - 226ms/epoch - 14ms/step
# Epoch 29/100
#
# Epoch 29: loss improved from 0.01540 to 0.01536, saving model to ./Model/case_2/LSTM/model_7030\save_model.hdf5
# 16/16 - 0s - loss: 0.0154 - val_loss: 0.0206 - 245ms/epoch - 15ms/step
# Epoch 30/100
#
# Epoch 30: loss improved from 0.01536 to 0.01534, saving model to ./Model/case_2/LSTM/model_7030\save_model.hdf5
# 16/16 - 0s - loss: 0.0153 - val_loss: 0.0415 - 242ms/epoch - 15ms/step
# Epoch 31/100
#
# Epoch 31: loss improved from 0.01534 to 0.01507, saving model to ./Model/case_2/LSTM/model_7030\save_model.hdf5
# 16/16 - 0s - loss: 0.0151 - val_loss: 0.0169 - 243ms/epoch - 15ms/step
# Epoch 32/100
#
# Epoch 32: loss improved from 0.01507 to 0.01434, saving model to ./Model/case_2/LSTM/model_7030\save_model.hdf5
# 16/16 - 0s - loss: 0.0143 - val_loss: 0.0413 - 258ms/epoch - 16ms/step
# Epoch 33/100
#
# Epoch 33: loss did not improve from 0.01434
# 16/16 - 0s - loss: 0.0151 - val_loss: 0.0294 - 238ms/epoch - 15ms/step
# Epoch 34/100
#
# Epoch 34: loss improved from 0.01434 to 0.01365, saving model to ./Model/case_2/LSTM/model_7030\save_model.hdf5
# 16/16 - 0s - loss: 0.0137 - val_loss: 0.0173 - 266ms/epoch - 17ms/step
# Epoch 35/100
#
# Epoch 35: loss did not improve from 0.01365
# 16/16 - 0s - loss: 0.0144 - val_loss: 0.0216 - 244ms/epoch - 15ms/step
# Epoch 36/100
#
# Epoch 36: loss did not improve from 0.01365
# 16/16 - 0s - loss: 0.0146 - val_loss: 0.0136 - 230ms/epoch - 14ms/step
# Epoch 37/100
#
# Epoch 37: loss did not improve from 0.01365
# 16/16 - 0s - loss: 0.0137 - val_loss: 0.0166 - 238ms/epoch - 15ms/step
# Epoch 38/100
#
# Epoch 38: loss did not improve from 0.01365
# 16/16 - 0s - loss: 0.0137 - val_loss: 0.0210 - 236ms/epoch - 15ms/step
# Epoch 39/100
#
# Epoch 39: loss did not improve from 0.01365
# 16/16 - 0s - loss: 0.0146 - val_loss: 0.0136 - 249ms/epoch - 16ms/step
# Epoch 40/100
#
# Epoch 40: loss improved from 0.01365 to 0.01326, saving model to ./Model/case_2/LSTM/model_7030\save_model.hdf5
# 16/16 - 0s - loss: 0.0133 - val_loss: 0.0228 - 260ms/epoch - 16ms/step
# Epoch 41/100
#
# Epoch 41: loss did not improve from 0.01326
# 16/16 - 0s - loss: 0.0134 - val_loss: 0.0343 - 234ms/epoch - 15ms/step
# Epoch 42/100
#
# Epoch 42: loss improved from 0.01326 to 0.01242, saving model to ./Model/case_2/LSTM/model_7030\save_model.hdf5
# 16/16 - 0s - loss: 0.0124 - val_loss: 0.0210 - 250ms/epoch - 16ms/step
# Epoch 43/100
#
# Epoch 43: loss did not improve from 0.01242
# 16/16 - 0s - loss: 0.0138 - val_loss: 0.0301 - 250ms/epoch - 16ms/step
# Epoch 44/100
#
# Epoch 44: loss did not improve from 0.01242
# 16/16 - 0s - loss: 0.0130 - val_loss: 0.0269 - 260ms/epoch - 16ms/step
# Epoch 45/100
#
# Epoch 45: loss improved from 0.01242 to 0.01198, saving model to ./Model/case_2/LSTM/model_7030\save_model.hdf5
# 16/16 - 0s - loss: 0.0120 - val_loss: 0.0204 - 266ms/epoch - 17ms/step
# Epoch 46/100
#
# Epoch 46: loss did not improve from 0.01198
# 16/16 - 0s - loss: 0.0130 - val_loss: 0.0234 - 242ms/epoch - 15ms/step
# Epoch 47/100
#
# Epoch 47: loss did not improve from 0.01198
# 16/16 - 0s - loss: 0.0125 - val_loss: 0.0164 - 250ms/epoch - 16ms/step
# Epoch 48/100
#
# Epoch 48: loss did not improve from 0.01198
# 16/16 - 0s - loss: 0.0126 - val_loss: 0.0134 - 238ms/epoch - 15ms/step
# Epoch 49/100
#
# Epoch 49: loss did not improve from 0.01198
# 16/16 - 0s - loss: 0.0125 - val_loss: 0.0187 - 237ms/epoch - 15ms/step
# Epoch 50/100
#
# Epoch 50: loss did not improve from 0.01198
# 16/16 - 0s - loss: 0.0127 - val_loss: 0.0157 - 235ms/epoch - 15ms/step
# Epoch 51/100
#
# Epoch 51: loss did not improve from 0.01198
# 16/16 - 0s - loss: 0.0127 - val_loss: 0.0299 - 248ms/epoch - 16ms/step
# Epoch 52/100
#
# Epoch 52: loss improved from 0.01198 to 0.01197, saving model to ./Model/case_2/LSTM/model_7030\save_model.hdf5
# 16/16 - 0s - loss: 0.0120 - val_loss: 0.0146 - 272ms/epoch - 17ms/step
# Epoch 53/100
#
# Epoch 53: loss did not improve from 0.01197
# 16/16 - 0s - loss: 0.0120 - val_loss: 0.0217 - 231ms/epoch - 14ms/step
# Epoch 54/100
#
# Epoch 54: loss improved from 0.01197 to 0.01170, saving model to ./Model/case_2/LSTM/model_7030\save_model.hdf5
# 16/16 - 0s - loss: 0.0117 - val_loss: 0.0127 - 267ms/epoch - 17ms/step
# Epoch 55/100
#
# Epoch 55: loss did not improve from 0.01170
# 16/16 - 0s - loss: 0.0117 - val_loss: 0.0140 - 242ms/epoch - 15ms/step
# Epoch 56/100
#
# Epoch 56: loss did not improve from 0.01170
# 16/16 - 0s - loss: 0.0120 - val_loss: 0.0129 - 233ms/epoch - 15ms/step
# Epoch 57/100
#
# Epoch 57: loss did not improve from 0.01170
# 16/16 - 0s - loss: 0.0119 - val_loss: 0.0135 - 234ms/epoch - 15ms/step
# Epoch 58/100
#
# Epoch 58: loss improved from 0.01170 to 0.01168, saving model to ./Model/case_2/LSTM/model_7030\save_model.hdf5
# 16/16 - 0s - loss: 0.0117 - val_loss: 0.0132 - 255ms/epoch - 16ms/step
# Epoch 59/100
#
# Epoch 59: loss improved from 0.01168 to 0.01127, saving model to ./Model/case_2/LSTM/model_7030\save_model.hdf5
# 16/16 - 0s - loss: 0.0113 - val_loss: 0.0194 - 246ms/epoch - 15ms/step
# Epoch 60/100
#
# Epoch 60: loss improved from 0.01127 to 0.01105, saving model to ./Model/case_2/LSTM/model_7030\save_model.hdf5
# 16/16 - 0s - loss: 0.0110 - val_loss: 0.0353 - 262ms/epoch - 16ms/step
# Epoch 61/100
#
# Epoch 61: loss did not improve from 0.01105
# 16/16 - 0s - loss: 0.0113 - val_loss: 0.0281 - 254ms/epoch - 16ms/step
# Epoch 62/100
#
# Epoch 62: loss improved from 0.01105 to 0.01062, saving model to ./Model/case_2/LSTM/model_7030\save_model.hdf5
# 16/16 - 0s - loss: 0.0106 - val_loss: 0.0173 - 260ms/epoch - 16ms/step
# Epoch 63/100
#
# Epoch 63: loss did not improve from 0.01062
# 16/16 - 0s - loss: 0.0118 - val_loss: 0.0273 - 247ms/epoch - 15ms/step
# Epoch 64/100
#
# Epoch 64: loss did not improve from 0.01062
# 16/16 - 0s - loss: 0.0109 - val_loss: 0.0179 - 228ms/epoch - 14ms/step
# Epoch 65/100
#
# Epoch 65: loss did not improve from 0.01062
# 16/16 - 0s - loss: 0.0111 - val_loss: 0.0172 - 237ms/epoch - 15ms/step
# Epoch 66/100
#
# Epoch 66: loss did not improve from 0.01062
# 16/16 - 0s - loss: 0.0113 - val_loss: 0.0290 - 227ms/epoch - 14ms/step
# Epoch 67/100
#
# Epoch 67: loss did not improve from 0.01062
# 16/16 - 0s - loss: 0.0110 - val_loss: 0.0135 - 235ms/epoch - 15ms/step
# Epoch 68/100
#
# Epoch 68: loss did not improve from 0.01062
# 16/16 - 0s - loss: 0.0116 - val_loss: 0.0127 - 222ms/epoch - 14ms/step
# Epoch 69/100
#
# Epoch 69: loss improved from 0.01062 to 0.00980, saving model to ./Model/case_2/LSTM/model_7030\save_model.hdf5
# 16/16 - 0s - loss: 0.0098 - val_loss: 0.0281 - 239ms/epoch - 15ms/step
# Epoch 70/100
#
# Epoch 70: loss did not improve from 0.00980
# 16/16 - 0s - loss: 0.0115 - val_loss: 0.0129 - 252ms/epoch - 16ms/step
# Epoch 71/100
#
# Epoch 71: loss did not improve from 0.00980
# 16/16 - 0s - loss: 0.0104 - val_loss: 0.0155 - 226ms/epoch - 14ms/step
# Epoch 72/100
#
# Epoch 72: loss did not improve from 0.00980
# 16/16 - 0s - loss: 0.0116 - val_loss: 0.0204 - 224ms/epoch - 14ms/step
# Epoch 73/100
#
# Epoch 73: loss improved from 0.00980 to 0.00978, saving model to ./Model/case_2/LSTM/model_7030\save_model.hdf5
# 16/16 - 0s - loss: 0.0098 - val_loss: 0.0116 - 239ms/epoch - 15ms/step
# Epoch 74/100
#
# Epoch 74: loss did not improve from 0.00978
# 16/16 - 0s - loss: 0.0105 - val_loss: 0.0169 - 224ms/epoch - 14ms/step
# Epoch 75/100
#
# Epoch 75: loss did not improve from 0.00978
# 16/16 - 0s - loss: 0.0111 - val_loss: 0.0124 - 223ms/epoch - 14ms/step
# Epoch 76/100
#
# Epoch 76: loss did not improve from 0.00978
# 16/16 - 0s - loss: 0.0109 - val_loss: 0.0185 - 225ms/epoch - 14ms/step
# Epoch 77/100
#
# Epoch 77: loss did not improve from 0.00978
# 16/16 - 0s - loss: 0.0105 - val_loss: 0.0193 - 233ms/epoch - 15ms/step
# Epoch 78/100
#
# Epoch 78: loss did not improve from 0.00978
# 16/16 - 0s - loss: 0.0106 - val_loss: 0.0182 - 227ms/epoch - 14ms/step
# Epoch 79/100
#
# Epoch 79: loss did not improve from 0.00978
# 16/16 - 0s - loss: 0.0107 - val_loss: 0.0162 - 226ms/epoch - 14ms/step
# Epoch 80/100
#
# Epoch 80: loss did not improve from 0.00978
# 16/16 - 0s - loss: 0.0107 - val_loss: 0.0135 - 225ms/epoch - 14ms/step
# Epoch 81/100
#
# Epoch 81: loss did not improve from 0.00978
# 16/16 - 0s - loss: 0.0105 - val_loss: 0.0146 - 225ms/epoch - 14ms/step
# Epoch 82/100
#
# Epoch 82: loss did not improve from 0.00978
# 16/16 - 0s - loss: 0.0105 - val_loss: 0.0180 - 217ms/epoch - 14ms/step
# Epoch 83/100
#
# Epoch 83: loss did not improve from 0.00978
# 16/16 - 0s - loss: 0.0104 - val_loss: 0.0120 - 222ms/epoch - 14ms/step
# Epoch 84/100
#
# Epoch 84: loss did not improve from 0.00978
# 16/16 - 0s - loss: 0.0107 - val_loss: 0.0170 - 225ms/epoch - 14ms/step
# Epoch 85/100
#
# Epoch 85: loss improved from 0.00978 to 0.00954, saving model to ./Model/case_2/LSTM/model_7030\save_model.hdf5
# 16/16 - 0s - loss: 0.0095 - val_loss: 0.0206 - 242ms/epoch - 15ms/step
# Epoch 86/100
#
# Epoch 86: loss did not improve from 0.00954
# 16/16 - 0s - loss: 0.0108 - val_loss: 0.0185 - 224ms/epoch - 14ms/step
# Epoch 87/100
#
# Epoch 87: loss did not improve from 0.00954
# 16/16 - 0s - loss: 0.0096 - val_loss: 0.0124 - 226ms/epoch - 14ms/step
# Epoch 88/100
#
# Epoch 88: loss did not improve from 0.00954
# 16/16 - 0s - loss: 0.0105 - val_loss: 0.0133 - 229ms/epoch - 14ms/step
# Epoch 89/100
#
# Epoch 89: loss did not improve from 0.00954
# 16/16 - 0s - loss: 0.0100 - val_loss: 0.0129 - 221ms/epoch - 14ms/step
# Epoch 90/100
#
# Epoch 90: loss did not improve from 0.00954
# 16/16 - 0s - loss: 0.0108 - val_loss: 0.0123 - 220ms/epoch - 14ms/step
# Epoch 91/100
#
# Epoch 91: loss did not improve from 0.00954
# 16/16 - 0s - loss: 0.0098 - val_loss: 0.0133 - 230ms/epoch - 14ms/step
# Epoch 92/100
#
# Epoch 92: loss did not improve from 0.00954
# 16/16 - 0s - loss: 0.0100 - val_loss: 0.0240 - 218ms/epoch - 14ms/step
# Epoch 93/100
#
# Epoch 93: loss did not improve from 0.00954
# 16/16 - 0s - loss: 0.0104 - val_loss: 0.0144 - 235ms/epoch - 15ms/step
# Epoch 94/100
#
# Epoch 94: loss improved from 0.00954 to 0.00929, saving model to ./Model/case_2/LSTM/model_7030\save_model.hdf5
# 16/16 - 0s - loss: 0.0093 - val_loss: 0.0121 - 260ms/epoch - 16ms/step
# Epoch 95/100
#
# Epoch 95: loss did not improve from 0.00929
# 16/16 - 0s - loss: 0.0093 - val_loss: 0.0119 - 226ms/epoch - 14ms/step
# Epoch 96/100
#
# Epoch 96: loss did not improve from 0.00929
# 16/16 - 0s - loss: 0.0104 - val_loss: 0.0114 - 238ms/epoch - 15ms/step
# Epoch 97/100
#
# Epoch 97: loss did not improve from 0.00929
# 16/16 - 0s - loss: 0.0105 - val_loss: 0.0191 - 235ms/epoch - 15ms/step
# Epoch 98/100
#
# Epoch 98: loss improved from 0.00929 to 0.00912, saving model to ./Model/case_2/LSTM/model_7030\save_model.hdf5
# 16/16 - 0s - loss: 0.0091 - val_loss: 0.0113 - 252ms/epoch - 16ms/step
# Epoch 99/100
#
# Epoch 99: loss did not improve from 0.00912
# 16/16 - 0s - loss: 0.0101 - val_loss: 0.0133 - 226ms/epoch - 14ms/step
# Epoch 100/100
#
# Epoch 100: loss did not improve from 0.00912
# 16/16 - 0s - loss: 0.0101 - val_loss: 0.0172 - 230ms/epoch - 14ms/step
# Thời gian thực thi mô hình: 26.58 giây

# %%
#Model
final_model = load_model("./Model/case_2/LSTM/model_7030/save_model.hdf5")

# %%
#dữ liệu train
Y_train_predict = final_model.predict(X_train) #dự đoán trên tập đã train
Y_train_predict = sc.inverse_transform(Y_train_predict) #giá thực dự đoán
Y_train = sc.inverse_transform(Y_train) #giá thực train
# Out:
# 42/42 [==============================] - 1s 2ms/step

# %% [markdown]
# # DỰ ĐOÁN TRÊN TẬP TEST

# %%
#dữ liệu test
import time
start_model = time.time()  # Bắt đầu đo thời gian
Y_test_predict = final_model.predict(X_test)
end_model = time.time()  # Kết thúc đo thời gian
print(f"Thời gian thực thi mô hình: {end_model - start_model:.2f} giây")
Y_test_predict = sc.inverse_transform(Y_test_predict) #giá dự đoán
Y_test = sc.inverse_transform(Y_test) #giá thực
# Out:
# 18/18 [==============================] - 0s 3ms/step
# Thời gian thực thi mô hình: 0.10 giây

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import mean_absolute_error, mean_squared_error

# Tính toán các giá trị cho tập Train
mae_train = round(mean_absolute_error(Y_train, Y_train_predict), 3)
mse_train = round(mean_squared_error(Y_train, Y_train_predict), 3)
rmse_train = round(np.sqrt(mse_train), 3)

# Tính toán các giá trị cho tập Test
mae_test = round(mean_absolute_error(Y_test, Y_test_predict), 3)
mse_test = round(mean_squared_error(Y_test, Y_test_predict), 3)
rmse_test = round(np.sqrt(mse_test), 3)

# Tạo DataFrame để hiển thị kết quả
metrics = pd.DataFrame({
    "Tập dữ liệu": ["Train", "Test"],
    "MAE": [mae_train, mae_test],
    "MSE": [mse_train, mse_test],
    "RMSE": [rmse_train, rmse_test]
})

# In kết quả
print(metrics)
print(f"Thời gian thực thi mô hình: {end_model - start_model:.2f} giây")
# Out:
#   Tập dữ liệu     MAE       MSE    RMSE
# 0       Train  30.207  2558.837  50.585
# 1        Test  63.632  6623.968  81.388
# Thời gian thực thi mô hình: 0.10 giây

# %%
# Xác định 70% dữ liệu làm tập train
train_size = int(len(df_usd_ML) * 0.7)

# Cắt lại cho đúng chiều dài:
train_data1 = df_usd_ML[6:train_size+1].copy()
test_data1 = df_usd_ML[train_size+2:].copy()


print(len(train_data1), len(Y_train_predict))
print(len(test_data1), len(Y_test_predict))

# Cắt dữ liệu dự đoán để khớp với dữ liệu gốc
Y_train_predict = Y_train_predict[:len(train_data1)]
Y_test_predict = Y_test_predict[:len(test_data1)]

# Đảm bảo test_data1 có số lượng dòng khớp với Y_test_predict
test_data1 = test_data1.iloc[:len(Y_test_predict)]

plt.figure(figsize=(24,8))
plt.plot(df_usd_ML, label='Giá thực tế', color='red')  # đường giá thực

# Thêm dữ liệu dự đoán vào train_data1 và test_data1
train_data1["Dự đoán"] = Y_train_predict
plt.plot(train_data1["Dự đoán"], label='Giá dự đoán train', color='green')

test_data1["Dự đoán"] = Y_test_predict
plt.plot(test_data1["Dự đoán"], label='Giá dự đoán test', color='blue')

plt.title('So sánh giá dự báo và giá thực tế')
plt.xlabel('Thời gian')
plt.ylabel('Giá mua chuyển khoản (VNĐ)')
plt.legend()
plt.show()
# Out:
# 1332 1332
# 572 572

# %%
from tensorflow.keras.models import load_model

# Gọi lại mô hình đã lưu
loaded_model = load_model("./Model/case_2/LSTM/model_7030/save_model.hdf5")
# Dự đoán lại trên tập test
Y_test_predict = loaded_model.predict(X_test)
# Đảo chuẩn hóa (inverse transform)
Y_test_predict = sc.inverse_transform(Y_test_predict)

# Tạo bảng so sánh
compare_df = pd.DataFrame({
    "Giá thực tế": Y_test.flatten(),
    "Giá dự đoán": Y_test_predict.flatten()
})

# Làm tròn về số nguyên
compare_df = compare_df.astype(int)
pd.set_option('display.max_rows', None)
# Hiển thị toàn bộ bảng
display(compare_df)
compare_df.to_csv("./Model/case_2/LSTM/model_7030/predict.csv", index=False)
# Out:
# 18/18 [==============================] - 0s 2ms/step
#      Giá thực tế  Giá dự đoán
# 0          24150        24142
# 1          24210        24136
# 2          24240        24149
# 3          24220        24172
# 4          24210        24189
# 5          24210        24199
# 6          24210        24204
# 7          24210        24205
# 8          24245        24204
# 9          24265        24211
# 10         24270        24223
# 11         24275        24236
# 12         24275        24247
# 13         24275        24255
# 14         24290        24261
# 15         24328        24267
# 16         24350        24280
# 17         24370        24297
# 18         24360        24317
# 19         24360        24331
# 20         24360        24339
# 21         24420        24344
# 22         24390        24359
# 23         24380        24368
# 24         24420        24370
# 25         24390        24379
# 26         24390        24381
# 27         24390        24381
# 28         24385        24379
# 29         24390        24376
# 30         24410        24375
# 31         24410        24379
# 32         24350        24384
# 33         24350        24375
# 34         24350        24363
# 35         24160        24353
# 36         24150        24304
# 37         24190        24250
# 38         24190        24216
# 39         24130        24195
# 40         24130        24172
# 41         24130        24153
# 42         24200        24140
# 43         24190        24149
# 44         24100        24159
# 45         24115        24148
# 46         24075        24136
# 47         24075        24118
# 48         24075        24100
# 49         24005        24087
# 50         23950        24063
# 51         24015        24029
# 52         24050        24014
# 53         24080        24016
# 54         24080        24030
# 55         24080        24046
# 56         24075        24059
# 57         24080        24067
# 58         24045        24072
# 59         24090        24067
# 60         24110        24069
# 61         24110        24078
# 62         24110        24087
# 63         24065        24095
# 64         24090        24090
# 65         24095        24088
# 66         24090        24088
# 67         24050        24087
# 68         24050        24077
# 69         24050        24067
# 70         24060        24059
# 71         24090        24056
# 72         24080        24061
# 73         24080        24066
# 74         24070        24071
# 75         24070        24072
# 76         24070        24071
# 77         24140        24070
# 78         24175        24084
# 79         24170        24108
# 80         24160        24129
# 81         24060        24142
# 82         24060        24128
# 83         24060        24107
# 84         24060        24088
# 85         24130        24073
# 86         24140        24079
# 87         24060        24094
# 88         24080        24091
# 89         24080        24088
# 90         24080        24084
# 91         24080        24081
# 92         24155        24078
# 93         24180        24093
# 94         24190        24117
# 95         24190        24140
# 96         24190        24159
# 97         24190        24171
# 98         24175        24178
# 99         24185        24178
# 100        24215        24178
# 101        24295        24184
# 102        24290        24209
# 103        24290        24234
# 104        24290        24253
# 105        24295        24266
# 106        24370        24275
# 107        24360        24297
# 108        24385        24315
# 109        24375        24334
# 110        24375        24347
# 111        24375        24355
# 112        24365        24359
# 113        24390        24359
# 114        24430        24362
# 115        24430        24375
# 116        24425        24388
# 117        24425        24397
# 118        24425        24404
# 119        24375        24407
# 120        24235        24398
# 121        24255        24355
# 122        24240        24315
# 123        24160        24281
# 124        24160        24240
# 125        24160        24205
# 126        24200        24181
# 127        24190        24176
# 128        24230        24176
# 129        24230        24186
# 130        24230        24198
# 131        24230        24208
# 132        24230        24215
# 133        24230        24219
# 134        24230        24221
# 135        24230        24221
# 136        24270        24221
# 137        24340        24230
# 138        24340        24255
# 139        24340        24281
# 140        24360        24300
# 141        24360        24318
# 142        24340        24331
# 143        24420        24335
# 144        24450        24352
# 145        24450        24376
# 146        24450        24397
# 147        24500        24413
# 148        24460        24434
# 149        24450        24444
# 150        24480        24445
# 151        24470        24448
# 152        24470        24450
# 153        24470        24451
# 154        24500        24452
# 155        24510        24458
# 156        24520        24468
# 157        24530        24479
# 158        24500        24489
# 159        24500        24491
# 160        24500        24490
# 161        24450        24487
# 162        24460        24473
# 163        24480        24461
# 164        24530        24457
# 165        24550        24467
# 166        24550        24485
# 167        24550        24501
# 168        24560        24513
# 169        24590        24524
# 170        24610        24537
# 171        24610        24553
# 172        24610        24565
# 173        24610        24574
# 174        24610        24580
# 175        24590        24583
# 176        24610        24581
# 177        24610        24580
# 178        24610        24581
# 179        24630        24582
# 180        24630        24588
# 181        24630        24594
# 182        24630        24598
# 183        24710        24601
# 184        24790        24620
# 185        24770        24658
# 186        24780        24689
# 187        24780        24713
# 188        24780        24730
# 189        24790        24740
# 190        24790        24747
# 191        24790        24751
# 192        24830        24753
# 193        24840        24763
# 194        24840        24775
# 195        24840        24786
# 196        24960        24794
# 197        25008        24825
# 198        25130        24866
# 199        25130        24928
# 200        25163        24983
# 201        25163        25031
# 202        25163        25065
# 203        25175        25086
# 204        25178        25100
# 205        25177        25108
# 206        25167        25112
# 207        25118        25113
# 208        25118        25101
# 209        25118        25089
# 210        25118        25078
# 211        25118        25070
# 212        25118        25066
# 213        25144        25063
# 214        25143        25068
# 215        25147        25074
# 216        25147        25080
# 217        25157        25084
# 218        25155        25089
# 219        25161        25092
# 220        25178        25096
# 221        25184        25102
# 222        25184        25109
# 223        25184        25115
# 224        25179        25119
# 225        25182        25120
# 226        25182        25121
# 227        25152        25122
# 228        25250        25115
# 229        25250        25129
# 230        25250        25146
# 231        25259        25161
# 232        25263        25174
# 233        25266        25184
# 234        25250        25191
# 235        25277        25192
# 236        25277        25196
# 237        25277        25200
# 238        25281        25204
# 239        25268        25207
# 240        25265        25207
# 241        25250        25205
# 242        25254        25200
# 243        25254        25195
# 244        25254        25192
# 245        25234        25190
# 246        25218        25184
# 247        25213        25176
# 248        25213        25167
# 249        25213        25160
# 250        25213        25155
# 251        25213        25152
# 252        25214        25151
# 253        25222        25151
# 254        25226        25153
# 255        25217        25155
# 256        25221        25156
# 257        25221        25157
# 258        25221        25157
# 259        25231        25158
# 260        25251        25160
# 261        25249        25166
# 262        25247        25173
# 263        25248        25177
# 264        25248        25180
# 265        25248        25182
# 266        25255        25182
# 267        25245        25184
# 268        25250        25184
# 269        25257        25184
# 270        25253        25185
# 271        25253        25186
# 272        25253        25187
# 273        25244        25187
# 274        25245        25185
# 275        25250        25184
# 276        25243        25183
# 277        25238        25182
# 278        25238        25179
# 279        25238        25177
# 280        25235        25176
# 281        25234        25174
# 282        25239        25172
# 283        25245        25172
# 284        25240        25174
# 285        25240        25175
# 286        25240        25175
# 287        25237        25176
# 288        25237        25175
# 289        25168        25174
# 290        25150        25159
# 291        25158        25138
# 292        25158        25122
# 293        25158        25111
# 294        25154        25104
# 295        25157        25100
# 296        25177        25098
# 297        25120        25102
# 298        25121        25095
# 299        25121        25086
# 300        25121        25078
# 301        25115        25072
# 302        25120        25067
# 303        25080        25065
# 304        25060        25055
# 305        25040        25042
# 306        25040        25025
# 307        25040        25011
# 308        24930        25001
# 309        24980        24971
# 310        24995        24953
# 311        24980        24945
# 312        24930        24940
# 313        24930        24926
# 314        24930        24912
# 315        24940        24902
# 316        24950        24898
# 317        24850        24897
# 318        24870        24878
# 319        24890        24861
# 320        24890        24852
# 321        24890        24848
# 322        24820        24847
# 323        24740        24832
# 324        24760        24799
# 325        24780        24772
# 326        24810        24756
# 327        24810        24754
# 328        24810        24757
# 329        24710        24763
# 330        24660        24747
# 331        24680        24716
# 332        24690        24690
# 333        24690        24674
# 334        24690        24664
# 335        24690        24660
# 336        24690        24659
# 337        24690        24660
# 338        24675        24661
# 339        24580        24658
# 340        24430        24634
# 341        24430        24575
# 342        24430        24518
# 343        24500        24473
# 344        24490        24458
# 345        24385        24455
# 346        24410        24435
# 347        24390        24420
# 348        24390        24406
# 349        24390        24393
# 350        24380        24384
# 351        24430        24376
# 352        24470        24382
# 353        24410        24401
# 354        24400        24406
# 355        24400        24403
# 356        24400        24398
# 357        24460        24393
# 358        24430        24403
# 359        24410        24408
# 360        24460        24406
# 361        24420        24415
# 362        24420        24415
# 363        24420        24413
# 364        24400        24410
# 365        24430        24403
# 366        24480        24403
# 367        24580        24416
# 368        24580        24453
# 369        24580        24489
# 370        24580        24518
# 371        24670        24538
# 372        24665        24569
# 373        24665        24595
# 374        24670        24614
# 375        24640        24626
# 376        24640        24628
# 377        24640        24626
# 378        24660        24622
# 379        24765        24622
# 380        24810        24648
# 381        25010        24685
# 382        24980        24762
# 383        24980        24829
# 384        24980        24877
# 385        25070        24908
# 386        25092        24944
# 387        25220        24978
# 388        25233        25030
# 389        25197        25079
# 390        25197        25110
# 391        25197        25127
# 392        25194        25136
# 393        25164        25137
# 394        25118        25130
# 395        25090        25111
# 396        25114        25088
# 397        25114        25073
# 398        25114        25064
# 399        25125        25059
# 400        25160        25060
# 401        25170        25070
# 402        25197        25083
# 403        25130        25100
# 404        25130        25100
# 405        25130        25094
# 406        25116        25088
# 407        25160        25079
# 408        25180        25080
# 409        25184        25090
# 410        25190        25101
# 411        25190        25112
# 412        25190        25120
# 413        25200        25125
# 414        25205        25130
# 415        25200        25134
# 416        25200        25137
# 417        25200        25138
# 418        25200        25138
# 419        25200        25139
# 420        25197        25139
# 421        25200        25138
# 422        25200        25138
# 423        25175        25138
# 424        25160        25133
# 425        25160        25124
# 426        25160        25116
# 427        25149        25109
# 428        25170        25103
# 429        25172        25102
# 430        25176        25104
# 431        25164        25108
# 432        25164        25109
# 433        25164        25108
# 434        25157        25107
# 435        25170        25105
# 436        25165        25105
# 437        25171        25106
# 438        25177        25107
# 439        25177        25110
# 440        25177        25113
# 441        25185        25115
# 442        25183        25118
# 443        25191        25120
# 444        25219        25123
# 445        25240        25132
# 446        25240        25145
# 447        25240        25156
# 448        25230        25165
# 449        25223        25168
# 450        25236        25168
# 451        25225        25168
# 452        25238        25167
# 453        25238        25167
# 454        25238        25169
# 455        25243        25171
# 456        25251        25173
# 457        25251        25177
# 458        25259        25180
# 459        25250        25184
# 460        25250        25186
# 461        25250        25186
# 462        25253        25186
# 463        25208        25186
# 464        25186        25177
# 465        25194        25162
# 466        25198        25150
# 467        25198        25143
# 468        25198        25138
# 469        25200        25136
# 470        25203        25136
# 471        25194        25138
# 472        25189        25137
# 473        25150        25135
# 474        25150        25124
# 475        25150        25113
# 476        25150        25105
# 477        25090        25098
# 478        24960        25082
# 479        24960        25038
# 480        24800        24995
# 481        24800        24927
# 482        24800        24866
# 483        24800        24821
# 484        24800        24792
# 485        24800        24775
# 486        24800        24768
# 487        24800        24765
# 488        24800        24765
# 489        24800        24765
# 490        25140        24765
# 491        25000        24838
# 492        24980        24889
# 493        25090        24918
# 494        25110        24957
# 495        25110        24993
# 496        25110        25020
# 497        25200        25037
# 498        25340        25065
# 499        25380        25122
# 500        25300        25183
# 501        25220        25215
# 502        25220        25214
# 503        25220        25202
# 504        25280        25187
# 505        25340        25186
# 506        25340        25203
# 507        25350        25223
# 508        25320        25243
# 509        25320        25253
# 510        25320        25255
# 511        25310        25255
# 512        25330        25251
# 513        25360        25250
# 514        25380        25258
# 515        25370        25271
# 516        25370        25281
# 517        25370        25288
# 518        25420        25292
# 519        25390        25305
# 520        25320        25311
# 521        25300        25298
# 522        25300        25279
# 523        25330        25261
# 524        25330        25254
# 525        25340        25252
# 526        25290        25254
# 527        25280        25248
# 528        25320        25238
# 529        25350        25237
# 530        25350        25246
# 531        25350        25255
# 532        25360        25263
# 533        25350        25272
# 534        25370        25276
# 535        25380        25282
# 536        25400        25289
# 537        25400        25298
# 538        25400        25307
# 539        25450        25314
# 540        25450        25329
# 541        25390        25343
# 542        25390        25341
# 543        25400        25334
# 544        25400        25329
# 545        25400        25325
# 546        25380        25323
# 547        25460        25317
# 548        25460        25329
# 549        25620        25345
# 550        25600        25391
# 551        25600        25432
# 552        25600        25464
# 553        25600        25485
# 554        25780        25497
# 555        25822        25539
# 556        25610        25591
# 557        25560        25590
# 558        25560        25563
# 559        25560        25533
# 560        25640        25507
# 561        25650        25504
# 562        25650        25511
# 563        25700        25523
# 564        25760        25545
# 565        25760        25576
# 566        25760        25604
# 567        25700        25623
# 568        25755        25623
# 569        25781        25628
# 570        25814        25638
# 571        25835        25654
