# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler #chuẩn hóa dữ liệu
from keras.callbacks import ModelCheckpoint #lưu lại huấn luyện tốt nhất
from tensorflow.keras.models import load_model #tải mô hình
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import ModelCheckpoint

import random
import tensorflow as tf

#các lớp để xây dựng mô hình
from keras.models import Sequential #đầu vào
from keras.layers import LSTM #học phụ thuộc
from keras.layers import Dropout, BatchNormalization #tránh học tủ
from keras.layers import Dense #đầu ra

#kiểm tra độ chính xác của mô hình
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
random.seed(42)
np.random.seed(42)
tf.random.set_seed(42)

# %%
df_usd = pd.read_parquet("./minio/usd/part-00000-18b834c3-cd6d-42ae-82c3-638999ff6d84-c000.snappy.parquet", engine="pyarrow")
df_usd.head()
# Out:
#         ngay ma_ngoai_te ten_ngoai_te  mua_chuyen_khoan      ban
# 0 2020-02-01         USD    US DOLLAR           23165.0  23305.0
# 1 2020-02-02         USD    US DOLLAR           23165.0  23305.0
# 2 2020-02-03         USD    US DOLLAR           23200.0  23340.0
# 3 2020-02-04         USD    US DOLLAR           23170.0  23310.0
# 4 2020-02-05         USD    US DOLLAR           23160.0  23300.0

# %%
df_usd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1911 entries, 0 to 1910
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ngay              1911 non-null   datetime64[ns]
#  1   ma_ngoai_te       1911 non-null   object
#  2   ten_ngoai_te      1911 non-null   object
#  3   mua_chuyen_khoan  1911 non-null   float64
#  4   ban               1911 non-null   float64
# dtypes: datetime64[ns](1), float64(2), object(2)
# memory usage: 74.8+ KB

# %%
df_usd.describe()
# Out:
#                       ngay  mua_chuyen_khoan           ban
# count                 1911       1911.000000   1911.000000
# mean   2022-09-13 00:00:00      23666.414443  23934.197279
# min    2020-02-01 00:00:00      22480.000000  22745.000000
# 25%    2021-05-23 12:00:00      22985.000000  23170.000000
# 50%    2022-09-13 00:00:00      23300.000000  23620.000000
# 75%    2024-01-03 12:00:00      24390.000000  24730.000000
# max    2025-04-25 00:00:00      25835.000000  26195.000000
# std                    NaN        885.147984    926.810272

# %%
print(df_usd.dtypes)
# Out:
# ngay                datetime64[ns]
# ma_ngoai_te                 object
# ten_ngoai_te                object
# mua_chuyen_khoan           float64
# ban                        float64
# dtype: object

# %%
import matplotlib.pyplot as plt
from matplotlib.dates import YearLocator, DateFormatter, MonthLocator

# Vẽ biểu đồ
plt.figure(figsize=(10, 5))
plt.plot(df_usd['ngay'].values, df_usd['mua_chuyen_khoan'].values, label='Giá mua chuyển khoản', color='red')

plt.xlabel('Năm')
plt.ylabel('Giá mua chuyển khoản')
plt.title('Biểu đồ tỷ giá VND_USD mua chuyển khoảng qua các năm')
plt.legend(loc='best')

# Định dạng trục x
plt.gca().xaxis.set_major_locator(YearLocator())
plt.gca().xaxis.set_major_formatter(DateFormatter('%Y'))
plt.gca().xaxis.set_minor_locator(MonthLocator())

plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
df_usd_ML = pd.DataFrame(df_usd, columns=['ngay','mua_chuyen_khoan'])
df_usd_ML.index = df_usd_ML.ngay
df_usd_ML.drop('ngay', axis = 1, inplace=True)
df_usd_ML.head()
# Out:
#             mua_chuyen_khoan
# ngay
# 2020-02-01           23165.0
# 2020-02-02           23165.0
# 2020-02-03           23200.0
# 2020-02-04           23170.0
# 2020-02-05           23160.0

# %%
print(df_usd_ML.columns)
# Out:
# Index(['mua_chuyen_khoan'], dtype='object')

# %%
data = df_usd_ML.values

# %%
data
# Out:
# array([[23165.],
#        [23165.],
#        [23200.],
#        ...,
#        [25781.],
#        [25814.],
#        [25835.]])

# %%
#hàm hóa dữ liệu
sc = MinMaxScaler(feature_range=(0,1))

#chuẩn hóa dữ train
scale_data = sc.fit_transform(data)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))

plt.plot(scale_data, label="Dữ liệu sau chuẩn hóa", color="red")

plt.xlabel("Thời gian (Index)")
plt.ylabel("Giá trị sau chuẩn hóa")
plt.title("Biểu đồ dữ liệu sau khi chuẩn hóa bằng MinMaxScaler")
plt.legend()
plt.show()

# %%
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Bidirectional, LSTM, Dense, Dropout

# Chọn window
window_size = 7
X_train, Y_train = [], []

for i in range(len(scale_data) - window_size):
    X_train.append(scale_data[i:i + window_size])
    Y_train.append(scale_data[i + window_size])

X_train = np.array(X_train)
Y_train = np.array(Y_train)

# Phân chia tập dữ liệu thành tập train và test
split_index = int(0.8 * len(X_train))

X_train, X_test = X_train[:split_index], X_train[split_index:]
Y_train, Y_test = Y_train[:split_index], Y_train[split_index:]

# Đảm bảo dữ liệu có đúng shape cho mô hình BiLSTM
X_train = X_train.reshape((X_train.shape[0], window_size, -1))
X_test = X_test.reshape((X_test.shape[0], window_size, -1))

# %%
print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
print("y_train shape:", Y_train.shape)
print("y_test shape:", Y_test.shape)
# Out:
# X_train shape: (1523, 7, 1)
# X_test shape: (381, 7, 1)
# y_train shape: (1523, 1)
# y_test shape: (381, 1)

# %%
print("Shape of X_train:", X_train.shape)
# Out:
# Shape of X_train: (1523, 7, 1)

# %% [markdown]
# # MODEL

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Bidirectional, BatchNormalization

# Xây dựng mô hình BiLSTM
model = Sequential()

# Lớp BiLSTM đầu tiên (return_sequences=True để kết nối lớp tiếp theo)
model.add(Bidirectional(LSTM(units=64, return_sequences=True, input_shape=(X_train.shape[1], 1))))
model.add(BatchNormalization())  # Ổn định dữ liệu đầu ra

# Lớp BiLSTM thứ hai
model.add(Bidirectional(LSTM(units=64)))
model.add(BatchNormalization())

# Dropout để giảm overfitting
model.add(Dropout(0.5))

# Lớp Dense đầu ra
model.add(Dense(1))

# Compile mô hình
model.compile(loss='mean_absolute_error', optimizer='sgd')

# %% [markdown]
# # huấn luyện mô hình

# %%
save_model = "./Model/case_1/BiLSTM/model_SGD/save_model.hdf5"
best_model = ModelCheckpoint(save_model,monitor='loss',verbose=2,save_best_only=True,mode='auto')

import time
start_model = time.time()  # Bắt đầu đo thời gian
model.fit(X_train,Y_train,epochs=100,batch_size=50,validation_split=0.4,verbose=2,callbacks=[best_model])
end_model = time.time()  # Kết thúc đo thời gian
print(f"Thời gian thực thi mô hình: {end_model - start_model:.2f} giây")
# Out:
# Epoch 1/100
#
# Epoch 1: loss improved from inf to 0.92993, saving model to ./Model/case_1/BiLSTM/model_SGD\save_model.hdf5
# 19/19 - 6s - loss: 0.9299 - val_loss: 0.3877 - 6s/epoch - 297ms/step
# Epoch 2/100
#
# Epoch 2: loss improved from 0.92993 to 0.75956, saving model to ./Model/case_1/BiLSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.7596 - val_loss: 0.3291 - 278ms/epoch - 15ms/step
# Epoch 3/100
#
# Epoch 3: loss improved from 0.75956 to 0.66761, saving model to ./Model/case_1/BiLSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.6676 - val_loss: 0.3302 - 278ms/epoch - 15ms/step
# Epoch 4/100
#
# Epoch 4: loss improved from 0.66761 to 0.56600, saving model to ./Model/case_1/BiLSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.5660 - val_loss: 0.3784 - 285ms/epoch - 15ms/step
# Epoch 5/100
#
# Epoch 5: loss did not improve from 0.56600
# 19/19 - 0s - loss: 0.5835 - val_loss: 0.3503 - 255ms/epoch - 13ms/step
# Epoch 6/100
#
# Epoch 6: loss improved from 0.56600 to 0.47922, saving model to ./Model/case_1/BiLSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.4792 - val_loss: 0.3692 - 298ms/epoch - 16ms/step
# Epoch 7/100
#
# Epoch 7: loss improved from 0.47922 to 0.40256, saving model to ./Model/case_1/BiLSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.4026 - val_loss: 0.3725 - 314ms/epoch - 17ms/step
# Epoch 8/100
#
# Epoch 8: loss improved from 0.40256 to 0.35906, saving model to ./Model/case_1/BiLSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.3591 - val_loss: 0.3328 - 290ms/epoch - 15ms/step
# Epoch 9/100
#
# Epoch 9: loss improved from 0.35906 to 0.28233, saving model to ./Model/case_1/BiLSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.2823 - val_loss: 0.3766 - 291ms/epoch - 15ms/step
# Epoch 10/100
#
# Epoch 10: loss improved from 0.28233 to 0.24328, saving model to ./Model/case_1/BiLSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.2433 - val_loss: 0.3607 - 277ms/epoch - 15ms/step
# Epoch 11/100
#
# Epoch 11: loss improved from 0.24328 to 0.23230, saving model to ./Model/case_1/BiLSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.2323 - val_loss: 0.3768 - 278ms/epoch - 15ms/step
# Epoch 12/100
#
# Epoch 12: loss improved from 0.23230 to 0.17851, saving model to ./Model/case_1/BiLSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.1785 - val_loss: 0.3420 - 282ms/epoch - 15ms/step
# Epoch 13/100
#
# Epoch 13: loss improved from 0.17851 to 0.16350, saving model to ./Model/case_1/BiLSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.1635 - val_loss: 0.3565 - 291ms/epoch - 15ms/step
# Epoch 14/100
#
# Epoch 14: loss improved from 0.16350 to 0.12408, saving model to ./Model/case_1/BiLSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.1241 - val_loss: 0.3182 - 291ms/epoch - 15ms/step
# Epoch 15/100
#
# Epoch 15: loss improved from 0.12408 to 0.10760, saving model to ./Model/case_1/BiLSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.1076 - val_loss: 0.3432 - 291ms/epoch - 15ms/step
# Epoch 16/100
#
# Epoch 16: loss improved from 0.10760 to 0.08844, saving model to ./Model/case_1/BiLSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0884 - val_loss: 0.3377 - 297ms/epoch - 16ms/step
# Epoch 17/100
#
# Epoch 17: loss improved from 0.08844 to 0.07366, saving model to ./Model/case_1/BiLSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0737 - val_loss: 0.3306 - 278ms/epoch - 15ms/step
# Epoch 18/100
#
# Epoch 18: loss improved from 0.07366 to 0.05672, saving model to ./Model/case_1/BiLSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0567 - val_loss: 0.3488 - 316ms/epoch - 17ms/step
# Epoch 19/100
#
# Epoch 19: loss improved from 0.05672 to 0.05114, saving model to ./Model/case_1/BiLSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0511 - val_loss: 0.3221 - 279ms/epoch - 15ms/step
# Epoch 20/100
#
# Epoch 20: loss improved from 0.05114 to 0.04478, saving model to ./Model/case_1/BiLSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0448 - val_loss: 0.3498 - 273ms/epoch - 14ms/step
# Epoch 21/100
#
# Epoch 21: loss did not improve from 0.04478
# 19/19 - 0s - loss: 0.0448 - val_loss: 0.3396 - 251ms/epoch - 13ms/step
# Epoch 22/100
#
# Epoch 22: loss improved from 0.04478 to 0.03520, saving model to ./Model/case_1/BiLSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0352 - val_loss: 0.3415 - 282ms/epoch - 15ms/step
# Epoch 23/100
#
# Epoch 23: loss improved from 0.03520 to 0.03485, saving model to ./Model/case_1/BiLSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0348 - val_loss: 0.3210 - 287ms/epoch - 15ms/step
# Epoch 24/100
#
# Epoch 24: loss did not improve from 0.03485
# 19/19 - 0s - loss: 0.0357 - val_loss: 0.2912 - 250ms/epoch - 13ms/step
# Epoch 25/100
#
# Epoch 25: loss improved from 0.03485 to 0.02690, saving model to ./Model/case_1/BiLSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0269 - val_loss: 0.3031 - 292ms/epoch - 15ms/step
# Epoch 26/100
#
# Epoch 26: loss did not improve from 0.02690
# 19/19 - 0s - loss: 0.0278 - val_loss: 0.2979 - 251ms/epoch - 13ms/step
# Epoch 27/100
#
# Epoch 27: loss improved from 0.02690 to 0.02400, saving model to ./Model/case_1/BiLSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0240 - val_loss: 0.2865 - 269ms/epoch - 14ms/step
# Epoch 28/100
#
# Epoch 28: loss did not improve from 0.02400
# 19/19 - 0s - loss: 0.0259 - val_loss: 0.2681 - 255ms/epoch - 13ms/step
# Epoch 29/100
#
# Epoch 29: loss improved from 0.02400 to 0.02123, saving model to ./Model/case_1/BiLSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0212 - val_loss: 0.2776 - 274ms/epoch - 14ms/step
# Epoch 30/100
#
# Epoch 30: loss did not improve from 0.02123
# 19/19 - 0s - loss: 0.0237 - val_loss: 0.1941 - 253ms/epoch - 13ms/step
# Epoch 31/100
#
# Epoch 31: loss did not improve from 0.02123
# 19/19 - 0s - loss: 0.0239 - val_loss: 0.2314 - 254ms/epoch - 13ms/step
# Epoch 32/100
#
# Epoch 32: loss did not improve from 0.02123
# 19/19 - 0s - loss: 0.0219 - val_loss: 0.2403 - 243ms/epoch - 13ms/step
# Epoch 33/100
#
# Epoch 33: loss improved from 0.02123 to 0.01847, saving model to ./Model/case_1/BiLSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0185 - val_loss: 0.1618 - 274ms/epoch - 14ms/step
# Epoch 34/100
#
# Epoch 34: loss did not improve from 0.01847
# 19/19 - 0s - loss: 0.0211 - val_loss: 0.1808 - 245ms/epoch - 13ms/step
# Epoch 35/100
#
# Epoch 35: loss improved from 0.01847 to 0.01781, saving model to ./Model/case_1/BiLSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0178 - val_loss: 0.2267 - 284ms/epoch - 15ms/step
# Epoch 36/100
#
# Epoch 36: loss did not improve from 0.01781
# 19/19 - 0s - loss: 0.0197 - val_loss: 0.1441 - 243ms/epoch - 13ms/step
# Epoch 37/100
#
# Epoch 37: loss did not improve from 0.01781
# 19/19 - 0s - loss: 0.0180 - val_loss: 0.1594 - 241ms/epoch - 13ms/step
# Epoch 38/100
#
# Epoch 38: loss improved from 0.01781 to 0.01698, saving model to ./Model/case_1/BiLSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0170 - val_loss: 0.1743 - 259ms/epoch - 14ms/step
# Epoch 39/100
#
# Epoch 39: loss improved from 0.01698 to 0.01615, saving model to ./Model/case_1/BiLSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0161 - val_loss: 0.0842 - 266ms/epoch - 14ms/step
# Epoch 40/100
#
# Epoch 40: loss did not improve from 0.01615
# 19/19 - 0s - loss: 0.0181 - val_loss: 0.0939 - 235ms/epoch - 12ms/step
# Epoch 41/100
#
# Epoch 41: loss improved from 0.01615 to 0.01591, saving model to ./Model/case_1/BiLSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0159 - val_loss: 0.1877 - 253ms/epoch - 13ms/step
# Epoch 42/100
#
# Epoch 42: loss did not improve from 0.01591
# 19/19 - 0s - loss: 0.0171 - val_loss: 0.0894 - 231ms/epoch - 12ms/step
# Epoch 43/100
#
# Epoch 43: loss improved from 0.01591 to 0.01514, saving model to ./Model/case_1/BiLSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0151 - val_loss: 0.0900 - 252ms/epoch - 13ms/step
# Epoch 44/100
#
# Epoch 44: loss did not improve from 0.01514
# 19/19 - 0s - loss: 0.0152 - val_loss: 0.1239 - 235ms/epoch - 12ms/step
# Epoch 45/100
#
# Epoch 45: loss did not improve from 0.01514
# 19/19 - 0s - loss: 0.0164 - val_loss: 0.0291 - 225ms/epoch - 12ms/step
# Epoch 46/100
#
# Epoch 46: loss improved from 0.01514 to 0.01411, saving model to ./Model/case_1/BiLSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0141 - val_loss: 0.0827 - 250ms/epoch - 13ms/step
# Epoch 47/100
#
# Epoch 47: loss did not improve from 0.01411
# 19/19 - 0s - loss: 0.0155 - val_loss: 0.0493 - 232ms/epoch - 12ms/step
# Epoch 48/100
#
# Epoch 48: loss did not improve from 0.01411
# 19/19 - 0s - loss: 0.0149 - val_loss: 0.0522 - 225ms/epoch - 12ms/step
# Epoch 49/100
#
# Epoch 49: loss did not improve from 0.01411
# 19/19 - 0s - loss: 0.0155 - val_loss: 0.0668 - 224ms/epoch - 12ms/step
# Epoch 50/100
#
# Epoch 50: loss improved from 0.01411 to 0.01391, saving model to ./Model/case_1/BiLSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0139 - val_loss: 0.0618 - 248ms/epoch - 13ms/step
# Epoch 51/100
#
# Epoch 51: loss did not improve from 0.01391
# 19/19 - 0s - loss: 0.0168 - val_loss: 0.0198 - 236ms/epoch - 12ms/step
# Epoch 52/100
#
# Epoch 52: loss improved from 0.01391 to 0.01369, saving model to ./Model/case_1/BiLSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0137 - val_loss: 0.0199 - 254ms/epoch - 13ms/step
# Epoch 53/100
#
# Epoch 53: loss did not improve from 0.01369
# 19/19 - 0s - loss: 0.0146 - val_loss: 0.0242 - 237ms/epoch - 12ms/step
# Epoch 54/100
#
# Epoch 54: loss improved from 0.01369 to 0.01204, saving model to ./Model/case_1/BiLSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0120 - val_loss: 0.0265 - 268ms/epoch - 14ms/step
# Epoch 55/100
#
# Epoch 55: loss did not improve from 0.01204
# 19/19 - 0s - loss: 0.0140 - val_loss: 0.0693 - 238ms/epoch - 13ms/step
# Epoch 56/100
#
# Epoch 56: loss did not improve from 0.01204
# 19/19 - 0s - loss: 0.0130 - val_loss: 0.0100 - 240ms/epoch - 13ms/step
# Epoch 57/100
#
# Epoch 57: loss did not improve from 0.01204
# 19/19 - 0s - loss: 0.0143 - val_loss: 0.0111 - 232ms/epoch - 12ms/step
# Epoch 58/100
#
# Epoch 58: loss improved from 0.01204 to 0.01138, saving model to ./Model/case_1/BiLSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0114 - val_loss: 0.0355 - 254ms/epoch - 13ms/step
# Epoch 59/100
#
# Epoch 59: loss did not improve from 0.01138
# 19/19 - 0s - loss: 0.0129 - val_loss: 0.0496 - 234ms/epoch - 12ms/step
# Epoch 60/100
#
# Epoch 60: loss did not improve from 0.01138
# 19/19 - 0s - loss: 0.0125 - val_loss: 0.0597 - 235ms/epoch - 12ms/step
# Epoch 61/100
#
# Epoch 61: loss did not improve from 0.01138
# 19/19 - 0s - loss: 0.0135 - val_loss: 0.0228 - 234ms/epoch - 12ms/step
# Epoch 62/100
#
# Epoch 62: loss did not improve from 0.01138
# 19/19 - 0s - loss: 0.0129 - val_loss: 0.0651 - 228ms/epoch - 12ms/step
# Epoch 63/100
#
# Epoch 63: loss did not improve from 0.01138
# 19/19 - 0s - loss: 0.0145 - val_loss: 0.0166 - 244ms/epoch - 13ms/step
# Epoch 64/100
#
# Epoch 64: loss did not improve from 0.01138
# 19/19 - 0s - loss: 0.0136 - val_loss: 0.0393 - 231ms/epoch - 12ms/step
# Epoch 65/100
#
# Epoch 65: loss did not improve from 0.01138
# 19/19 - 0s - loss: 0.0129 - val_loss: 0.0122 - 232ms/epoch - 12ms/step
# Epoch 66/100
#
# Epoch 66: loss did not improve from 0.01138
# 19/19 - 0s - loss: 0.0123 - val_loss: 0.0399 - 230ms/epoch - 12ms/step
# Epoch 67/100
#
# Epoch 67: loss did not improve from 0.01138
# 19/19 - 0s - loss: 0.0115 - val_loss: 0.0570 - 226ms/epoch - 12ms/step
# Epoch 68/100
#
# Epoch 68: loss did not improve from 0.01138
# 19/19 - 0s - loss: 0.0119 - val_loss: 0.0282 - 226ms/epoch - 12ms/step
# Epoch 69/100
#
# Epoch 69: loss improved from 0.01138 to 0.01130, saving model to ./Model/case_1/BiLSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0113 - val_loss: 0.0765 - 254ms/epoch - 13ms/step
# Epoch 70/100
#
# Epoch 70: loss did not improve from 0.01130
# 19/19 - 0s - loss: 0.0134 - val_loss: 0.0235 - 242ms/epoch - 13ms/step
# Epoch 71/100
#
# Epoch 71: loss improved from 0.01130 to 0.01122, saving model to ./Model/case_1/BiLSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0112 - val_loss: 0.0227 - 260ms/epoch - 14ms/step
# Epoch 72/100
#
# Epoch 72: loss improved from 0.01122 to 0.01068, saving model to ./Model/case_1/BiLSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0107 - val_loss: 0.0131 - 267ms/epoch - 14ms/step
# Epoch 73/100
#
# Epoch 73: loss did not improve from 0.01068
# 19/19 - 0s - loss: 0.0129 - val_loss: 0.0536 - 241ms/epoch - 13ms/step
# Epoch 74/100
#
# Epoch 74: loss did not improve from 0.01068
# 19/19 - 0s - loss: 0.0125 - val_loss: 0.0097 - 235ms/epoch - 12ms/step
# Epoch 75/100
#
# Epoch 75: loss did not improve from 0.01068
# 19/19 - 0s - loss: 0.0121 - val_loss: 0.0177 - 238ms/epoch - 13ms/step
# Epoch 76/100
#
# Epoch 76: loss did not improve from 0.01068
# 19/19 - 0s - loss: 0.0110 - val_loss: 0.0365 - 240ms/epoch - 13ms/step
# Epoch 77/100
#
# Epoch 77: loss did not improve from 0.01068
# 19/19 - 0s - loss: 0.0149 - val_loss: 0.0168 - 232ms/epoch - 12ms/step
# Epoch 78/100
#
# Epoch 78: loss did not improve from 0.01068
# 19/19 - 0s - loss: 0.0133 - val_loss: 0.0340 - 228ms/epoch - 12ms/step
# Epoch 79/100
#
# Epoch 79: loss did not improve from 0.01068
# 19/19 - 0s - loss: 0.0130 - val_loss: 0.0127 - 244ms/epoch - 13ms/step
# Epoch 80/100
#
# Epoch 80: loss did not improve from 0.01068
# 19/19 - 0s - loss: 0.0125 - val_loss: 0.0352 - 226ms/epoch - 12ms/step
# Epoch 81/100
#
# Epoch 81: loss did not improve from 0.01068
# 19/19 - 0s - loss: 0.0135 - val_loss: 0.0145 - 231ms/epoch - 12ms/step
# Epoch 82/100
#
# Epoch 82: loss did not improve from 0.01068
# 19/19 - 0s - loss: 0.0126 - val_loss: 0.0462 - 226ms/epoch - 12ms/step
# Epoch 83/100
#
# Epoch 83: loss did not improve from 0.01068
# 19/19 - 0s - loss: 0.0110 - val_loss: 0.0258 - 233ms/epoch - 12ms/step
# Epoch 84/100
#
# Epoch 84: loss did not improve from 0.01068
# 19/19 - 0s - loss: 0.0144 - val_loss: 0.0329 - 230ms/epoch - 12ms/step
# Epoch 85/100
#
# Epoch 85: loss did not improve from 0.01068
# 19/19 - 0s - loss: 0.0133 - val_loss: 0.0164 - 231ms/epoch - 12ms/step
# Epoch 86/100
#
# Epoch 86: loss did not improve from 0.01068
# 19/19 - 0s - loss: 0.0122 - val_loss: 0.0152 - 246ms/epoch - 13ms/step
# Epoch 87/100
#
# Epoch 87: loss did not improve from 0.01068
# 19/19 - 0s - loss: 0.0124 - val_loss: 0.0093 - 230ms/epoch - 12ms/step
# Epoch 88/100
#
# Epoch 88: loss did not improve from 0.01068
# 19/19 - 0s - loss: 0.0149 - val_loss: 0.0308 - 226ms/epoch - 12ms/step
# Epoch 89/100
#
# Epoch 89: loss did not improve from 0.01068
# 19/19 - 0s - loss: 0.0121 - val_loss: 0.0254 - 238ms/epoch - 13ms/step
# Epoch 90/100
#
# Epoch 90: loss did not improve from 0.01068
# 19/19 - 0s - loss: 0.0135 - val_loss: 0.0162 - 237ms/epoch - 12ms/step
# Epoch 91/100
#
# Epoch 91: loss improved from 0.01068 to 0.00979, saving model to ./Model/case_1/BiLSTM/model_SGD\save_model.hdf5
# 19/19 - 0s - loss: 0.0098 - val_loss: 0.0459 - 273ms/epoch - 14ms/step
# Epoch 92/100
#
# Epoch 92: loss did not improve from 0.00979
# 19/19 - 0s - loss: 0.0120 - val_loss: 0.0281 - 252ms/epoch - 13ms/step
# Epoch 93/100
#
# Epoch 93: loss did not improve from 0.00979
# 19/19 - 0s - loss: 0.0126 - val_loss: 0.0517 - 254ms/epoch - 13ms/step
# Epoch 94/100
#
# Epoch 94: loss did not improve from 0.00979
# 19/19 - 0s - loss: 0.0137 - val_loss: 0.0273 - 251ms/epoch - 13ms/step
# Epoch 95/100
#
# Epoch 95: loss did not improve from 0.00979
# 19/19 - 0s - loss: 0.0122 - val_loss: 0.0269 - 251ms/epoch - 13ms/step
# Epoch 96/100
#
# Epoch 96: loss did not improve from 0.00979
# 19/19 - 0s - loss: 0.0114 - val_loss: 0.0108 - 250ms/epoch - 13ms/step
# Epoch 97/100
#
# Epoch 97: loss did not improve from 0.00979
# 19/19 - 0s - loss: 0.0145 - val_loss: 0.0109 - 252ms/epoch - 13ms/step
# Epoch 98/100
#
# Epoch 98: loss did not improve from 0.00979
# 19/19 - 0s - loss: 0.0126 - val_loss: 0.0260 - 255ms/epoch - 13ms/step
# Epoch 99/100
#
# Epoch 99: loss did not improve from 0.00979
# 19/19 - 0s - loss: 0.0107 - val_loss: 0.0189 - 248ms/epoch - 13ms/step
# Epoch 100/100
#
# Epoch 100: loss did not improve from 0.00979
# 19/19 - 0s - loss: 0.0106 - val_loss: 0.0105 - 269ms/epoch - 14ms/step
# Thời gian thực thi mô hình: 30.95 giây

# %%
#Model
final_model = load_model("./Model/case_1/BiLSTM/model_SGD/save_model.hdf5")

# %%
#dữ liệu train
Y_train_predict = final_model.predict(X_train) #dự đoán trên tập đã train
Y_train_predict = sc.inverse_transform(Y_train_predict) #giá thực dự đoán
Y_train = sc.inverse_transform(Y_train) #giá thực train
# Out:
# 48/48 [==============================] - 1s 3ms/step

# %% [markdown]
# # DỰ ĐOÁN TRÊN TẬP TEST

# %%
#dữ liệu test
import time
start_model = time.time()  # Bắt đầu đo thời gian
Y_test_predict = final_model.predict(X_test)
end_model = time.time()  # Kết thúc đo thời gian
print(f"Thời gian thực thi mô hình: {end_model - start_model:.2f} giây")
Y_test_predict = sc.inverse_transform(Y_test_predict) #giá dự đoán
Y_test = sc.inverse_transform(Y_test) #giá thực
# Out:
# 12/12 [==============================] - 0s 3ms/step
# Thời gian thực thi mô hình: 0.08 giây

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import mean_absolute_error, mean_squared_error

# Tính toán các giá trị cho tập Train
mae_train = round(mean_absolute_error(Y_train, Y_train_predict), 3)
mse_train = round(mean_squared_error(Y_train, Y_train_predict), 3)
rmse_train = round(np.sqrt(mse_train), 3)

# Tính toán các giá trị cho tập Test
mae_test = round(mean_absolute_error(Y_test, Y_test_predict), 3)
mse_test = round(mean_squared_error(Y_test, Y_test_predict), 3)
rmse_test = round(np.sqrt(mse_test), 3)

# Tạo DataFrame để hiển thị kết quả
metrics = pd.DataFrame({
    "Tập dữ liệu": ["Train", "Test"],
    "MAE": [mae_train, mae_test],
    "MSE": [mse_train, mse_test],
    "RMSE": [rmse_train, rmse_test]
})

# In kết quả
print(metrics)
print(f"Thời gian thực thi mô hình: {end_model - start_model:.2f} giây")
# Out:
#   Tập dữ liệu      MAE        MSE     RMSE
# 0       Train   90.991  13716.653  117.118
# 1        Test  240.778  60296.705  245.554
# Thời gian thực thi mô hình: 0.08 giây

# %%
# Xác định 80% dữ liệu làm tập train
train_size = int(len(df_usd_ML) * 0.8)

# Cắt lại cho đúng chiều dài:
train_data1 = df_usd_ML[6:train_size+1].copy()
test_data1 = df_usd_ML[train_size+2:].copy()


print(len(train_data1), len(Y_train_predict))
print(len(test_data1), len(Y_test_predict))


plt.figure(figsize=(24,8))
plt.plot(df_usd_ML,label='Giá thực tế',color='red') #đường giá thực
train_data1['Dự đoán'] = Y_train_predict #thêm dữ liệu
plt.plot(train_data1['Dự đoán'],label='Giá dự đoán train',color='green') #đường giá dự báo train
test_data1['Dự đoán'] = Y_test_predict #thêm dữ liệu
plt.plot(test_data1['Dự đoán'],label='Giá dự đoán test',color='blue') #đường giá dự báo test
plt.title('So sánh giá dự báo và giá thực tế') #đặt tên biểu đồ
plt.xlabel('Thời gian') #đặt tên hàm x
plt.ylabel('Giá mua chuyển khoản (VNĐ)') #đặt tên hàm y
plt.legend() #chú thích
plt.show()
# Out:
# 1523 1523
# 381 381

# %%
from tensorflow.keras.models import load_model

# Gọi lại mô hình đã lưu
loaded_model = load_model("./Model/case_1/BiLSTM/model_SGD/save_model.hdf5")
# Dự đoán lại trên tập test
Y_test_predict = loaded_model.predict(X_test)
# Đảo chuẩn hóa (inverse transform)
Y_test_predict = sc.inverse_transform(Y_test_predict)

# Tạo bảng so sánh
compare_df = pd.DataFrame({
    "Giá thực tế": Y_test.flatten(),
    "Giá dự đoán": Y_test_predict.flatten()
})

# Làm tròn về số nguyên
compare_df = compare_df.astype(int)
pd.set_option('display.max_rows', None)
# Hiển thị toàn bộ bảng
display(compare_df)
compare_df.to_csv("./Model/case_1/BiLSTM/model_SGD/predict.csv", index=False)
# Out:
# 12/12 [==============================] - 1s 3ms/step
#      Giá thực tế  Giá dự đoán
# 0          24790        25031
# 1          24830        25032
# 2          24840        25054
# 3          24840        25071
# 4          24840        25080
# 5          24960        25084
# 6          25008        25149
# 7          25130        25206
# 8          25130        25301
# 9          25163        25350
# 10         25163        25392
# 11         25163        25409
# 12         25175        25414
# 13         25178        25419
# 14         25177        25424
# 15         25167        25425
# 16         25118        25421
# 17         25118        25393
# 18         25118        25378
# 19         25118        25370
# 20         25118        25366
# 21         25118        25365
# 22         25144        25366
# 23         25143        25380
# 24         25147        25387
# 25         25147        25392
# 26         25157        25395
# 27         25155        25402
# 28         25161        25403
# 29         25178        25407
# 30         25184        25418
# 31         25184        25426
# 32         25184        25430
# 33         25179        25433
# 34         25182        25431
# 35         25182        25431
# 36         25152        25430
# 37         25250        25415
# 38         25250        25458
# 39         25250        25479
# 40         25259        25492
# 41         25263        25503
# 42         25266        25510
# 43         25250        25512
# 44         25277        25505
# 45         25277        25515
# 46         25277        25520
# 47         25281        25523
# 48         25268        25527
# 49         25265        25522
# 50         25250        25517
# 51         25254        25507
# 52         25254        25503
# 53         25254        25502
# 54         25234        25501
# 55         25218        25491
# 56         25213        25478
# 57         25213        25469
# 58         25213        25463
# 59         25213        25461
# 60         25213        25461
# 61         25214        25461
# 62         25222        25462
# 63         25226        25466
# 64         25217        25471
# 65         25221        25468
# 66         25221        25469
# 67         25221        25469
# 68         25231        25469
# 69         25251        25474
# 70         25249        25487
# 71         25247        25493
# 72         25248        25495
# 73         25248        25497
# 74         25248        25497
# 75         25255        25496
# 76         25245        25500
# 77         25250        25496
# 78         25257        25497
# 79         25253        25501
# 80         25253        25501
# 81         25253        25501
# 82         25244        25501
# 83         25245        25497
# 84         25250        25494
# 85         25243        25496
